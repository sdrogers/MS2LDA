# %% [markdown]
# Beer3 Positive Results
# ============

# %% [markdown]
# 1. LDA
# -------

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from lda_for_fragments import Ms2Lda
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
import sys

from sklearn import preprocessing
from sklearn.decomposition import PCA
import networkx as nx
from networkx.readwrite import json_graph

# %%
n_topics = 50
n_samples = 100

fragment_filename = 'input/Beer_3_T10_POS_fragments.csv'
neutral_loss_filename = 'input/Beer_3_T10_POS_losses.csv'
mzdiff_filename = None

ms1_filename = 'input/Beer_3_T10_POS_ms1.csv'
ms2_filename = 'input/Beer_3_T10_POS_ms2.csv'

# %%
ms2lda = Ms2Lda(fragment_filename, neutral_loss_filename, mzdiff_filename, 
                ms1_filename, ms2_filename, n_topics, n_samples)
ms2lda.run_lda()
# Out:
# Data shape (856, 1725)
# Fitting model...
# DONE!

# %%
ms2lda.write_results('beer3_pos')
# Out:
# Writing topics to results/beer3_pos/beer3_pos_topics.csv
# Writing fragments x topics to results/beer3_pos/beer3_pos_all.csv
# Writing topic docs to results/beer3_pos/beer3_pos_docs.csv

# %%
topic_fragments = ms2lda.model.topic_word_
n_top_frags = 20
for i,topic_dist in enumerate(topic_fragments):
    topic_f = np.array(ms2lda.data.columns.values)[np.argsort(topic_dist)][:-n_top_frags:-1]
    out_string = 'Topic {}: {}'.format(i, ', '.join(topic_f.astype('str')))
    print(out_string)
# Out:
# Topic 0: fragment_91.05413, fragment_67.05455, fragment_81.07, fragment_79.05417, fragment_105.07017, fragment_93.06982, fragment_55.05468, fragment_69.07013, fragment_59.04942, fragment_107.08554, fragment_95.08537, fragment_53.0026, loss_148.07347, fragment_53.03889, fragment_57.07007, loss_56.06222, loss_102.06815, fragment_119.0857, fragment_117.09077
# Topic 1: fragment_84.08071, fragment_56.04978, fragment_67.05455, fragment_130.08581, loss_18.01058, fragment_130.0871, loss_207.07436, fragment_183.11187, loss_179.07935, loss_190.04798, fragment_213.12438, fragment_92.05787, fragment_274.12622, loss_103.0638, fragment_82.065, fragment_98.05999, fragment_244.11768, loss_137.0686, loss_18.00904
# Topic 2: fragment_118.06547, fragment_188.07057, fragment_148.07578, fragment_108.04426, fragment_53.03889, fragment_91.05413, fragment_81.03337, fragment_94.06505, fragment_146.05941, loss_201.06337, loss_173.06877, loss_160.0369, fragment_133.05284, loss_66.03222, fragment_206.0825, fragment_106.06503, loss_146.05776, loss_136.037, fragment_80.04949
# Topic 3: loss_196.05806, loss_184.05828, fragment_98.05999, fragment_87.03159, loss_208.05803, fragment_56.04978, loss_150.05297, loss_84.04249, fragment_144.06586, fragment_195.11211, fragment_68.0498, loss_210.07384, fragment_112.03985, fragment_70.02898, loss_249.08478, fragment_84.04422, fragment_80.04949, fragment_167.1183, loss_154.04764
# Topic 4: loss_74.03668, loss_102.03162, fragment_107.04885, fragment_136.07598, loss_94.02658, loss_78.03146, fragment_61.02851, fragment_56.04978, fragment_57.03369, fragment_84.04422, fragment_116.99462, loss_102.06815, fragment_98.98387, loss_18.01103, fragment_127.01556, loss_66.03112, loss_54.03128, fragment_202.10835, fragment_135.04439
# Topic 5: fragment_132.10161, loss_162.05266, loss_120.04178, fragment_91.03921, loss_257.11102, fragment_84.04422, fragment_162.0756, loss_18.01103, loss_233.11089, loss_273.1058, fragment_276.14368, loss_324.10561, fragment_118.0861, fragment_71.0858, fragment_97.02839, loss_180.06335, loss_208.05803, fragment_143.03192, fragment_230.14
# Topic 6: fragment_110.05976, fragment_112.08703, loss_66.03222, fragment_276.12192, fragment_70.06514, loss_272.08959, fragment_180.10128, fragment_108.08067, loss_227.10065, loss_18.00834, loss_60.03238, fragment_82.065, loss_18.01058, fragment_96.08073, loss_134.0566, fragment_134.09682, fragment_134.05999, fragment_95.02388, loss_239.10044
# Topic 7: loss_64.01556, loss_90.03154, loss_78.03146, loss_106.02645, loss_92.04714, loss_135.05318, loss_18.01103, loss_92.01082, loss_82.02658, loss_107.05823, loss_36.02083, loss_104.04745, fragment_94.06505, loss_123.05299, loss_163.08425, loss_93.04256, loss_46.00455, fragment_71.0494, loss_175.08434
# Topic 8: loss_17.02676, fragment_125.07087, fragment_98.05999, loss_125.04751, loss_142.07382, fragment_91.05413, fragment_146.11787, fragment_153.06584, fragment_154.07315, fragment_120.08041, loss_173.10494, loss_154.07421, fragment_80.04949, fragment_142.03245, fragment_93.06982, fragment_155.08107, fragment_103.05449, loss_87.03188, loss_101.08372
# Topic 9: fragment_115.05434, loss_76.01613, fragment_144.08074, loss_89.04756, fragment_130.06466, fragment_91.05413, fragment_117.07034, loss_47.0369, loss_74.0004, loss_103.02703, loss_18.01058, fragment_53.03889, loss_48.02067, fragment_117.05718, fragment_62.92941, fragment_143.0739, loss_117.0425, fragment_142.06474, fragment_103.05449
# Topic 10: loss_97.05266, loss_125.04751, loss_141.07865, fragment_98.05999, loss_28.03102, fragment_121.07623, fragment_211.0709, fragment_95.04936, loss_73.01579, fragment_87.0554, fragment_154.07315, fragment_91.05413, fragment_154.04951, loss_113.08407, loss_27.99479, fragment_122.06034, fragment_72.04465, loss_142.07382, fragment_150.05564
# Topic 11: fragment_56.04978, fragment_84.04422, fragment_130.05052, loss_129.04222, fragment_102.05469, loss_35.03718, fragment_129.06583, fragment_147.07582, loss_174.0641, fragment_53.0026, loss_146.06892, loss_111.0318, loss_91.02682, fragment_325.11203, fragment_167.08158, loss_175.04792, loss_128.05788, fragment_195.07569, fragment_101.07117
# Topic 12: fragment_70.06514, fragment_84.04422, fragment_98.05999, fragment_116.07114, loss_161.06862, fragment_144.06586, loss_115.0632, fragment_248.11294, fragment_164.07061, fragment_96.04414, fragment_72.04411, fragment_116.07015, fragment_126.05565, fragment_128.07032, loss_160.0847, fragment_182.08216, loss_341.13229, fragment_93.05445, loss_168.06301
# Topic 13: fragment_53.0026, fragment_69.07013, fragment_91.05413, fragment_57.07007, fragment_111.11652, fragment_55.05468, fragment_275.12787, fragment_105.07017, loss_154.13594, fragment_67.05455, fragment_175.07621, fragment_193.08583, fragment_221.08119, loss_249.12114, fragment_107.08554, fragment_119.0857, loss_53.04808, fragment_293.13725, fragment_205.08718
# Topic 14: fragment_132.08134, fragment_120.08041, fragment_292.11665, fragment_166.08632, fragment_103.05449, fragment_105.07017, fragment_53.03889, fragment_130.06466, fragment_310.12707, fragment_81.03337, loss_360.12677, fragment_264.12442, fragment_244.09625, fragment_119.07336, loss_387.13762, fragment_178.08711, fragment_219.10217, fragment_129.07001, loss_324.10561
# Topic 15: fragment_53.0026, fragment_84.04422, fragment_91.05413, fragment_109.03969, loss_120.04253, fragment_56.04978, loss_159.05307, fragment_109.0288, loss_165.06335, fragment_126.0665, fragment_71.01309, fragment_147.04377, fragment_65.03877, fragment_55.01824, fragment_130.05052, fragment_238.07123, loss_133.07373, loss_116.04727, fragment_256.08031
# Topic 16: fragment_55.05468, fragment_69.03368, loss_59.03701, fragment_114.09125, fragment_101.05975, fragment_60.04476, loss_84.04249, loss_185.09038, loss_101.04749, loss_118.07392, fragment_76.03917, fragment_147.06556, loss_113.08407, loss_195.07466, loss_126.05238, loss_324.10561, fragment_202.07071, loss_101.08372, fragment_108.04426
# Topic 17: fragment_91.05413, fragment_103.05449, fragment_53.03889, fragment_79.05417, fragment_121.06489, fragment_120.08041, fragment_105.07017, fragment_93.06982, loss_91.02682, fragment_95.04936, fragment_166.08632, fragment_83.01292, fragment_67.01808, loss_193.07363, fragment_123.04462, fragment_199.02413, fragment_209.08106, fragment_119.04986, fragment_147.06769
# Topic 18: loss_64.01685, fragment_88.03909, loss_46.00455, fragment_58.99527, fragment_110.05976, fragment_134.09682, fragment_150.05923, fragment_56.04978, loss_74.0004, fragment_104.05297, fragment_55.01824, fragment_133.03244, fragment_87.02619, fragment_125.04693, fragment_80.04949, fragment_193.13421, fragment_72.04465, fragment_109.07644, fragment_53.03889
# Topic 19: loss_159.08928, fragment_55.01824, fragment_96.08073, loss_133.07373, loss_18.0095, loss_105.07856, fragment_115.05434, loss_161.10472, loss_36.02194, loss_115.0998, fragment_89.00601, loss_171.08919, fragment_114.09125, fragment_114.05541, fragment_68.0498, fragment_224.12739, fragment_201.12805, fragment_239.09204, fragment_242.13989
# Topic 20: loss_59.04851, fragment_72.08072, loss_17.02648, fragment_60.0559, fragment_114.10281, loss_71.07342, loss_223.06938, fragment_97.07643, fragment_72.04465, fragment_55.02948, fragment_112.08703, fragment_257.16048, fragment_55.05468, loss_80.01024, loss_128.03138, fragment_168.11266, loss_237.08515, fragment_111.0555, loss_211.06909
# Topic 21: fragment_98.05999, fragment_114.10281, fragment_131.12918, fragment_136.06241, fragment_157.10848, fragment_55.05468, fragment_72.08072, fragment_235.07575, fragment_97.02839, fragment_97.07643, fragment_207.07983, fragment_178.07836, fragment_278.05554, fragment_115.08711, fragment_165.07001, fragment_60.0559, fragment_263.06919, fragment_189.0702, fragment_205.06525
# Topic 22: fragment_69.03368, fragment_83.04895, loss_108.0422, fragment_74.06037, fragment_99.04455, loss_36.02083, loss_110.02127, fragment_117.05484, fragment_121.02826, loss_78.03146, loss_116.04727, fragment_53.03889, fragment_57.03369, fragment_129.05473, loss_96.0424, fragment_65.03877, loss_18.01058, fragment_71.0494, fragment_148.03977
# Topic 23: fragment_60.08102, loss_59.07329, fragment_104.10731, fragment_56.04978, fragment_98.98387, loss_132.04205, fragment_71.0731, loss_46.00455, loss_149.06875, fragment_125.00056, loss_118.02644, loss_200.07938, loss_85.08914, fragment_258.10964, loss_106.02645, fragment_112.11181, fragment_116.03449, fragment_184.07456, fragment_221.01905
# Topic 24: fragment_85.02833, fragment_69.03368, fragment_145.04997, fragment_97.02839, fragment_127.0387, fragment_109.0288, fragment_81.03337, fragment_73.02851, fragment_61.02851, fragment_53.03889, fragment_57.03369, fragment_163.06062, fragment_55.01824, loss_197.08977, fragment_99.04455, fragment_99.04366, fragment_71.0494, loss_125.0685, loss_215.10018
# Topic 25: fragment_94.03985, fragment_55.02948, loss_43.00568, fragment_119.03519, fragment_82.04028, fragment_153.04074, fragment_110.03459, fragment_135.02961, fragment_128.04552, fragment_71.06064, loss_27.01114, fragment_109.05048, fragment_152.05613, loss_18.01058, fragment_92.02426, fragment_81.03337, loss_99.05338, fragment_110.03498, loss_132.0896
# Topic 26: fragment_72.08072, fragment_59.04942, fragment_88.07588, loss_89.08399, fragment_58.06553, loss_154.02954, loss_140.01437, fragment_123.01112, fragment_53.0026, fragment_90.09112, loss_122.00401, loss_124.01923, loss_153.04567, fragment_168.0692, loss_159.09243, fragment_70.06514, loss_341.13229, loss_44.02606, loss_142.03003
# Topic 27: fragment_96.04414, fragment_81.03337, fragment_53.03889, fragment_80.04949, fragment_94.06505, fragment_122.06034, fragment_55.01824, loss_27.99523, loss_43.98978, fragment_110.05976, loss_55.98959, fragment_68.0498, fragment_164.10657, fragment_123.05504, loss_59.01317, fragment_78.03416, fragment_106.02879, loss_141.04225, fragment_93.05723
# Topic 28: fragment_121.06489, fragment_103.05449, fragment_53.03889, fragment_91.05413, fragment_93.06982, fragment_51.0234, fragment_95.04936, loss_87.0684, fragment_81.03337, loss_59.07329, loss_31.04205, loss_127.09933, loss_61.05279, fragment_105.03345, loss_75.0684, loss_85.08914, fragment_77.03872, loss_99.06814, loss_89.08399
# Topic 29: loss_144.04206, fragment_97.02839, loss_132.04205, fragment_69.03368, loss_150.05297, loss_190.04798, fragment_84.04422, loss_160.0369, loss_18.01191, loss_147.05328, loss_18.01013, loss_178.04751, loss_36.02083, fragment_130.04926, loss_148.03699, loss_207.07436, loss_149.06875, fragment_55.01824, fragment_127.0387
# Topic 30: fragment_55.05468, loss_161.06862, loss_145.07348, fragment_126.09181, loss_146.05776, loss_133.07373, loss_160.07338, loss_162.08892, loss_62.03715, fragment_154.08576, fragment_82.065, loss_134.0581, fragment_198.1136, fragment_98.05999, loss_132.04205, loss_18.0095, loss_90.03154, loss_118.06294, loss_66.03112
# Topic 31: fragment_128.07032, loss_387.13762, fragment_225.12393, fragment_98.09682, loss_225.08489, loss_181.09473, loss_253.11586, fragment_140.04986, fragment_167.06103, fragment_205.07619, fragment_81.03337, fragment_495.26484, fragment_327.07802, fragment_273.14302, fragment_206.0825, fragment_147.11301, fragment_82.065, fragment_207.09112, loss_179.07935
# Topic 32: fragment_72.08072, fragment_70.06514, fragment_71.0494, fragment_60.0558, fragment_175.12006, loss_59.04757, fragment_116.07114, fragment_112.08703, fragment_158.09178, fragment_130.09705, loss_105.05437, fragment_60.0559, fragment_110.07086, fragment_98.9847, fragment_185.09247, fragment_143.11762, fragment_157.09711, loss_115.0632, loss_251.11485
# Topic 33: loss_45.0213, fragment_108.04426, loss_18.01058, fragment_80.04949, fragment_53.03889, fragment_109.05257, fragment_65.03877, fragment_134.05999, loss_71.03707, fragment_106.06503, fragment_152.07031, loss_99.03179, loss_43.00568, fragment_124.07536, fragment_81.05755, loss_130.06264, loss_97.05266, fragment_55.01824, loss_101.01115
# Topic 34: loss_27.99479, fragment_53.03889, loss_30.01047, loss_68.02589, fragment_91.05413, fragment_65.03877, loss_70.04156, loss_26.01544, loss_44.02606, loss_56.02613, loss_40.03143, fragment_95.04936, fragment_81.03337, fragment_77.03872, fragment_93.06982, fragment_55.01824, loss_42.04695, fragment_146.0609, fragment_61.03978
# Topic 35: loss_36.02194, loss_178.04751, fragment_56.04978, loss_17.0258, fragment_102.05469, fragment_216.08561, fragment_143.05747, fragment_112.03985, fragment_90.05539, fragment_170.08149, loss_162.05266, fragment_58.02903, fragment_97.02839, fragment_64.9275, fragment_234.09787, loss_157.07381, loss_150.05297, fragment_74.05986, fragment_188.09246
# Topic 36: fragment_65.03877, fragment_57.07007, fragment_111.04429, fragment_89.06008, fragment_133.08628, fragment_95.04936, fragment_149.02364, fragment_144.10184, fragment_137.05983, fragment_177.11272, fragment_121.06489, fragment_85.06477, fragment_155.07009, fragment_113.0602, fragment_239.14817, fragment_102.0918, fragment_89.0594, fragment_195.12241, fragment_283.17358
# Topic 37: loss_17.02617, fragment_71.06871, loss_225.08489, loss_179.07935, fragment_128.07032, fragment_260.11164, loss_277.11587, loss_61.02871, fragment_100.11239, loss_48.02067, loss_162.05266, fragment_122.07171, fragment_141.05511, fragment_173.13899, fragment_242.10069, fragment_214.10804, fragment_100.07624, fragment_198.1136, fragment_99.05557
# Topic 38: fragment_83.06042, fragment_95.06076, fragment_110.07176, fragment_81.04506, fragment_93.04514, fragment_68.0498, fragment_82.05229, fragment_56.04978, fragment_54.03416, loss_188.07961, fragment_156.07692, fragment_82.05293, loss_100.027, fragment_136.06241, loss_163.08425, loss_146.05776, fragment_107.06036, fragment_119.03519, fragment_59.04942
# Topic 39: fragment_58.06553, loss_18.01013, fragment_82.065, loss_46.04164, fragment_59.07336, loss_106.06294, loss_102.06815, fragment_60.08102, loss_18.01058, fragment_112.07583, fragment_62.06029, loss_44.02606, fragment_136.03974, fragment_142.12254, loss_85.05252, fragment_162.09143, loss_114.06812, fragment_164.03461, loss_111.0684
# Topic 40: loss_60.021, loss_42.01046, loss_88.01596, fragment_60.04476, loss_105.04249, fragment_84.04487, fragment_61.01085, fragment_114.05541, loss_77.04746, fragment_120.04802, fragment_72.04465, fragment_78.03737, loss_115.02685, fragment_55.01824, fragment_103.02173, loss_18.01103, loss_106.02645, loss_87.03188, loss_119.05808
# Topic 41: fragment_70.06514, fragment_100.07534, loss_60.021, fragment_71.0494, loss_171.08919, fragment_146.08112, loss_183.0892, fragment_112.05007, loss_120.07822, loss_132.07854, fragment_156.13794, fragment_107.0708, fragment_196.09544, loss_116.04727, fragment_164.09263, loss_504.16871, fragment_185.12828, fragment_98.09593, fragment_87.06774
# Topic 42: loss_63.03183, fragment_55.01824, loss_117.0425, fragment_101.02309, fragment_83.01292, fragment_165.05564, fragment_179.06947, fragment_167.03433, loss_59.01317, loss_92.01082, fragment_225.07566, fragment_95.05992, fragment_115.08711, fragment_163.07451, loss_36.02194, fragment_101.07117, fragment_73.0843, fragment_261.11335, fragment_205.04866
# Topic 43: fragment_86.09652, fragment_69.07013, fragment_72.08072, fragment_55.05468, loss_77.04746, loss_60.021, fragment_128.10739, loss_113.08407, fragment_57.05774, loss_89.05962, fragment_62.92941, fragment_160.1326, fragment_189.12435, fragment_73.0647, fragment_62.06029, loss_88.05246, fragment_90.09184, fragment_283.16892, loss_100.03743
# Topic 44: fragment_119.04876, fragment_147.04377, fragment_91.05413, loss_126.10441, loss_134.0566, loss_172.10979, fragment_57.07007, loss_219.08244, loss_160.03397, fragment_123.04462, loss_236.10888, loss_113.08407, loss_126.09326, loss_56.08736, fragment_261.63818, fragment_127.11204, loss_231.10841, loss_189.13603, fragment_182.08216
# Topic 45: fragment_86.06014, fragment_87.04389, fragment_68.0498, fragment_69.03368, fragment_98.05999, fragment_194.08209, fragment_140.07024, fragment_104.071, fragment_110.05976, loss_86.0366, loss_179.07935, fragment_163.07451, loss_129.07874, fragment_112.07583, fragment_181.08644, loss_18.01058, fragment_182.08216, fragment_184.04364, fragment_212.09231
# Topic 46: fragment_89.03862, fragment_177.05473, fragment_145.02839, fragment_117.03314, fragment_149.05997, fragment_78.04654, fragment_134.03644, fragment_63.02323, fragment_72.08072, fragment_106.04123, fragment_91.05413, fragment_248.12779, fragment_60.0558, fragment_53.03889, loss_193.07363, fragment_135.04439, fragment_72.04465, fragment_105.03345, fragment_186.05403
# Topic 47: loss_46.00544, fragment_56.04978, fragment_84.04422, loss_75.03188, loss_74.0004, loss_73.01648, fragment_68.04931, loss_87.03188, fragment_172.09755, fragment_143.11762, fragment_176.8761, fragment_74.05986, loss_73.01579, fragment_98.09682, fragment_97.07643, loss_89.01085, loss_89.04756, loss_86.0366, fragment_109.04829
# Topic 48: fragment_69.03368, fragment_85.02833, fragment_57.03369, loss_162.05266, fragment_55.01824, loss_180.06335, fragment_81.03337, fragment_97.02839, loss_198.07419, fragment_53.03889, loss_246.09516, fragment_127.0387, loss_226.06843, loss_208.05803, loss_312.10563, loss_222.07433, loss_211.10548, loss_317.13365, fragment_229.05108
# Topic 49: fragment_116.07114, fragment_70.06514, fragment_84.04422, loss_143.05793, fragment_181.09784, fragment_209.09245, fragment_56.04978, loss_208.08492, loss_254.09018, loss_115.0632, loss_111.0318, loss_271.11657, loss_157.03751, fragment_227.10395, loss_46.00455, loss_226.0948, loss_171.0529, fragment_125.07087, fragment_116.07015

# %%
print len(ms2lda.model.loglikelihoods_)
plt.plot(ms2lda.model.loglikelihoods_)
# Out:
# 10

# %% [markdown]
# 2. PCA
# -------

# %% [markdown]
# Here we use PCA to project the vector of topics for each parent peak to lower-dimensional space for visualisation purposes. First ensure the variables are scaled.

# %%
df = ms2lda.docdf.transpose() # topics x documents matrix
# df = fragments_topicdf.transpose() # topics x words matrix
print df.shape

# normalise and scale the variables
scaled_mat = preprocessing.scale(df, axis=0)
# print scaled_mat.mean(axis=0)
# print scaled_mat.std(axis=0)
# Out:
# (856, 50)

# %% [markdown]
# Then run PCA

# %%
pca = PCA()
pca.fit(scaled_mat)
X_r = pca.transform(scaled_mat)

plt.figure()
plt.hist(X_r[:, 0], bins=30)
plt.title('First transformed variable')
plt.show()

plt.figure()
plt.hist(X_r[:, 1], bins=30)
plt.title('Second transformed variable')
plt.show()

print np.argmax(np.abs(pca.components_[0, :]))
# Out:
# 41

# %% [markdown]
# But the explained variances by the first few principal components are too low ..??

# %%
print X_r.shape
print np.sum(pca.explained_variance_ratio_)
print('explained variance by the principal components: %s' % str(pca.explained_variance_ratio_))
# Out:
# (856, 50)
# 1.0
# explained variance by the principal components: [  2.77158600e-02   2.67231859e-02   2.60783039e-02   2.47436943e-02
#    2.44355005e-02   2.39739765e-02   2.35758094e-02   2.33540258e-02
#    2.31546007e-02   2.28626821e-02   2.26328545e-02   2.23369529e-02
#    2.21799636e-02   2.20001277e-02   2.19337572e-02   2.18357546e-02
#    2.13520810e-02   2.11820082e-02   2.11190103e-02   2.09577859e-02
#    2.07857197e-02   2.07443476e-02   2.05055530e-02   2.04063421e-02
#    2.03159671e-02   2.02385537e-02   2.00633941e-02   1.99396979e-02
#    1.97766248e-02   1.94238146e-02   1.92925214e-02   1.92708392e-02
#    1.91499220e-02   1.89951270e-02   1.87979469e-02   1.84564801e-02
#    1.83707119e-02   1.79339235e-02   1.78515979e-02   1.78065048e-02
#    1.74859639e-02   1.72769777e-02   1.69849031e-02   1.68457337e-02
#    1.66204389e-02   1.63634112e-02   1.61487193e-02   1.53667622e-02
#    1.46335657e-02   6.20128051e-32]

# %%
plt.figure()
plt.scatter(X_r[:, 0], X_r[:, 1])
plt.xlabel('1st princomp')
plt.ylabel('2nd princomp')
plt.title('Projected parent peaks')

# %% [markdown]
# 3. Network
# ------------

# %% [markdown]
# We can try to put the parent peaks on a network too.

# %%
# df = topicdf.transpose() # topic x terms matrix
df = ms2lda.docdf.transpose() # documents x topic matrix
print df.shape
# Out:
# (856, 50)

# %%
# create adjacency matrix A

# first compute euclidean distance between the topics
from scipy.spatial.distance import cdist
A = cdist(df, df, 'euclidean')
print A.shape

# crudely convert to similarities
maxval = A.max()
A = 1-(A/maxval)
plt.figure()
plt.hist(A)
plt.title('Histogram of values in the adjacency matrix')
plt.show()

# set a threshold of 0.80 for the similarity values for the network graph
for i in xrange(A.shape[0]):
    for j in xrange(A.shape[1]):
        if A[i, j] < 0.80:
            A[i, j] = 0

plt.figure()
plt.matshow(A)
plt.colorbar()
plt.title('Adjacency matrix after thresholding', y=1.2)
plt.show()
# Out:
# (856, 856)

# %%
dt = [('len', float)]
A = A.view(dt)
G = nx.from_numpy_matrix(A)
pos = nx.spring_layout(G, k=0.01, iterations=20)
nx.draw(G, pos, node_size=10, with_labels=False)

# %% [markdown]
# Now we see some connected components in the network graph. Below we print the largest top-20 components.
#
# Parent peaks in the same component are connected in the graph above, i.e. they form some sort of clusters, suggesting they share topics in common?

# %%
components = sorted(nx.connected_components(G), key = len, reverse=True)
counter = 1
for comp in components:
    if counter > 20:
        break
    print "Component " + str(counter)
    print "=============="
    idx = np.array(comp)-1 # nodes are indexed from 1 .. N
    ms1_rows = ms2lda.ms1.iloc[idx]
    print ms1_rows[['peakID', 'mz', 'rt', 'intensity']].to_string(index=False, justify='left')
    counter += 1
    print
# Out:
# Component 1
# ==============
#  peakID  mz           rt        intensity
#  12564    180.138238  1037.050  1.527932e+06
#   9107    505.176703   662.160  4.163804e+06
#   9113    218.124765   691.613  4.310692e+05
#   9114    527.158699   668.607  7.642530e+06
#   9131    129.065795   632.053  1.117484e+08
#  10522    372.189735   617.886  2.403418e+06
#  10524    212.095090   739.434  5.293236e+06
#   5733    124.039353   335.339  4.551394e+06
#   5734    127.050233   414.504  2.761295e+07
#   4972    275.160048   414.504  1.319308e+06
#  10530    291.163250   564.091  3.559679e+06
#   7770    138.054881   546.349  4.148492e+08
#  10543    319.149792   943.404  4.451091e+05
#  10589    244.176503   927.424  5.340527e+05
#   7785    259.128812   559.317  1.632118e+06
#  10392    148.096785   843.717  3.449339e+05
#  10860    176.122209   999.442  2.659295e+06
#   9377    331.147568   714.479  2.697733e+05
#   9379    408.240353   731.995  3.381979e+05
#   7311    235.165081   532.509  4.462398e+08
#   9668    471.218615   712.790  1.624741e+06
#  12207    104.106957   988.951  1.219680e+07
#  12380    131.129116   973.922  1.216931e+07
#   9933     97.028439   669.781  5.048380e+06
#  12387    131.129124   825.457  1.447870e+07
#   9995    309.165468   796.424  1.522512e+07
#  12555    180.138244  1144.760  6.492133e+05
#  12562    180.138243  1176.410  3.134171e+05
#  12563    180.138241  1018.080  7.479064e+05
#  10026    255.170156   835.064  3.377589e+05
#  12747    265.154531  1093.700  4.872180e+05
#   7175    306.168514   517.032  9.032314e+05
#   6325    156.065501   451.307  4.051054e+06
#   4979    279.154589   333.702  7.684322e+05
#   4980    279.154806   377.378  1.991341e+06
#   5002    245.164829   409.811  1.280331e+06
#   8586    150.076064   649.151  5.674696e+05
#  10311    163.060020   627.372  1.109648e+06
#  10340    155.117848   898.140  2.775934e+05
#  12554    180.138235  1076.090  1.978641e+06
#  10369    266.159627   872.604  1.875728e+07
#   7216    136.061723   496.313  5.973374e+08
#  10378    145.049549   668.607  7.363181e+06
#   7252    140.068108   529.173  5.316128e+06
#   7298    248.060997   543.289  1.111248e+06
#  10411    189.159682   859.763  5.534961e+07
#   7312    244.078992   547.980  1.945942e+06
#   8827   1009.345299   662.160  8.001868e+05
#   4971    275.159990   313.268  5.063432e+05
#
# Component 2
# ==============
#  peakID  mz           rt       intensity
#  8917     457.202781  672.871    350569.156250
#  6592     490.192016  491.538   2826933.750000
#  5693     177.075755  438.661    843755.562500
#  5698     210.112462  295.922   1928826.625000
#   5448   318.154851   432.115    744336.68750
#  12548   180.138249  1163.280    421484.15625
#
# Component 18
# ==============
#  peakID  mz          rt       intensity
#   9029   829.281233  684.580   1110404.62500
#   8885   261.036898  652.424   4012573.00000
#   7963   267.119687  585.875  15400065.00000
#  10022   363.184381  791.985   1081165.50000
#   9640   342.139507  701.499   2355515.75000
#   8845   238.037900  668.607    481449.34375
#   9663   337.171614  710.377  11498357.00000
#   5831   325.089434  460.808    835600.12500
#   5839   134.081161  404.875   8498799.00000
#
# Component 19
# ==============
#  peakID  mz          rt        intensity
#   8204   307.099882   614.695  1.754536e+06
#   7208   388.181130   513.775  2.656016e+07
#   7210   126.054960   422.465  1.693873e+08
#   8702   498.260055   619.436  2.220032e+06
#  10959   189.134550  1043.000  3.090480e+05
#  10952   255.097364  1076.090  1.333229e+06
#   8246   217.068239   619.436  1.134236e+06
#   9664   337.171699   736.276  9.891919e+05
#  10531   291.163158   593.907  4.720964e+06
#
# Component 20
# ==============
#  peakID  mz          rt       intensity
#  6725    270.154550  469.996  34123228.0000
#  3498    397.170579  310.690    909261.4375
#   906    339.253081  216.950   1582195.0000
#  1882    538.280413  241.536   1318128.6250
#  4366    210.169996  277.930   5235238.5000
#  6286    174.076131  451.307   3236672.5000
#  6289    174.076126  424.099   1977824.2500
#  4961    164.093157  409.811  13233217.0000

# %% [markdown]
# 4. Document-Topics Distribution
# ----------------------------------

# %% [markdown]
# Visualise the document-topic distributions

# %%
df = ms2lda.docdf.transpose()
print df.shape
plt.pcolor(df, norm=None, cmap='Blues')
plt.tight_layout()
plt.xlabel('Topics')
plt.ylabel('Parent peaks')
plt.title('Documents-topics distributions')
plt.show()
# Out:
# (856, 50)

# %% [markdown]
# Nothing useful here ...

# %% [markdown]
# 5. Shared Fragments within a Topic
# --------------------------------------

# %% [markdown]
# For every topic, we visualise the 'words' shared in common across the documents.
#
# Specifically, in the plots below, for each topic, we identify the top few parent peaks where the topic occurs. The plot then shows the parent peaks (coloured in blue), all its fragment peaks (coloured in yellow) and the fragment peaks identified in the topic (coloured in red).

# %%
# %reload_ext autoreload
from lda_for_fragments import Ms2Lda

n_parents = 10 # how many parent peaks per topic
n_words = 10 # how many highest-likelihood words to choose per topic

ms2lda.plot_lda_fragments(n_parents, n_words)
# Out:
# Topic 0
# ==========
#
# Parent peaks
#
#      peakID	mz		rt		int		prob
# 1    1985 	313.23734	243.181		6.437e+05	0.990
# 2    1918 	309.22704	251.436		4.982e+05	0.976
# 3    2628 	365.19595	225.881		2.922e+06	0.974
# 4    3353 	295.22678	246.483		2.128e+06	0.953
# 5    2103 	331.24799	251.436		8.954e+05	0.948
# 6    2834 	241.17968	239.890		4.509e+05	0.941
# 7    2429 	257.04205	241.536		2.261e+06	0.935
# 8    1828 	311.13680	254.771		6.126e+05	0.903
# 9    4108 	251.18519	259.764		8.181e+06	0.903
# 10   2622 	346.25883	253.125		1.561e+06	0.892
#
# Fragments
#
# 1    fragment_91.05413 (0.063)
#  peakID  MSnParentPeakID  mz         rt       intensity
#

#  peakID  MSnParentPeakID  mz        rt       intensity
#  20998   7701             67.05456  565.049  11021.76
#  22596   8805             67.05449  653.683  12545.89
#  22917   8957             67.05450  667.654  13712.29
# 4    fragment_130.08581 (0.059)
#  peakID  MSnParentPeakID  mz        rt       intensity
#  20346   7174             130.0858  512.680  84984.36
#  22593   8805             130.0862  653.683  15359.35
#  22905   8944             130.0858  675.580  14836.70
#  22915   8957             130.0857  667.654  91572.50
#
# Losses
#
# loss_18.01058	0.021
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-3d34d3b52f65> in <module>()
#       5 n_words = 5 # how many highest-likelihood words to choose per topic
#       6
# ----> 7 ms2lda.plot_lda_fragments(n_parents, n_words)
#
# /home/joewandy/git/metabolomics_tools/justin/lda_for_fragments.py in plot_lda_fragments(self, n_docs, n_words)
#     428                 plt.legend(handles=[blue_patch, yellow_patch, red_patch, green_patch])
#     429
# --> 430                 plt.show()
#     431
#     432             # break
#
# /usr/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in show(*args, **kw)
#     153     """
#     154     global _show
# --> 155     return _show(*args, **kw)
#     156
#     157
#
# /usr/local/lib/python2.7/dist-packages/IPython/kernel/zmq/pylab/backend_inline.pyc in show(close)
#      30     try:
#      31         for figure_manager in Gcf.get_all_fig_managers():
# ---> 32             display(figure_manager.canvas.figure)
#      33     finally:
#      34         show._to_draw = []
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/display.pyc in display(*objs, **kwargs)
#     157             publish_display_data(data=obj, metadata=metadata)
#     158         else:
# --> 159             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     160             if not format_dict:
#     161                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in format(self, obj, include, exclude)
#     172             md = None
#     173             try:
# --> 174                 data = formatter(obj)
#     175             except:
#     176                 # FIXME: log the exception
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in __call__(self, obj)
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in catch_format_error(method, self, *args, **kwargs)
#     217     """show traceback on failed format call"""
#     218     try:
# --> 219         r = method(self, *args, **kwargs)
#     220     except NotImplementedError:
#     221         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     328                 pass
#     329             else:
# --> 330                 return printer(obj)
#     331             # Finally look for special method names
#     332             method = _safe_get_formatter_method(obj, self.print_method)
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     205
#     206     if 'png' in formats:
# --> 207         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     208     if 'retina' in formats or 'png2x' in formats:
#     209         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     115
#     116     bytes_io = BytesIO()
# --> 117     fig.canvas.print_figure(bytes_io, **kw)
#     118     data = bytes_io.getvalue()
#     119     if fmt == 'svg':
#
# /usr/lib/python2.7/dist-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2139                     orientation=orientation,
#    2140                     dryrun=True,
# -> 2141                     **kwargs)
#    2142                 renderer = self.figure._cachedRenderer
#    2143                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /usr/lib/python2.7/dist-packages/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     531             _png.write_png(renderer._renderer.buffer_rgba(),
#     532                            renderer.width, renderer.height,
# --> 533                            filename_or_obj, self.figure.dpi)
#     534         finally:
#     535             if close:
#
# KeyboardInterrupt:

# %% [markdown]
# 6. Topics Membership of Fragment Peaks
# ------------------------------------------

# %% [markdown]
# For every parent peak, we visualise the topic membership of its fragment peaks.

# %%
# plot_lda_parents(fragments_data, fragments_model, fragments_docdf, ms1, ms2)

# %% [markdown]
# 7. Number of Topics
# ----------------------

# %% [markdown]
# Compute the held-out perplexity on the testing set and plot as the no. of topics is increased ..
