# %% [markdown]
# Beer3 Positive Results
# ==============

# %% [markdown]
# 1. LDA
# -------

# %%
from lda_for_fragments import run_lda
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# We set K=100 (arbitrarily) and collect 1000 samples during Gibbs sampling.

# %%
n_topics = 50
n_samples = 500

# %% [markdown]
# Then .. For each document (i.e. parent peak), we have the following bag-of-words of features:
# 1. The discretised m/z value of its fragment peaks. For the value, we use the the logged intensity of the fragment peak, scaled from 0..100.
# 2. The discretised m/z value of neutral losses. For the value, we use the log intensity of the neutral loss peak, scaled from 0..100.
# 3. The discretised m/z differences between each pair of fragment peaks. For the value, we use the count of occurences of such m/z differences (e.g. 1, 2, 3), scaled from 0..100.
#
# A lot of heuristics (thresholding, etc). were used when extracting these features from the mzXML files. See extractFeatures.R for more details.

# %% [markdown]
# The discretisation step we use to prerocess the input before passing it to the model seems quite dodgy now. We see in the histogram below the tall bars at bin=10, 20 and 30. These come from (3) above. The rest of the histogram bins come from (1) and (2).

# %%
data, model, topicdf, docdf = run_lda('beer3_pos', 
                         'input/Beer_3_T10_POS_fragments.csv', 
                         'input/Beer_3_T10_POS_losses.csv', 
                         'input/Beer_3_T10_POS_mzdiffs.csv', 
                         n_topics, n_samples)
# Out:
# bin=0 count=0.0
# bin=1 count=0.0
# bin=2 count=0.0
# bin=3 count=0.0
# bin=4 count=0.0
# bin=5 count=0.0
# bin=6 count=0.0
# bin=7 count=0.0
# bin=8 count=0.0
# bin=9 count=0.0
# bin=10 count=25649.0
# bin=11 count=0.0
# bin=12 count=0.0
# bin=13 count=0.0
# bin=14 count=0.0
# bin=15 count=0.0
# bin=16 count=0.0
# bin=17 count=0.0
# bin=18 count=0.0
# bin=19 count=0.0
# bin=20 count=2771.0
# bin=21 count=0.0
# bin=22 count=0.0
# bin=23 count=0.0
# bin=24 count=0.0
# bin=25 count=0.0
# bin=26 count=0.0
# bin=27 count=0.0
# bin=28 count=0.0
# bin=29 count=0.0
# bin=30 count=554.0
# bin=31 count=0.0
# bin=32 count=0.0
# bin=33 count=0.0
# bin=34 count=0.0
# bin=35 count=0.0
# bin=36 count=0.0
# bin=37 count=0.0
# bin=38 count=0.0
# bin=39 count=0.0
# bin=40 count=135.0
# bin=41 count=0.0
# bin=42 count=109.0
# bin=43 count=554.0
# bin=44 count=829.0
# bin=45 count=882.0
# bin=46 count=804.0
# bin=47 count=821.0
# bin=48 count=802.0
# bin=49 count=753.0
# bin=50 count=656.0
# bin=51 count=555.0
# bin=52 count=474.0
# bin=53 count=455.0
# bin=54 count=461.0
# bin=55 count=412.0
# bin=56 count=334.0
# bin=57 count=310.0
# bin=58 count=286.0
# bin=59 count=241.0
# bin=60 count=243.0
# bin=61 count=173.0
# bin=62 count=156.0
# bin=63 count=130.0
# bin=64 count=101.0
# bin=65 count=76.0
# bin=66 count=66.0
# bin=67 count=67.0
# bin=68 count=51.0
# bin=69 count=41.0
# bin=70 count=56.0
# bin=71 count=38.0
# bin=72 count=36.0
# bin=73 count=16.0
# bin=74 count=11.0
# bin=75 count=25.0
# bin=76 count=15.0
# bin=77 count=10.0
# bin=78 count=7.0
# bin=79 count=10.0
# bin=80 count=9.0
# bin=81 count=2.0
# bin=82 count=3.0
# bin=83 count=3.0
# bin=84 count=0.0
# bin=85 count=1.0
# bin=86 count=3.0
# bin=87 count=3.0
# bin=88 count=0.0
# bin=89 count=2.0
# bin=90 count=2.0
# bin=91 count=0.0
# bin=92 count=2.0
# bin=93 count=0.0
# bin=94 count=0.0
# bin=95 count=1.0
# bin=96 count=0.0
# bin=97 count=0.0
# bin=98 count=0.0
# Data shape (856, 3758)
# Fitting model...
# DONE!
# Writing topics to results/beer3_pos/beer3_pos_topics.csv
# Writing fragments x topics to results/beer3_pos/beer3_pos_all.csv
# Writing topic docs to results/beer3_pos/beer3_pos_docs.csv

# %% [markdown]
# LDA results can be found in the three files generated above.

# %% [markdown]
# 2. PCA
# -------

# %% [markdown]
# Here we use PCA to project the topics to lower-dimensional space for visualisation purposes. First ensure the variables are scaled.

# %%
from sklearn import preprocessing
# df = docdf # topics x documents matrix
df = topicdf.transpose() # topics x words matrix
print df.shape

# normalise and scale the variables
scaled_mat = preprocessing.scale(df, axis=0)
# print scaled_mat.mean(axis=0)
# print scaled_mat.std(axis=0)
# Out:
# (50, 3758)

# %% [markdown]
# Then run PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(scaled_mat)
X_r = pca.transform(scaled_mat)

# %% [markdown]
# But the explained variances by the first two principal components are too low ..??

# %%
print X_r.shape
print('explained variance by the first two principal components: %s' % str(pca.explained_variance_ratio_))
# Out:
# (50, 2)
# explained variance by the first two principal components: [ 0.05593861  0.03847196]

# %%
plt.figure()
plt.scatter(X_r[:, 0], X_r[:, 1])
plt.xlabel('1st princomp')
plt.ylabel('2nd princomp')
plt.title('Projected topics')

# %% [markdown]
# 3. Network
# ------------

# %% [markdown]
# We can try to put the topics on a network too.

# %%
df = topicdf.transpose()
print df.shape # df is the topic x terms matrix
# Out:
# (50, 3758)

# %%
# create adjacency matrix A

# first compute euclidean distance between the topics
from scipy.spatial.distance import cdist
A = cdist(scaled_mat, scaled_mat, 'euclidean')

# crudely convert to similarities
maxval = A.max()
A = 1-(A/maxval)
plt.hist(A)

# set a threshold of 0.3 for the similarity values for the network graph
for i in xrange(A.shape[0]):
    for j in xrange(A.shape[1]):
        if A[i, j] < 0.40:
            A[i, j] = 0

plt.matshow(A)
plt.colorbar()
plt.show()

# %%
import networkx as nx
from networkx.readwrite import json_graph
dt = [('len', float)]
A = A.view(dt)
G = nx.from_numpy_matrix(A)
pos = nx.spring_layout(G, k=0.3, iterations=20)
nx.draw(G,pos,font_size=8)

# %% [markdown]
# Hard to conclude antyhing .... It seems like there are some 'core' topics that the rest are connected to (in the high-dimensional Euclidean space). However, take note the network graph above can be misleading due to the thresholding values used.

# %% [markdown]
# 4. Topics
# -----------

# %% [markdown]
# Visualise the document-topic distributions

# %%
df = docdf.transpose()
print df.shape
plt.pcolor(df, norm=None, cmap='Blues')
plt.tight_layout()
plt.xlabel('Topics')
plt.ylabel('Parent peaks')
plt.title('Documents-topics distributions')
plt.show()
# Out:
# (856, 50)

# %% [markdown]
# For every topic, check the words inside.

# %%
n_docs = 10
n_fragments = 20

topic_fragments = model.topic_word_
headers = list(docdf.columns.values)

for i, topic_dist in enumerate(topic_fragments):
    
    print "Topic " + str(i)
    print "=========="
    print
    
    column_values = np.array(docdf.columns.values)    
    doc_dist = docdf.iloc[[i]].as_matrix().flatten()
    idx = np.argsort(doc_dist)[::-1] # argsort in descending order
    topic_d = np.array(column_values)[idx]
    topic_p = np.array(doc_dist)[idx]
    top_n_docs = topic_d[1:n_docs]
    top_n_docs_p = topic_p[1:n_docs]
    
    print "Parent peaks"
    print "\n".join(' - %s\t%.3f' % t for t in zip(top_n_docs, top_n_docs_p))

    column_values = np.array(data.columns.values)
    idx = np.argsort(topic_dist)[::-1] # argsort in descending order
    topic_w = np.array(column_values)[idx]
    topic_p = np.array(topic_dist)[idx]    
    fragments = []
    fragments_p = []
    others = []
    others_p = []
    for w, p in zip(topic_w, topic_p):
        if len(fragments) > n_fragments:
            break
        if w.startswith('fragment'):
            fragments.append(w)
            fragments_p.append(p)
        else:
            others.append(w)
            others_p.append(p)

    print "Fragments"
    print "\n".join(' - %s\t%.3f' % t for t in zip(fragments, fragments_p))

    print "Others"
    print "\n".join(' - %-15s\t%.3f' % t for t in zip(others, others_p))
    print
# Out:
# Topic 0
# ==========
#
# Parent peaks
#  - 180.08657_630.413	0.987
#  - 180.08661_668.607	0.974
#  - 180.0866_603.508	0.705
#  - 180.08663_565.722	0.693
#  - 162.07608_720.791	0.682
#  - 240.10764_688.576	0.619
#  - 163.06003_601.884	0.575
#  - 198.0972_627.372	0.530
#  - 163.05996_668.607	0.458
# Fragments
#  - fragment_69.03368	0.025
#  - fragment_85.02833	0.023
#  - fragment_81.03337	0.020
#  - fragment_53.03889	0.018
#  - fragment_57.03369	0.017
#  - fragment_127.0387	0.016
#  - fragment_97.02839	0.016
#  - fragment_162.0756	0.014
#  - fragment_61.02851	0.012
#  - fragment_73.02851	0.012
#  - fragment_55.01824	0.011
#  - fragment_56.96508	0.010
#  - fragment_105.03345	0.010
#  - fragment_99.04366	0.009
#  - fragment_84.04422	0.008
#  - fragment_145.04997	0.008
#  - fragment_96.04414	0.008
#  - fragment_60.04476	0.007
#  - fragment_144.06586	0.007
#  - fragment_72.04465	0.007
#  - fragment_72.04411	0.006
# Others
#  - loss_108.0422  	0.023
#  - loss_111.05298 	0.016
#  - loss_95.05815  	0.016
#  - loss_125.0685  	0.016
#  - loss_110.02127 	0.015
#  - loss_82.02658  	0.014
#  - loss_99.05338  	0.013
#  - loss_94.02658  	0.012
#  - loss_127.04792 	0.012
#  - loss_123.05299 	0.012
#  - loss_83.05819  	0.012
#  - loss_75.05313  	0.012
#  - loss_35.03655  	0.012
#  - loss_81.04258  	0.011
#  - loss_107.05823 	0.011
#  - loss_53.04808  	0.011
#  - loss_96.0424   	0.009
#  - mzdiff_27.9947 	0.009
#  - loss_119.05808 	0.009
#  - loss_102.03162 	0.025
#  - loss_102.06815 	0.020
#  - loss_42.01046  	0.014
#  - loss_105.07856 	0.012
#  - loss_160.0847  	0.011
#  - loss_134.0566  	0.010
#  - loss_85.08914  	0.009
#  - loss_89.05962  	0.009
#  - loss_159.05307 	0.008
#  - loss_144.05304 	0.007
#  - loss_59.07329  	0.006
#  - mzdiff_18.01058	0.006
#  - loss_46.04164  	0.006
#  - loss_114.06812 	0.005
#  - loss_174.0641  	0.005
#  - loss_189.06336 	0.005
#
# Topic 3
# ==========
#
# Parent peaks
#  - 546.68913_611.45	0.997
#  - 374.79834_645.99	0.992
#  - 546.68903_636.638	0.991
#  - 374.79827_597.184	0.983
#  - 364.79478_611.45	0.970
#  - 561.69431_619.436	0.931
#  - 469.20801_494.747	0.908
#  - 298.09687_412.921	0.877
#  - 374.79834_622.592	0.709
# Fragments
#  - fragment_136.06241	0.058
#  - fragment_97.02839	0.031
#  - fragment_98.05999	0.025
#  - fragment_114.10281	0.025
#  - fragment_119.03519	0.024
#  - fragment_96.04414	0.021
#  - fragment_137.04629	0.017
#  - fragment_216.02841	0.014
#  - fragment_263.06919	0.014
#  - fragment_291.06357	0.013
#  - fragment_219.08071	0.013
#  - fragment_178.07836	0.013
#  - fragment_278.05554	0.012
#  - fragment_157.10848	0.012
#  - fragment_115.05434	0.011
#  - fragment_189.0702	0.011
#  - fragment_250.0931	0.010
#  - fragment_247.07449	0.010
#  - fragment_207.07983	0.010
#  - fragment_97.07643	0.010
#  - fragment_276.1563	0.009
# Others
#
#
# Topic 4
# ==========
#
# Parent peaks
#  - 260.14908_955.832	0.854
#  - 218.10224_518.554	0.815
#  - 245.16483_409.811	0.805
#  - 260.14913_972.508	0.801
#  - 260.14913_857.431	0.748
#  - 259.11322_605.017	0.739
#  - 252.0865_499.47	0.501
#  - 230.04813_440.293	0.467
#  - 315.50208_633.586	0.379
# Fragments
#  - fragment_70.06514	0.026
#  - fragment_74.05986	0.026
#  - fragment_224.12739	0.015
#  - fragment_242.13989	0.015
#  - fragment_125.07087	0.014
#  - fragment_84.04422	0.012
#  - fragment_115.05434	0.012
#  - fragment_58.99527	0.011
#  - fragment_195.09145	0.011
#  - fragment_160.07676	0.011
#  - fragment_206.0825	0.010
#  - fragment_182.0845	0.010
#  - fragment_193.0757	0.010
#  - fragment_55.05468	0.010
#  - fragment_181.07491	0.010
#  - fragment_138.03764	0.009
#  - fragment_114.03788	0.009
#  - fragment_154.06586	0.009
#  - fragment_111.11652	0.009
#  - fragment_105.11003	0.008
#  - fragment_87.09938	0.008
# Others
#  - loss_46.00455  	0.050
#  - loss_36.02194  	0.027
#  - loss_18.0095   	0.015
#  - loss_18.00904  	0.010
#  - loss_64.01685  	0.009
#
# Topic 5
# ==========
#
# Parent peaks
#  - 431.27921_203.748	0.994
#  - 295.15397_205.41	0.994
#  - 333.20596_207.039	0.994
#  - 417.26345_203.748	0.993
#  - 265.10696_228.159	0.991
#  - 435.12384_213.692	0.977
#  - 281.1382_205.41	0.945
#  - 449.2355_205.41	0.919
#  - 408.27431_207.039	0.904
# Fragments
#  - fragment_69.07013	0.041
#  - fragment_91.05413	0.027
#  - fragment_53.0026	0.018
#  - fragment_221.08119	0.017
#  - fragment_83.01292	0.016
#  - fragment_53.03889	0.015
#  - fragment_195.06547	0.014
#  - fragment_55.01824	0.012
#  - fragment_167.03433	0.011
#  - fragment_195.0292	0.011
#  - fragment_219.10217	0.011
#  - fragment_81.03337	0.011
#  - fragment_293.13725	0.011
#  - fragment_57.07007	0.011
#  - fragment_79.05417	0.010
#  - fragment_67.01808	0.010
#  - fragment_209.08106	0.009
#  - fragment_115.05434	0.009
#  - fragment_239.09204	0.009
#  - fragment_109.0288	0.008
#  - fragment_123.04462	0.008
# Others
#  - loss_56.06222  	0.027
#  - loss_212.17723 	0.010
#  - loss_148.07347 	0.009
#  - loss_42.04695  	0.008
#
# Topic 6
# ==========
#
# Parent peaks
#  - 286.11303_597.184	0.938
#  - 282.11956_358.105	0.935
#  - 260.11281_422.465	0.648
#  - 205.06826_614.695	0.618
#  - 529.17571_513.775	0.524
#  - 282.1196_412.921	0.517
#  - 236.14916_864.146	0.475
#  - 320.13405_460.808	0.405
#  - 763.28442_515.409	0.380
# Fragments
#  - fragment_69.03368	0.036
#  - fragment_57.03369	0.027
#  - fragment_85.02833	0.024
#  - fragment_136.06241	0.021
#  - fragment_75.04398	0.016
#  - fragment_119.03519	0.016
#  - fragment_87.04389	0.015
#  - fragment_59.04942	0.014
#  - fragment_97.02839	0.013
#  - fragment_101.05975	0.012
#  - fragment_393.13834	0.011
#  - fragment_93.05445	0.010
#  - fragment_141.05511	0.009
#  - fragment_94.03985	0.008
#  - fragment_71.0494	0.008
#  - fragment_73.02851	0.007
#  - fragment_96.04414	0.006
#  - fragment_61.02851	0.005
#  - fragment_55.01824	0.005
#  - fragment_326.12623	0.005
#  - fragment_159.02719	0.005
# Others
#  - loss_179.07935 	0.096
#  - loss_213.08497 	0.035
#  - loss_197.08977 	0.031
#  - loss_227.10065 	0.029
#  - loss_211.10548 	0.022
#  - loss_201.08487 	0.020
#  - loss_185.09038 	0.019
#  - loss_225.08489 	0.018
#  - loss_181.05929 	0.018
#  - loss_146.05776 	0.016
#  - loss_195.07466 	0.015
#  - loss_176.06826 	0.014
#  - loss_207.07436 	0.014
#  - loss_223.06938 	0.013
#  - loss_239.10044 	0.013
#  - loss_163.08425 	0.012
#  - loss_213.12105 	0.010
#  - loss_135.05318 	0.008
#  - mzdiff_27.9947 	0.006
#  - loss_188.07961 	0.006
#  - mzdiff_15.99485	0.006
#  - mzdiff_18.01032	0.006
#  - mzdiff_32.02613	0.005
#  - loss_211.06909 	0.005
#  - loss_18.00904  	0.005
#  - loss_221.08974 	0.005
#
# Topic 7
# ==========
#
# Parent peaks
#  - 104.10696_988.951	0.973
#  - 204.14012_929.629	0.948
#  - 366.0794_493.109	0.948
#  - 378.2637_205.41	0.900
#  - 553.36919_276.253	0.896
#  - 794.29776_606.606	0.849
#  - fragment_56.04978	0.019
#  - fragment_148.07578	0.015
#  - fragment_68.04931	0.012
#  - fragment_103.05449	0.011
#  - fragment_80.04949	0.011
#  - fragment_146.05941	0.010
#  - fragment_97.07643	0.010
#  - fragment_62.92941	0.009
#  - fragment_86.06014	0.009
#  - fragment_121.96575	0.008
#  - fragment_166.08632	0.007
#  - fragment_96.06838	0.007
#  - fragment_79.05417	0.006
#  - fragment_147.06769	0.006
#  - fragment_109.07644	0.006
#  - fragment_117.05718	0.006
#  - fragment_72.08072	0.006
# Others
#  - loss_87.03188  	0.033
#  - loss_91.02682  	0.033
#  - loss_75.03188  	0.031
#  - loss_115.02685 	0.017
#  - loss_46.00544  	0.015
#  - loss_141.04225 	0.010
#  - loss_73.01648  	0.009
#  - loss_113.04717 	0.009
#  - loss_45.0213   	0.008
#  - loss_76.01613  	0.008
#  - loss_125.04751 	0.007
#  - loss_46.04164  	0.007
#  - loss_89.01085  	0.007
#  - loss_157.03751 	0.007
#  - loss_119.02147 	0.007
#  - loss_86.0366   	0.006
#  - loss_114.03136 	0.006
#
# Topic 13
# ==========
#
# Parent peaks
#  - 291.16316_593.907	0.998
#  - 291.16317_729.738	0.989
#  - 306.16862_636.638	0.979
#  - 291.08388_465.402	0.935
#  - 363.18438_791.985	0.918
#  - 291.16318_632.053	0.915
#  - 372.18967_636.638	0.833
#  - 276.15782_595.502	0.814
#  - 276.15795_636.638	0.768
# Fragments
#  - fragment_55.05468	0.022
#  - fragment_131.12918	0.022
#  - fragment_72.08072	0.022
#  - fragment_98.05999	0.021
#  - fragment_114.10281	0.017
#  - fragment_157.10848	0.016
#  - fragment_60.0559	0.014
#  - fragment_235.07575	0.013
#  - fragment_165.07001	0.013
#  - fragment_207.07983	0.012
#  - fragment_97.07643	0.012
#  - fragment_278.05554	0.010
#  - fragment_178.07836	0.010
#  - fragment_234.06713	0.009
#  - fragment_115.08711	0.009
#  - fragment_205.06525	0.008
#  - fragment_189.0702	0.007
#  - fragment_261.63818	0.007
#  - fragment_221.05948	0.006
#  - fragment_263.06919	0.006
#  - fragment_91.05413	0.006
# Others
#  - mzdiff_59.04846	0.010
#  - loss_193.10288 	0.009
#  - loss_219.08244 	0.008
#  - loss_160.03397 	0.008
#  - loss_236.10888 	0.007
#  - loss_134.0566  	0.007
#  - loss_126.09326 	0.007
#  - loss_56.08736  	0.007
#  - loss_113.08407 	0.007
#  - loss_200.10904 	0.006
#  - loss_231.10841 	0.006
#
# Topic 14
# ==========
#
# Parent peaks
#  - 310.12846_372.653	0.809
#  - 490.19215_452.947	0.790
#  - 490.19202_491.538	0.732
#  - 222.11246_286.004	0.679
#  - 166.08624_499.47	0.505
#  - 344.13393_534.05	0.380
#  - 292.19063_221.946	0.341
#  - 293.13821_205.41	0.306
#  - 328.13907_419.222	0.304
# Fragments
#  - fragment_120.08041	0.032
#  - fragment_103.05449	0.029
#  - fragment_130.06466	0.016
#  - fragment_91.05413	0.016
#  - fragment_166.08632	0.014
#  - fragment_132.08134	0.013
#  - fragment_292.11665	0.011
#  - fragment_117.05718	0.010
#  - fragment_87.03159	0.010
#  - fragment_118.06547	0.009
#  - fragment_310.12707	0.009
#  - fragment_146.0609	0.009
#  - fragment_115.05434	0.009
#  - fragment_105.07017	0.009
#  - fragment_79.05417	0.008
#  - fragment_264.12442	0.008
#  - fragment_244.09625	0.008
#  - fragment_129.07001	0.007
#  - fragment_85.02833	0.006
#  - fragment_119.07336	0.006
#  - fragment_144.08044	0.005
# Others
#  - loss_198.07419 	0.012
#  - loss_237.08515 	0.009
#  - loss_223.06938 	0.008
#  - loss_249.08478 	0.006
#
# Topic 15
# ==========
#
# Parent peaks
#  - 413.2129_1051.83	0.990
#  - 413.21294_1120.58	0.973
#  - 371.16205_207.039	0.904
#  - 413.21291_970.739	0.875
#  - 416.21393_905.841	0.865
#  - 260.11272_543.289	0.792
#  - 238.0379_668.607	0.685
#  - 254.16094_1153.58	0.571
#  - 627.18648_587.564	0.568
# Fragments
#  - fragment_167.1183	0.026
#  - fragment_84.08071	0.022
#  - fragment_195.11211	0.017
#  - fragment_72.08072	0.017
#  - fragment_377.19044	0.015
#  - fragment_85.02833	0.012
#  - fragment_81.03337	0.012
#  - fragment_360.168	0.011
#  - fragment_125.07087	0.011
#  - fragment_89.10723	0.011
#  - fragment_69.03368	0.010
#  - fragment_98.05999	0.009
#  - fragment_61.01085	0.008
#  - fragment_150.05923	0.008
#  - fragment_104.05297	0.008
#  - fragment_133.03244	0.008
#  - fragment_378.17828	0.007
#  - fragment_58.99527	0.007
#  - fragment_194.12832	0.007
#  - fragment_198.1136	0.007
#  - fragment_150.09231	0.007
# Others
#  - loss_341.13229 	0.032
#  - loss_246.09516 	0.031
#  - loss_329.13215 	0.020
#  - loss_343.14788 	0.016
#  - loss_263.12151 	0.014
#  - loss_215.10018 	0.010
#  - loss_324.10561 	0.008
#  - loss_36.02194  	0.007
#  - loss_60.03238  	0.007
#
# Topic 16
# ==========
#
# Parent peaks
#  - 264.07443_417.639	0.977
#  - 156.0768_752.158	0.852
#  - 156.07677_620.99	0.830
#  - 143.08151_501.043	0.811
#  - 483.22023_479.488	0.810
#  - 156.0768_668.607	0.780
#  - 234.13352_302.542	0.768
#  - 127.05023_414.504	0.762
#  - 153.06585_425.682	0.711
# Fragments
#  - fragment_83.06042	0.085
#  - fragment_95.06076	0.071
#  - fragment_81.04506	0.041
#  - fragment_56.04978	0.041
#  - fragment_110.07176	0.034
#  - fragment_68.0498	0.028
#  - fragment_93.04514	0.023
#  - fragment_82.05229	0.019
#  - fragment_54.03416	0.019
#  - fragment_125.07087	0.019
#  - fragment_84.04422	0.015
#  - fragment_82.05293	0.015
#  - fragment_111.0555	0.010
#  - fragment_108.056	0.009
#  - fragment_122.07171	0.009
#  - fragment_137.07039	0.008
#  - fragment_81.04442	0.008
#  - fragment_124.087	0.008
#  - fragment_107.06036	0.008
#  - fragment_126.0665	0.008
#  - fragment_95.05992	0.008
# Others
#  - mzdiff_27.01083	0.018
#  - loss_100.027   	0.014
#  - loss_73.01648  	0.013
#  - loss_73.01579  	0.011
#  - mzdiff_54.02187	0.009
#  - mzdiff_24.99537	0.009
#  - mzdiff_27.01127	0.008
#  - mzdiff_27.01047	0.008
#
# Topic 17
# ==========
#
# Parent peaks
#  - 244.14033_1107.85	0.857
#  - 244.14032_1112.59	0.856
#  - 258.15598_1076.09	0.836
#  - 239.15006_589.081	0.819
#  - 228.14548_1120.26	0.794
#  - 239.13891_408.169	0.676
#  - 203.15026_860.383	0.633
#  - 318.16867_730.481	0.503
#  - 131.12912_825.457	0.484
# Fragments
#  - fragment_73.0647	0.038
#  - fragment_98.05999	0.028
#  - fragment_101.05975	0.026
#  - fragment_103.03868	0.018
#  - fragment_80.04949	0.016
#  - fragment_99.04366	0.014
#  - fragment_185.09247	0.013
#  - fragment_107.06036	0.013
#  - fragment_155.08107	0.013
#  - fragment_259.11604	0.012
#  - fragment_55.05468	0.011
#  - fragment_71.06064	0.010
#  - fragment_134.09682	0.009
#  - fragment_193.13421	0.009
#  - fragment_221.1404	0.009
#  - fragment_161.10742	0.008
#  - fragment_91.05413	0.008
#  - fragment_211.12026	0.008
#  - fragment_119.07336	0.008
#  - fragment_176.1067	0.007
#  - fragment_110.05976	0.006
# Others
#  - loss_59.04851  	0.076
#  - loss_132.0896  	0.028
#  - loss_174.11115 	0.016
#  - loss_342.1163  	0.013
#  - loss_120.07822 	0.013
#  - mzdiff_27.9947 	0.011
#  - loss_89.05962  	0.009
#
# Topic 18
# ==========
#
# Parent peaks
#  - 606.37016_269.747	0.995
#  - 650.39629_269.747	0.993
#  - 672.40933_269.747	0.959
#  - 584.35683_271.396	0.947
#  - 352.30572_234.884	0.809
#  - 344.22788_284.365	0.800
#  - 254.10221_294.27	0.679
#  - 388.25394_281.137	0.675
#  - 560.4712_271.396	0.641
# Fragments
#  - fragment_89.06008	0.053
#  - fragment_133.08628	0.041
#  - fragment_188.07057	0.029
#  - fragment_81.03337	0.029
#  - fragment_177.11272	0.024
#  - fragment_239.14817	0.018
#  - fragment_111.04429	0.017
#  - fragment_155.07009	0.017
#  - fragment_206.0825	0.015
#  - fragment_195.12241	0.014
#  - fragment_172.07629	0.014
#  - fragment_283.17358	0.014
#  - fragment_95.04936	0.012
#  - fragment_113.0602	0.011
#  - fragment_190.08769	0.010
#  - fragment_99.04455	0.010
#  - fragment_87.04389	0.008
#  - fragment_137.05983	0.008
#  - fragment_243.12234	0.007
#  - fragment_327.20145	0.007
#  - fragment_131.07078	0.007
# Others
#  - loss_136.037   	0.026
#  - loss_160.0369  	0.023
#  - loss_201.06337 	0.022
#  - loss_173.06877 	0.021
#  - loss_66.03222  	0.020
#  - loss_163.04805 	0.019
#  - loss_146.05776 	0.018
#  - loss_132.04205 	0.017
#  - loss_148.03699 	0.015
#  - mzdiff_44.02566	0.013
#  - mzdiff_44.02618	0.013
#  - loss_64.01556  	0.011
#  - loss_175.04792 	0.011
#  - loss_82.02658  	0.011
#  - mzdiff_66.01026	0.010
#  - loss_90.03154  	0.008
#  - mzdiff_88.05173	0.008
#  - loss_46.00455  	0.008
#  - mzdiff_106.0614	0.007
#
# Topic 19
# ==========
#
# Parent peaks
#  - 257.16059_966.056	0.979
#  - 175.11894_1027.77	0.951
#  - 175.11897_1050.21	0.919
#  - 90.05496_630.413	0.891
#  - 499.22482_711.245	0.877
#  - 218.12476_691.613	0.872
#  - 319.16114_896.485	0.871
#  - 244.1765_927.424	0.813
#  - 416.26157_556.072	0.800
# Fragments
#  - fragment_72.08072	0.144
#  - fragment_60.0559	0.040
#  - fragment_112.08703	0.039
#  - fragment_114.10281	0.031
#  - fragment_60.0558	0.030
#  - fragment_70.06514	0.029
#  - fragment_71.0494	0.027
#  - fragment_116.07114	0.022
#  - fragment_175.12006	0.018
#  - fragment_130.09705	0.018
#  - fragment_158.09178	0.015
#  - fragment_97.07643	0.013
#  - fragment_257.16048	0.010
#  - fragment_72.04465	0.010
#  - fragment_84.08071	0.008
#  - fragment_115.08711	0.005
#  - fragment_147.12488	0.005
#  - fragment_186.08755	0.005
#  - fragment_168.11266	0.005
#  - fragment_204.09937	0.005
#  - fragment_301.15214	0.004
# Others
#  - loss_71.07342  	0.021
#  - loss_59.04757  	0.015
#  - mzdiff_42.02198	0.013
#  - loss_105.05437 	0.012
#  - loss_60.03238  	0.010
#  - loss_115.0632  	0.009
#  - mzdiff_52.03123	0.006
#  - mzdiff_59.04778	0.006
#  - loss_70.04156  	0.005
#  - mzdiff_115.06433	0.005
#  - loss_45.02229  	0.005
#  - loss_17.0272   	0.005
#  - mzdiff_46.00583	0.005
#  - mzdiff_56.0154 	0.005
#  - mzdiff_105.05478	0.005
#  - mzdiff_59.04846	0.005
#  - mzdiff_54.04685	0.005
#
# Topic 20
# ==========
#
# Parent peaks
#  - 314.15982_412.921	0.483
#  - 318.15485_432.115	0.419
#  - 252.10761_592.308	0.414
#  - 342.15486_412.921	0.356
#  - 296.0976_624.196	0.293
#  - 344.13393_534.05	0.190
#  - 306.1336_281.137	0.094
#  - 291.16318_632.053	0.062
#  - 420.18633_449.698	0.054
# Fragments
#  - fragment_80.04949	0.006
#  - fragment_55.01824	0.006
#  - fragment_73.02851	0.005
#  - fragment_127.0387	0.005
#  - fragment_70.02898	0.005
#  - fragment_53.03889	0.004
#  - fragment_65.03877	0.004
#  - fragment_143.05747	0.004
#  - fragment_97.02839	0.004
#  - fragment_88.03967	0.004
#  - fragment_174.09146	0.004
#  - fragment_68.04931	0.004
#  - fragment_100.03928	0.004
#  - fragment_161.06855	0.003
#  - fragment_99.04455	0.003
#  - fragment_58.02903	0.003
#  - fragment_57.03405	0.003
#  - fragment_93.06982	0.003
#  - fragment_59.03686	0.003
#  - fragment_56.04978	0.003
#  - fragment_61.02851	0.003
# Others
#  - mzdiff_38.0159 	0.006
#  - loss_261.12114 	0.006
#  - loss_259.10618 	0.006
#  - loss_208.05803 	0.006
#  - mzdiff_42.01046	0.006
#  - loss_247.10561 	0.006
#  - mzdiff_55.98974	0.006
#  - mzdiff_15.99464	0.005
#  - loss_188.07961 	0.005
#  - mzdiff_27.99553	0.005
#  - mzdiff_27.9947 	0.005
#
# Topic 22
# ==========
#
# Parent peaks
#  - 245.12839_369.407	0.948
#  - 245.12839_282.73	0.945
#  - 272.13516_669.781	0.916
#  - 249.08444_428.854	0.898
#  - 277.16578_749.46	0.855
#  - 277.1658_776.132	0.848
#  - 455.21367_955.832	0.832
#  - 251.13887_911.813	0.795
#  - 261.12325_372.653	0.717
# Fragments
#  - fragment_91.05413	0.070
#  - fragment_147.04377	0.064
#  - fragment_70.06514	0.043
#  - fragment_119.04876	0.042
#  - fragment_98.05999	0.035
#  - fragment_65.03877	0.024
#  - fragment_154.07315	0.024
#  - fragment_153.06584	0.016
#  - fragment_107.04885	0.015
#  - fragment_103.05449	0.012
#  - fragment_120.08041	0.012
#  - fragment_72.08072	0.012
#  - fragment_93.06982	0.010
#  - fragment_125.07087	0.008
#  - fragment_130.06466	0.007
#  - fragment_92.05787	0.007
#  - fragment_80.04949	0.007
#  - fragment_260.13924	0.007
#  - fragment_142.03245	0.006
#  - fragment_217.13508	0.006
#  - fragment_119.04986	0.006
# Others
#  - loss_125.04751 	0.044
#  - loss_142.07382 	0.028
#  - loss_73.01579  	0.022
#  - loss_154.07421 	0.017
#  - mzdiff_27.9947 	0.017
#  - mzdiff_20.98899	0.015
#  - mzdiff_55.98974	0.010
#  - loss_27.9937   	0.008
#  - mzdiff_76.97888	0.008
#  - mzdiff_27.99513	0.008
#  - mzdiff_54.01028	0.007
#  - mzdiff_48.98374	0.007
#  - loss_170.06921 	0.007
#
# Topic 23
# ==========
#
# Parent peaks
#  - 133.06885_565.722	0.978
#  - 309.0371_349.996	0.900
#  - 119.08965_568.665	0.890
#  - 407.23907_279.485	0.865
#  - 365.19167_313.268	0.829
#  - 351.17604_328.784	0.802
#  - 138.05488_546.349	0.568
#  - 351.12221_647.573	0.536
#  - 118.08621_568.665	0.489
# Fragments
#  - fragment_68.0498	0.052
#  - fragment_96.04414	0.051
#  - fragment_104.071	0.017
#  - fragment_56.04978	0.012
#  - fragment_122.06034	0.011
#  - fragment_69.03368	0.011
#  - fragment_81.03337	0.010
#  - fragment_164.10657	0.008
#  - fragment_263.08114	0.007
#  - fragment_92.04951	0.006
#  - fragment_109.05257	0.005
#  - fragment_73.0843	0.005
#  - fragment_87.06383	0.004
#  - fragment_139.00237	0.004
#  - fragment_111.00762	0.004
#  - fragment_56.05813	0.004
#  - fragment_281.15008	0.004
#  - fragment_323.19641	0.004
#  - fragment_210.1116	0.004
#  - fragment_267.13461	0.004
#  - fragment_230.04731	0.004
# Others
#  - loss_46.00544  	0.339
#  - loss_63.03183  	0.116
#  - loss_60.021    	0.040
#  - loss_43.98978  	0.030
#  - loss_59.01317  	0.019
#  - loss_36.02194  	0.015
#  - loss_36.02083  	0.013
#  - loss_84.04249  	0.012
#  - loss_61.02871  	0.011
#  - loss_77.04746  	0.009
#  - fragment_527.15802	0.011
#  - fragment_246.13424	0.011
#  - fragment_53.0026	0.007
#  - fragment_146.08112	0.007
#  - fragment_111.11652	0.007
#  - fragment_228.10047	0.006
#  - fragment_182.09618	0.006
#  - fragment_231.08369	0.006
#  - fragment_180.08059	0.006
#  - fragment_196.09544	0.006
#  - fragment_165.07001	0.006
#  - fragment_167.07347	0.006
#  - fragment_458.1229	0.006
# Others
#  - loss_162.05266 	0.126
#  - loss_180.06335 	0.072
#  - loss_324.10561 	0.071
#  - loss_387.13762 	0.054
#  - loss_120.04178 	0.038
#  - loss_504.16871 	0.032
#  - loss_342.1163  	0.020
#  - loss_312.10563 	0.016
#  - loss_226.06843 	0.015
#  - mzdiff_144.04298	0.009
#  - loss_222.07433 	0.007
#  - mzdiff_48.02082	0.006
#  - mzdiff_162.05046	0.006
#
# Topic 27
# ==========
#
# Parent peaks
#  - 216.12311_409.811	0.975
#  - 216.12306_351.627	0.955
#  - 553.36897_223.606	0.896
#  - 216.12305_385.459	0.861
#  - 200.09176_300.895	0.619
#  - 237.11188_236.531	0.525
#  - 218.13866_633.586	0.519
#  - 321.05963_438.661	0.493
#  - 319.15411_231.552	0.441
# Fragments
#  - fragment_55.05468	0.027
#  - fragment_154.08576	0.022
#  - fragment_84.08071	0.021
#  - fragment_126.09181	0.021
#  - fragment_198.1136	0.019
#  - fragment_56.04978	0.019
#  - fragment_82.065	0.013
#  - fragment_150.09231	0.012
#  - fragment_67.05455	0.010
#  - fragment_209.12971	0.009
#  - fragment_98.05999	0.009
#  - fragment_148.11175	0.009
#  - fragment_54.03416	0.007
#  - fragment_81.03337	0.007
#  - fragment_94.06505	0.006
#  - fragment_200.12846	0.006
#  - fragment_199.02413	0.005
#  - fragment_263.09309	0.005
#  - fragment_175.12224	0.004
#  - fragment_147.11654	0.004
#  - fragment_134.09682	0.004
# Others
#  - loss_161.06862 	0.034
#  - loss_146.05776 	0.029
#  - loss_148.07347 	0.026
#  - loss_160.07338 	0.023
#  - loss_162.08892 	0.023
#  - loss_90.03154  	0.019
#  - loss_132.04205 	0.017
#  - loss_134.0581  	0.017
#  - loss_18.0095   	0.014
#  - loss_62.03715  	0.013
#  - loss_118.06294 	0.013
#  - loss_66.03112  	0.012
#  - loss_46.00455  	0.009
#  - mzdiff_28.03097	0.008
#  - loss_150.08907 	0.008
#  - loss_54.03217  	0.008
#  - loss_175.08434 	0.008
#  - loss_116.04727 	0.008
#  - loss_137.0686  	0.007
#  - mzdiff_29.02597	0.006
#  - mzdiff_42.01109	0.005
#  - mzdiff_27.01047	0.005
#  - mzdiff_26.01566	0.005
#  - mzdiff_56.02668	0.005
#  - loss_171.0529  	0.004
#  - loss_82.02658  	0.004
#
# Topic 28
# ==========
#
# Parent peaks
#  - 294.1546_380.61	0.870
#  - 294.15452_435.357	0.862
#  - 252.10771_619.436	0.836
#  - 336.16523_292.609	0.745
#  - 294.15451_471.593	0.716
#  - 308.17038_286.004	0.701
#  - 234.09711_592.308	0.686
#  - 456.20753_509.007	0.628
#  - 262.12836_501.043	0.573
# Fragments
#  - fragment_112.03985	0.020
#  - fragment_97.02839	0.020
#  - fragment_56.04978	0.015
#  - fragment_84.04422	0.014
#  - fragment_102.05469	0.014
#  - fragment_69.03368	0.013
#  - fragment_216.08561	0.013
#  - fragment_132.10161	0.013
#  - fragment_81.03337	0.013
#  - fragment_58.02903	0.012
#  - fragment_57.03369	0.011
#  - fragment_55.01824	0.011
#  - fragment_143.05747	0.011
#  - fragment_276.14368	0.010
#  - fragment_87.03159	0.010
#  - fragment_90.05539	0.007
#  - fragment_122.06034	0.007
#  - fragment_88.03909	0.007
#  - fragment_230.14	0.007
#  - fragment_234.09787	0.006
#  - fragment_170.08149	0.006
# Others
#  - loss_150.05297 	0.021
#  - loss_178.04751 	0.021
#  - loss_162.05266 	0.020
#  - loss_208.05803 	0.018
#  - loss_196.05806 	0.017
#  - loss_36.02194  	0.016
#  - loss_84.04249  	0.009
#  - loss_64.01556  	0.009
#  - loss_190.04798 	0.008
#  - loss_18.0095   	0.007
#  - loss_226.06843 	0.007
#  - mzdiff_27.9947 	0.007
#  - loss_126.05238 	0.006
#
# Topic 29
# ==========
#
# Parent peaks
#  - 121.06481_459.215	0.997
#  - 166.12263_696.858	0.996
#  - 152.107_259.764	0.996
#  - 180.13824_1018.08	0.996
#  - 180.13824_1111.52	0.996
#  - 121.0648_259.764	0.996
#  - 180.13825_1163.28	0.995
#  - 166.12262_723.897	0.995
#  - 180.13824_1037.05	0.995
# Fragments
#  - fragment_121.06489	0.080
#  - fragment_53.03889	0.066
#  - fragment_103.05449	0.056
#  - fragment_91.05413	0.055
#  - fragment_93.06982	0.048
#  - fragment_95.04936	0.043
#  - fragment_81.03337	0.030
#  - fragment_51.0234	0.030
#  - fragment_77.03872	0.016
#  - fragment_55.01824	0.015
#  - fragment_65.03877	0.012
#  - fragment_105.03345	0.010
#  - fragment_60.08102	0.009
#  - fragment_105.04464	0.008
#  - fragment_152.10755	0.008
#  - fragment_134.01288	0.006
#  - fragment_61.03978	0.004
#  - fragment_56.96508	0.004
#  - fragment_166.12285	0.003
#  - fragment_102.04684	0.003
#  - fragment_165.07812	0.002
# Others
#  - loss_87.0684   	0.015
#  - loss_59.07329  	0.014
#  - loss_68.02589  	0.013
#  - loss_31.04205  	0.013
#  - loss_127.09933 	0.011
#  - loss_85.08914  	0.011
#  - loss_30.01047  	0.011
#  - mzdiff_38.01529	0.010
#  - loss_75.0684   	0.010
#  - loss_89.08399  	0.010
#  - loss_77.0838   	0.010
#  - loss_61.05279  	0.010
#  - loss_27.99479  	0.009
#  - loss_56.02613  	0.009
#  - loss_99.06814  	0.009
#  - loss_71.07342  	0.009
#  - loss_75.10479  	0.009
#  - mzdiff_26.0153 	0.008
#  - loss_57.05775  	0.008
#  - mzdiff_30.01086	0.008
#  - loss_45.05793  	0.008
#  - mzdiff_40.03074	0.008
#  - loss_120.05731 	0.008
#  - mzdiff_50.01547	0.008
#  - mzdiff_40.03112	0.008
#  - mzdiff_27.99513	0.008
#  - loss_44.02606  	0.008
#  - loss_70.04156  	0.008
#  - mzdiff_26.01566	0.008
#  - loss_40.03143  	0.008
#  - loss_49.05257  	0.007
#  - loss_101.08372 	0.007
#  - mzdiff_68.0258 	0.007
#  - loss_26.01544  	0.007
#  - loss_73.0525   	0.006
#  - loss_46.12551  	0.006
#  - mzdiff_42.01046	0.006
#  - mzdiff_52.03123	0.005
#  - mzdiff_18.01032	0.005
#  - mzdiff_44.02618	0.005
#  - loss_113.08407 	0.005
#  - mzdiff_70.04154	0.004
#  - loss_59.03701  	0.004
#  - mzdiff_42.0465 	0.004
#  - mzdiff_27.99436	0.004
#  - mzdiff_23.99973	0.003
#  - mzdiff_22.0212 	0.003
#  - mzdiff_16.03111	0.003
#  - mzdiff_26.01499	0.003
#  - mzdiff_30.01007	0.003
#  - loss_115.0998  	0.003
#  - mzdiff_22.02049	0.003
#  - mzdiff_18.01058	0.003
#
# Topic 30
# ==========
#
# Parent peaks
#  - 236.09164_380.61	0.893
#  - 236.09166_349.996	0.893
#  - 218.08119_277.93	0.892
#  - 218.08116_325.502	0.870
#  - 240.12286_437.038	0.634
#  - 353.19594_218.622	0.579
#  - 175.02367_705.821	0.386
#  - 127.03897_346.733	0.369
#  - 256.09666_263.096	0.350
# Fragments
#  - fragment_115.05434	0.015
#  - fragment_172.07629	0.013
#  - fragment_91.05413	0.013
#  - fragment_144.08074	0.013
#  - fragment_130.06466	0.012
#  - fragment_62.92941	0.011
#  - fragment_64.9275	0.009
#  - fragment_142.06474	0.008
#  - fragment_117.05718	0.008
#  - fragment_53.03889	0.008
#  - fragment_160.07491	0.008
#  - fragment_65.03877	0.008
#  - fragment_200.07205	0.007
#  - fragment_189.8815	0.007
#  - fragment_218.08163	0.007
#  - fragment_103.05449	0.007
#  - fragment_200.06981	0.007
#  - fragment_95.04936	0.007
#  - fragment_81.03337	0.006
#  - fragment_154.06586	0.006
#  - fragment_143.07219	0.006
# Others
#  - loss_74.0004   	0.047
#  - loss_76.01613  	0.022
#  - loss_103.02703 	0.016
#  - loss_64.01556  	0.011
#  - loss_92.01082  	0.010
#  - loss_89.04756  	0.009
#  - loss_48.02067  	0.007
#  - loss_101.01115 	0.007
#  - loss_88.01596  	0.006
#  - loss_36.02001  	0.006
#  - loss_46.00544  	0.006
#
# Topic 31
# ==========
#
# Parent peaks
#  - 176.09174_556.072	0.753
#  - 309.13776_846.264	0.629
#  - 145.04957_466.972	0.613
#  - 158.0812_438.661	0.589
#  - 188.09171_510.582	0.544
#  - 174.03854_587.564	0.525
#  - 148.06029_494.747	0.512
#  - 276.14406_435.357	0.510
#  - 174.07613_424.099	0.508
# Fragments
#  - fragment_55.01824	0.042
#  - fragment_56.04978	0.031
#  - fragment_98.05999	0.031
#  - fragment_128.07032	0.020
#  - fragment_225.12393	0.017
#  - fragment_98.09682	0.015
#  - fragment_53.03889	0.015
#  - fragment_140.07024	0.010
#  - fragment_147.11301	0.009
#  - fragment_71.0494	0.008
#  - fragment_164.10657	0.007
#  - fragment_273.14302	0.007
#  - fragment_130.0871	0.007
#  - fragment_142.08712	0.006
#  - fragment_180.10128	0.006
#  - fragment_116.07015	0.005
#  - fragment_258.13332	0.004
#  - fragment_291.15733	0.004
#  - fragment_255.13406	0.004
#  - fragment_188.07308	0.003
#  - fragment_121.96666	0.003
# Others
#  - loss_64.01556  	0.094
#  - loss_18.01103  	0.068
#  - loss_60.021    	0.048
#  - loss_90.03154  	0.047
#  - loss_88.01596  	0.044
#  - loss_106.02645 	0.043
#  - loss_144.04206 	0.028
#  - loss_78.03146  	0.025
#  - loss_92.01082  	0.020
#  - loss_36.02083  	0.019
#  - loss_76.01613  	0.016
#  - loss_48.02067  	0.012
#  - mzdiff_27.9947 	0.011
#  - loss_89.01085  	0.009
#  - mzdiff_46.00516	0.007
#  - loss_118.02644 	0.006
#  - mzdiff_32.02613	0.004
#  - mzdiff_72.021  	0.004
#  - mzdiff_42.01046	0.004
#  - loss_207.11028 	0.003
#  - loss_385.12297 	0.003
#  - mzdiff_60.0201 	0.003
#
# Topic 32
# ==========
#
# Parent peaks
#  - 489.22746_228.159	0.988
#  - 369.20378_248.128	0.970
#  - 124.03935_335.339	0.914
#  - 680.48034_221.946	0.912
#  - 663.45372_221.946	0.897
#  - 152.03182_483.773	0.886
#  - 647.45872_220.295	0.839
#  - 279.159_236.531	0.764
#  - 163.13286_259.764	0.743
# Fragments
#  - fragment_53.03889	0.109
#  - fragment_105.07017	0.081
#  - fragment_91.05413	0.078
#  - fragment_65.03877	0.072
#  - fragment_79.05417	0.060
#  - fragment_57.07007	0.029
#  - fragment_103.05449	0.028
#  - fragment_134.05999	0.024
#  - fragment_117.07034	0.020
#  - fragment_119.04876	0.020
#  - fragment_106.06503	0.014
#  - fragment_121.06489	0.013
#  - fragment_104.04995	0.012
#  - fragment_495.26484	0.012
#  - fragment_327.07802	0.012
#  - fragment_152.07031	0.012
#  - fragment_551.33272	0.008
#  - fragment_119.04986	0.008
#  - fragment_147.11654	0.007
#  - fragment_137.05983	0.007
#  - fragment_67.04206	0.007
# Others
#  - mzdiff_52.03123	0.014
#  - loss_27.99523  	0.013
#  - mzdiff_50.01547	0.012
#  - mzdiff_38.01529	0.011
#  - mzdiff_24.00044	0.010
#  - mzdiff_26.01606	0.009
#  - mzdiff_26.0153 	0.009
#  - loss_117.0425  	0.009
#  - loss_91.02682  	0.007
#
# Topic 33
# ==========
#
# Parent peaks
#  - 210.17001_322.471	0.991
#  - 268.21177_261.408	0.970
#  - 193.14347_277.93	0.842
#  - 193.14348_366.198	0.837
#  - 97.02844_669.781	0.736
#  - 251.18519_259.764	0.714
#  - 288.10539_633.586	0.665
#  - 211.14411_323.903	0.622
#  - 236.11278_241.536	0.604
# Fragments
#  - fragment_59.04942	0.091
#  - fragment_53.0026	0.081
#  - fragment_91.05413	0.035
#  - fragment_57.03369	0.028
#  - fragment_117.09077	0.028
#  - fragment_98.9847	0.021
#  - mzdiff_64.01674	0.004
#  - mzdiff_27.99436	0.004
#  - mzdiff_64.0161 	0.004
#  - mzdiff_88.01617	0.004
#  - mzdiff_15.99507	0.003
#  - mzdiff_27.99513	0.003
#  - mzdiff_92.01087	0.003
#  - mzdiff_43.98964	0.003
#  - mzdiff_18.01138	0.003
#  - mzdiff_66.03197	0.003
#  - mzdiff_51.99519	0.003
#  - mzdiff_27.99553	0.003
#  - mzdiff_54.03191	0.003
#  - mzdiff_102.0318	0.003
#  - mzdiff_84.02099	0.003
#  - mzdiff_24.00008	0.003
#  - mzdiff_73.99962	0.003
#  - mzdiff_82.02719	0.003
#  - mzdiff_20.0048 	0.003
#  - mzdiff_94.02699	0.003
#  - loss_329.13215 	0.002
#  - mzdiff_36.02189	0.002
#  - mzdiff_90.03216	0.002
#  - mzdiff_25.97912	0.002
#  - mzdiff_46.00583	0.002
#  - mzdiff_42.00997	0.002
# ...
#  - loss_45.0213   	0.010
#  - loss_89.04756  	0.010
#  - mzdiff_59.03704	0.008
#  - mzdiff_24.00008	0.007
#  - loss_113.08407 	0.007
#  - loss_101.08372 	0.006
#  - loss_73.01648  	0.006
#  - loss_103.0638  	0.006
#  - loss_97.05266  	0.005
#  - mzdiff_17.02651	0.005
#  - mzdiff_53.02637	0.005
#  - mzdiff_29.02632	0.004
#  - loss_17.02648  	0.004
#
# Topic 38
# ==========
#
# Parent peaks
#  - 264.08993_274.685	0.945
#  - 190.10734_328.784	0.874
#  - 198.11249_459.215	0.870
#  - 321.1479_286.004	0.814
#  - 515.41312_223.606	0.804
#  - 190.10737_416.08	0.800
#  - 190.10733_387.071	0.732
#  - 186.07611_441.78	0.718
#  - 191.10254_598.691	0.556
# Fragments
#  - fragment_144.10184	0.025
#  - fragment_60.04476	0.017
#  - fragment_126.05565	0.015
#  - fragment_102.0918	0.014
#  - fragment_85.06477	0.012
#  - fragment_89.00601	0.011
#  - fragment_98.05999	0.010
#  - fragment_57.07007	0.010
#  - fragment_144.06586	0.009
#  - fragment_62.06029	0.008
#  - fragment_143.01708	0.008
#  - fragment_138.05451	0.008
#  - fragment_95.04936	0.007
#  - fragment_55.01824	0.007
#  - fragment_110.07086	0.007
#  - fragment_73.02851	0.007
#  - fragment_137.05983	0.007
#  - fragment_162.05453	0.006
#  - fragment_99.04455	0.006
#  - fragment_148.09614	0.006
#  - fragment_109.0288	0.006
# Others
#  - loss_78.03146  	0.047
#  - loss_105.04249 	0.032
#  - loss_17.02617  	0.032
#  - loss_107.05823 	0.026
#  - loss_135.05318 	0.023
#  - loss_102.03162 	0.020
#  - loss_35.03718  	0.016
#  - loss_106.02645 	0.014
#  - loss_88.01596  	0.014
#  - loss_133.03727 	0.013
#  - loss_123.05299 	0.013
#  - loss_130.06264 	0.012
#  - loss_60.021    	0.012
#  - loss_119.05808 	0.010
#  - loss_128.04708 	0.009
#  - loss_95.05815  	0.009
#  - loss_42.01046  	0.008
#  - loss_79.06321  	0.007
#  - loss_66.03222  	0.007
#  - fragment_87.0554	0.012
#  - fragment_65.03877	0.012
#  - fragment_154.04951	0.011
#  - fragment_122.06034	0.010
#  - fragment_95.04936	0.009
#  - fragment_81.03337	0.008
#  - fragment_133.06155	0.008
#  - fragment_172.06128	0.007
#  - fragment_92.04951	0.007
#  - fragment_96.04414	0.006
#  - fragment_241.082	0.006
#  - fragment_103.03868	0.005
# Others
#  - loss_317.13365 	0.020
#  - loss_300.10745 	0.015
#  - loss_36.02083  	0.013
#  - loss_132.04205 	0.009
#  - loss_160.0369  	0.009
#  - mzdiff_27.9947 	0.009
#  - loss_119.02147 	0.009
#  - loss_18.01013  	0.008
#  - loss_92.01082  	0.007
#  - loss_246.09516 	0.005
#
# Topic 41
# ==========
#
# Parent peaks
#  - 354.191_243.181	0.997
#  - 340.17556_254.771	0.997
#  - 382.22217_231.552	0.996
#  - 366.19963_224.227	0.995
#  - 398.21725_231.552	0.987
#  - 367.21161_212.026	0.977
#  - 220.11798_374.23	0.918
#  - 387.15665_208.697	0.900
#  - 349.2008_210.369	0.881
# Fragments
#  - fragment_91.05413	0.019
#  - fragment_79.05417	0.016
#  - fragment_57.07007	0.015
#  - fragment_69.07013	0.015
#  - fragment_67.05455	0.014
#  - fragment_105.07017	0.013
#  - fragment_53.0026	0.010
#  - fragment_261.14913	0.010
#  - fragment_93.06982	0.010
#  - fragment_225.07566	0.010
#  - fragment_128.06203	0.010
#  - fragment_107.08554	0.008
#  - fragment_275.12787	0.008
#  - fragment_331.19013	0.007
#  - fragment_81.07	0.006
#  - fragment_113.0602	0.006
#  - fragment_119.0857	0.006
#  - fragment_263.12955	0.006
#  - fragment_133.06448	0.006
#  - fragment_287.12822	0.006
#  - fragment_131.08493	0.006
# Others
#  - loss_130.06264 	0.008
#  - loss_53.04808  	0.006
#  - mzdiff_35.9999 	0.006
#
# Topic 42
# ==========
#
# Parent peaks
#  - 532.43947_223.606	0.980
#  - 150.07745_438.661	0.923
#  - 487.17874_559.317	0.881
#  - 282.11955_657.338	0.879
#  - 255.09736_1076.09	0.812
#  - 344.09753_491.538	0.776
#  - 228.12308_263.096	0.721
#  - 560.47099_223.606	0.648
#  - 210.11246_244.833	0.628
# Fragments
#  - fragment_80.04949	0.092
#  - fragment_53.03889	0.030
#  - fragment_108.04426	0.024
#  - fragment_55.01824	0.023
#  - fragment_109.05257	0.019
#  - fragment_96.04414	0.016
#  - fragment_73.02851	0.016
#  - fragment_65.03877	0.014
#  - fragment_133.05119	0.013
#  - fragment_78.03416	0.013
#  - fragment_94.03985	0.011
#  - fragment_112.05007	0.011
#  - fragment_136.03974	0.010
#  - fragment_126.05442	0.010
#  - fragment_81.05755	0.009
#  - fragment_150.07838	0.009
#  - fragment_143.01554	0.009
#  - fragment_164.03461	0.008
#  - fragment_123.05504	0.007
#  - fragment_108.04319	0.007
#  - fragment_182.11724	0.007
# Others
#  - loss_132.04205 	0.027
#  - loss_149.06875 	0.022
#  - loss_159.05307 	0.014
#  - loss_102.06815 	0.012
#  - loss_114.06812 	0.012
#  - loss_186.06388 	0.010
#  - loss_173.06877 	0.009
#  - loss_130.06264 	0.009
#  - loss_200.07938 	0.009
#  - mzdiff_27.9947 	0.008
#  - loss_188.07961 	0.008
#  - loss_27.99523  	0.008
#  - mzdiff_18.01006	0.008
#  - loss_161.06862 	0.007
#  - mzdiff_27.01083	0.007
#  - loss_175.04792 	0.007
#
# Topic 43
# ==========
#
# Parent peaks
#  - 265.15453_1145.81	0.982
#  - 498.26006_619.436	0.952
#  - 540.27088_263.096	0.932
#  - 540.33066_274.685	0.909
#  - 323.17141_565.722	0.896
#  - 369.11816_290.983	0.804
#  - 307.17645_565.722	0.751
#  - 307.09988_614.695	0.591
#  - 246.11238_264.755	0.247
# Fragments
#  - fragment_89.03862	0.039
#  - fragment_145.02839	0.034
#  - fragment_117.03314	0.033
#  - fragment_177.05473	0.031
#  - fragment_149.05997	0.023
#  - fragment_78.04654	0.023
#  - fragment_134.03644	0.020
#  - fragment_63.02323	0.014
#  - fragment_106.04123	0.014
#  - fragment_72.08072	0.013
#  - fragment_248.12779	0.011
#  - fragment_135.04439	0.011
#  - fragment_91.05413	0.009
#  - fragment_186.05403	0.008
#  - fragment_53.03889	0.008
#  - fragment_105.03345	0.008
#  - fragment_364.22204	0.007
#  - fragment_100.07534	0.007
#  - fragment_171.14886	0.007
#  - fragment_346.21476	0.006
#  - fragment_188.17605	0.006
# Others
#  - mzdiff_27.9947 	0.013
#  - loss_193.07363 	0.011
#  - mzdiff_71.01339	0.010
#  - mzdiff_55.98974	0.010
#  - mzdiff_43.01819	0.009
#  - mzdiff_27.99513	0.009
#  - mzdiff_60.02168	0.008
#  - mzdiff_32.02613	0.006
#
# Topic 44
# ==========
#
# Parent peaks
#  - 309.16551_711.245	0.774
#  - 295.14995_687.048	0.745
#  - 337.17161_710.377	0.703
#  - 457.20278_672.871	0.690
#  - 318.12953_570.233	0.663
#  - 309.16551_736.276	0.661
#  - 480.18242_598.691	0.535
#  - 440.17634_568.665	0.526
#  - 337.1717_736.276	0.450
# Fragments
#  - fragment_81.03337	0.045
#  - fragment_128.07032	0.042
#  - fragment_84.08071	0.035
#  - fragment_100.07534	0.033
#  - fragment_260.11164	0.014
#  - fragment_190.09757	0.011
#  - fragment_53.03889	0.010
#  - fragment_173.13899	0.009
#  - fragment_214.10804	0.009
#  - fragment_242.10069	0.009
#  - fragment_198.1136	0.009
#  - fragment_291.15295	0.008
#  - fragment_112.08703	0.007
#  - fragment_55.05468	0.006
#  - fragment_238.1197	0.006
#  - fragment_100.07624	0.005
#  - fragment_109.06342	0.005
#  - fragment_256.13007	0.005
#  - fragment_85.02833	0.005
#  - fragment_282.10975	0.005
#  - fragment_55.02948	0.005
# Others
#  - loss_225.08489 	0.038
#  - loss_223.06938 	0.028
#  - loss_179.07935 	0.019
#  - loss_162.05266 	0.019
#  - loss_253.11586 	0.018
#  - loss_181.09473 	0.014
#  - loss_277.11587 	0.014
#  - loss_211.06909 	0.013
#  - loss_207.07436 	0.012
#  - loss_80.01024  	0.011
#  - loss_128.03138 	0.010
#  - loss_239.10044 	0.007
#  - mzdiff_43.98964	0.007
#  - loss_208.05803 	0.005
#  - mzdiff_145.07342	0.005
#  - loss_385.12297 	0.005
#  - loss_237.08515 	0.005
#  - loss_209.0664  	0.005
#  - loss_18.01058  	0.005
#  - mzdiff_143.05888	0.005
#
# Topic 45
# ==========
#
# Parent peaks
#  - 327.19533_208.697	0.916
#  - 302.12098_501.043	0.885
#  - 394.25876_208.697	0.787
#  - 362.2165_502.727	0.727
#  - 264.14408_241.536	0.690
#  - 246.16992_244.833	0.608
#  - 277.15831_299.24	0.584
#  - 345.21336_294.27	0.546
#  - 359.10373_286.004	0.535
# Fragments
#  - fragment_110.07176	0.041
#  - fragment_156.07692	0.039
#  - fragment_143.11762	0.037
#  - fragment_129.10184	0.016
#  - fragment_91.05413	0.016
#  - fragment_201.12805	0.016
#  - fragment_115.05434	0.016
#  - fragment_57.07007	0.015
#  - fragment_131.08493	0.011
#  - fragment_173.13225	0.010
#  - fragment_252.10826	0.010
#  - fragment_129.07001	0.010
#  - fragment_189.12435	0.010
#  - fragment_171.11266	0.009
#  - fragment_159.08048	0.009
#  - fragment_69.07013	0.008
#  - fragment_74.05986	0.006
#  - fragment_182.07858	0.006
#  - fragment_126.09181	0.006
#  - fragment_383.20101	0.006
#  - fragment_290.16097	0.006
# Others
#  - loss_198.12539 	0.009
#  - loss_36.02194  	0.009
#  - mzdiff_46.00516	0.008
#  - mzdiff_23.97512	0.007
#  - loss_105.04249 	0.007
#  - mzdiff_63.03185	0.006
#  - loss_18.01058  	0.006
#  - loss_120.04253 	0.006
#
# Topic 46
# ==========
#
# Parent peaks
#  - 274.09193_536.439	0.962
#  - 324.21702_220.295	0.911
#  - 465.10293_513.775	0.855
#  - 268.10247_597.184	0.706
#  - 220.08152_624.196	0.696
#  - 238.092_624.196	0.335
#  - 234.0972_641.423	0.303
#  - 402.15072_560.934	0.264
#  - 370.16089_491.538	0.223
# Fragments
#  - fragment_97.02839	0.016
#  - fragment_154.04951	0.012
#  - fragment_84.04422	0.011
#  - fragment_127.0387	0.011
#  - fragment_164.07061	0.009
#  - fragment_56.04978	0.009
#  - fragment_53.03889	0.009
#  - fragment_108.04426	0.009
#  - fragment_55.01824	0.009
#  - fragment_130.05052	0.008
#  - fragment_81.03337	0.008
#  - fragment_202.07071	0.008
#  - fragment_109.0288	0.008
#  - fragment_192.06673	0.007
#  - fragment_68.0498	0.007
#  - fragment_53.0026	0.006
#  - fragment_126.05565	0.006
#  - fragment_238.07123	0.006
#  - fragment_69.03368	0.006
#  - fragment_256.08031	0.005
#  - fragment_142.05017	0.005
# Others
#  - loss_162.05266 	0.013
#  - loss_144.04206 	0.012
#  - loss_132.04205 	0.008
#  - loss_160.0369  	0.007
#  - loss_180.06335 	0.007
#  - mzdiff_74.00056	0.007
#
# Topic 47
# ==========
#
# Parent peaks
#  - 338.34169_233.227	0.991
#  - mzdiff_83.037  	0.008
#  - mzdiff_55.00528	0.008
#  - loss_106.02645 	0.008
#  - mzdiff_26.01566	0.007
#  - loss_78.03146  	0.007
#  - mzdiff_27.01083	0.007
#  - mzdiff_27.9947 	0.006
#  - mzdiff_38.0159 	0.006
#  - loss_120.04178 	0.006
#  - mzdiff_69.02122	0.006
#  - mzdiff_68.02643	0.006
#  - mzdiff_65.0265 	0.005
#  - mzdiff_27.99553	0.005
#  - mzdiff_42.01109	0.005
#  - mzdiff_54.01028	0.005
#  - mzdiff_96.02201	0.005
#  - mzdiff_41.02643	0.005
#  - mzdiff_42.01046	0.005
#  - mzdiff_27.99513	0.005
#  - mzdiff_38.01529	0.005
#  - mzdiff_66.01125	0.005
#  - mzdiff_39.9948 	0.005
#  - mzdiff_80.0258 	0.005
#  - mzdiff_25.97912	0.005
#  - mzdiff_109.05223	0.005
#  - mzdiff_55.00592	0.005
#  - mzdiff_43.00536	0.005
#  - mzdiff_81.02108	0.005
#  - mzdiff_84.02197	0.005
#  - mzdiff_39.99536	0.004
#  - loss_66.03112  	0.004
#
# Topic 49
# ==========
#
# Parent peaks
#  - 229.15463_538.378	0.989
#  - 236.16836_532.509	0.977
#  - 352.24414_531.443	0.958
#  - 229.1546_525.002	0.917
#  - 341.06339_460.808	0.912
#  - 325.08943_460.808	0.909
#  - 366.095_444.82	0.908
#  - 299.16084_955.415	0.908
#  - 435.12642_310.69	0.904
# Fragments
#  - fragment_70.06514	0.606
#  - fragment_58.06553	0.041
#  - fragment_96.08073	0.029
#  - fragment_71.06871	0.024
#  - fragment_118.0861	0.022
#  - fragment_114.05541	0.015
#  - fragment_68.0498	0.012
#  - fragment_114.09125	0.010
#  - fragment_55.01824	0.010
#  - fragment_142.08712	0.006
#  - fragment_117.07399	0.006
#  - fragment_125.07087	0.005
#  - fragment_59.06225	0.003
#  - fragment_124.07647	0.003
#  - fragment_97.08923	0.003
#  - fragment_210.13178	0.003
#  - fragment_71.06294	0.003
#  - fragment_241.15668	0.003
#  - fragment_126.07422	0.003
#  - fragment_124.07536	0.003
#  - fragment_305.08192	0.003
# Others
#  - loss_159.08928 	0.020
#  - loss_133.07373 	0.018
#  - loss_171.08919 	0.014
#  - loss_115.0998  	0.009
#  - loss_161.10472 	0.009
#  - loss_105.07856 	0.009
#  - loss_101.08372 	0.006
#  - mzdiff_26.01566	0.006
#  - loss_115.0632  	0.005
#  - mzdiff_38.01529	0.005
#  - mzdiff_43.99041	0.004
#  - mzdiff_60.021  	0.004
#  - loss_111.0684  	0.004
#  - loss_113.08407 	0.003
#  - mzdiff_46.00583	0.003
#  - mzdiff_41.06244	0.003
#  - mzdiff_46.00516	0.003
#  - mzdiff_28.03097	0.003
#  - mzdiff_59.03704	0.003
#  - mzdiff_84.02197	0.003

# %% [markdown]
# make a plot (plus the intensity) from the report above ...

# %% [markdown]
# 5. No. of Topics
# -------------------

# %% [markdown]
# Compute the held-out perplexity on the testing set and plot as the no. of topics is increased ..
