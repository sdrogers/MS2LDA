# %% [markdown]
# Example Notebook 2: Loading MS2LDA Analysis
# ==============================================

# %% [markdown]
# This notebook demonstrates loading an existing MS2LDA analysis containing discovered Mass2Motifs, alongside the list of MS1 and MS2 peaks with putative elemental formula annotations.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import pandas as pd
from IPython.display import display

# %%
import os
import sys
basedir = '../MS2LDA/python'
sys.path.append(basedir)

from lda_for_fragments import Ms2Lda

# %% [markdown]
# If there's any error above, ensure that the basedir correctly points to the location of the MS2LDA Python codes.

# %% [markdown]
# Save the whole project so we don't have to re-run everything the next time .. The message parameter can be omitted.

# %%
ms2lda.save_project('beer3test.project', 
                    message="Beer3Pos analysis for the manuscript with SIRIUS EF Annotation")

# %% [markdown]
# <hr/>

# %% [markdown]
# <h2>3. Results</h2>

# %% [markdown]
# <h3>a. Resuming Project (Optional)</h3>

# %% [markdown]
# If you saved the project in step (2c), you can resume from here the next time you load this notebook ..

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
basedir = '../'
sys.path.append(basedir)

import numpy as np
import pandas as pd
import pylab as plt
from IPython.display import display
from lda_for_fragments import Ms2Lda
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ms2lda = Ms2Lda.resume_from('results/beer3pos.project')
# Out:
# Project loaded from results/beer3pos.project time taken = 21.2584190369
#  - input_filenames =
# 	../input/manuscript/Beer3pos_MS1filter_Method3_fragments.csv
# 	../input/manuscript/Beer3pos_MS1filter_Method3_losses.csv
# 	../input/manuscript/Beer3pos_MS1filter_Method3_ms1.csv
# 	../input/manuscript/Beer3pos_MS1filter_Method3_ms2.csv
#  - df.shape = (1422, 4496)
#  - K = 300
#  - alpha = 0.166666666667
#  - beta = 0.1
#  - number of samples stored = 1
#  - last_saved_timestamp = Fri Oct 16 02:56:11 2015
#  - message = Beer3Pos analysis for the manuscript with SIRIUS EF Annotation

# %%
display(ms2lda.ms1)
# Out:
#        peakID  MSnParentPeakID  msLevel        rt           mz      intensity  \
# 1           1                0        1   578.503    70.065165  16431632.0000
# 5           5                0        1   566.043    72.080799   1067314.7500
# 12         12                0        1  1210.110    72.080818   1025769.1250
# 15         15                0        1   468.470    73.064788    925079.4375
# 19         19                0        1   656.240    76.039316   1047793.6875
# 24         24                0        1  1027.660    76.075699   1636355.7500
# 33         33                0        1   562.308    81.033514    766053.0000
# 37         37                0        1   632.557    83.060245    705789.6250
# 42         42                0        1   486.476    84.044375   2827970.7500
# 46         46                0        1   566.043    84.080711    978819.3750
# 51         51                0        1   667.614    85.028372   3757659.5000
# 55         55                0        1   465.819    85.028381   2102897.0000
# 67         67                0        1   415.512    86.059962   1211292.7500
# 70         70                0        1   646.272    86.060008   8953359.0000
# 78         78                0        1  1005.220    86.060024   1433368.6250
# 82         82                0        1  1018.270    86.060026    532986.6250
# 86         86                0        1   280.189    86.096375   1282799.1250
# 93         93                0        1   519.739    86.096417   2307827.7500
# 99         99                0        1   646.272    87.044055  12338473.0000
# 105       105                0        1   636.289    87.055276    735020.5000
# 111       111                0        1   434.590    89.059678    787915.5625
# 123       123                0        1   908.712    89.070924   1793272.5000
# 131       131                0        1   645.032    90.054941   2888840.5000
# 138       138                0        1   433.349    90.054973    695324.8750
# 141       141                0        1   631.311    90.054973   6755740.0000
# 148       148                0        1   804.705    90.091364   2163393.0000
# 171       171                0        1   402.687    96.044368   1281763.5000
# 176       176                0        1   389.139    96.044381   1998793.8750
# 185       185                0        1   667.614    97.028420   5013418.0000
# 191       191                0        1   467.234    97.028429   1216976.8750
# ...       ...              ...      ...       ...          ...            ...
# 34244   34244                0        1   270.932   628.382780    780065.3750
# 34263   34263                0        1   690.253   633.271325    587176.0000
# 34277   34277                0        1   217.007   647.458533   1605510.2500
# 34294   34294                0        1   677.736   649.218679   1740094.1250
# 34311   34311                0        1   270.932   650.396089    699251.7500
# 34325   34325                0        1   223.381   654.332121   1803081.5000
# 34352   34352                0        1   273.606   660.523315    538620.6250
# 34357   34357                0        1   218.245   663.453627   3320170.0000
# 34381   34381                0        1   218.245   666.512338    745498.8125
# 34391   34391                0        1   225.864   666.512400    731283.6250
# 34401   34401                0        1   666.373   667.228500   2478907.0000
# 34430   34430                0        1   676.494   667.228943   4032921.7500
# 34459   34459                0        1   661.235   668.260475    804232.2500
# 34478   34478                0        1   269.685   672.409058    618715.6250
# 34489   34489                0        1   219.484   680.480234   2931464.5000
# 34510   34510                0        1   677.736   684.255481  21881570.0000
# 34556   34556                0        1   677.736   689.211029   5848416.0000
# 34565   34565                0        1   514.793   763.284320   1701424.8750
# 34570   34570                0        1   605.939   794.297548    972980.6875
# 34588   34588                0        1   685.234   829.280913   1226801.3750
# 34603   34603                0        1   676.494   829.281206    815349.0000
# 34618   34618                0        1   686.519   846.307934   4944562.5000
# 34648   34648                0        1   686.519   851.263349   1416975.1250
# 34652   34652                0        1   689.007   991.333787    950191.9375
# 34667   34667                0        1   689.007  1008.360999   2832173.2500
# 34690   34690                0        1   661.235  1009.344582    941096.8125
# 34707   34707                0        1   663.894  1026.371495   1586896.0000
# 34726   34726                0        1   670.092  1031.326474    642023.0000
# 34730   34730                0        1   661.235  1031.326611    862887.0000
# 34734   34734                0        1   222.140  1046.844951   1334056.7500
#
#        Sample  GroupPeakMSn  CollisionEnergy annotation
# 1           1             0                0      C4H7N
# 5           1             0                0      C4H9N
# 12          1             0                0      C4H9N
# 15          1             0                0      C4H8O
# 19          1             0                0        NaN
# 24          1             0                0     C3H9NO
# 33          1             0                0      C5H4O
# 37          1             0                0     C4H6N2
# 42          1             0                0     C4H5NO
# 46          1             0                0      C5H9N
# 51          1             0                0     C4H4O2
# 55          1             0                0     C4H4O2
# 67          1             0                0     C4H7NO
# 70          1             0                0     C4H7NO
# 78          1             0                0     C4H7NO
# 82          1             0                0     C4H7NO
# 86          1             0                0     C5H11N
# 93          1             0                0        NaN
# 99          1             0                0     C4H6O2
# 105         1             0                0    C3H6N2O
# 111         1             0                0     C4H8O2
# 123         1             0                0    C3H8N2O
# 131         1             0                0    C3H7NO2
# 138         1             0                0        NaN
# 141         1             0                0    C3H7NO2
# 148         1             0                0    C4H11NO
# 171         1             0                0     C5H5NO
# 176         1             0                0     C5H5NO
# 185         1             0                0     C5H4O2
# 191         1             0                0     C5H4O2
# ...       ...           ...              ...        ...
# 34244       1             0                0        NaN
# 34263       1             0                0        NaN
# 34277       1             0                0        NaN
# 34294       1             0                0        NaN
# 34311       1             0                0        NaN
# 34325       1             0                0        NaN
# 34352       1             0                0        NaN
# 34357       1             0                0        NaN
# 34381       1             0                0        NaN
# 34391       1             0                0        NaN
# 34401       1             0                0        NaN
# 34430       1             0                0        NaN
# 34459       1             0                0        NaN
# 34478       1             0                0        NaN
# 34489       1             0                0        NaN
# 34510       1             0                0        NaN
# 34556       1             0                0        NaN
# 34565       1             0                0        NaN
# 34570       1             0                0        NaN
# 34588       1             0                0        NaN
# 34603       1             0                0        NaN
# 34618       1             0                0        NaN
# 34648       1             0                0        NaN
# 34652       1             0                0        NaN
# 34667       1             0                0        NaN
# 34690       1             0                0        NaN
# 34707       1             0                0        NaN
# 34726       1             0                0        NaN
# 34730       1             0                0        NaN
# 34734       1             0                0        NaN
#
# [1422 rows x 10 columns]

# %%
display(ms2lda.ms2)
# Out:
#        peakID  MSnParentPeakID  msLevel       rt          mz  intensity  \
# 792       792              789        2  577.268   70.065056   1.000000
# 942       942              932        2  531.059  118.086075   1.000000
# 17512   17512            17496        2  604.701  104.107330   1.000000
# 307       307              298        2  933.275  104.107353   1.000000
# 2648     2648             2632        2  495.514  136.062347   1.000000
# 936       936              932        2  531.059   58.065453   0.533076
# 14567   14567            14559        2  531.059  118.086113   1.000000
# 303       303              298        2  933.275   60.080959   0.485118
# 2916     2916             2888        2  545.999  138.054489   1.000000
# 937       937              932        2  531.059   59.073425   0.344497
# 17509   17509            17496        2  604.701   86.096504   0.339775
# 17514   17514            17496        2  604.701  125.000565   0.298987
# 17511   17511            17496        2  604.701   98.983826   0.237496
# 1801     1801             1795        2  484.002   84.044189   1.000000
# 797       797              789        2  577.268  116.071083   0.086414
# 17503   17503            17496        2  604.701   60.081024   0.190594
# 1889     1889             1878        2  566.043   84.080688   1.000000
# 1729     1729             1718        2  631.311   83.060341   1.000000
# 1756     1756             1745        2  627.569   83.060341   1.000000
# 1321     1321             1309        2  420.520  108.044136   1.000000
# 18426   18426            18367        2  635.046  248.112946   1.000000
# 17506   17506            17496        2  604.701   71.073257   0.148102
# 2647     2647             2632        2  495.514  119.035172   0.225609
# 17520   17520            17496        2  604.701  258.109772   0.125070
# 855       855              848        2  577.268   71.068779   1.000000
# 867       867              860        2  577.268   71.068779   1.000000
# 2909     2909             2888        2  545.999   94.064751   0.258640
# 14560   14560            14559        2  531.059   58.065567   0.204514
# 2912     2912             2888        2  545.999  110.059761   0.207781
# 301       301              298        2  933.275   58.065456   0.092595
# ...       ...              ...      ...      ...         ...        ...
# 34641   34641            34618        2  686.519  216.278397   0.001974
# 34665   34665            34652        2  689.007  321.063751   0.011014
# 30036   30036            30011        2  212.020  119.048721   0.029921
# 30108   30108            30083        2  208.313  119.048721   0.029921
# 32857   32857            32849        2  956.847  276.134827   0.052007
# 27139   27139            27094        2  212.020  151.040359   0.039023
# 27345   27345            27300        2  205.736  151.040359   0.039023
# 32462   32462            32448        2  563.553  106.065033   0.035201
# 32759   32759            32750        2  539.755  105.033417   0.056723
# 587       587              583        2  642.551  112.039764   0.006248
# 3171     3171             3170        2  559.742   55.054649   0.107236
# 19769   19769            19736        2  478.834   95.085373   0.011279
# 19843   19843            19810        2  467.234   95.085373   0.011279
# 19947   19947            19914        2  470.943   95.085373   0.011279
# 20021   20021            19988        2  457.122   95.085373   0.011279
# 28285   28285            28253        2  249.534  137.059799   0.004444
# 1408     1408             1398        2  467.234  109.059158   0.091647
# 33261   33261            33259        2  559.742   57.033623   0.003580
# 6208     6208             6195        2  374.457   96.080780   0.040377
# 34132   34132            34118        2  659.996  128.070206   0.023226
# 32458   32458            32448        2  563.553   91.054131   0.035151
# 19740   19740            19736        2  478.834   55.020515   0.011269
# 19814   19814            19810        2  467.234   55.020515   0.011269
# 19918   19918            19914        2  470.943   55.020515   0.011269
# 19992   19992            19988        2  457.122   55.020515   0.011269
# 32581   32581            32572        2  960.666  217.134705   0.016870
# 1594     1594             1571        2  411.615  110.097008   0.042077
# 1622     1622             1599        2  418.038  110.097008   0.042077
# 1667     1667             1644        2  402.687  110.097008   0.042077
# 33545   33545            33541        2  222.140   57.072845   0.003764
#
#        Sample  GroupPeakMSn  CollisionEnergy fragment_bin_id loss_bin_id  \
# 792         1             0                0        70.06514    46.00539
# 942         1             0                0       118.08614         nan
# 17512       1             0                0       104.10738    154.0027
# 307         1             0                0       104.10738         nan
# 2648        1             0                0       136.06239         nan
# 936         1             0                0        58.06552    60.02094
# 14567       1             0                0       118.08614   117.07884
# 303         1             0                0        60.08102    44.02604
# 2916        1             0                0       138.05452         nan
# 937         1             0                0        59.07323    59.01322
# 17509       1             0                0        86.09652   172.01297
# 17514       1             0                0       125.00052   133.10962
# 17511       1             0                0        98.98385   159.12561
# 1801        1             0                0         84.0442    46.00539
# 797         1             0                0       116.07116         nan
# 17503       1             0                0        60.08102         nan
# 1889        1             0                0        84.08071    46.00539
# 1729        1             0                0        83.06041    46.00539
# 1756        1             0                0        83.06041    46.04168
# 1321        1             0                0       108.04425    18.00923
# 18426       1             0                0       248.11291    18.00923
# 17506       1             0                0        71.07325         nan
# 2647        1             0                0       119.03518    17.02527
# 17520       1             0                0       258.10965         nan
# 855         1             0                0        71.06872         nan
# 867         1             0                0        71.06872    46.00539
# 2909        1             0                0        94.06475    43.98989
# 14560       1             0                0        58.06552   177.09988
# 2912        1             0                0       110.05978    27.99401
# 301         1             0                0        58.06552    46.04168
# ...       ...           ...              ...             ...         ...
# 34641       1             0                0        216.2784         nan
# 34665       1             0                0       321.06375         nan
# 30036       1             0                0       119.04874         nan
# 30108       1             0                0       119.04874         nan
# 32857       1             0                0       276.13513   179.07913
# 27139       1             0                0       151.04036    196.1459
# 27345       1             0                0       151.04036         nan
# 32462       1             0                0       106.06503         nan
# 32759       1             0                0       105.03345         nan
# 587         1             0                0       112.03981         nan
# 3171        1             0                0        55.05466    89.01112
# 19769       1             0                0        95.08541         nan
# 19843       1             0                0        95.08541         nan
# 19947       1             0                0        95.08541   181.05877
# 20021       1             0                0        95.08541   181.05877
# 28285       1             0                0       137.05989         nan
# 1408        1             0                0       109.05898         nan
# 33261       1             0                0         57.0337         nan
# 6208        1             0                0        96.08074    72.02092
# 34132       1             0                0       128.07037         nan
# 32458       1             0                0        91.05413         nan
# 19740       1             0                0        55.02052         nan
# 19814       1             0                0        55.02052         nan
# 19918       1             0                0        55.02052         nan
# 19992       1             0                0        55.02052         nan
# 32581       1             0                0       217.13504         nan
# 1594        1             0                0       110.09699         nan
# 1622        1             0                0       110.09699    17.97339
# 1667        1             0                0       110.09699    17.97339
# 33545       1             0                0        57.07285         nan
#
#       annotation
# 792        C4H7N
# 942     C5H11NO2
# 17512    C5H13NO
# 307      C5H13NO
# 2648      C5H5N5
# 936        C3H7N
# 14567   C5H11NO2
# 303        C3H9N
# 2916     C7H7NO2
# 937        C3H8N
# 17509     C5H11N
# 17514        NaN
# 17511        NaN
# 1801      C4H5NO
# 797      C5H9NO2
# 17503      C3H9N
# 1889       C5H9N
# 1729      C4H6N2
# 1756      C4H6N2
# 1321      C6H5NO
# 18426  C10H17NO6
# 17506      C4H8N
# 2647      C5H2N4
# 17520  C8H20NO6P
# 855          NaN
# 867          NaN
# 2909       C6H7N
# 14560      C3H7N
# 2912      C6H7NO
# 301        C3H7N
# ...          ...
# 34641        NaN
# 34665        NaN
# 30036        NaN
# 30108        NaN
# 32857        NaN
# 27139        NaN
# 27345        NaN
# 32462        NaN
# 32759        NaN
# 587          NaN
# 3171        C4H6
# 19769        NaN
# 19843        NaN
# 19947        NaN
# 20021        NaN
# 28285     C8H8O2
# 1408         NaN
# 33261        NaN
# 6208       C6H9N
# 34132        NaN
# 32458        NaN
# 19740        NaN
# 19814        NaN
# 19918        NaN
# 19992        NaN
# 32581        NaN
# 1594         NaN
# 1622         NaN
# 1667         NaN
# 33545        NaN
#
# [27128 rows x 12 columns]

# %% [markdown]
# <h3>b. Thresholding</h3>

# %% [markdown]
# For the purpose of visualisation only, we threshold the document-topic and topic-word distributions produced by LDA, so we can say which topics are used in which documents, and which words 'belongs' to a topic. This needs to be done before step (b) and (c) below.

# %%
# Thresholding the doc_topic and topic_word matrices
ms2lda.do_thresholding(th_doc_topic=0.05, th_topic_word=0.01)

# %% [markdown]
# From this point onwards, we will refer to an LDA topic as **Mass2Motif** when interpreting the results.

# %% [markdown]
# <h3>c. Print Results</h3>

# %% [markdown]
# Print which fragment/loss features occur with probability above the thresholds defined above in each Mass2Motif.

# %%
ms2lda.print_motif_features()

# %% [markdown]
# We can also save the output to CSV files

# %%
ms2lda.write_results('beer3pos_csv_out')

# %% [markdown]
# <h3>d. Cosine Clustering (optional)</h3>

# %% [markdown]
# We plot the cosine clustering of the parent ions to investigate the agreement/difference between peaks that have been clustered by cosine clustering vs motifs from LDA. First we need to construct the clustering. To do this, we can use either the hierarchical clustering with Euclidean distance from scipy or an alternative greedy clustering method we devise, which works as follows: **(1)** find the next unprocessed parent ion having max intensity, **(2)** group this to other parents with cosine similarity over the threshold (0.55), **(3)** repeat until all parents have been processed.

# %%
# method is either 'hierarchical' or 'greedy'
# peak_names, clustering = ms2lda.run_cosine_clustering(method='hierarchical', th_clustering=0.80)
peak_names, clustering = ms2lda.run_cosine_clustering(method='greedy', th_clustering=0.55)

# %%
print "Found {} clusters".format(np.max(clustering))

# %% [markdown]
# Then we pick some Mass2Motifs, e.g. 102 and 220 below, and plot how all the parent ions cluster based on their cosine similarity. The parent ions of interest that have been assigned to the motif (above the threshold) are indicated as red dots in the plot.

# %%
G, cluster_interests = ms2lda.plot_cosine_clustering(102, clustering, peak_names)
for cluster in sorted(cluster_interests):
    interest_members = cluster_interests[cluster]
    print "Cluster %d with %d parent ion(s) of interest:" % (cluster, len(interest_members))
    display(ms2lda.ms1[ms2lda.ms1['peakID'].isin(interest_members)])

# %%
G, cluster_interests = ms2lda.plot_cosine_clustering(220, clustering, peak_names)
for cluster in sorted(cluster_interests):
    interest_members = cluster_interests[cluster]
    print "Cluster %d with %d parent ion(s) of interest:" % (cluster, len(interest_members))
    display(ms2lda.ms1[ms2lda.ms1['peakID'].isin(interest_members)])

# %% [markdown]
# <h3>e. Visualisation</h3>

# %% [markdown]
# A visualisation module is provided to explore the results. This can be run in either interactively in the browser or non-interactively by plotting all results in this notebook (which can be a lot of plots!)

# %% [markdown]
# <h4>Set Visualisation Parameters</h4>

# %%
# If True, an interactive visualisation is shown in a separate tab. 
# You need to interrupt the kernel to stop it once you're done with it (from the menu above, Kernel > Interrupt).
interactive=True

# %%
# Used for graph visualisation in the interactive mode only. 
# Specifies the 'special' nodes to be coloured differently.
special_nodes = [
    # you can colour the MS1 peak in the graph
    # 'doc_peakid', where peakid is the peak ID of the MS1 peak    
    ('doc_21758', 'gold'),
    # you can also colour the Mass2Motif in the graph
    ('motif_0', '#ff1493')
]

# If nothing ..
# special_nodes = None

# %%
# read the annotation assigned to each Mass2Motif from a CSV file
# this could also be stored in e.g. a database
import csv
motif_annotation = {}
for item in csv.reader(open("results/beer3pos_annotation.csv"), skipinitialspace=True):
    key = int(item[0])
    val = item[1]
    print str(key) + '\t' + val
    motif_annotation[key] = val

# here we set all the motifs having annotations as special nodes too
motif_colour = '#CC0000'
to_add_list = ['motif_' + str(x) for x in motif_annotation.keys()]
for item in to_add_list:
    special_nodes.append((item, motif_colour))

# If nothing ..
# motif_annotation = {} # or just leave the 'additional_info' parameter out when calling plot_lda_fragments below
# Out:
# 260	Water loss indicative of a free hydroxyl group - often seen in sugary structures
# 262	Carboxylic acid group (COOH) - generic substructure in amino acids and organic acids
# 226	Loss of [hexose-H2O] - suggests hexose conjugation (e.g. glucose) substructure
# 158	Leucine related substructure
# 243	Conjugation of a phosphate group (H4O4P) substructure
# 127	Conjugation of a phosphate group (H4O4P) substructure
# 174	Pyroglutamic acid (pyroglutamate) substructure
# 59	Pyroglutamic acid (pyroglutamate) substructure
# 214	Amine loss,  suggests free NH2 group in fragmented molecule
# 60	Double water loss for metabolites containing OH groups + aliphatic chain,  e.g. sugars
# 151	[proline-H2O],  suggests conjugated proline substructure.
# 40	Imidazole group linked to a carboxylgroup through one CH2 group
# 284	Suggests dihydroxylated benzene ring substructure
# 276	Alkyl aromatic substructure,  suggests aromatic ring with 2-carbon alkyl chain attached
# 45	Pipecolic acid (pipecolate) substructure
# 78	Trimethylated amine connected to a carboxylic acid group substructure (e.g. betaine)
# 184	Trimethylated amine connected to a carboxylic acid group substructure (e.g. betaine)
# 130	Cytosine + a loss of conjugated deoxyribose substructure
# 220	Adenine substructure
# 55	Cinnamic acid (cinnamate) substructure
# 241	Histidine substructure
# 13	Glutamine substructure
# 115	[phenylalanine-COOH] based substructure
# 162	Xanthine based substructure
# 19	Ferulic acid based substructure
# 58	Phenylacetaldehyde substructure (benzene ring with ethanol group attached)
# 202	Tryptophan related substructure
# 131	[hexose-H2O] substructure (a hexose conjugation,  e.g. glucose)
# 129	[hexose-H2O] substructure (a hexose conjugation,  e.g. glucose)
# 222	Serine substructure
# 230	y-aminobutyric acid (amimobutyrate) substructure
# 67	Aconitic acid (aconitate) substructure
# 42	Asparagine substructure
# 166	5-methylcytosine substructure
# 102	Unclear yet - Aromatic ring with long alkyl chain?
# 82	Agmatine based substructure - conjugated to ??
# 69	Possibly suggests 2-OH-4-oxo-pentanoic acid substructure
# 23	Large organic acid?
# 90	Combinations of small generic losses like CH2O2 + CH4O = C2H6O3

# %% [markdown]
# <h4>Run Visualisation</h4>

# %%
ms2lda.plot_lda_fragments(interactive=interactive, to_highlight=special_nodes, additional_info=motif_annotation)
# Out:
# Ranking motifs ...
#  - Mass2Motif 0 h-index = 2
#  - Mass2Motif 1 h-index = 2
#  - Mass2Motif 2 h-index = 1
#  - Mass2Motif 3 h-index = 2
#  - Mass2Motif 4 h-index = 3
#  - Mass2Motif 5 h-index = 5
#  - Mass2Motif 6 h-index = 4
#  - Mass2Motif 7 h-index = 5
#  - Mass2Motif 8 h-index = 3
#  - Mass2Motif 9 h-index = 5
#  - Mass2Motif 10 h-index = 4
#  - Mass2Motif 11 h-index = 4
#  - Mass2Motif 12 h-index = 4
#  - Mass2Motif 13 h-index = 5
#  - Mass2Motif 14 h-index = 2
#  - Mass2Motif 15 h-index = 3
#  - Mass2Motif 16 h-index = 4
#  - Mass2Motif 17 h-index = 4
#  - Mass2Motif 18 h-index = 2
#  - Mass2Motif 19 h-index = 6
#  - Mass2Motif 20 h-index = 3
#  - Mass2Motif 21 h-index = 2
#  - Mass2Motif 22 h-index = 5
#  - Mass2Motif 23 h-index = 7
#  - Mass2Motif 24 h-index = 3
#  - Mass2Motif 25 h-index = 3
#  - Mass2Motif 26 h-index = 6
#  - Mass2Motif 27 h-index = 3
#  - Mass2Motif 28 h-index = 3
#  - Mass2Motif 29 h-index = 1
#  - Mass2Motif 30 h-index = 2
#  - Mass2Motif 31 h-index = 2
#  - Mass2Motif 32 h-index = 2
#  - Mass2Motif 33 h-index = 3
#  - Mass2Motif 34 h-index = 3
#  - Mass2Motif 35 h-index = 3
#  - Mass2Motif 36 h-index = 3
#  - Mass2Motif 37 h-index = 2
#  - Mass2Motif 38 h-index = 2
#  - Mass2Motif 39 h-index = 3
#  - Mass2Motif 40 h-index = 3
#  - Mass2Motif 41 h-index = 4
#  - Mass2Motif 42 h-index = 5
#  - Mass2Motif 43 h-index = 4
#  - Mass2Motif 44 h-index = 2
#  - Mass2Motif 45 h-index = 4
#  - Mass2Motif 46 h-index = 1
#  - Mass2Motif 47 h-index = 5
#  - Mass2Motif 48 h-index = 4
#  - Mass2Motif 49 h-index = 4
#  - Mass2Motif 50 h-index = 5
#  - Mass2Motif 51 h-index = 3
#  - Mass2Motif 52 h-index = 4
#  - Mass2Motif 53 h-index = 2
#  - Mass2Motif 54 h-index = 1
#  - Mass2Motif 55 h-index = 5
#  - Mass2Motif 56 h-index = 3
#  - Mass2Motif 57 h-index = 1
#  - Mass2Motif 58 h-index = 7
#  - Mass2Motif 59 h-index = 2
#  - Mass2Motif 60 h-index = 1
#  - Mass2Motif 61 h-index = 2
#  - Mass2Motif 62 h-index = 3
#  - Mass2Motif 63 h-index = 6
#  - Mass2Motif 64 h-index = 2
#  - Mass2Motif 65 h-index = 6
#  - Mass2Motif 66 h-index = 4
#  - Mass2Motif 67 h-index = 2
#  - Mass2Motif 68 h-index = 9
#  - Mass2Motif 69 h-index = 7
#  - Mass2Motif 70 h-index = 2
#  - Mass2Motif 71 h-index = 3
#  - Mass2Motif 72 h-index = 5
#  - Mass2Motif 73 h-index = 3
#  - Mass2Motif 74 h-index = 4
#  - Mass2Motif 75 h-index = 2
#  - Mass2Motif 76 h-index = 3
#  - Mass2Motif 77 h-index = 3
#  - Mass2Motif 78 h-index = 1
#  - Mass2Motif 79 h-index = 4
#  - Mass2Motif 80 h-index = 2
#  - Mass2Motif 81 h-index = 2
#  - Mass2Motif 82 h-index = 13
#  - Mass2Motif 83 h-index = 2
#  - Mass2Motif 84 h-index = 7
#  - Mass2Motif 85 h-index = 3
#  - Mass2Motif 86 h-index = 2
#  - Mass2Motif 87 h-index = 4
#  - Mass2Motif 88 h-index = 2
#  - Mass2Motif 89 h-index = 1
#  - Mass2Motif 90 h-index = 7
#  - Mass2Motif 91 h-index = 5
#  - Mass2Motif 92 h-index = 2
#  - Mass2Motif 93 h-index = 1
#  - Mass2Motif 94 h-index = 2
#  - Mass2Motif 95 h-index = 3
#  - Mass2Motif 96 h-index = 1
#  - Mass2Motif 97 h-index = 4
#  - Mass2Motif 98 h-index = 2
#  - Mass2Motif 99 h-index = 2
#  - Mass2Motif 100 h-index = 2
#  - Mass2Motif 101 h-index = 2
#  - Mass2Motif 102 h-index = 14
#  - Mass2Motif 103 h-index = 5
#  - Mass2Motif 104 h-index = 5
#  - Mass2Motif 105 h-index = 4
#  - Mass2Motif 106 h-index = 4
#  - Mass2Motif 107 h-index = 2
#  - Mass2Motif 108 h-index = 1
#  - Mass2Motif 109 h-index = 3
#  - Mass2Motif 110 h-index = 2
#  - Mass2Motif 111 h-index = 3
#  - Mass2Motif 112 h-index = 6
#  - Mass2Motif 113 h-index = 3
#  - Mass2Motif 114 h-index = 1
#  - Mass2Motif 115 h-index = 6
#  - Mass2Motif 116 h-index = 3
#  - Mass2Motif 117 h-index = 4
#  - Mass2Motif 118 h-index = 2
#  - Mass2Motif 119 h-index = 4
#  - Mass2Motif 120 h-index = 3
#  - Mass2Motif 121 h-index = 7
#  - Mass2Motif 122 h-index = 2
#  - Mass2Motif 123 h-index = 5
#  - Mass2Motif 124 h-index = 2
#  - Mass2Motif 125 h-index = 3
#  - Mass2Motif 126 h-index = 3
#  - Mass2Motif 127 h-index = 2
#  - Mass2Motif 128 h-index = 1
#  - Mass2Motif 129 h-index = 12
#  - Mass2Motif 130 h-index = 4
#  - Mass2Motif 131 h-index = 9
#  - Mass2Motif 132 h-index = 2
#  - Mass2Motif 133 h-index = 1
#  - Mass2Motif 134 h-index = 2
#  - Mass2Motif 135 h-index = 2
#  - Mass2Motif 136 h-index = 3
#  - Mass2Motif 137 h-index = 5
#  - Mass2Motif 138 h-index = 3
#  - Mass2Motif 139 h-index = 6
#  - Mass2Motif 140 h-index = 3
#  - Mass2Motif 141 h-index = 3
#  - Mass2Motif 142 h-index = 3
#  - Mass2Motif 143 h-index = 4
#  - Mass2Motif 144 h-index = 4
#  - Mass2Motif 145 h-index = 3
#  - Mass2Motif 146 h-index = 1
#  - Mass2Motif 147 h-index = 1
#  - Mass2Motif 148 h-index = 2
#  - Mass2Motif 149 h-index = 5
#  - Mass2Motif 150 h-index = 2
#  - Mass2Motif 151 h-index = 4
#  - Mass2Motif 152 h-index = 1
#  - Mass2Motif 153 h-index = 4
#  - Mass2Motif 154 h-index = 4
#  - Mass2Motif 155 h-index = 4
#  - Mass2Motif 156 h-index = 4
#  - Mass2Motif 157 h-index = 2
#  - Mass2Motif 158 h-index = 3
#  - Mass2Motif 159 h-index = 4
#  - Mass2Motif 160 h-index = 8
#  - Mass2Motif 161 h-index = 5
#  - Mass2Motif 162 h-index = 5
#  - Mass2Motif 163 h-index = 5
#  - Mass2Motif 164 h-index = 3
#  - Mass2Motif 165 h-index = 3
#  - Mass2Motif 166 h-index = 5
#  - Mass2Motif 167 h-index = 6
#  - Mass2Motif 168 h-index = 4
#  - Mass2Motif 169 h-index = 3
#  - Mass2Motif 170 h-index = 2
#  - Mass2Motif 171 h-index = 3
#  - Mass2Motif 172 h-index = 2
#  - Mass2Motif 173 h-index = 7
#  - Mass2Motif 174 h-index = 2
#  - Mass2Motif 175 h-index = 3
#  - Mass2Motif 176 h-index = 2
#  - Mass2Motif 177 h-index = 2
#  - Mass2Motif 178 h-index = 2
#  - Mass2Motif 179 h-index = 4
#  - Mass2Motif 180 h-index = 6
#  - Mass2Motif 181 h-index = 4
#  - Mass2Motif 182 h-index = 3
#  - Mass2Motif 183 h-index = 2
#  - Mass2Motif 184 h-index = 5
#  - Mass2Motif 185 h-index = 6
#  - Mass2Motif 186 h-index = 5
#  - Mass2Motif 187 h-index = 7
#  - Mass2Motif 188 h-index = 3
#  - Mass2Motif 189 h-index = 4
#  - Mass2Motif 190 h-index = 3
#  - Mass2Motif 191 h-index = 4
#  - Mass2Motif 192 h-index = 4
#  - Mass2Motif 193 h-index = 3
#  - Mass2Motif 194 h-index = 2
#  - Mass2Motif 195 h-index = 2
#  - Mass2Motif 196 h-index = 4
#  - Mass2Motif 197 h-index = 1
#  - Mass2Motif 198 h-index = 3
#  - Mass2Motif 199 h-index = 2
#  - Mass2Motif 200 h-index = 3
#  - Mass2Motif 201 h-index = 2
#  - Mass2Motif 202 h-index = 8
#  - Mass2Motif 203 h-index = 1
#  - Mass2Motif 204 h-index = 2
#  - Mass2Motif 205 h-index = 4
#  - Mass2Motif 206 h-index = 2
#  - Mass2Motif 207 h-index = 5
#  - Mass2Motif 208 h-index = 3
#  - Mass2Motif 209 h-index = 2
#  - Mass2Motif 210 h-index = 2
#  - Mass2Motif 211 h-index = 4
#  - Mass2Motif 212 h-index = 7
#  - Mass2Motif 213 h-index = 2
#  - Mass2Motif 214 h-index = 1
#  - Mass2Motif 215 h-index = 2
#  - Mass2Motif 216 h-index = 4
#  - Mass2Motif 217 h-index = 1
#  - Mass2Motif 218 h-index = 3
#  - Mass2Motif 219 h-index = 2
#  - Mass2Motif 220 h-index = 3
#  - Mass2Motif 221 h-index = 3
#  - Mass2Motif 222 h-index = 6
#  - Mass2Motif 223 h-index = 1
#  - Mass2Motif 224 h-index = 2
#  - Mass2Motif 225 h-index = 3
#  - Mass2Motif 226 h-index = 1
#  - Mass2Motif 227 h-index = 5
#  - Mass2Motif 228 h-index = 4
#  - Mass2Motif 229 h-index = 3
#  - Mass2Motif 230 h-index = 1
#  - Mass2Motif 231 h-index = 3
#  - Mass2Motif 232 h-index = 1
#  - Mass2Motif 233 h-index = 3
#  - Mass2Motif 234 h-index = 3
#  - Mass2Motif 235 h-index = 2
#  - Mass2Motif 236 h-index = 3
#  - Mass2Motif 237 h-index = 2
#  - Mass2Motif 238 h-index = 2
#  - Mass2Motif 239 h-index = 2
#  - Mass2Motif 240 h-index = 3
#  - Mass2Motif 241 h-index = 7
#  - Mass2Motif 242 h-index = 3
#  - Mass2Motif 243 h-index = 3
#  - Mass2Motif 244 h-index = 2
#  - Mass2Motif 245 h-index = 2
#  - Mass2Motif 246 h-index = 3
#  - Mass2Motif 247 h-index = 4
#  - Mass2Motif 248 h-index = 2
#  - Mass2Motif 249 h-index = 5
#  - Mass2Motif 250 h-index = 2
#  - Mass2Motif 251 h-index = 2
#  - Mass2Motif 252 h-index = 2
#  - Mass2Motif 253 h-index = 3
#  - Mass2Motif 254 h-index = 3
#  - Mass2Motif 255 h-index = 1
#  - Mass2Motif 256 h-index = 3
#  - Mass2Motif 257 h-index = 3
#  - Mass2Motif 258 h-index = 2
#  - Mass2Motif 259 h-index = 4
#  - Mass2Motif 260 h-index = 2
#  - Mass2Motif 261 h-index = 3
#  - Mass2Motif 262 h-index = 3
#  - Mass2Motif 263 h-index = 1
#  - Mass2Motif 264 h-index = 3
#  - Mass2Motif 265 h-index = 3
#  - Mass2Motif 266 h-index = 4
#  - Mass2Motif 267 h-index = 2
#  - Mass2Motif 268 h-index = 1
#  - Mass2Motif 269 h-index = 4
#  - Mass2Motif 270 h-index = 7
#  - Mass2Motif 271 h-index = 2
#  - Mass2Motif 272 h-index = 2
#  - Mass2Motif 273 h-index = 4
#  - Mass2Motif 274 h-index = 2
#  - Mass2Motif 275 h-index = 3
#  - Mass2Motif 276 h-index = 5
#  - Mass2Motif 277 h-index = 3
#  - Mass2Motif 278 h-index = 2
#  - Mass2Motif 279 h-index = 1
#  - Mass2Motif 280 h-index = 2
#  - Mass2Motif 281 h-index = 2
#  - Mass2Motif 282 h-index = 3
#  - Mass2Motif 283 h-index = 2
#  - Mass2Motif 284 h-index = 5
#  - Mass2Motif 285 h-index = 2
#  - Mass2Motif 286 h-index = 4
#  - Mass2Motif 287 h-index = 5
#  - Mass2Motif 288 h-index = 3
#  - Mass2Motif 289 h-index = 2
#  - Mass2Motif 290 h-index = 2
#  - Mass2Motif 291 h-index = 3
#  - Mass2Motif 292 h-index = 8
#  - Mass2Motif 293 h-index = 5
#  - Mass2Motif 294 h-index = 5
#  - Mass2Motif 295 h-index = 3
#  - Mass2Motif 296 h-index = 3
#  - Mass2Motif 297 h-index = 3
#  - Mass2Motif 298 h-index = 2
#  - Mass2Motif 299 h-index = 2
# DONE!
#
# Generating plots for Mass2Motif 102 h-index=14, degree=67
# Generating plots for Mass2Motif 82 h-index=13, degree=28
# Generating plots for Mass2Motif 129 h-index=12, degree=73
# Generating plots for Mass2Motif 68 h-index=9, degree=10
# Generating plots for Mass2Motif 131 h-index=9, degree=129
# Generating plots for Mass2Motif 160 h-index=8, degree=11
# Generating plots for Mass2Motif 202 h-index=8, degree=15
# Generating plots for Mass2Motif 292 h-index=8, degree=8
# Generating plots for Mass2Motif 23 h-index=7, degree=16
# Generating plots for Mass2Motif 58 h-index=7, degree=42
# Generating plots for Mass2Motif 69 h-index=7, degree=47
# Generating plots for Mass2Motif 84 h-index=7, degree=7
# Generating plots for Mass2Motif 90 h-index=7, degree=12
