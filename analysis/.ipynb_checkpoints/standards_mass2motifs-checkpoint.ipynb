# %% [markdown]
# <h1>Mass2Motifs of Standard Compounds</h1>

# %% [markdown]
# This notebook plots the mass2motifs of standard compounds.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import sys
basedir = '../MS2LDA/python'
sys.path.append(basedir)

import numpy as np
import pandas as pd
import networkx as nx
import pylab as plt

import matplotlib as mpl
import matplotlib.cm as cm

from IPython.display import display
from lda_for_fragments import Ms2Lda
from visualisation.networkx.lda_visualisation import *

# get rid of annoying warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h2>1. Load Data and apply thresholding</h2>
#
# Load an existing Beer3pos project and apply thresholding below.

# %%
ms2lda = Ms2Lda.resume_from('projects/Manuscript_Beer3POSmode_EFassigner_ALLextended.project')
# Out:
# Project loaded from projects/Manuscript_Beer3POSmode_EFassigner_ALLextended.project time taken = 24.8485808372
#  - input_filenames =
# 	../input/manuscript/Beer3pos_MS1filter_Method3_fragments.csv
# 	../input/manuscript/Beer3pos_MS1filter_Method3_losses.csv
# 	../input/manuscript/Beer3pos_MS1filter_Method3_ms1.csv
# 	../input/manuscript/Beer3pos_MS1filter_Method3_ms2.csv
#  - df.shape = (1422, 4496)
#  - K = 300
#  - alpha = 0.166666666667
#  - beta = 0.1
#  - number of samples stored = 1
#  - last_saved_timestamp = 11/30/15 16:11:30
#  - message = Beer3Pos analysis for the manuscript with EFassigner EF assignments for ms1, fragments, and losses

# %%
ms2lda.do_thresholding(th_doc_topic=0.05, th_topic_word=0.01)

# %% [markdown]
# <h2>2. Create network graph</h2>

# %% [markdown]
# Load the motifs of interest from an external file

# %%
import csv
motif_annotation = {}
motif_idx = {}
i = 0
for item in csv.reader(open("annotations/beer3pos_annotation_Nov2015.csv"), skipinitialspace=True):
    key = int(item[0])
    val = item[1]
    print str(key) + "\t" + val
    motif_annotation[key] = val
    motif_idx[key] = i
    i += 1

motifs_of_interest = motif_annotation.keys()    

# map each motif to the colourmap too
# http://matplotlib.org/1.2.1/mpl_examples/pylab_examples/show_colormaps.hires.png
norm = mpl.colors.Normalize(vmin=min(motif_idx.values()), vmax=max(motif_idx.values()))
cmap = cm.gist_rainbow
motif_colour = cm.ScalarMappable(norm=norm, cmap=cmap)
# Out:
# 2	 "Small nitrogen containing fragment ion - often proline or ornithine derived"
# 260	 "Water loss - indicative of a free hydroxyl group"
# 262	 "Combined loss of H2O and CO
# 226	 "Loss of [hexose-H2O] - suggests hexose conjugation (e.g. glucose) substructure"
# 158	 "Leucine substructure"
# 243	 "Conjugation of a phosphate group (H4O4P) substructure"
# 127	 "Conjugation of a phosphate group (H4O4P) substructure"
# 53	 "Losses indicative of a hexose with NH2 group"
# 98	 "Fragments possibly indicative for N-Methyl-oxo-pyrrolidinecarboxylic acid like structure"
# 174	 "Pyroglutamic acid (pyroglutamate) substructure"
# 59	 "Pyroglutamic acid (pyroglutamate) substructure"
# 214	 "Amine loss - suggests free NH2 group in fragmented molecule"
# 60	 "Double water loss - indicative for metabolites containing multiple OH groups and aliphatic chain
# 151	 "[proline-H2O] suggests conjugated proline substructure"
# 280	 "Loss possibly indicative of carboxylic acid group with 1-carbon attached"
# 40	 "Imidazole group linked to a carboxylgroup through one CH2 group substructure"
# 284	 "Fragments indicative for dihydroxylated benzene ring substructure"
# 276	 "Alkyl aromatic substructure - suggests aromatic ring with 2-carbon alkyl chain attached"
# 45	 "Pipecolic acid (pipecolate) substructure"
# 79	 "Trimethylated amine connected to a carboxylic acid group substructure (e.g. betaine)"
# 184	 "Trimethylated amine connected to a carboxylic acid group substructure (e.g. betaine)"
# 130	 "Cytosine and a loss of conjugated deoxyribose substructure"
# 220	 "Adenine substructure"
# 55	 "Cinnamic acid (cinnamate) substructure"
# 241	 "Histidine substructure"
# 13	 "Glutamine substructure"
# 115	 "[phenylalanine-COOH] substructure"
# 162	 "Guanine substructure"
# 19	 "Ferulic acid substructure"
# 58	 "Ethylphenol substructure (e.g. resulting from Tyramine - MzCloud)"
# 202	 "Tryptophan related substructure"
# 82	 "Possibly suggests agmatine based substructure (C5H15N4)
# 131	 "fragments from [hexose-H2O] substructure (a hexose conjugation
# 129	 "fragments from [hexose-H2O] substructure (a hexose conjugation
# 222	 "Serine substructure"
# 230	 "y-aminobutyric acid (amimobutyrate) substructure"
# 67	 "Aconitic acid (aconitate) substructure"
# 17	 "Tyrosine substructure"
# 42	 "Asparagine substructure"
# 166	 "5-methylcytosine substructure"
# 211	 "N-acetylputrescine substructure"
# 69	 "Possibly suggests 2-OH-4-oxo-pentanoic acid substructure"
# 230	 "N/O-acetylation loss"
# 91	 "Aromatic substructure
# 156	 "[Pentose-H2O] loss

# %%
G = get_network_graph(ms2lda, motifs_of_interest)
print "\n" + nx.info(G)
# Out:
# Removed 256 motifs from the graph because they're not in the list
# Removed [] from the graph because they don't share documents with other motifs in the list
# Removed 367 unconnected documents from the graph
#
# Name:
# Type: Graph
# Number of nodes: 1099
# Number of edges: 1708
# Average degree:   3.1083

# %% [markdown]
# How many MS1 peaks can be explained by the M2Ms in the validated list?

# %%
ms1_count = 0
nodes = G.nodes(data=True)
for node_id, node_data in nodes:
    # 1 for doc, 2 for motif
    if node_data['group'] == 1: 
        ms1_count += 1
        
print "%d (out of %d) MS1 peaks found in the graph" % (ms1_count, ms2lda.ms1.shape[0])
# Out:
# 1055 (out of 1422) MS1 peaks found in the graph

# %% [markdown]
# <h2>3. Standard Peaks</h2>

# %% [markdown]
# Now we need to find which MS1 peaks match the list of standards. First, load the standard csv.

# %%
mode = 'POS' # either 'POS' or 'NEG'

std_peaks = []
with open("results/StandardsCombined_20150422_forJoe.csv", "rb") as infile:
   reader = csv.reader(infile)
   next(reader, None)  # skip the headers
   for row in reader:
    stdmix = int(row[0])
    compound_name = row[1]
    formula = row[2]
    polarity = row[3]
    mz = float(row[4])
    rt = float(row[5]) * 60
    mh_intensity = float(row[6])
    tup = (stdmix, compound_name, formula, polarity, mz, rt, mh_intensity)
    if mode == 'POS' and polarity == '+':
        std_peaks.append(tup)
    elif mode == 'NEG' and polarity == '-':
        std_peaks.append(tup)

for tup in std_peaks:
    print tup
# Out:
# (1, '1-Naphthylacetic acid', 'C12H10O2', '+', 187.07535, 249.60000000000002, 54057.0)
# (1, 'Serotonin', 'C10H12N2O', '+', 177.10242, 259.20000000000005, 97472.0)
# (1, 'Melatonin', 'C13H16N2O2', '+', 233.12831, 276.0, 642246756.0)
# (1, 'Phenylhydrazine', 'C6H8N2', '+', 109.07608, 301.8, 5947432.0)
# (1, 'Nicotinate', 'C6H5NO2', '+', 124.03932, 412.2, 761863744.0)
# (1, 'Pyridoxine', 'C8H11NO3', '+', 170.0811, 435.59999999999997, 1744299213.0)
# (1, 'riboflavin', 'C17H20N4O6', '+', 377.14548, 452.4, 9255138.0)
# (1, 'Glycerol', 'C3H8O3', '+', 93.05468, 480.0, 2873527.0)
# (1, 'Adenine', 'C5H5N5', '+', 136.06174, 491.99999999999994, 167402201.0)
# (1, 'Creatinine', 'C4H7N3O', '+', 114.06613, 496.79999999999995, 1055015474.0)
# (1, 'L-Phenylalanine', 'C9H11NO2', '+', 166.0862, 499.8, 54983812.0)
# (1, 'L-Leucine', 'C6H13NO2', '+', 132.10185, 520.8, 178751219.0)
# (1, '4-Aminobenzoate', 'C7H7NO2', '+', 138.05498, 511.2, 21075822.0)
# (1, 'Inosine', 'C10H12N4O5', '+', 269.08783, 528.0, 59555340.0)
# (1, '2-Phenylglycine', 'C8H9NO2', '+', 152.07066, 434.40000000000003, 52368552.0)
# (1, 'Selenomethionine', 'C5H11NO2Se', '+', 192.00856, 538.8000000000001, 1204510.0)
# (1, 'L-Methionine', 'C5H11NO2S', '+', 150.05827, 541.1999999999999, 237439616.0)
# (1, 'Imidazole-4-acetate', 'C5H6N2O2', '+', 127.05019, 532.1999999999999, 591056553.0)
# (1, 'L-Tryptophan', 'C11H12N2O2', '+', 205.0972, 555.0, 85868328.0)
# (1, 'N-Acetyl-D-glucosamine', 'C8H15NO6', '+', 222.0972, 550.2, 40293668.0)
# (1, 'Cytidine', 'C9H13N3O5', '+', 244.09267, 561.5999999999999, 109541168.0)
# (1, 'Guanine', 'C5H5N5O', '+', 152.05673, 589.8, 48549375.0)
# (1, 'L-Valine', 'C5H11NO2', '+', 118.08617, 570.6, 94664961.0)
# (1, 'L-Proline', 'C5H9NO2', '+', 116.07052, 580.8, 551809540.0)
# (1, 'sn-glycero-3-Phosphocholine', 'C8H20NO6P', '+', 258.10983, 607.8000000000001, 600267181.0)
# (1, 'L-Threonine', 'C4H9NO3', '+', 120.06553, 619.2, 41668297.0)
# (1, 'trans-4-Hydroxy-L-proline', 'C5H9NO3', '+', 132.06543, 622.8000000000001, 181788617.0)
# (1, 'L-Histidine', 'C6H9N3O2', '+', 156.07669, 622.8000000000001, 135748481.0)
# (1, 'N2-Acetyl-L-lysine', 'C8H16N2O3', '+', 189.12335, 628.2, 274050538.0)
# (1, 'D-Glucosamine', 'C6H13NO5', '+', 180.08659, 642.6, 33959746.0)
# (1, 'L-Glutamine', 'C5H10N2O3', '+', 147.07628, 633.0, 196459361.0)
# (1, 'Taurine', 'C2H7NO3S', '+', 126.02196, 642.6, 6621584.0)
# (1, 'L-Aspartate', 'C4H7NO4', '+', 134.04468, 620.4, 3993775.0)
# (1, 'L-Asparagine', 'C4H8N2O3', '+', 133.06073, 638.4000000000001, 14474836.0)
# (1, 'beta-Alanine', 'C3H7NO2', '+', 90.05495, 646.1999999999999, 42118740.0)
# (1, 'Glycine', 'C2H5NO2', '+', 76.03931, 658.8000000000001, 939664.0)
# (1, 'dGMP', 'C10H14N5O7P', '+', 348.07013, 622.8000000000001, 5793276.0)
# (1, 'L-Serine', 'C3H7NO3', '+', 106.0499, 657.6, 5023721.0)
# (1, 'Ethanolamine phosphate', 'C2H8NO4P', '+', 142.02641, 647.4, 2184874.0)
# (1, 'L-Citrulline', 'C6H13N3O3', '+', 176.10294, 656.4, 150086389.0)
# (1, 'L-Cystine', 'C6H12N2O4S2', '+', 241.03096, 646.1999999999999, 2724121.0)
# (1, 'meso-2_6-Diaminoheptanedioate', 'C7H14N2O4', '+', 191.10257, 704.4, 24997648.0)
# (1, 'L-2_4-Diaminobutanoate', 'C4H10N2O2', '+', 119.08153, 743.4000000000001, 8581862.0)
# (1, 'Thiamin', 'C12H16N4OS', '+', 265.11157, 971.4000000000001, 86997239.0)
# (1, 'L-Lysine', 'C6H14N2O2', '+', 147.11275, 927.6, 27170994.0)
# (1, 'L-Arginine', 'C6H14N4O2', '+', 175.11894, 996.0000000000001, 81114888.0)
# (1, 'Spermidine', 'C7H19N3', '+', 146.1653, 655.2, 197078.0)
# (2, 'Dopamine', 'C8H11NO2', '+', 154.0862, 287.4, 40341.0)
# (2, 'Thiopurine S-methylether', 'C6H6N4S', '+', 167.03845, 377.4, 634543936.0)
# (2, "5'-Methylthioadenosine", 'C11H15N5O3S', '+', 298.09711, 389.40000000000003, 390153184.0)
# (2, 'Nicotinamide', 'C6H6N2O', '+', 123.05511, 400.79999999999995, 685030490.0)
# (2, '4-(beta-Acetylaminoethyl)imidazole', 'C7H11N3O', '+', 154.09747, 417.0, 1379768122.0)
# (2, 'Pyridoxal', 'C8H9NO3', '+', 168.06543, 429.6, 608319049.0)
# (2, '6-Methylaminopurine', 'C6H7N5', '+', 150.07741, 438.0, 775948865.0)
# (2, 'Deoxyadenosine', 'C10H13N5O3', '+', 252.10889, 444.0, 454320908.0)
# (2, 'Pantothenate', 'C9H17NO5', '+', 220.11797, 442.8, 181716297.0)
# (2, 'Uracil', 'C4H4N2O2', '+', 113.03453, 463.2, 1527604.0)
# (2, 'Picolinic acid', 'C6H5NO2', '+', 124.03933, 453.0, 113954470.0)
# (2, 'thymine', 'C5H6N2O2', '+', 127.05025, 421.8, 11481343.0)
# (2, 'Adenosine', 'C10H13N5O4', '+', 268.10388, 473.4, 345087256.0)
# (2, 'Hypoxanthine', 'C5H4N4O', '+', 137.04578, 514.2, 35869148.0)
# (2, '5-Oxoproline', 'C5H7NO3', '+', 130.04996, 491.4, 210756304.0)
# (2, 'HEPES', 'C8H18N2O4S', '+', 239.10619, 493.8, 267895472.0)
# (2, 'L-Kynurenine', 'C10H12N2O3', '+', 209.09196, 525.6, 68356288.0)
# (2, 'Betaine', 'C5H11NO2', '+', 118.0863, 534.6, 1013664457.0)
# (2, 'cytosine', 'C4H5N3O', '+', 112.05048, 552.6, 411004000.0)
# (2, 'FAD', 'C27H33N9O15P2', '+', 786.16376, 505.2, 6358408.0)
# (2, 'L-isoleucine', 'C6H13NO2', '+', 132.1019, 551.4, 418656568.0)
# (2, 'Methylcysteine', 'C4H9NO2S', '+', 136.04269, 547.8000000000001, 20173226.0)
# (2, 'Ala-Gly', 'C5H10N2O3', '+', 147.07646, 540.0, 39837364.0)
# (2, 'Guanosine', 'C10H13N5O5', '+', 284.09857, 579.6, 1116780.0)
# (2, 'dAMP', 'C10H14N5O6P', '+', 332.07513, 543.6, 108266808.0)
# (2, '1-Aminocyclopropane-1-carboxylate', 'C4H7NO2', '+', 102.05495, 569.4, 28384760.0)
# (2, 'N(pi)-Methyl-L-histidine', 'C7H11N3O2', '+', 170.09233, 567.0, 336747680.0)
# (2, 'L-Carnitine', 'C7H15NO3', '+', 162.1125, 589.8, 181991312.0)
# (2, 'Eflornithine', 'C6H12F2N2O2', '+', 183.09406, 592.1999999999999, 156069088.0)
# (2, 'L-Tyrosine', 'C9H11NO3', '+', 182.08125, 338.4, 24434979.0)
# (2, '4-Trimethylammoniobutanoate', 'C7H15NO2', '+', 146.11751, 583.2, 2679002692.0)
# (2, 'S-Adenosyl-L-homocysteine', 'C14H20N6O5S', '+', 385.12888, 579.6, 25534442.0)
# (2, 'AMP', 'C10H14N5O7P', '+', 348.0704, 570.6, 38047904.0)
# (2, 'Glycylglycine', 'C4H8N2O3', '+', 133.06082, 589.8, 9148713.0)
# (2, 'Phenol', 'C6H6O', '+', 95.04906, 250.79999999999998, 135561.0)
# (2, 'D-Glucosamine-6-phosphate', 'C6H14NO8P', '+', 260.05276, 646.8, 945023.0)
# (2, 'L-Alanine', 'C3H7NO2', '+', 90.055, 633.6, 5523150.0)
# (2, 'Choline phosphate', 'C5H14NO4P', '+', 184.07321, 615.0, 983609153.0)
# (2, 'dCMP', 'C9H14N3O7P', '+', 308.06418, 599.4, 9706832.0)
# (2, 'L-2-Aminoadipate', 'C6H11NO4', '+', 162.07599, 613.8000000000001, 17816216.0)
# (2, 'L-homoserine', 'C4H9NO3', '+', 120.06561, 637.8000000000001, 91565828.0)
# (2, 'N-Acetylornithine', 'C7H14N2O3', '+', 175.10773, 634.8, 225278559.0)
# (2, '4-Aminobutanoate', 'C4H9NO2', '+', 104.0705, 649.2, 146788884.0)
# (2, 'L-Cystathionine', 'C7H14N2O4S', '+', 223.07465, 671.4, 3162790.0)
# (2, 'agmatine', 'C5H14N4', '+', 131.1292, 694.2, 82848.0)
# (2, 'Spermine', 'C10H26N4', '+', 203.22292, 660.6, 83041.0)
# (2, 'Choline', 'C5H13NO', '+', 104.10692, 915.0, 220669227.0)
# (2, '1-Aminopropan-2-ol', 'C3H9NO', '+', 76.07569, 938.4000000000001, 10069281.0)
# (2, 'L-Ornithine', 'C5H12N2O2', '+', 133.09711, 871.1999999999999, 27688528.0)
# (2, '5-Methoxytryptamine', 'C11H14N2O', '+', 191.11812, 389.40000000000003, 345956.0)
# (2, 'L-2_3-Diaminopropanoate', 'C3H8N2O2', '+', 105.06589, 654.6, 409019.0)
# (2, '1_3-Diaminopropane', 'C3H10N2', '+', 75.09167, 738.6, 13318.0)
# (3, 'Dihydrolipoamide', 'C8H17NOS2', '+', 208.08241, 277.8, 209470.0)
# (3, 'lipoamide', 'C8H15NOS2', '+', 206.06679, 294.0, 335437062.0)
# (3, '2-Aminobutan-4-olide', 'C4H7NO2', '+', 102.05494, 379.8, 128745378.0)
# (3, '2-hydroxyethyldisulfide', 'C4H10O2S2', '+', 155.0192, 402.6, 216825.0)
# (3, 'Isonicotinic acid', 'C6H5NO2', '+', 124.03926, 415.2, 1102801408.0)
# (3, 'L-cysteine', 'C3H7NO2S', '+', 122.02703, 612.6, 12799374.0)
# (3, 'L-Noradrenaline', 'C8H11NO3', '+', 170.0813, 457.8, 96950.0)
# (3, 'O-Acetylcarnitine', 'C9H17NO4', '+', 204.12289, 520.2, 2530268729.0)
# (3, 'O-Acetyl-L-serine', 'C5H9NO4', '+', 148.06027, 586.8, 34229806.0)
# (3, 'L-Homocysteine', 'C4H9NO2S', '+', 136.04271, 655.2, 8255562.0)
# (3, '5-Aminolevulinate', 'C5H9NO3', '+', 132.06534, 578.4000000000001, 427691986.0)
# (3, 'gamma-L-Glutamyl-L-cysteine', 'C8H14N2O5S', '+', 251.06941, 591.5999999999999, 39698196.0)
# (3, 'glutathione', 'C10H17N3O6S', '+', 308.09119, 592.8000000000001, 1590969.0)
# (3, 'Acetylcholine', 'C7H15NO2', '+', 146.11748, 754.2, 1215947874.0)
# (3, 'L-Cystine', 'C6H12N2O4S2', '+', 241.03101, 647.4, 9650940.0)
# (3, 'Mercaptoethanol', 'C2H6OS', '+', 79.02116, 1307.3999999999999, 39880590.0)
# (3, 'Glutathione disulfide', 'C20H32N6O12S2', '+', 613.15936, 655.2, 15392025.0)
# (3, 'Bis-gamma-glutamylcystine', 'C16H26N4O10S2', '+', 499.11624, 668.4000000000001, 7591751.0)

# %% [markdown]
# Find out the peak ids in our MS1 dataframe that match these standards

# %%
import math

mass_tol = 3
rt_tol = 12

std = np.array(std_peaks)
std_mz = np.array([x[4] for x in std_peaks])
std_rt = np.array([x[5] for x in std_peaks])
matches = {}

ms1_label = {}
for row in ms2lda.ms1.itertuples(index=True):
    peakid = row[1]
    mz = row[5]
    rt = row[4]

    # the following line is hacky for pos mode data
    mass_delta = mz*mass_tol*1e-6
    mass_start = mz-mass_delta
    mass_end = mz+mass_delta
    rt_start = rt-rt_tol
    rt_end = rt+rt_tol

    match_mass = (std_mz>mass_start) & (std_mz<mass_end)
    match_rt = (std_rt>rt_start) & (std_rt<rt_end)
    match = match_mass & match_rt

    res = std[match]
    if len(res) == 1:
        closest = tuple(res[0])
        matches[closest] = row
        ms1_label[row[1]] = closest[1]        
    elif len(res)>1:
        closest = None
        min_dist = sys.maxint
        for match_res in res:
            match_mz = float(match_res[4])
            match_rt = float(match_res[5])
            dist = math.sqrt((match_rt-rt)**2 + (match_mz-mz)**2)
            if dist < min_dist:
                min_dist = dist
                closest = match_res
        closest = tuple(closest)
        matches[closest] = row
        ms1_label[row[1]] = closest[1]

print "Matches found %d/%d" % (len(matches), len(std))
print

ms1_list = []
for match in matches:
    key = str(match)
    ms1_row = matches[match]
    value = str(ms1_row)
    pid = ms1_row[1]
    print "Standard %s" % key
    print "MS1 %s" % value
    print
    ms1_list.append(pid)
# Out:
# Matches found 45/117
#
# Standard ('3', 'O-Acetylcarnitine', 'C9H17NO4', '+', '204.12289', '520.2', '2530268729.0')
# MS1 Pandas(Index=10237, peakID=10237, MSnParentPeakID=0, msLevel=1, rt=518.50300000000004, mz=204.12305134669299, intensity=2407559.25, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C9H18O4N')
#
# Standard ('2', 'L-homoserine', 'C4H9NO3', '+', '120.06561', '637.8', '91565828.0')
# MS1 Pandas(Index=1003, peakID=1003, MSnParentPeakID=0, msLevel=1, rt=633.80399999999997, mz=120.065513905275, intensity=5077896.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C4H10O3N')
#
# Standard ('2', '5-Oxoproline', 'C5H7NO3', '+', '130.04996', '491.4', '210756304.0')
# MS1 Pandas(Index=1795, peakID=1795, MSnParentPeakID=0, msLevel=1, rt=484.00199999999995, mz=130.04989405333401, intensity=247324512.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C5H8O3N')
#
# Standard ('3', 'O-Acetyl-L-serine', 'C5H9NO4', '+', '148.06027', '586.8', '34229806.0')
# MS1 Pandas(Index=3970, peakID=3970, MSnParentPeakID=0, msLevel=1, rt=598.46900000000005, mz=148.06034209730601, intensity=6657020.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C5H10O4N')
#
# Standard ('1', 'Pyridoxine', 'C8H11NO3', '+', '170.0811', '435.6', '1744299213.0')
# MS1 Pandas(Index=6289, peakID=6289, MSnParentPeakID=0, msLevel=1, rt=433.34899999999999, mz=170.08113568683601, intensity=38320380.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C8H12O3N')
#
# Standard ('2', 'N(pi)-Methyl-L-histidine', 'C7H11N3O2', '+', '170.09233', '567.0', '336747680.0')
# MS1 Pandas(Index=6319, peakID=6319, MSnParentPeakID=0, msLevel=1, rt=558.49900000000002, mz=170.092377926247, intensity=3766961.75, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C7H12O2N3')
#
# Standard ('2', '6-Methylaminopurine', 'C6H7N5', '+', '150.07741', '438.0', '775948865.0')
# MS1 Pandas(Index=4121, peakID=4121, MSnParentPeakID=0, msLevel=1, rt=437.16500000000002, mz=150.077447046223, intensity=15326802.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C6H8N5')
#
# Standard ('2', 'L-Carnitine', 'C7H15NO3', '+', '162.1125', '589.8', '181991312.0')
# MS1 Pandas(Index=5456, peakID=5456, MSnParentPeakID=0, msLevel=1, rt=582.24800000000005, mz=162.11244671357599, intensity=7117894.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C7H16O3N')
#
# Standard ('1', 'L-Phenylalanine', 'C9H11NO2', '+', '166.0862', '499.8', '54983812.0')
# MS1 Pandas(Index=6001, peakID=6001, MSnParentPeakID=0, msLevel=1, rt=499.24099999999999, mz=166.08629754340501, intensity=15979306.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C9H12O2N')
#
# Standard ('1', 'L-Lysine', 'C6H14N2O2', '+', '147.11275', '927.6', '27170994.0')
# MS1 Pandas(Index=3912, peakID=3912, MSnParentPeakID=0, msLevel=1, rt=933.27499999999998, mz=147.11268581093699, intensity=1298433.75, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C6H15O2N2')
#
# Standard ('1', 'L-Aspartate', 'C4H7NO4', '+', '134.04468', '620.4', '3993775.0')
# MS1 Pandas(Index=2566, peakID=2566, MSnParentPeakID=0, msLevel=1, rt=614.625, mz=134.04472729268201, intensity=1106318.875, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C4H8O4N')
#
# Standard ('1', 'beta-Alanine', 'C3H7NO2', '+', '90.05495', '646.2', '42118740.0')
# MS1 Pandas(Index=131, peakID=131, MSnParentPeakID=0, msLevel=1, rt=645.03199999999993, mz=90.054941057094993, intensity=2888840.5, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C3H8O2N')
#
# Standard ('1', 'Guanine', 'C5H5N5O', '+', '152.05673', '589.8', '48549375.0')
# MS1 Pandas(Index=4307, peakID=4307, MSnParentPeakID=0, msLevel=1, rt=588.45900000000006, mz=152.05668981527901, intensity=165917856.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C5H14NS2')
#
# Standard ('1', 'L-Arginine', 'C6H14N4O2', '+', '175.11894', '996.0', '81114888.0')
# MS1 Pandas(Index=7005, peakID=7005, MSnParentPeakID=0, msLevel=1, rt=1002.67, mz=175.118924458717, intensity=42606024.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C6H15O2N4')
#
# Standard ('1', 'L-Tryptophan', 'C11H12N2O2', '+', '205.0972', '555.0', '85868328.0')
# MS1 Pandas(Index=10364, peakID=10364, MSnParentPeakID=0, msLevel=1, rt=553.52699999999993, mz=205.09717729569198, intensity=36771424.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C11H13O2N2')
#
# Standard ('2', 'Guanosine', 'C10H13N5O5', '+', '284.09857', '579.6', '1116780.0')
# MS1 Pandas(Index=21533, peakID=21533, MSnParentPeakID=0, msLevel=1, rt=582.24800000000005, mz=284.09880854382197, intensity=4361483.5, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C9H18O9N')
#
# Standard ('2', 'Pantothenate', 'C9H17NO5', '+', '220.11797', '442.8', '181716297.0')
# MS1 Pandas(Index=12206, peakID=12206, MSnParentPeakID=0, msLevel=1, rt=433.34899999999999, mz=220.11793988892501, intensity=4474088.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C9H18O5N')
#
# Standard ('1', 'L-Glutamine', 'C5H10N2O3', '+', '147.07628', '633.0', '196459361.0')
# MS1 Pandas(Index=3808, peakID=3808, MSnParentPeakID=0, msLevel=1, rt=628.81600000000003, mz=147.076372363237, intensity=28795256.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C5H11O3N2')
#
# Standard ('2', 'L-Ornithine', 'C5H12N2O2', '+', '133.09711', '871.2', '27688528.0')
# MS1 Pandas(Index=2538, peakID=2538, MSnParentPeakID=0, msLevel=1, rt=874.87300000000005, mz=133.09711927974502, intensity=31991762.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C5H13O2N2')
#
# Standard ('1', 'L-Leucine', 'C6H13NO2', '+', '132.10185', '520.8', '178751219.0')
# MS1 Pandas(Index=2403, peakID=2403, MSnParentPeakID=0, msLevel=1, rt=519.73900000000003, mz=132.101911929008, intensity=28418200.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C6H14O2N')
#
# Standard ('2', 'L-Cystathionine', 'C7H14N2O4S', '+', '223.07465', '671.4', '3162790.0')
# MS1 Pandas(Index=12421, peakID=12421, MSnParentPeakID=0, msLevel=1, rt=668.85300000000007, mz=223.074605013942, intensity=547783.8125, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C9H20PS2')
#
# Standard ('1', 'Glycine', 'C2H5NO2', '+', '76.03931', '658.8', '939664.0')
# MS1 Pandas(Index=19, peakID=19, MSnParentPeakID=0, msLevel=1, rt=656.24000000000001, mz=76.039316182226003, intensity=1047793.6875, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C2H6O2N')
#
# Standard ('2', '4-(beta-Acetylaminoethyl)imidazole', 'C7H11N3O', '+', '154.09747', '417.0', '1379768122.0')
# MS1 Pandas(Index=4608, peakID=4608, MSnParentPeakID=0, msLevel=1, rt=416.798, mz=154.09735505255199, intensity=2377199.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C7H12ON3')
#
# Standard ('2', 'Adenosine', 'C10H13N5O4', '+', '268.10388', '473.4', '345087256.0')
# MS1 Pandas(Index=18872, peakID=18872, MSnParentPeakID=0, msLevel=1, rt=469.70699999999999, mz=268.10389286728298, intensity=8295168.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C9H18O8N')
#
# Standard ('2', 'L-Alanine', 'C3H7NO2', '+', '90.055', '633.6', '5523150.0')
# MS1 Pandas(Index=141, peakID=141, MSnParentPeakID=0, msLevel=1, rt=631.31100000000004, mz=90.054972748587488, intensity=6755740.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C3H8O2N')
#
# Standard ('1', 'Cytidine', 'C9H13N3O5', '+', '244.09267', '561.6', '109541168.0')
# MS1 Pandas(Index=15724, peakID=15724, MSnParentPeakID=0, msLevel=1, rt=559.74199999999996, mz=244.09279817231601, intensity=19470474.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C11H19ONPS')
#
# Standard ('2', 'Nicotinamide', 'C6H6N2O', '+', '123.05511', '400.8', '685030490.0')
# MS1 Pandas(Index=1174, peakID=1174, MSnParentPeakID=0, msLevel=1, rt=411.61500000000001, mz=123.05520769021601, intensity=11639933.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C6H7ON2')
#
# Standard ('2', '4-Aminobutanoate', 'C4H9NO2', '+', '104.0705', '649.2', '146788884.0')
# MS1 Pandas(Index=288, peakID=288, MSnParentPeakID=0, msLevel=1, rt=646.27199999999993, mz=104.07054507208001, intensity=118432208.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C4H10O2N')
#
# Standard ('1', 'L-Histidine', 'C6H9N3O2', '+', '156.07669', '622.8', '135748481.0')
# MS1 Pandas(Index=4779, peakID=4779, MSnParentPeakID=0, msLevel=1, rt=621.07400000000007, mz=156.076766819657, intensity=110043960.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C6H10O2N3')
#
# Standard ('1', 'L-Proline', 'C5H9NO2', '+', '116.07052', '580.8', '551809540.0')
# MS1 Pandas(Index=789, peakID=789, MSnParentPeakID=0, msLevel=1, rt=577.26800000000003, mz=116.07054437949199, intensity=2079356160.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C5H10O2N')
#
# Standard ('2', 'Deoxyadenosine', 'C10H13N5O3', '+', '252.10889', '444.0', '454320908.0')
# MS1 Pandas(Index=16867, peakID=16867, MSnParentPeakID=0, msLevel=1, rt=439.64699999999999, mz=252.10891383095901, intensity=29635886.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C9H18O7N')
#
# Standard ('1', 'L-Citrulline', 'C6H13N3O3', '+', '176.10294', '656.4', '150086389.0')
# MS1 Pandas(Index=7113, peakID=7113, MSnParentPeakID=0, msLevel=1, rt=653.75800000000004, mz=176.102996289212, intensity=48279332.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C6H14O3N3')
#
# Standard ('2', "5'-Methylthioadenosine", 'C11H15N5O3S', '+', '298.09711', '389.4', '390153184.0')
# MS1 Pandas(Index=23395, peakID=23395, MSnParentPeakID=0, msLevel=1, rt=386.30800000000005, mz=298.09681976476702, intensity=2876561.75, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C10H20O7NS')
#
# Standard ('2', 'Betaine', 'C5H11NO2', '+', '118.0863', '534.6', '1013664457.0')
# MS1 Pandas(Index=932, peakID=932, MSnParentPeakID=0, msLevel=1, rt=531.05899999999997, mz=118.086198721751, intensity=1698129920.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C5H12O2N')
#
# Standard ('2', 'cytosine', 'C4H5N3O', '+', '112.05048', '552.6', '411004000.0')
# MS1 Pandas(Index=567, peakID=567, MSnParentPeakID=0, msLevel=1, rt=550.95800000000008, mz=112.050568008429, intensity=19761036.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C4H6ON3')
#
# Standard ('1', 'N-Acetyl-D-glucosamine', 'C8H15NO6', '+', '222.0972', '550.2', '40293668.0')
# MS1 Pandas(Index=12331, peakID=12331, MSnParentPeakID=0, msLevel=1, rt=547.23900000000003, mz=222.09723946990897, intensity=3724312.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C8H16O6N')
#
# Standard ('1', 'riboflavin', 'C17H20N4O6', '+', '377.14548', '452.4', '9255138.0')
# MS1 Pandas(Index=30635, peakID=30635, MSnParentPeakID=0, msLevel=1, rt=452.14400000000001, mz=377.14515211594704, intensity=1369326.125, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C13H27ON6P2S')
#
# Standard ('2', 'thymine', 'C5H6N2O2', '+', '127.05025', '421.8', '11481343.0')
# MS1 Pandas(Index=1414, peakID=1414, MSnParentPeakID=0, msLevel=1, rt=410.32599999999996, mz=127.05011856597099, intensity=40250532.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C5H7O2N2')
#
# Standard ('1', 'L-Asparagine', 'C4H8N2O3', '+', '133.06073', '638.4', '14474836.0')
# MS1 Pandas(Index=2511, peakID=2511, MSnParentPeakID=0, msLevel=1, rt=636.28899999999999, mz=133.06072884080299, intensity=25519770.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C4H9O3N2')
#
# Standard ('3', '5-Aminolevulinate', 'C5H9NO3', '+', '132.06534', '578.4', '427691986.0')
# MS1 Pandas(Index=2254, peakID=2254, MSnParentPeakID=0, msLevel=1, rt=567.28800000000001, mz=132.06546053496999, intensity=18472026.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C5H10O3N')
#
# Standard ('1', 'Adenine', 'C5H5N5', '+', '136.06174', '492.0', '167402201.0')
# MS1 Pandas(Index=2632, peakID=2632, MSnParentPeakID=0, msLevel=1, rt=495.51400000000001, mz=136.061800803691, intensity=599815168.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C5H6N5')
#
# Standard ('1', 'sn-glycero-3-Phosphocholine', 'C8H20NO6P', '+', '258.10983', '607.8', '600267181.0')
# MS1 Pandas(Index=17496, peakID=17496, MSnParentPeakID=0, msLevel=1, rt=604.70100000000002, mz=258.10986877630796, intensity=1099428992.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C11H20N3S2')
#
# Standard ('1', 'Nicotinate', 'C6H5NO2', '+', '124.03932', '412.2', '761863744.0')
# MS1 Pandas(Index=1226, peakID=1226, MSnParentPeakID=0, msLevel=1, rt=401.06900000000002, mz=124.039344637138, intensity=6944196.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C6H6O2N')
#
# Standard ('1', 'L-Methionine', 'C5H11NO2S', '+', '150.05827', '541.2', '237439616.0')
# MS1 Pandas(Index=4103, peakID=4103, MSnParentPeakID=0, msLevel=1, rt=539.755, mz=150.05839767528701, intensity=5108756.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C5H12O2NS')
#
# Standard ('2', 'Choline phosphate', 'C5H14NO4P', '+', '184.07321', '615.0', '983609153.0')
# MS1 Pandas(Index=7901, peakID=7901, MSnParentPeakID=0, msLevel=1, rt=615.86199999999997, mz=184.07328873010201, intensity=23100436.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C5H15O4NP')

# %%
m2m_list = motifs_of_interest
word_map, motif_words = ms2lda.print_motif_features(quiet=True)
for i in range(len(ms1_list)):
    
    ms1 = ms1_list[i]
    df = print_report(ms2lda, G, ms1, motif_annotation, motif_words, motif_colour, motif_idx, word_map, 
                      ms1_label=ms1_label, xlim_upper=300)
    display(df) # show the table to see the mz, annotations, etc
# Out:
#  - M2M_131	: fragments from [hexose-H2O] substructure (a hexose conjugation, e.g. glucose)
# 		  fragment_85.02832 (0.566),fragment_69.03368 (0.105),fragment_97.02839 (0.088),fragment_61.02854 (0.070),fragment_57.0337 (0.045),fragment_91.03925 (0.022),fragment_127.03868 (0.021),fragment_73.0285 (0.019),fragment_55.01824 (0.019),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0    85.028305       1.000000   fragment_85.02832             131
# 1   204.124115       0.269851  fragment_204.12411             NaN
# 2    60.081009       0.126211   fragment_60.08102             NaN
# 3   145.049988       0.084996  fragment_145.04997             NaN
# 4   158.080551       0.059581  fragment_158.08046             NaN
# 5    57.033707       0.038970    fragment_57.0337             131
# 6   140.070328       0.036045  fragment_140.07024             NaN
# 7    84.080688       0.029436   fragment_84.08071             NaN
# 8   112.075859       0.025067  fragment_112.07584             NaN
# 9    72.080780       0.024387    fragment_72.0807             NaN
# 10  144.101715       0.021775  fragment_144.10184             NaN
# 11   58.065495       0.019419   fragment_58.06552             NaN
# 12   55.054604       0.017157   fragment_55.05466             NaN
# 13   70.065086       0.016704   fragment_70.06514             NaN
# 14   98.059982       0.012066   fragment_98.06001             NaN
# 15  186.075699       0.010386  fragment_186.07581             NaN
#
#          loss_word  loss_motif                    ef
# 0   loss_119.09448         NaN  C4H5O2,loss_C5H13O2N
# 1              NaN         NaN              C10H14N5
# 2   loss_144.04202         NaN    C3H10N,loss_C6H8O4
# 3    loss_59.07313         NaN     C6H9O4,loss_C3H9N
# 4              NaN         NaN              C7H12O3N
# 5   loss_147.08937         NaN   C3H5O,loss_C6H13O3N
# 6    loss_64.05223         NaN              C7H10O2N
# 7   loss_120.04228         NaN    C5H10N,loss_C4H8O4
# 8    loss_92.04711         NaN   C6H10ON,loss_C3H8O3
# 9   loss_132.04207         NaN    C4H10N,loss_C5H8O4
# 10   loss_60.02094         NaN  C7H14O2N,loss_C2H4O2
# 11  loss_146.05771         NaN    C3H8N,loss_C6H10O4
# 12  loss_149.06869         NaN    C4H7,loss_C5H11O4N
# 13  loss_134.05766         NaN    C4H8N,loss_C5H10O4
# 14  loss_106.06374         NaN   C5H8ON,loss_C4H10O3
# 15   loss_18.04478         NaN              C8H12O4N
#  - M2M_262	: Combined loss of H2O and CO, suggests free carboxylic acid group (COOH) substructure
# 		  loss_46.00539 (0.854),loss_74.0003 (0.058),loss_47.0087 (0.017),fragment_100.11239 (0.016),
#        ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   74.060349       1.000000   fragment_74.06031             NaN
# 1   56.049747       0.386553   fragment_56.04977             NaN
# 2  102.091774       0.154149  fragment_102.09182             NaN
# 3  102.054504       0.144799   fragment_102.0547             NaN
# 4  120.101738       0.129224   fragment_120.1017             NaN
# 5   58.065491       0.079124   fragment_58.06552             NaN
# 6   57.034039       0.065922    fragment_57.0337             NaN
#
#        loss_word  loss_motif                 ef
# 0  loss_46.00539         262  C3H8ON,loss_CH2O2
# 1  loss_64.01595         NaN              C3H6N
# 2  loss_17.97339         NaN            C5H12ON
# 3  loss_18.00923         NaN            C4H8O2N
# 4            NaN         NaN           C5H14O2N
# 5  loss_62.00034         NaN              C3H8N
# 6  loss_63.03191         NaN  C3H5O,loss_CH5O2N
#  - M2M_174	: Pyroglutamic acid (pyroglutamate) substructure
# 		  fragment_84.0442 (0.854),fragment_56.04977 (0.102),
#  - M2M_262	: Combined loss of H2O and CO, suggests free carboxylic acid group (COOH) substructure
# 		  loss_46.00539 (0.854),loss_74.0003 (0.058),loss_47.0087 (0.017),fragment_100.11239 (0.016),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0    84.044189       1.000000    fragment_84.0442             174
# 1    56.049809       0.126340   fragment_56.04977             174
# 2   130.050613       0.080313  fragment_130.05051             NaN
# 3    53.002689       0.014785   fragment_53.00259             NaN
# 4   102.055672       0.002177  fragment_102.05568             NaN
# 5    84.896111       0.001458   fragment_84.89611             NaN
# 6    72.818222       0.001417   fragment_72.81822             NaN
# 7    64.463036       0.001337   fragment_64.46304             NaN
# 8   113.690063       0.001295  fragment_113.69006             NaN
# 9   103.106133       0.001274  fragment_103.10613             NaN
# 10   53.997986       0.001267   fragment_53.99797             NaN
#
#         loss_word  loss_motif                 ef
# 0   loss_46.00539         262  C4H6ON,loss_CH2O2
# 1    loss_74.0003         262  C3H6N,loss_C2H2O3
# 2             NaN         NaN            C5H8O3N
# 3   loss_77.04757         NaN  C3HO,loss_C2H7O2N
# 4   loss_27.99401         NaN                NaN
# 5             NaN         NaN                NaN
# 6             NaN         NaN                NaN
# 7             NaN         NaN                NaN
# 8             NaN         NaN                NaN
# 9             NaN         NaN                NaN
# 10  loss_76.05234         NaN        loss_C3H8O2
#  - M2M_174	: Pyroglutamic acid (pyroglutamate) substructure
# 		  fragment_84.0442 (0.854),fragment_56.04977 (0.102),
#        ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   84.044144       1.000000    fragment_84.0442             174
# 1   56.049824       0.178829   fragment_56.04977             174
# 2  102.054649       0.164297   fragment_102.0547             NaN
# 3  130.050461       0.112925  fragment_130.05051             NaN
# 4   85.028168       0.023997   fragment_85.02832             NaN
# 5  148.060303       0.023909  fragment_148.06033             NaN
# 6  112.075813       0.017748  fragment_112.07584             NaN
#
#        loss_word  loss_motif                  ef
# 0  loss_64.01595         NaN              C4H6ON
# 1  loss_92.01076         NaN   C3H6N,loss_C2H4O4
# 2  loss_46.00539         NaN  C4H8O2N,loss_CH2O2
# 3  loss_18.00923         NaN             C5H8O3N
# 4  loss_63.03191         NaN  C4H5O2,loss_CH5O2N
# 5            NaN         NaN            C5H10O4N
# 6   loss_35.9844         NaN             C6H10ON
#  - M2M_260	: Water loss - indicative of a free hydroxyl group
# 		  loss_18.00923 (0.942),fragment_176.09136 (0.015),
#  - M2M_60	: Double water loss - indicative for metabolites containing multiple OH groups and aliphatic chain, e.g. as in sugars
# 		  loss_36.01851 (0.913),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   152.070267       1.000000  fragment_152.07028             NaN
# 1   134.060013       0.982310  fragment_134.06003             NaN
# 2   109.052605       0.287127  fragment_109.05264             NaN
# 3   170.081390       0.222130   fragment_170.0813             NaN
# 4    79.054184       0.152112   fragment_79.05416             NaN
# 5    53.038906       0.107635   fragment_53.03888             NaN
# 6   106.064941       0.093034  fragment_106.06503             NaN
# 7    80.049446       0.081468   fragment_80.04949             NaN
# 8   124.075218       0.080897  fragment_124.07522             NaN
# 9   110.059799       0.046957  fragment_110.05978             NaN
# 10   81.057632       0.046283   fragment_81.05752             NaN
# 11  122.060219       0.038623  fragment_122.06027             NaN
# 12  123.068169       0.029166  fragment_123.06823             NaN
# 13   96.080650       0.026297   fragment_96.08074             NaN
# 14   94.064896       0.026292   fragment_94.06475             NaN
# 15   81.033249       0.025268   fragment_81.03334             NaN
# 16   96.044098       0.021545   fragment_96.04413             NaN
# 17   95.049316       0.020170   fragment_95.04936             NaN
# 18   65.038734       0.018286   fragment_65.03878             NaN
# 19   82.064934       0.013194   fragment_82.06499             NaN
# 20  108.044212       0.013110  fragment_108.04425             NaN
# 21   51.023357       0.012271   fragment_51.02338             NaN
# 22  170.095993       0.011173  fragment_170.09598             NaN
# 23   67.041481       0.007798   fragment_67.04148             NaN
# 24  105.044617       0.005681  fragment_105.04464             NaN
# 25  107.048782       0.005436  fragment_107.04883             NaN
# 26   84.044113       0.005200    fragment_84.0442             NaN
# 27   93.057014       0.004370   fragment_93.05717             NaN
# 28   68.049225       0.004027   fragment_68.04924             NaN
#
#          loss_word  loss_motif                  ef
# 0    loss_18.00923         260           C2H11ON5P
# 1    loss_36.01851          60              C8H8ON
# 2    loss_61.02852         NaN           C2H10ON2P
# 3              NaN         NaN            C8H12O3N
# 4     loss_91.0268         NaN   C6H7,loss_C2H5O3N
# 5   loss_117.04227         NaN   C4H5,loss_C4H7O3N
# 6    loss_64.01595         NaN               C7H8N
# 7    loss_90.03155         NaN   C5H6N,loss_C3H6O3
# 8    loss_46.00539         NaN  C7H10ON,loss_CH2O2
# 9    loss_60.02094         NaN  C6H8ON,loss_C2H4O2
# 10   loss_89.02361         NaN                 NaN
# 11   loss_48.02104         NaN   C7H8ON,loss_CH4O2
# 12   loss_47.01308         NaN           C3H12ON2P
# 13    loss_74.0003         NaN  C6H10N,loss_C2H2O3
# 14    loss_76.0159         NaN   C6H8N,loss_C2H4O3
# 15   loss_89.04752         NaN  C5H5O,loss_C3H7O2N
# 16   loss_74.03681         NaN  C5H6ON,loss_C3H6O2
# 17   loss_75.03184         NaN  C6H7O,loss_C2H5O2N
# 18  loss_105.04255         NaN   C5H5,loss_C3H7O3N
# 19   loss_88.01588         NaN   C5H8N,loss_C3H4O3
# 20   loss_62.03678         NaN  C6H6ON,loss_C2H6O2
# 21  loss_119.05812         NaN   C4H3,loss_C4H9O3N
# 22             NaN         NaN             C12H12N
# 23  loss_103.03876         NaN       loss_C2H5O2N3
# 24             NaN         NaN              C6H5N2
# 25   loss_63.03191         NaN   C7H7O,loss_CH5O2N
# 26   loss_86.03669         NaN  C4H6ON,loss_C4H6O2
# 27   loss_77.02433         NaN            C2H10N2P
# 28  loss_102.03159         NaN   C4H6N,loss_C4H6O3
#  - M2M_40	: Imidazole group linked to a carboxylgroup through one CH2 group substructure
# 		  fragment_83.06041 (0.433),fragment_129.06581 (0.130),fragment_56.04977 (0.073),fragment_230.15978 (0.045),loss_132.09749 (0.022),fragment_257.12534 (0.012),
#  - M2M_262	: Combined loss of H2O and CO, suggests free carboxylic acid group (COOH) substructure
# 		  loss_46.00539 (0.854),loss_74.0003 (0.058),loss_47.0087 (0.017),fragment_100.11239 (0.016),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   124.087044       1.000000  fragment_124.08698             NaN
# 1    96.068291       0.749972   fragment_96.06827             NaN
# 2   170.091705       0.548146  fragment_170.09171             NaN
# 3   109.076538       0.400958  fragment_109.07636             NaN
# 4    83.060471       0.343872   fragment_83.06041              40
# 5    95.060829       0.300049   fragment_95.06076             NaN
# 6    97.076408       0.204232   fragment_97.07643             NaN
# 7    56.049877       0.134257   fragment_56.04977              40
# 8    81.045074       0.128215   fragment_81.04501             NaN
# 9    68.049881       0.097533   fragment_68.04977             NaN
# 10  125.071114       0.082813  fragment_125.07093             NaN
# 11  126.102783       0.047084  fragment_126.10278             NaN
# 12   93.057968       0.043759   fragment_93.05793             NaN
#
#          loss_word  loss_motif                   ef
# 0    loss_46.00539         262   C6H10N3,loss_CH2O2
# 1    loss_74.02423         NaN                  NaN
# 2              NaN         NaN            C7H12O2N3
# 3    loss_61.01619         NaN   C6H9N2,loss_CH3O2N
# 4    loss_87.03196         NaN  C4H7N2,loss_C3H5O2N
# 5    loss_75.03184         NaN  C5H7N2,loss_C2H5O2N
# 6    loss_73.01611         NaN  C5H9N2,loss_C2H3O2N
# 7   loss_114.04263         NaN  C3H6N,loss_C4H6O2N2
# 8    loss_89.04752         NaN  C4H5N2,loss_C3H7O2N
# 9   loss_102.04259         NaN  C4H6N,loss_C3H6O2N2
# 10   loss_45.02125         NaN   C6H9ON2,loss_CH3ON
# 11   loss_43.98989         NaN     C6H12N3,loss_CO2
# 12             NaN         NaN             C2H10N2P
#  - No M2M for this MS1 peak at the specified thresholding levels
# None
#  - M2M_131	: fragments from [hexose-H2O] substructure (a hexose conjugation, e.g. glucose)
# 		  fragment_85.02832 (0.566),fragment_69.03368 (0.105),fragment_97.02839 (0.088),fragment_61.02854 (0.070),fragment_57.0337 (0.045),fragment_91.03925 (0.022),fragment_127.03868 (0.021),fragment_73.0285 (0.019),fragment_55.01824 (0.019),
#        ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0  162.112808       1.000000  fragment_162.11281             NaN
# 1  103.038605       0.439828  fragment_103.03863             NaN
# 2   60.081043       0.429422   fragment_60.08102             NaN
# 3   85.028313       0.304272   fragment_85.02832             131
# 4  102.091858       0.200151  fragment_102.09182             NaN
# 5   58.065536       0.084210   fragment_58.06552             NaN
# 6   57.033707       0.064344    fragment_57.0337             131
# 7   59.073090       0.041019   fragment_59.07323             NaN
# 8  144.080505       0.007790  fragment_144.08061             NaN
#
#         loss_word  loss_motif                   ef
# 0             NaN         NaN             C7H16O3N
# 1   loss_59.07393         NaN    C4H7O3,loss_C3H9N
# 2  loss_102.03159         NaN   C3H10N,loss_C4H6O3
# 3   loss_77.08387         NaN               C4H5O2
# 4   loss_60.02094         NaN  C5H12ON,loss_C2H4O2
# 5  loss_104.04718         NaN    C3H8N,loss_C4H8O3
# 6  loss_105.07881         NaN  C3H5O,loss_C4H11O2N
# 7  loss_103.03876         NaN        loss_C2H5O2N3
# 8             NaN         NaN              C10H10N
#  - M2M_115	: [phenylalanine-COOH] substructure
# 		  fragment_120.0804 (0.513),fragment_103.05448 (0.153),fragment_166.08631 (0.070),loss_45.99208 (0.048),fragment_93.06981 (0.020),fragment_91.05413 (0.020),fragment_53.03888 (0.018),
#  - M2M_262	: Combined loss of H2O and CO, suggests free carboxylic acid group (COOH) substructure
# 		  loss_46.00539 (0.854),loss_74.0003 (0.058),loss_47.0087 (0.017),fragment_100.11239 (0.016),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   120.080345       1.000000   fragment_120.0804             115
# 1   166.072067       0.382615  fragment_166.07209             NaN
# 2   103.054443       0.367646  fragment_103.05448             115
# 3   167.056732       0.118901  fragment_167.05677             NaN
# 4   124.050262       0.073254  fragment_124.05026             NaN
# 5   149.045929       0.063575  fragment_149.04599             NaN
# 6    79.054192       0.053536   fragment_79.05416             NaN
# 7    91.054077       0.050550   fragment_91.05413             115
# 8    93.069763       0.049533   fragment_93.06981             115
# 9    53.038937       0.048328   fragment_53.03888             115
# 10  166.086319       0.029295  fragment_166.08631             115
# 11  142.061386       0.020962  fragment_142.06139             NaN
# 12   69.044449       0.019122   fragment_69.04449             NaN
# 13  131.049286       0.018264  fragment_131.04941             NaN
# 14  107.048706       0.017898  fragment_107.04883             NaN
# 15  107.024628       0.016960  fragment_107.02463             NaN
# 16  153.040878       0.016297  fragment_153.04074             NaN
# 17   67.029068       0.016126   fragment_67.02909             NaN
# 18   55.029484       0.014523   fragment_55.02948             NaN
# 19   79.028801       0.013314    fragment_79.0288             NaN
# 20   95.049324       0.011344   fragment_95.04936             NaN
# 21  118.065414       0.009839  fragment_118.06544             NaN
# 22   96.055717       0.009409   fragment_96.05573             NaN
# 23  121.064857       0.008631  fragment_121.06489             NaN
# 24   94.039642       0.007669    fragment_94.0397             NaN
# 25   51.023361       0.004367   fragment_51.02338             NaN
# 26  121.050964       0.004047    fragment_121.051             NaN
# 27  119.073311       0.003982  fragment_119.07334             NaN
# 28  124.059410       0.003824  fragment_124.05943             NaN
# 29  102.046829       0.003639  fragment_102.04684             NaN
# 30  149.058167       0.003573  fragment_149.05817             NaN
# 31  128.045486       0.003303  fragment_128.04551             NaN
# 32  123.066643       0.002809  fragment_123.06667             NaN
# 33  110.034538       0.002667  fragment_110.03458             NaN
# 34  109.051498       0.002424  fragment_109.05152             NaN
# 35  110.145195       0.002182   fragment_110.1452             NaN
# 36  184.230927       0.002054  fragment_184.23093             NaN
# 37  105.044632       0.002029  fragment_105.04464             NaN
# 38   64.564743       0.001948   fragment_64.56474             NaN
# 39   80.024323       0.001908   fragment_80.02432             NaN
# 40  108.209518       0.001781  fragment_108.20952             NaN
# 41   80.218918       0.001753   fragment_80.21892             NaN
# 42   51.266205       0.001713    fragment_51.2662             NaN
#
#          loss_word  loss_motif                 ef
# 0    loss_46.00539         262  C8H10N,loss_CH2O2
# 1              NaN         NaN           C6H16NS2
# 2    loss_63.03191         NaN   C8H7,loss_CH5O2N
# 3              NaN         NaN           C6H7O2N4
# 4              NaN         NaN            C5H6ON3
# 5     loss_17.0403         NaN            C6H13S2
# 6    loss_87.03196         NaN  C6H7,loss_C3H5O2N
# 7    loss_75.03184         NaN  C7H7,loss_C2H5O2N
# 8    loss_73.01611         NaN  C7H9,loss_C2H3O2N
# 9   loss_113.04742         NaN  C4H5,loss_C5H7O2N
# 10             NaN         NaN           C9H12O2N
# 11             NaN         NaN           C5H8O2N3
# 12             NaN         NaN             C3H5N2
# 13   loss_35.03689         NaN              C9H7O
# 14     loss_59.037         NaN  C7H7O,loss_C2H5ON
# 15             NaN         NaN                NaN
# 16             NaN         NaN           C5H13OS2
# 17             NaN         NaN             C3H3N2
# 18             NaN         NaN             C2H3N2
# 19             NaN         NaN             C4H3N2
# 20   loss_71.03691         NaN  C6H7O,loss_C3H5ON
# 21   loss_48.02104         NaN   C8H8N,loss_CH4O2
# 22             NaN         NaN             C4H6N3
# 23   loss_45.02125         NaN   C8H9O,loss_CH3ON
# 24    loss_72.0457         NaN             C4H4N3
# 25  loss_115.06303         NaN  C4H3,loss_C5H9O2N
# 26             NaN         NaN             C5H5N4
# 27   loss_47.01308         NaN           C4H12N2P
# 28             NaN         NaN                NaN
# 29             NaN         NaN             C4H9NP
# 30   loss_17.02527         NaN          C3H10ON4P
# 31             NaN         NaN           C4H6O2N3
# 32             NaN         NaN             C5H7N4
# 33             NaN         NaN            C4H4ON3
# 34             NaN         NaN                NaN
# 35             NaN         NaN                NaN
# 36             NaN         NaN                NaN
# 37             NaN         NaN             C6H5N2
# 38             NaN         NaN                NaN
# 39             NaN         NaN             C3H2N3
# 40             NaN         NaN                NaN
# 41             NaN         NaN                NaN
# 42             NaN         NaN                NaN
#  - M2M_45	: Pipecolic acid (pipecolate) substructure
# 		  fragment_84.08071 (0.757),fragment_56.04977 (0.059),fragment_130.08587 (0.059),loss_91.06316 (0.022),fragment_67.05454 (0.015),
#        ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   84.080612       1.000000   fragment_84.08071              45
# 1  130.087036       0.150856  fragment_130.08705             NaN
# 2   56.049725       0.094670   fragment_56.04977              45
# 3   64.927513       0.083763   fragment_64.92754             NaN
# 4  123.965050       0.074708  fragment_123.96513             NaN
# 5   70.065063       0.046102   fragment_70.06514             NaN
# 6   67.054482       0.036039   fragment_67.05454              45
#
#        loss_word  loss_motif                  ef
# 0  loss_63.03191         NaN  C5H10N,loss_CH5O2N
# 1  loss_17.02527         NaN                 NaN
# 2  loss_91.06316          45  C3H6N,loss_C3H9O2N
# 3            NaN         NaN                 NaN
# 4            NaN         NaN                 NaN
# 5  loss_77.04757         NaN  C4H8N,loss_C2H7O2N
# 6            NaN         NaN                C5H7
#  - M2M_280	: Loss possibly indicative of carboxylic acid group with 1-carbon attached
# 		  loss_60.02094 (0.741),loss_106.02643 (0.053),fragment_158.11806 (0.052),
#  - M2M_42	: Asparagine substructure
# 		  fragment_74.02353 (0.251),fragment_88.03919 (0.220),fragment_87.05542 (0.078),fragment_133.06148 (0.077),fragment_70.02895 (0.038),fragment_158.04483 (0.034),fragment_60.04477 (0.020),fragment_116.0344 (0.019),loss_101.04757 (0.016),fragment_175.12257 (0.015),loss_188.07979 (0.012),fragment_88.0218 (0.010),
#  - M2M_262	: Combined loss of H2O and CO, suggests free carboxylic acid group (COOH) substructure
# 		  loss_46.00539 (0.854),loss_74.0003 (0.058),loss_47.0087 (0.017),fragment_100.11239 (0.016),
#       ms2_mz  ms2_intensity      fragment_word  fragment_motif      loss_word  \
# 0  74.023651       1.000000  fragment_74.02353              42  loss_60.02094
# 1  88.039185       0.501179  fragment_88.03919              42  loss_46.00539
# 2  88.075974       0.169731  fragment_88.07588             NaN  loss_45.96902
# 3  58.065617       0.124050  fragment_58.06552             NaN            NaN
# 4  70.065109       0.059535  fragment_70.06514             NaN  loss_63.97936
#
#    loss_motif                   ef
# 0         280  C2H4O2N,loss_C2H4O2
# 1         262   C3H6O2N,loss_CH2O2
# 2         NaN              C4H10ON
# 3         NaN                C3H8N
# 4         NaN        C4H8N,loss_O4
#  - M2M_260	: Water loss - indicative of a free hydroxyl group
# 		  loss_18.00923 (0.942),fragment_176.09136 (0.015),
#       ms2_mz  ms2_intensity      fragment_word  fragment_motif      loss_word  \
# 0  90.055382       1.000000  fragment_90.05533             NaN            NaN
# 1  72.044762       0.737399  fragment_72.04466             NaN  loss_18.00923
# 2  72.080750       0.521527   fragment_72.0807             NaN  loss_17.97339
# 3  90.091835       0.194263  fragment_90.09183             NaN            NaN
# 4  73.084145       0.191845  fragment_73.08418             NaN            NaN
# 5  61.028442       0.153448  fragment_61.02854             NaN  loss_29.02613
#
#    loss_motif                ef
# 0         NaN           C3H8O2N
# 1         260            C3H6ON
# 2         NaN            C4H10N
# 3         NaN               NaN
# 4         NaN               NaN
# 5         NaN  C2H5O2,loss_CH3N
#  - M2M_162	: Xanthine substructure
# 		  fragment_152.05609 (0.327),fragment_153.04074 (0.126),loss_115.06303 (0.067),loss_151.04878 (0.045),fragment_110.03458 (0.040),fragment_135.02953 (0.036),loss_116.06671 (0.031),loss_197.05414 (0.020),fragment_128.04551 (0.020),fragment_314.11224 (0.016),loss_114.07908 (0.016),
#  - M2M_214	: Amine loss - suggests free NH2 group in fragmented molecule
# 		  loss_17.02527 (0.883),fragment_366.10831 (0.021),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   152.056046       1.000000  fragment_152.05609             162
# 1   153.040680       0.496599  fragment_153.04074             162
# 2   110.034615       0.241523  fragment_110.03458             162
# 3   135.029663       0.214475  fragment_135.02953             162
# 4   128.045486       0.097583  fragment_128.04551             162
# 5    55.029549       0.065586   fragment_55.02948             NaN
# 6    80.024315       0.040756   fragment_80.02432             NaN
# 7    82.040253       0.036542   fragment_82.04025             NaN
# 8   107.035301       0.032890   fragment_107.0353             NaN
# 9   134.046738       0.023744  fragment_134.04671             NaN
# 10  109.050453       0.023515  fragment_109.05053             NaN
# 11   93.008537       0.018903   fragment_93.00853             NaN
# 12   65.013390       0.006373   fragment_65.01338             NaN
# 13  154.025894       0.006288  fragment_154.02586             NaN
# 14  136.012741       0.005379  fragment_136.01274             NaN
# 15  171.815414       0.004537  fragment_171.81541             NaN
# 16  139.108246       0.003830  fragment_139.10825             NaN
# 17  113.438583       0.003613  fragment_113.43858             NaN
# 18   60.828163       0.003543   fragment_60.82816             NaN
# 19   68.013062       0.003506   fragment_68.01311             NaN
# 20   80.492226       0.003428   fragment_80.49223             NaN
# 21   96.144203       0.003406    fragment_96.1442             NaN
# 22   56.773869       0.003141   fragment_56.77387             NaN
#
#         loss_word  loss_motif                   ef
# 0             NaN         NaN             C4H10O5N
# 1             NaN         NaN             C5H13OS2
# 2   loss_42.02193         NaN   C4H4ON3,loss_CH2N2
# 3   loss_17.02527         214              C5H11S2
# 4             NaN         NaN             C4H6O2N3
# 5             NaN         NaN               C2H3N2
# 6   loss_72.03221         NaN  C3H2N3,loss_C2H4ON2
# 7   loss_70.01648         NaN  C3H4N3,loss_C2H2ON2
# 8   loss_45.02125         NaN    C4H3N4,loss_CH3ON
# 9   loss_18.00923         NaN               C5H4N5
# 10  loss_43.00571         NaN     C4H5N4,loss_CHON
# 11  loss_59.04824         NaN    C4HON2,loss_CH5N3
# 12  loss_87.04293         NaN   C3HN2,loss_C2H5ON3
# 13            NaN         NaN             C3H9O4NP
# 14            NaN         NaN                  NaN
# 15            NaN         NaN                  NaN
# 16            NaN         NaN                  NaN
# 17            NaN         NaN                  NaN
# 18            NaN         NaN                  NaN
# 19            NaN         NaN               C3H2ON
# 20            NaN         NaN                  NaN
# 21            NaN         NaN                  NaN
# 22            NaN         NaN                  NaN
#  - M2M_2	: Small nitrogen containing fragment ion - often proline or ornithine derived
# 		  fragment_70.06514 (0.979),
#  - M2M_151	: [proline-H2O] suggests conjugated proline substructure
# 		  fragment_116.07116 (0.473),loss_143.05783 (0.166),loss_161.06841 (0.128),loss_115.06303 (0.101),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0    70.065071       1.000000   fragment_70.06514               2
# 1    60.055779       0.250707   fragment_60.05587             NaN
# 2   175.119873       0.240603  fragment_175.12007             NaN
# 3   116.071106       0.154991  fragment_116.07116             151
# 4   130.096909       0.064236  fragment_130.09701             NaN
# 5   158.091492       0.054776  fragment_158.09177             NaN
# 6    71.049438       0.022285   fragment_71.04937             NaN
# 7    72.080750       0.021085    fragment_72.0807             NaN
# 8   112.087013       0.020357  fragment_112.08704             NaN
# 9   157.108337       0.014321  fragment_157.10838             NaN
# 10   98.059944       0.003659   fragment_98.06001             NaN
# 11   68.049210       0.003171   fragment_68.04924             NaN
# 12   97.075478       0.003143   fragment_97.07555             NaN
# 13   74.023460       0.003107   fragment_74.02353             NaN
# 14   76.973976       0.003024   fragment_76.97398             NaN
# 15  141.064438       0.002980  fragment_141.06444             NaN
# 16   88.075821       0.002934   fragment_88.07588             NaN
# 17  138.387360       0.002818  fragment_138.38736             NaN
# 18  143.067230       0.002756  fragment_143.06763             NaN
# 19  102.802864       0.002746  fragment_102.80286             NaN
# 20  109.705719       0.002533  fragment_109.70572             NaN
# 21   54.438702       0.002171    fragment_54.4387             NaN
# 22   61.387680       0.002162   fragment_61.38768             NaN
#
#          loss_word  loss_motif                    ef
# 0    loss_105.0541         NaN   C4H8N,loss_C2H7O2N3
# 1   loss_115.06303         151    CH6N3,loss_C5H9O2N
# 2              NaN         NaN                   NaN
# 3    loss_59.04824         NaN   C5H10O2N,loss_CH5N3
# 4    loss_45.02195         NaN              C5H12ON3
# 5    loss_17.02527         NaN             C6H12O2N3
# 6              NaN         NaN                 C4H7O
# 7   loss_103.03876         NaN  C4H10N,loss_C2H5O2N3
# 8    loss_63.03191         NaN   C5H10N3,loss_CH5O2N
# 9    loss_18.00923         NaN              C6H13ON4
# 10   loss_77.05878         NaN                C5H8ON
# 11  loss_107.06986         NaN   C4H6N,loss_C2H9O2N3
# 12   loss_78.04263         NaN                C5H9N2
# 13             NaN         NaN               C2H4O2N
# 14             NaN         NaN                   NaN
# 15             NaN         NaN               H10ON6P
# 16   loss_87.04293         NaN  C4H10ON,loss_C2H5ON3
# 17             NaN         NaN                   NaN
# 18             NaN         NaN               C3H7ON6
# 19             NaN         NaN                   NaN
# 20             NaN         NaN                   NaN
# 21             NaN         NaN                   NaN
# 22             NaN         NaN                   NaN
#  - M2M_202	: Tryptophan related substructure
# 		  fragment_118.06544 (0.155),fragment_146.05935 (0.129),fragment_188.07061 (0.106),fragment_130.06468 (0.061),fragment_91.05413 (0.049),fragment_146.06086 (0.046),fragment_115.05435 (0.045),fragment_144.08061 (0.034),fragment_143.07379 (0.033),fragment_117.05719 (0.032),fragment_261.09335 (0.027),fragment_170.06037 (0.026),fragment_132.08143 (0.023),fragment_128.04963 (0.018),fragment_142.06476 (0.014),
#  - M2M_211	: N-acetylputrescine substructure
# 		  loss_59.037 (0.567),fragment_114.09123 (0.097),loss_101.04757 (0.042),loss_59.00065 (0.030),fragment_131.11777 (0.029),fragment_425.1355 (0.029),fragment_72.04466 (0.023),fragment_60.04477 (0.014),
#  - M2M_214	: Amine loss - suggests free NH2 group in fragmented molecule
# 		  loss_17.02527 (0.883),fragment_366.10831 (0.021),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   188.070572       1.000000  fragment_188.07061             202
# 1   118.065468       0.910780  fragment_118.06544             202
# 2   146.059402       0.658810  fragment_146.05935             202
# 3    91.054146       0.296194   fragment_91.05413             202
# 4   115.054367       0.268003  fragment_115.05435             202
# 5   143.073792       0.204197  fragment_143.07379             202
# 6   144.080597       0.196105  fragment_144.08061             202
# 7   117.057220       0.174524  fragment_117.05719             202
# 8   132.081421       0.148421  fragment_132.08143             202
# 9   142.064621       0.107717  fragment_142.06476             202
# 10  159.092072       0.093365  fragment_159.09194             NaN
# 11  130.064926       0.092998  fragment_130.06468             202
# 12  170.060287       0.079957  fragment_170.06037             202
# 13  117.070213       0.049186  fragment_117.07032             NaN
# 14  116.061714       0.029525  fragment_116.06168             NaN
# 15  103.054504       0.025196  fragment_103.05448             NaN
# 16   65.038757       0.018240   fragment_65.03878             NaN
# 17  144.044510       0.011550  fragment_144.04451             NaN
# 18   74.023506       0.011242   fragment_74.02353             NaN
# 19  128.049652       0.010137  fragment_128.04963             202
# 20  160.074738       0.009748  fragment_160.07487             NaN
# 21  105.070190       0.008810  fragment_105.07019             NaN
# 22  140.049820       0.006626  fragment_140.04987             NaN
# 23   53.038822       0.006565   fragment_53.03888             NaN
# 24  194.995819       0.005492  fragment_194.99582             NaN
# 25  131.073608       0.004939  fragment_131.07361             NaN
# 26  116.049858       0.004885  fragment_116.04983             NaN
# 27   94.437073       0.004633   fragment_94.43707             NaN
# 28   90.046448       0.004632   fragment_90.04643             NaN
# 29   71.331963       0.004574   fragment_71.33196             NaN
# 30  200.874496       0.004374   fragment_200.8745             NaN
# 31   62.521790       0.004293   fragment_62.52179             NaN
# 32   97.889832       0.004228   fragment_97.88983             NaN
# 33   55.876587       0.003906   fragment_55.87659             NaN
#
#          loss_word  loss_motif                   ef
# 0    loss_17.02527         214            C11H10O2N
# 1    loss_87.03196         NaN   C8H8N,loss_C3H5O2N
# 2      loss_59.037         211  C3H9N5P,loss_C2H5ON
# 3   loss_114.04263         NaN   C7H7,loss_C4H6O2N2
# 4    loss_90.04283         NaN   C9H7,loss_C2H6O2N2
# 5              NaN         NaN             C6H12N2P
# 6    loss_61.01619         NaN  C10H10N,loss_CH3O2N
# 7              NaN         NaN             C4H10N2P
# 8    loss_73.01611         NaN  C9H10N,loss_C2H3O2N
# 9    loss_63.03191         NaN   C10H8N,loss_CH5O2N
# 10   loss_46.00539         NaN  C10H11N2,loss_CH2O2
# 11   loss_75.03184         NaN   C9H8N,loss_C2H5O2N
# 12   loss_35.03689         NaN              C11H8ON
# 13   loss_88.02701         NaN   C9H9,loss_C2H4O2N2
# 14             NaN         NaN                  NaN
# 15  loss_102.04259         NaN   C8H7,loss_C3H6O2N2
# 16  loss_140.05793         NaN     C5H5,loss_H9ON6P
# 17   loss_61.05259         NaN   C9H6ON,loss_C2H7ON
# 18             NaN         NaN              C2H4O2N
# 19   loss_77.04757         NaN   C9H6N,loss_C2H7O2N
# 20             NaN         NaN             C4H11N5P
# 21  loss_100.02691         NaN   C8H9,loss_C3H4O2N2
# 22   loss_65.04759         NaN               C10H6N
# 23   loss_152.0579         NaN   C4H5,loss_C7H8O2N2
# 24             NaN         NaN            C7H4O3N2P
# 25   loss_74.02423         NaN             C5H12N2P
# 26   loss_89.04752         NaN   C8H6N,loss_C3H7O2N
# 27             NaN         NaN                  NaN
# 28             NaN         NaN               C3H9NP
# 29             NaN         NaN                  NaN
# 30             NaN         NaN                  NaN
# 31             NaN         NaN                  NaN
# 32             NaN         NaN                  NaN
# 33             NaN         NaN                  NaN
#  - M2M_162	: Xanthine substructure
# 		  fragment_152.05609 (0.327),fragment_153.04074 (0.126),loss_115.06303 (0.067),loss_151.04878 (0.045),fragment_110.03458 (0.040),fragment_135.02953 (0.036),loss_116.06671 (0.031),loss_197.05414 (0.020),fragment_128.04551 (0.020),fragment_314.11224 (0.016),loss_114.07908 (0.016),
#  - M2M_156	: [Pentose-H2O] loss, e.g. ribose
# 		  loss_132.04207 (0.683),loss_160.03691 (0.038),loss_149.06869 (0.037),fragment_102.06629 (0.030),loss_131.05794 (0.018),fragment_74.07118 (0.011),
#        ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0  152.055969       1.000000  fragment_152.05609             162
# 1  153.040634       0.319968  fragment_153.04074             162
# 2  135.029434       0.093066  fragment_135.02953             162
# 3  110.034515       0.090369  fragment_110.03458             162
# 4  128.045425       0.060353  fragment_128.04551             162
# 5   55.029404       0.021476   fragment_55.02948             NaN
#
#         loss_word  loss_motif                      ef
# 0  loss_132.04207         156    C4H10O5N,loss_C5H8O4
# 1  loss_131.05794         156   C5H13OS2,loss_C5H9O3N
# 2  loss_149.06869         156   C5H11S2,loss_C5H11O4N
# 3  loss_174.06386         NaN  C4H4ON3,loss_C6H10O4N2
# 4  loss_156.05307         NaN  C4H6O2N3,loss_C6H8O3N2
# 5             NaN         NaN                  C2H3N2
#  - No M2M for this MS1 peak at the specified thresholding levels
# None
#  - M2M_174	: Pyroglutamic acid (pyroglutamate) substructure
# 		  fragment_84.0442 (0.854),fragment_56.04977 (0.102),
#  - M2M_214	: Amine loss - suggests free NH2 group in fragmented molecule
# 		  loss_17.02527 (0.883),fragment_366.10831 (0.021),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0    84.044151       1.000000    fragment_84.0442             174
# 1   130.050446       0.335520  fragment_130.05051             NaN
# 2    56.049801       0.139607   fragment_56.04977             174
# 3    64.927521       0.071353   fragment_64.92754             NaN
# 4   123.963799       0.044999  fragment_123.96388             NaN
# 5   101.071007       0.030830  fragment_101.07126             NaN
# 6    85.028343       0.024785   fragment_85.02832             NaN
# 7   102.054558       0.024073   fragment_102.0547             NaN
# 8   147.075653       0.016963  fragment_147.07588             NaN
# 9    69.033623       0.016051   fragment_69.03368             NaN
# 10   70.065094       0.013340   fragment_70.06514             NaN
# 11   53.002563       0.010966   fragment_53.00259             NaN
# 12   58.065479       0.009929   fragment_58.06552             NaN
#
#         loss_word  loss_motif                  ef
# 0   loss_63.03191         NaN  C4H6ON,loss_CH5O2N
# 1   loss_17.02527         214             C5H8O3N
# 2    loss_91.0268         NaN  C3H6N,loss_C2H5O3N
# 3             NaN         NaN                 NaN
# 4             NaN         NaN             H2ON3S2
# 5   loss_46.00539         NaN  C4H9ON2,loss_CH2O2
# 6   loss_62.04775         NaN              C4H5O2
# 7   loss_45.02195         NaN             C4H8O2N
# 8             NaN         NaN           C5H11O3N2
# 9   loss_78.04263         NaN               C4H5O
# 10            NaN         NaN               C4H8N
# 11            NaN         NaN                C3HO
# 12  loss_89.01112         NaN  C3H8N,loss_C2H3O3N
#  - M2M_2	: Small nitrogen containing fragment ion - often proline or ornithine derived
# 		  fragment_70.06514 (0.979),
#  - M2M_214	: Amine loss - suggests free NH2 group in fragmented molecule
# 		  loss_17.02527 (0.883),fragment_366.10831 (0.021),
#  - M2M_151	: [proline-H2O] suggests conjugated proline substructure
# 		  fragment_116.07116 (0.473),loss_143.05783 (0.166),loss_161.06841 (0.128),loss_115.06303 (0.101),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0    70.065086       1.000000   fragment_70.06514               2
# 1   116.071007       0.165084  fragment_116.07116             151
# 2   115.086891       0.021284  fragment_115.08708             NaN
# 3    68.049767       0.003609   fragment_68.04977             NaN
# 4   133.097900       0.003367  fragment_133.09777             NaN
# 5    99.635223       0.002193   fragment_99.63522             NaN
# 6    92.026001       0.001910   fragment_92.02608             NaN
# 7   149.608582       0.001810  fragment_149.60858             NaN
# 8    77.039375       0.001747   fragment_77.03938             NaN
# 9   103.854904       0.001698  fragment_103.85492             NaN
# 10   82.870430       0.001568   fragment_82.87043             NaN
# 11   75.048897       0.001450    fragment_75.0489             NaN
# 12   51.809437       0.001383   fragment_51.80944             NaN
#
#         loss_word  loss_motif                 ef
# 0   loss_63.03191         NaN  C4H8N,loss_CH5O2N
# 1   loss_17.02527         214           C5H10O2N
# 2   loss_18.00923         NaN           C5H11ON2
# 3   loss_65.04759         NaN              C4H6N
# 4             NaN         NaN          C5H13O2N2
# 5             NaN         NaN                NaN
# 6             NaN         NaN            C2H7ONP
# 7             NaN         NaN                NaN
# 8             NaN         NaN                NaN
# 9             NaN         NaN                NaN
# 10            NaN         NaN                NaN
# 11            NaN         NaN                NaN
# 12            NaN         NaN                NaN
#  - M2M_158	: Leucine substructure
# 		  fragment_86.09652 (0.794),fragment_132.10154 (0.048),fragment_219.90121 (0.031),fragment_293.3515 (0.031),fragment_189.12428 (0.012),
#  - M2M_262	: Combined loss of H2O and CO, suggests free carboxylic acid group (COOH) substructure
# 		  loss_46.00539 (0.854),loss_74.0003 (0.058),loss_47.0087 (0.017),fragment_100.11239 (0.016),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0    86.096466       1.000000   fragment_86.09652             158
# 1   132.113068       0.084116    fragment_132.113             NaN
# 2   132.101547       0.074076  fragment_132.10154             158
# 3    55.054707       0.066982   fragment_55.05466             NaN
# 4    73.064720       0.055327   fragment_73.06466             NaN
# 5    60.055786       0.042801   fragment_60.05587             NaN
# 6    58.065479       0.040572   fragment_58.06552             NaN
# 7    69.070091       0.031471   fragment_69.07013             NaN
# 8    90.091843       0.028321   fragment_90.09183             NaN
# 9    59.073456       0.023820   fragment_59.07323             NaN
# 10   53.002563       0.009728   fragment_53.00259             NaN
# 11  106.384842       0.006672  fragment_106.38484             NaN
# 12   81.473747       0.006641   fragment_81.47375             NaN
# 13  101.251724       0.006321  fragment_101.25172             NaN
# 14  120.109093       0.005949  fragment_120.10909             NaN
# 15   54.204807       0.005425   fragment_54.20481             NaN
# 16   60.025780       0.005421   fragment_60.02578             NaN
# 17   63.693363       0.005059   fragment_63.69336             NaN
# 18   55.552742       0.005014   fragment_55.55274             NaN
#
#         loss_word  loss_motif                 ef
# 0   loss_46.00539         262  C5H12N,loss_CH2O2
# 1             NaN         NaN           C5H14ON3
# 2             NaN         NaN           C6H14O2N
# 3   loss_77.04757         NaN  C4H7,loss_C2H7O2N
# 4     loss_59.037         NaN  C4H9O,loss_C2H5ON
# 5    loss_72.0457         NaN              CH6N3
# 6    loss_74.0361         NaN  C3H8N,loss_C3H6O2
# 7   loss_63.03191         NaN   C5H9,loss_CH5O2N
# 8   loss_42.01003         NaN                NaN
# 9   loss_73.02871         NaN                NaN
# 10            NaN         NaN               C3HO
# 11            NaN         NaN                NaN
# 12            NaN         NaN                NaN
# 13            NaN         NaN                NaN
# 14            NaN         NaN                NaN
# 15            NaN         NaN                NaN
# 16            NaN         NaN                NaN
# 17            NaN         NaN                NaN
# 18            NaN         NaN                NaN
#  - No M2M for this MS1 peak at the specified thresholding levels
# None
#  - M2M_184	: Trimethylated amine connected to a carboxylic acid group substructure (e.g. betaine)
# 		  fragment_58.06552 (0.377),fragment_119.08937 (0.158),fragment_59.07323 (0.093),fragment_120.09034 (0.067),fragment_59.06877 (0.035),fragment_173.04168 (0.034),fragment_60.07657 (0.024),loss_59.01322 (0.021),fragment_76.07561 (0.011),
#       ms2_mz  ms2_intensity      fragment_word  fragment_motif      loss_word  \
# 0  58.065552       1.000000  fragment_58.06552             184  loss_17.97339
# 1  76.039101       0.415062  fragment_76.03918             NaN            NaN
# 2  76.075615       0.138594  fragment_76.07561             184            NaN
# 3  59.073471       0.135910  fragment_59.07323             184            NaN
#
#    loss_motif       ef
# 0         NaN    C3H8N
# 1         NaN  C2H6O2N
# 2         NaN  C3H10ON
# 3         NaN      NaN
#  - M2M_17	: Tyrosine substructure
# 		  fragment_136.07599 (0.256),fragment_182.08217 (0.092),fragment_123.04467 (0.058),fragment_165.05388 (0.050),fragment_160.90206 (0.048),fragment_119.04874 (0.042),fragment_102.0547 (0.032),fragment_95.04936 (0.026),fragment_247.1084 (0.022),fragment_161.0686 (0.019),fragment_119.04991 (0.018),fragment_165.05578 (0.017),fragment_154.08575 (0.017),loss_170.06884 (0.016),
#  - M2M_91	: Aromatic substructure, i.e., benzene ring with hydroxyl and amine substitution
# 		  fragment_108.04425 (0.249),fragment_80.04949 (0.111),fragment_53.03888 (0.099),fragment_126.05563 (0.090),loss_55.00558 (0.051),loss_58.00534 (0.042),fragment_55.01824 (0.028),loss_41.02668 (0.026),loss_60.04021 (0.026),loss_23.01523 (0.024),fragment_75.02734 (0.023),fragment_68.01311 (0.016),loss_86.00034 (0.015),loss_40.03137 (0.014),loss_101.01104 (0.013),fragment_88.05865 (0.011),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   136.076019       1.000000  fragment_136.07599              17
# 1   154.085831       0.355231  fragment_154.08575              17
# 2   108.080521       0.137766  fragment_108.08051             NaN
# 3    95.060814       0.117705   fragment_95.06076             NaN
# 4    93.057152       0.079216   fragment_93.05717             NaN
# 5   126.055809       0.078980  fragment_126.05563              91
# 6   154.049515       0.072335  fragment_154.04951             NaN
# 7    80.049583       0.063680   fragment_80.04949              91
# 8   108.044281       0.060566  fragment_108.04425              91
# 9    91.054314       0.055083   fragment_91.05413             NaN
# 10  118.065483       0.039079  fragment_118.06544             NaN
# 11   65.038780       0.037238   fragment_65.03878             NaN
# 12   79.054176       0.036300   fragment_79.05416             NaN
# 13   53.038837       0.035840   fragment_53.03888              91
# 14   81.070023       0.034085   fragment_81.07001             NaN
# 15   81.033340       0.031971   fragment_81.03334             NaN
# 16  134.060043       0.031116  fragment_134.06003             NaN
# 17  109.052650       0.030317  fragment_109.05264             NaN
# 18   68.049805       0.029967   fragment_68.04977             NaN
# 19  111.032112       0.029473  fragment_111.03205             NaN
#
#         loss_word  loss_motif                  ef
# 0             NaN         NaN             C8H10ON
# 1             NaN         NaN            C8H12O2N
# 2   loss_46.01667         NaN   C7H10N,loss_H2ON2
# 3     loss_59.037         NaN  C5H7N2,loss_C2H5ON
# 4             NaN         NaN            C2H10N2P
# 5             NaN         NaN                 NaN
# 6             NaN         NaN             C7H8O3N
# 7   loss_74.04767         NaN  C5H6N,loss_C2H6ON2
# 8    loss_46.0529         NaN              C6H6ON
# 9             NaN         NaN                C7H7
# 10  loss_36.03224         NaN               C8H8N
# 11   loss_89.0597         NaN   C5H5,loss_C2H7ON3
# 12            NaN         NaN                C6H7
# 13            NaN         NaN                C4H5
# 14            NaN         NaN                C6H9
# 15            NaN         NaN               C5H5O
# 16            NaN         NaN              C8H8ON
# 17  loss_45.04397         NaN           C2H10ON2P
# 18  loss_86.04753         NaN  C4H6N,loss_C3H6ON2
# 19            NaN         NaN                 NaN
#  - M2M_220	: Adenine substructure
# 		  fragment_136.06239 (0.688),loss_162.03528 (0.049),fragment_119.03518 (0.039),loss_153.04184 (0.027),fragment_137.04626 (0.020),
#  - M2M_156	: [Pentose-H2O] loss, e.g. ribose
# ...
# 10   81.052696       0.013493   fragment_81.05269             NaN
# 11   54.042419       0.012241   fragment_54.04244             NaN
# 12   84.039764       0.010303   fragment_84.03976             NaN
# 13   56.047333       0.006504   fragment_56.04734             NaN
# 14   68.013069       0.006269   fragment_68.01311             NaN
# 15  137.184769       0.006156  fragment_137.18477             NaN
# 16  100.629395       0.006116  fragment_100.62939             NaN
# 17   81.034012       0.006083   fragment_81.03402             NaN
# 18  137.145157       0.005776  fragment_137.14516             NaN
# 19  118.602737       0.005736  fragment_118.60274             NaN
# 20   94.733734       0.005564   fragment_94.73373             NaN
# 21   71.936928       0.005450   fragment_71.93693             NaN
# 22  104.030846       0.005372  fragment_104.03085             NaN
# 23   79.703476       0.005366   fragment_79.70348             NaN
#
#         loss_word  loss_motif                  ef
# 0             NaN         NaN                 NaN
# 1   loss_17.02527         214             C5H4O2N
# 2             NaN         NaN                 NaN
# 3   loss_18.00923         NaN             C5H5ON2
# 4   loss_43.00571         NaN    C4H6ON,loss_CHON
# 5   loss_73.01611         NaN  C3H4N,loss_C2H3O2N
# 6   loss_71.00026         NaN   C3H6N,loss_C2HO2N
# 7   loss_45.02125         NaN   C4H4ON,loss_CH3ON
# 8             NaN         NaN              C7H11S
# 9   loss_46.00539         NaN   C4H5N2,loss_CH2O2
# 10            NaN         NaN                 NaN
# 11            NaN         NaN                 NaN
# 12            NaN         NaN                 NaN
# 13            NaN         NaN                 NaN
# 14    loss_59.037         NaN  C3H2ON,loss_C2H5ON
# 15            NaN         NaN                 NaN
# 16            NaN         NaN                 NaN
# 17  loss_46.01667         NaN          loss_H2ON2
# 18            NaN         NaN                 NaN
# 19            NaN         NaN                 NaN
# 20            NaN         NaN                 NaN
# 21            NaN         NaN                 NaN
# 22            NaN         NaN                 NaN
# 23            NaN         NaN                 NaN
#  - M2M_42	: Asparagine substructure
# 		  fragment_74.02353 (0.251),fragment_88.03919 (0.220),fragment_87.05542 (0.078),fragment_133.06148 (0.077),fragment_70.02895 (0.038),fragment_158.04483 (0.034),fragment_60.04477 (0.020),fragment_116.0344 (0.019),loss_101.04757 (0.016),fragment_175.12257 (0.015),loss_188.07979 (0.012),fragment_88.0218 (0.010),
#  - M2M_211	: N-acetylputrescine substructure
# 		  loss_59.037 (0.567),fragment_114.09123 (0.097),loss_101.04757 (0.042),loss_59.00065 (0.030),fragment_131.11777 (0.029),fragment_425.1355 (0.029),fragment_72.04466 (0.023),fragment_60.04477 (0.014),
#  - M2M_262	: Combined loss of H2O and CO, suggests free carboxylic acid group (COOH) substructure
# 		  loss_46.00539 (0.854),loss_74.0003 (0.058),loss_47.0087 (0.017),fragment_100.11239 (0.016),
#        ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   74.023499       1.000000   fragment_74.02353              42
# 1   87.055374       0.327113   fragment_87.05542              42
# 2   88.038925       0.098559   fragment_88.03919              42
# 3  116.034180       0.071379   fragment_116.0344              42
# 4   70.028931       0.066063   fragment_70.02895              42
# 5  133.061234       0.048098  fragment_133.06148              42
#
#        loss_word  loss_motif                   ef
# 0    loss_59.037         211  C2H4O2N,loss_C2H5ON
# 1  loss_46.00539         262   C3H7ON2,loss_CH2O2
# 2  loss_45.02195         NaN              C3H6O2N
# 3  loss_17.02527         NaN              C4H6O3N
# 4  loss_63.03191         NaN   C3H4ON,loss_CH5O2N
# 5            NaN         NaN                  NaN
#  - M2M_260	: Water loss - indicative of a free hydroxyl group
# 		  loss_18.00923 (0.942),fragment_176.09136 (0.015),
#  - M2M_262	: Combined loss of H2O and CO, suggests free carboxylic acid group (COOH) substructure
# 		  loss_46.00539 (0.854),loss_74.0003 (0.058),loss_47.0087 (0.017),fragment_100.11239 (0.016),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0    86.060158       1.000000   fragment_86.06016             NaN
# 1   114.055367       0.485371   fragment_114.0554             NaN
# 2    55.018311       0.367145   fragment_55.01824             NaN
# 3    68.049873       0.218850   fragment_68.04977             NaN
# 4    53.038918       0.091089   fragment_53.03888             NaN
# 5    84.080666       0.088259   fragment_84.08071             NaN
# 6    73.028572       0.083616    fragment_73.0285             NaN
# 7    72.044762       0.058873   fragment_72.04466             NaN
# 8    96.044235       0.058463   fragment_96.04413             NaN
# 9    87.044022       0.051343   fragment_87.04391             NaN
# 10   69.033615       0.045783   fragment_69.03368             NaN
# 11  132.065521       0.040975  fragment_132.06554             NaN
# 12  132.112686       0.039251    fragment_132.113             NaN
# 13   60.044785       0.031613   fragment_60.04477             NaN
# 14   56.049778       0.025660   fragment_56.04977             NaN
# 15   73.065140       0.024119   fragment_73.06514             NaN
# 16   55.054615       0.022698   fragment_55.05466             NaN
# 17   97.028389       0.021554   fragment_97.02839             NaN
# 18  115.039131       0.020063  fragment_115.03913             NaN
# 19  132.091476       0.017816  fragment_132.09148             NaN
# 20   60.055794       0.016446   fragment_60.05587             NaN
# 21   85.084114       0.015942   fragment_85.08406             NaN
# 22   53.002571       0.012902   fragment_53.00259             NaN
# 23   90.091042       0.008465   fragment_90.09115             NaN
# 24   72.080658       0.007664    fragment_72.0807             NaN
# 25   54.034126       0.007574   fragment_54.03418             NaN
# 26  132.102997       0.007117    fragment_132.103             NaN
# 27   53.041389       0.006908   fragment_53.04139             NaN
# 28   73.084160       0.006310   fragment_73.08418             NaN
# 29   53.036625       0.005392   fragment_53.03662             NaN
# 30   58.028992       0.004209   fragment_58.02903             NaN
# 31   66.203384       0.003282   fragment_66.20338             NaN
# 32   71.049385       0.003184   fragment_71.04937             NaN
# 33   58.852303       0.003051    fragment_58.8523             NaN
# 34   67.267517       0.002949   fragment_67.26752             NaN
#
#         loss_word  loss_motif                  ef
# 0   loss_46.00539         262   C4H8ON,loss_CH2O2
# 1   loss_18.00923         260             C5H8O2N
# 2   loss_77.04757         NaN  C3H3O,loss_C2H7O2N
# 3   loss_64.01595         NaN               C4H6N
# 4   loss_79.02659         NaN                C4H5
# 5             NaN         NaN              C5H10N
# 6     loss_59.037         NaN  C3H5O2,loss_C2H5ON
# 7   loss_60.02094         NaN  C3H6ON,loss_C2H4O2
# 8   loss_36.01851         NaN              C5H6ON
# 9   loss_45.02125         NaN   C4H7O2,loss_CH3ON
# 10  loss_63.03191         NaN   C4H5O,loss_CH5O2N
# 11            NaN         NaN            C5H10O3N
# 12            NaN         NaN            C5H14ON3
# 13  loss_72.02092         NaN  C2H6ON,loss_C3H4O2
# 14   loss_76.0159         NaN   C3H6N,loss_C2H4O3
# 15  loss_59.00065         NaN    C4H9O,loss_CHO2N
# 16            NaN         NaN                C4H7
# 17  loss_35.03689         NaN              C5H5O2
# 18  loss_17.02527         NaN              C5H7O3
# 19            NaN         NaN                 NaN
# 20  loss_72.00912         NaN               CH6N3
# 21            NaN         NaN                 NaN
# 22  loss_79.06303         NaN                C3HO
# 23  loss_41.97401         NaN             C4H12ON
# 24  loss_59.98468         NaN              C4H10N
# 25  loss_78.03166         NaN   C3H4N,loss_C2H6O3
# 26            NaN         NaN                 NaN
# 27            NaN         NaN                 NaN
# 28            NaN         NaN                 NaN
# 29            NaN         NaN                 NaN
# 30  loss_74.03681         NaN  C2H4ON,loss_C3H6O2
# 31            NaN         NaN                 NaN
# 32  loss_61.01619         NaN   C4H7O,loss_CH3O2N
# 33            NaN         NaN                 NaN
# 34            NaN         NaN                 NaN
#  - M2M_220	: Adenine substructure
# 		  fragment_136.06239 (0.688),loss_162.03528 (0.049),fragment_119.03518 (0.039),loss_153.04184 (0.027),fragment_137.04626 (0.020),
#  - M2M_214	: Amine loss - suggests free NH2 group in fragmented molecule
# 		  loss_17.02527 (0.883),fragment_366.10831 (0.021),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   136.062347       1.000000  fragment_136.06239             220
# 1   119.035172       0.225609  fragment_119.03518             220
# 2   137.046173       0.096550  fragment_137.04626             220
# 3    92.024361       0.055838   fragment_92.02437             NaN
# 4    94.039642       0.036475    fragment_94.0397             NaN
# 5    67.029083       0.027608   fragment_67.02909             NaN
# 6   109.050591       0.014141  fragment_109.05053             NaN
# 7    55.029427       0.007642   fragment_55.02948             NaN
# 8    82.040268       0.007133   fragment_82.04025             NaN
# 9    77.013100       0.002313    fragment_77.0131             NaN
# 10   65.013374       0.002166   fragment_65.01338             NaN
# 11   53.997967       0.002028   fragment_53.99797             NaN
# 12  101.648109       0.001928  fragment_101.64811             NaN
# 13   78.658287       0.001866   fragment_78.65829             NaN
# 14   88.676323       0.001770   fragment_88.67632             NaN
# 15   70.917763       0.001740   fragment_70.91776             NaN
# 16   52.421421       0.001598   fragment_52.42142             NaN
#
#         loss_word  loss_motif                  ef
# 0             NaN         NaN              C5H6N5
# 1   loss_17.02527         214              C5H3N4
# 2             NaN         NaN             C5H5ON4
# 3   loss_44.03726         NaN   C4H2N3,loss_CH4N2
# 4   loss_42.02193         NaN   C4H4N3,loss_CH2N2
# 5             NaN         NaN              C3H3N2
# 6   loss_27.01101         NaN     C4H5N4,loss_CHN
# 7             NaN         NaN              C2H3N2
# 8   loss_54.02177         NaN  C3H4N3,loss_C2H2N2
# 9   loss_59.04824         NaN    C4HN2,loss_CH5N3
# 10  loss_71.04827         NaN   C3HN2,loss_C2H5N3
# 11  loss_82.06337         NaN                 NaN
# 12            NaN         NaN                 NaN
# 13            NaN         NaN                 NaN
# 14            NaN         NaN                 NaN
# 15            NaN         NaN                 NaN
# 16            NaN         NaN                 NaN
#  - No M2M for this MS1 peak at the specified thresholding levels
# None
#  - No M2M for this MS1 peak at the specified thresholding levels
# None
#  - M2M_214	: Amine loss - suggests free NH2 group in fragmented molecule
# 		  loss_17.02527 (0.883),fragment_366.10831 (0.021),
#  - M2M_262	: Combined loss of H2O and CO, suggests free carboxylic acid group (COOH) substructure
# 		  loss_46.00539 (0.854),loss_74.0003 (0.058),loss_47.0087 (0.017),fragment_100.11239 (0.016),
#        ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   56.049782       1.000000   fragment_56.04977             NaN
# 1   61.010868       0.946880   fragment_61.01086             NaN
# 2  104.052925       0.451922  fragment_104.05303             NaN
# 3  133.032288       0.311158   fragment_133.0324             NaN
# 4   87.026382       0.120967   fragment_87.02618             NaN
# 5  102.054794       0.114947   fragment_102.0547             NaN
# 6  150.057434       0.063206  fragment_150.05743             NaN
# 7   74.023499       0.063097   fragment_74.02353             NaN
# 8   74.059761       0.057672   fragment_74.05984             NaN
#
#        loss_word  loss_motif                  ef
# 0            NaN         NaN               C3H6N
# 1  loss_89.04752         NaN  C2H5S,loss_C3H7O2N
# 2  loss_46.00539         262  C4H10NS,loss_CH2O2
# 3  loss_17.02527         214             C5H9O2S
# 4  loss_63.03191         NaN   C4H7S,loss_CH5O2N
# 5            NaN         NaN             C4H8O2N
# 6            NaN         NaN                 NaN
# 7  loss_76.03519         NaN  C2H4O2N,loss_C3H8S
# 8            NaN         NaN              C3H8ON
#  - M2M_243	: Conjugation of a phosphate group (H4O4P) substructure
# 		  fragment_98.98385 (0.736),loss_56.02612 (0.030),fragment_127.01561 (0.019),fragment_173.02023 (0.018),fragment_261.03653 (0.011),
#  - M2M_158	: Leucine substructure
# 		  fragment_86.09652 (0.794),fragment_132.10154 (0.048),fragment_219.90121 (0.031),fragment_293.3515 (0.031),fragment_189.12428 (0.012),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   184.072342       1.000000  fragment_184.07228             NaN
# 1    86.096565       0.893794   fragment_86.09652             158
# 2    98.983879       0.699893   fragment_98.98385             243
# 3   124.999321       0.659842  fragment_124.99931             NaN
# 4    71.073318       0.354179   fragment_71.07325             NaN
# 5    60.081051       0.175230   fragment_60.08102             NaN
# 6    56.049843       0.075443   fragment_56.04977             NaN
# 7   104.107635       0.053037  fragment_104.10738             NaN
# 8    58.065556       0.052027   fragment_58.06552             NaN
# 9    70.036751       0.026254   fragment_70.03679             NaN
# 10   69.033638       0.020120   fragment_69.03368             NaN
# 11  116.994728       0.009399  fragment_116.99469             NaN
# 12   70.065109       0.009082   fragment_70.06514             NaN
# 13  143.010544       0.008545  fragment_143.01054             NaN
# 14   59.073036       0.007534   fragment_59.07323             NaN
# 15   84.052193       0.006525   fragment_84.05219             NaN
# 16   56.047333       0.004727   fragment_56.04734             NaN
# 17   82.208298       0.004389    fragment_82.2083             NaN
# 18   84.633331       0.004357   fragment_84.63333             NaN
# 19  113.073921       0.004090  fragment_113.07392             NaN
# 20   67.242935       0.003877   fragment_67.24294             NaN
# 21   58.586426       0.003639   fragment_58.58643             NaN
# 22   66.483749       0.003221   fragment_66.48375             NaN
#
#         loss_word  loss_motif                  ef
# 0             NaN         NaN           C7H10O3N3
# 1             NaN         NaN              C5H12N
# 2   loss_85.08945         NaN   H4O4P,loss_C5H11N
# 3   loss_59.07393         NaN  C2H6O4P,loss_C3H9N
# 4             NaN         NaN                 NaN
# 5             NaN         NaN              C3H10N
# 6             NaN         NaN               C3H6N
# 7             NaN         NaN             C5H14ON
# 8             NaN         NaN               C3H8N
# 9             NaN         NaN                 NaN
# 10            NaN         NaN               C4H5O
# 11            NaN         NaN                 NaN
# 12            NaN         NaN               C4H8N
# 13            NaN         NaN             C2H8O5P
# 14            NaN         NaN                 NaN
# 15  loss_100.0212         NaN                 NaN
# 16            NaN         NaN                 NaN
# 17            NaN         NaN                 NaN
# 18            NaN         NaN                 NaN
# 19  loss_71.00026         NaN         loss_C2HO2N
# 20            NaN         NaN                 NaN
# 21            NaN         NaN                 NaN
# 22            NaN         NaN                 NaN
