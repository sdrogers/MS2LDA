# %% [markdown]
# Cross-validation results
# ==============

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
basedir = '../'
sys.path.append(basedir)

from lda_for_fragments import Ms2Lda
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
import sys
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Beer3Pos
# ---------

# %% [markdown]
# Cross-validation results for alpha = 50/K, beta = 0.1

# %%
df = pd.read_csv('../cv_results/beer3pos.is/results.csv', sep=',|=', header=None)
df = df.sort([1])

# %%
ks = df.ix[:, 1]
mean_margs = df.ix[:, 3]
mean_perplexities = df.ix[:, 5]

plt.figure()
plt.subplot(1, 2, 1)
plt.xticks(rotation=90)
plt.plot(np.array(ks), np.array(mean_margs))
plt.grid()
plt.xlabel('K')
plt.ylabel('Log evidence')
plt.title('Log evidence')

plt.subplot(1, 2, 2)
plt.xticks(rotation=90)
plt.plot(np.array(ks), np.array(mean_perplexities))
plt.grid()
plt.xlabel('K')
plt.ylabel('Perplexity')
plt.title('Perplexity')

plt.suptitle('CV Results', fontsize=15)
plt.subplots_adjust(wspace=0.5)
plt.show()

# %% [markdown]
# Urine37Pos
# -----------

# %% [markdown]
# Cross-validation results for alpha = 50/K, beta = 0.1

# %%
df = pd.read_csv('../cv_results/urine37pos.is/results.csv', sep=',|=', header=None)
df = df.sort([1])

# %%
ks = df.ix[:, 1]
mean_margs = df.ix[:, 3]
mean_perplexities = df.ix[:, 5]

plt.figure()
plt.subplot(1, 2, 1)
plt.xticks(rotation=90)
plt.plot(np.array(ks), np.array(mean_margs))
plt.grid()
plt.xlabel('K')
plt.ylabel('Log evidence')
plt.title('Log evidence')

plt.subplot(1, 2, 2)
plt.xticks(rotation=90)
plt.plot(np.array(ks), np.array(mean_perplexities))
plt.grid()
plt.xlabel('K')
plt.ylabel('Perplexity')
plt.title('Perplexity')

plt.suptitle('CV Results', fontsize=15)
plt.subplots_adjust(wspace=0.5)
plt.show()
