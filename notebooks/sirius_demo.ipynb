# %% [markdown]
# <h1>In-silico fragmentation annotation with SIRIUS<h/1>

# %% [markdown]
# SIRIUS is an in-silico fragmentation tool written in Java, which can be found at http://bio.informatik.uni-jena.de/software/sirius/.
#
# In this notebook, we write a wrapper script to call sirius, passing it our MS1 and MS2 dataframes (before input to LDA). The results from this is another column ('annotation') in the dataframes, produced from running in-silico fragmentation using SIRIUS.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import sys
basedir = '../'
sys.path.append(basedir)

from IPython.display import display
import pandas as pd
import visualisation.sirius.sirius_wrapper as sir

# %% [markdown]
# <h2>Load ms1 and ms2 dataframes</h2>

# %%
ms1_filename = '../input/final/Beer_3_full1_5_2E5_pos_ms1.csv'
ms1 = pd.read_csv(ms1_filename, index_col=0)

# %%
ms2_filename = '../input/final/Beer_3_full1_5_2E5_pos_ms2.csv'
ms2 = pd.read_csv(ms2_filename, index_col=0)

# %% [markdown]
# <h2>Run sirius on the ms1 & ms2 dataframes</h2>
#
# Annotation is performed in SIRIUS for each MS1 peak using its child MS2 patterns. We set SIRIUS not to use the isotopic pattern information (which is not available, since we don't know what the isotopic peaks to the MS1 peak are, although we can try to find them out).

# %%
sirius_exec = '/home/joewandy/linux64/sirius' # path to the executable

# %%
# this will probably run 1000x times faster if we directly call the appropriate methods in the SIRIUS class,
# rather than the current way of create temp input file, which is then passed to SIRIUS through a subprocess 
annot_ms1, annot_ms2 = sir.annotate_sirius(ms1, ms2, sirius_exec, sirius_platform='orbitrap', verbose=False)
# Out:
# Annotating parent peakID=1, mass=70.0651651321, intensity=16431632.0, no. of fragments=2
# Annotating parent peakID=4, mass=70.065190596, intensity=602081.6875, no. of fragments=1
# Annotating parent peakID=6, mass=72.0807993876, intensity=1067314.75, no. of fragments=4
#  - 4 fragments annotated
# Annotating parent peakID=11, mass=72.0808183493, intensity=1025769.125, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=14, mass=73.0647880231, intensity=925079.4375, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=17, mass=76.0393161822, intensity=1047793.6875, no. of fragments=2
# Annotating parent peakID=20, mass=76.0756988501, intensity=1636355.75, no. of fragments=3
#  - 1 fragments annotated
# Annotating parent peakID=26, mass=81.0335144645, intensity=766053.0, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=29, mass=83.0602445276, intensity=705789.625, no. of fragments=3
#  - 3 fragments annotated
# Annotating parent peakID=33, mass=84.0443749596, intensity=2827970.75, no. of fragments=3
#  - 3 fragments annotated
# Annotating parent peakID=37, mass=84.080711141, intensity=978819.375, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=40, mass=85.0283720521, intensity=3757659.5, no. of fragments=1
# Annotating parent peakID=42, mass=85.0283772743, intensity=1687362.875, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=45, mass=85.0283813659, intensity=2102897.0, no. of fragments=4
#  - 2 fragments annotated
# Annotating parent peakID=52, mass=86.0599619264, intensity=1211292.75, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=55, mass=86.0600076184, intensity=8953359.0, no. of fragments=3
#  - 3 fragments annotated
# Annotating parent peakID=59, mass=86.0600237507, intensity=1433368.625, no. of fragments=1
# Annotating parent peakID=61, mass=86.0600258752, intensity=532986.625, no. of fragments=1
# Annotating parent peakID=63, mass=86.0961030608, intensity=569424.0, no. of fragments=1
# Annotating parent peakID=65, mass=86.0961288876, intensity=551113.25, no. of fragments=1
# Annotating parent peakID=67, mass=86.0963748955, intensity=1282799.125, no. of fragments=4
#  - 2 fragments annotated
# Annotating parent peakID=72, mass=86.0964166133, intensity=2307827.75, no. of fragments=1
# Annotating parent peakID=76, mass=87.0440553511, intensity=12338473.0, no. of fragments=2
# Annotating parent peakID=79, mass=87.0552762407, intensity=735020.5, no. of fragments=2
# Annotating parent peakID=82, mass=89.0596783774, intensity=787915.5625, no. of fragments=1
# Annotating parent peakID=89, mass=89.0709238988, intensity=1793272.5, no. of fragments=4
#  - 3 fragments annotated
# Annotating parent peakID=98, mass=90.0549410571, intensity=2888840.5, no. of fragments=3
# Annotating parent peakID=102, mass=90.0549725605, intensity=695324.875, no. of fragments=1
# Annotating parent peakID=104, mass=90.0549727486, intensity=6755740.0, no. of fragments=3
# Annotating parent peakID=108, mass=90.0913641833, intensity=2163393.0, no. of fragments=4
#  - 3 fragments annotated
# Annotating parent peakID=127, mass=96.0443678393, intensity=1281763.5, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=130, mass=96.0443805332, intensity=1998793.875, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=133, mass=97.028419709, intensity=5013418.0, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=144, mass=98.0600509168, intensity=1188735.25, no. of fragments=4
#  - 3 fragments annotated
# Annotating parent peakID=152, mass=98.0600603614, intensity=1189845.0, no. of fragments=4
#  - 3 fragments annotated
# Annotating parent peakID=157, mass=98.9839778261, intensity=961194.125, no. of fragments=2
# Annotating parent peakID=163, mass=98.9841526537, intensity=709943.625, no. of fragments=4
# Annotating parent peakID=168, mass=98.9841676969, intensity=1279995.125, no. of fragments=4
# Annotating parent peakID=178, mass=99.0440545306, intensity=588544.0625, no. of fragments=2
#  - 1 fragments annotated
# Annotating parent peakID=181, mass=99.0440740542, intensity=1300673.5, no. of fragments=4
#  - 2 fragments annotated
# Annotating parent peakID=189, mass=102.054967771, intensity=4110953.5, no. of fragments=5
#  - 3 fragments annotated
# Annotating parent peakID=195, mass=103.08658557, intensity=3137810.25, no. of fragments=3
#  - 3 fragments annotated
# Annotating parent peakID=199, mass=104.070516405, intensity=18100776.0, no. of fragments=8
#  - 4 fragments annotated
# Annotating parent peakID=208, mass=104.070545072, intensity=118432208.0, no. of fragments=5
#  - 5 fragments annotated
# Annotating parent peakID=214, mass=104.106854503, intensity=1231442304.0, no. of fragments=10
#  - 4 fragments annotated
# Annotating parent peakID=225, mass=104.106894967, intensity=4361059.5, no. of fragments=5
#  - 5 fragments annotated
# Annotating parent peakID=231, mass=105.069637137, intensity=745889.5625, no. of fragments=3
#  - 3 fragments annotated
# Annotating parent peakID=239, mass=105.103995143, intensity=5746207.5, no. of fragments=12
# Annotating parent peakID=252, mass=105.11023855, intensity=82191512.0, no. of fragments=12
# Annotating parent peakID=265, mass=105.113095164, intensity=3130095.25, no. of fragments=12
#  - 2 fragments annotated
# Annotating parent peakID=286, mass=106.111135121, intensity=3630380.0, no. of fragments=5
# Annotating parent peakID=292, mass=106.113431023, intensity=1912058.25, no. of fragments=5
# Annotating parent peakID=298, mass=108.044321906, intensity=34856424.0, no. of fragments=3
#  - 3 fragments annotated
# Annotating parent peakID=302, mass=108.044373405, intensity=986085.25, no. of fragments=3
#  - 3 fragments annotated
# Annotating parent peakID=306, mass=109.028429319, intensity=1310000.25, no. of fragments=4
#  - 4 fragments annotated
# Annotating parent peakID=311, mass=109.028441688, intensity=1104494.375, no. of fragments=1
# Annotating parent peakID=315, mass=110.060077309, intensity=6807544.0, no. of fragments=8
#  - 7 fragments annotated
# Annotating parent peakID=324, mass=110.071291657, intensity=5439790.5, no. of fragments=5
#  - 5 fragments annotated
# Annotating parent peakID=330, mass=111.044031796, intensity=707980.25, no. of fragments=6
#  - 2 fragments annotated
# Annotating parent peakID=337, mass=111.044051004, intensity=1971353.0, no. of fragments=9
#  - 4 fragments annotated
# Annotating parent peakID=347, mass=111.044064478, intensity=3665099.75, no. of fragments=7
#  - 4 fragments annotated
# Annotating parent peakID=355, mass=111.044064743, intensity=2400433.25, no. of fragments=7
#  - 4 fragments annotated
# Annotating parent peakID=363, mass=111.044078609, intensity=3321929.75, no. of fragments=9
#  - 4 fragments annotated
# Annotating parent peakID=373, mass=111.055291179, intensity=1379887.5, no. of fragments=6
#  - 5 fragments annotated
# Annotating parent peakID=388, mass=111.116812388, intensity=2909939.75, no. of fragments=1
# Annotating parent peakID=390, mass=112.050523012, intensity=4519468.5, no. of fragments=5
#  - 2 fragments annotated
# Annotating parent peakID=396, mass=112.050564033, intensity=13179168.0, no. of fragments=8
#  - 5 fragments annotated
# Annotating parent peakID=405, mass=112.050568008, intensity=19761036.0, no. of fragments=8
#  - 5 fragments annotated
# Annotating parent peakID=414, mass=112.086868689, intensity=2005735.625, no. of fragments=3
#  - 2 fragments annotated
# Annotating parent peakID=418, mass=113.034524867, intensity=3664498.75, no. of fragments=9
#  - 6 fragments annotated
# Annotating parent peakID=428, mass=113.034564025, intensity=5409486.0, no. of fragments=3
#  - 3 fragments annotated
# Annotating parent peakID=432, mass=113.053886465, intensity=823270.6875, no. of fragments=6
# Annotating parent peakID=439, mass=113.053895153, intensity=643787.25, no. of fragments=6
# Annotating parent peakID=446, mass=113.05973676, intensity=2381363.75, no. of fragments=15
#  - 2 fragments annotated
# Annotating parent peakID=462, mass=113.070938645, intensity=638811.1875, no. of fragments=2
#  - 1 fragments annotated
# Annotating parent peakID=465, mass=113.070944265, intensity=25932626.0, no. of fragments=15
#  - 7 fragments annotated
# Annotating parent peakID=481, mass=114.037949244, intensity=577217.6875, no. of fragments=6
# Annotating parent peakID=488, mass=114.054944406, intensity=2791614.25, no. of fragments=10
#  - 7 fragments annotated
# Annotating parent peakID=506, mass=114.055007314, intensity=5146769.0, no. of fragments=7
#  - 2 fragments annotated
# Annotating parent peakID=514, mass=114.05501045, intensity=573116.75, no. of fragments=8
#  - 3 fragments annotated
# Annotating parent peakID=523, mass=114.074347114, intensity=1506068.625, no. of fragments=11
# Annotating parent peakID=535, mass=114.091322352, intensity=2463983.5, no. of fragments=6
#  - 2 fragments annotated
# Annotating parent peakID=550, mass=115.086618163, intensity=3567727.25, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=553, mass=115.08676216, intensity=2304780.5, no. of fragments=3
#  - 3 fragments annotated
# Annotating parent peakID=557, mass=116.03417096, intensity=670937.0625, no. of fragments=7
#  - 3 fragments annotated
# Annotating parent peakID=573, mass=116.070544379, intensity=2079356160.0, no. of fragments=10
#  - 3 fragments annotated
# Annotating parent peakID=584, mass=116.070597914, intensity=13671213.0, no. of fragments=4
#  - 3 fragments annotated
# Annotating parent peakID=589, mass=116.070610915, intensity=5769414.0, no. of fragments=5
#  - 5 fragments annotated
# Annotating parent peakID=595, mass=117.018234849, intensity=654318.9375, no. of fragments=3
# Annotating parent peakID=599, mass=117.054540317, intensity=2952970.0, no. of fragments=3
#  - 3 fragments annotated
# Annotating parent peakID=603, mass=117.054555416, intensity=2834420.25, no. of fragments=9
#  - 2 fragments annotated
# Annotating parent peakID=613, mass=117.067568633, intensity=8147880.0, no. of fragments=8
# Annotating parent peakID=622, mass=117.073830808, intensity=117956944.0, no. of fragments=8
# Annotating parent peakID=638, mass=117.090992922, intensity=1080203.875, no. of fragments=1
# Annotating parent peakID=640, mass=117.091004875, intensity=2882627.5, no. of fragments=3
#  - 1 fragments annotated
# Annotating parent peakID=644, mass=117.091024291, intensity=1025745.8125, no. of fragments=1
# Annotating parent peakID=646, mass=117.102197855, intensity=1111373.125, no. of fragments=2
#  - 1 fragments annotated
# Annotating parent peakID=649, mass=118.049853813, intensity=915869.4375, no. of fragments=4
#  - 2 fragments annotated
# Annotating parent peakID=659, mass=118.074708438, intensity=9219364.0, no. of fragments=11
# Annotating parent peakID=671, mass=118.07712739, intensity=3339578.0, no. of fragments=11
# Annotating parent peakID=683, mass=118.086198722, intensity=1698129920.0, no. of fragments=10
#  - 4 fragments annotated
# Annotating parent peakID=694, mass=118.086248369, intensity=3415746.5, no. of fragments=4
#  - 4 fragments annotated
# Annotating parent peakID=699, mass=118.086260958, intensity=3440428.75, no. of fragments=4
#  - 4 fragments annotated
# Annotating parent peakID=704, mass=119.04907593, intensity=978863.6875, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=707, mass=119.08339566, intensity=7014034.5, no. of fragments=12
# Annotating parent peakID=720, mass=119.089581496, intensity=90325936.0, no. of fragments=12
# Annotating parent peakID=733, mass=120.047792877, intensity=736168.9375, no. of fragments=3
#  - 3 fragments annotated
# Annotating parent peakID=737, mass=120.04779697, intensity=6915450.0, no. of fragments=5
#  - 4 fragments annotated
# Annotating parent peakID=743, mass=120.065513905, intensity=5077896.0, no. of fragments=2
#  - 1 fragments annotated
# Annotating parent peakID=746, mass=120.065574651, intensity=813155.6875, no. of fragments=3
#  - 1 fragments annotated
# Annotating parent peakID=756, mass=120.080807682, intensity=3172405.0, no. of fragments=5
#  - 4 fragments annotated
# Annotating parent peakID=762, mass=120.090448595, intensity=7424051.0, no. of fragments=6
# Annotating parent peakID=769, mass=120.092934042, intensity=2205443.0, no. of fragments=6
# Annotating parent peakID=784, mass=121.064780587, intensity=4408663.5, no. of fragments=7
#  - 7 fragments annotated
# Annotating parent peakID=792, mass=121.064783874, intensity=3447124.25, no. of fragments=6
#  - 6 fragments annotated
# Annotating parent peakID=799, mass=121.064790126, intensity=5128256.0, no. of fragments=9
#  - 7 fragments annotated
# Annotating parent peakID=809, mass=121.06481725, intensity=3942153.75, no. of fragments=8
#  - 6 fragments annotated
# Annotating parent peakID=818, mass=121.06483761, intensity=2570730.25, no. of fragments=8
#  - 6 fragments annotated
# Annotating parent peakID=827, mass=121.071991502, intensity=1353168.0, no. of fragments=1
# Annotating parent peakID=829, mass=121.071995683, intensity=1363144.5, no. of fragments=1
# Annotating parent peakID=831, mass=121.072000647, intensity=1591689.625, no. of fragments=1
# Annotating parent peakID=839, mass=122.096403543, intensity=612063.5625, no. of fragments=5
#  - 1 fragments annotated
# Annotating parent peakID=845, mass=123.04735618, intensity=2307002.5, no. of fragments=8
#  - 3 fragments annotated
# Annotating parent peakID=854, mass=123.05520769, intensity=11639933.0, no. of fragments=9
#  - 7 fragments annotated
# Annotating parent peakID=876, mass=124.039272444, intensity=12376713.0, no. of fragments=7
#  - 5 fragments annotated
# Annotating parent peakID=884, mass=124.039323456, intensity=1712131.625, no. of fragments=3
#  - 2 fragments annotated
# Annotating parent peakID=888, mass=124.039344637, intensity=6944196.0, no. of fragments=7
#  - 5 fragments annotated
# Annotating parent peakID=896, mass=124.039363321, intensity=9968454.0, no. of fragments=7
#  - 5 fragments annotated
# Annotating parent peakID=904, mass=124.039364277, intensity=1910741.0, no. of fragments=3
#  - 2 fragments annotated
# Annotating parent peakID=908, mass=124.05868496, intensity=756052.1875, no. of fragments=7
# Annotating parent peakID=923, mass=124.086897104, intensity=815545.625, no. of fragments=5
#  - 2 fragments annotated
# Annotating parent peakID=929, mass=124.999499297, intensity=1414590.125, no. of fragments=7
# Annotating parent peakID=937, mass=125.07099219, intensity=862747.6875, no. of fragments=4
#  - 3 fragments annotated
# Annotating parent peakID=951, mass=126.054887967, intensity=159081920.0, no. of fragments=11
#  - 9 fragments annotated
# Annotating parent peakID=963, mass=126.066215078, intensity=24917608.0, no. of fragments=13
#  - 11 fragments annotated
# Annotating parent peakID=998, mass=127.015489348, intensity=2341086.75, no. of fragments=6
#  - 1 fragments annotated
# Annotating parent peakID=1005, mass=127.015567146, intensity=603563.3125, no. of fragments=6
#  - 1 fragments annotated
# Annotating parent peakID=1012, mass=127.038912598, intensity=2482716.25, no. of fragments=3
#  - 2 fragments annotated
# Annotating parent peakID=1016, mass=127.038946542, intensity=5368997.0, no. of fragments=8
#  - 8 fragments annotated
# Annotating parent peakID=1025, mass=127.038956331, intensity=930323.25, no. of fragments=9
#  - 3 fragments annotated
# Annotating parent peakID=1035, mass=127.038967067, intensity=1015541.1875, no. of fragments=9
#  - 3 fragments annotated
# Annotating parent peakID=1045, mass=127.038979122, intensity=774287.875, no. of fragments=10
#  - 2 fragments annotated
# Annotating parent peakID=1056, mass=127.038996623, intensity=2580205.25, no. of fragments=8
#  - 4 fragments annotated
# Annotating parent peakID=1065, mass=127.050118566, intensity=40250532.0, no. of fragments=15
#  - 8 fragments annotated
# Annotating parent peakID=1081, mass=127.050188471, intensity=8012240.5, no. of fragments=8
#  - 5 fragments annotated
# Annotating parent peakID=1090, mass=127.058215796, intensity=10634828.0, no. of fragments=15
#  - 1 fragments annotated
# Annotating parent peakID=1122, mass=127.069507965, intensity=903590.0625, no. of fragments=10
# Annotating parent peakID=1133, mass=127.086558685, intensity=911920.5625, no. of fragments=15
#  - 6 fragments annotated
# Annotating parent peakID=1159, mass=128.053448263, intensity=2208092.75, no. of fragments=17
#  - 8 fragments annotated
# Annotating parent peakID=1177, mass=128.070490366, intensity=2934589.0, no. of fragments=17
#  - 10 fragments annotated
# Annotating parent peakID=1195, mass=128.070538903, intensity=984962.625, no. of fragments=6
#  - 4 fragments annotated
# Annotating parent peakID=1202, mass=128.070568695, intensity=691384.4375, no. of fragments=17
#  - 10 fragments annotated
# Annotating parent peakID=1220, mass=128.070662572, intensity=2195675.5, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=1223, mass=128.081757842, intensity=985787.1875, no. of fragments=3
#  - 2 fragments annotated
# Annotating parent peakID=1227, mass=128.106887491, intensity=684077.75, no. of fragments=8
#  - 5 fragments annotated
# Annotating parent peakID=1236, mass=129.054577379, intensity=5021718.0, no. of fragments=6
#  - 6 fragments annotated
# Annotating parent peakID=1256, mass=129.065802218, intensity=119359424.0, no. of fragments=9
#  - 4 fragments annotated
# Annotating parent peakID=1266, mass=129.065965597, intensity=1042811.9375, no. of fragments=7
#  - 7 fragments annotated
# Annotating parent peakID=1274, mass=129.102125613, intensity=766099.0, no. of fragments=9
#  - 4 fragments annotated
# Annotating parent peakID=1292, mass=130.049867606, intensity=8683524.0, no. of fragments=14
#  - 7 fragments annotated
# Annotating parent peakID=1307, mass=130.049894053, intensity=247324512.0, no. of fragments=7
#  - 3 fragments annotated
# Annotating parent peakID=1327, mass=130.062931257, intensity=983075.125, no. of fragments=14
#  - 2 fragments annotated
# Annotating parent peakID=1342, mass=130.069216524, intensity=6914719.0, no. of fragments=14
# Annotating parent peakID=1357, mass=130.08626568, intensity=152407184.0, no. of fragments=11
#  - 7 fragments annotated
# Annotating parent peakID=1369, mass=130.086285865, intensity=2535633.75, no. of fragments=14
#  - 12 fragments annotated
# Annotating parent peakID=1384, mass=130.086297577, intensity=6383970.0, no. of fragments=8
#  - 6 fragments annotated
# Annotating parent peakID=1393, mass=130.097463074, intensity=13754282.0, no. of fragments=9
#  - 5 fragments annotated
# Annotating parent peakID=1403, mass=130.097466613, intensity=9581816.0, no. of fragments=9
#  - 5 fragments annotated
# Annotating parent peakID=1413, mass=130.097559243, intensity=12145713.0, no. of fragments=9
#  - 5 fragments annotated
# Annotating parent peakID=1447, mass=130.122668699, intensity=527831.5, no. of fragments=4
#  - 3 fragments annotated
# Annotating parent peakID=1458, mass=131.033883476, intensity=1089441.875, no. of fragments=10
#  - 4 fragments annotated
# Annotating parent peakID=1469, mass=131.047030097, intensity=798034.8125, no. of fragments=9
# Annotating parent peakID=1479, mass=131.053232769, intensity=13215777.0, no. of fragments=8
# Annotating parent peakID=1500, mass=131.070331583, intensity=5545167.5, no. of fragments=14
#  - 10 fragments annotated
# Annotating parent peakID=1515, mass=131.081541561, intensity=1243712.625, no. of fragments=12
#  - 11 fragments annotated
# Annotating parent peakID=1528, mass=131.089572695, intensity=10314822.0, no. of fragments=10
#  - 2 fragments annotated
# Annotating parent peakID=1551, mass=131.100862191, intensity=861120.25, no. of fragments=7
# Annotating parent peakID=1562, mass=131.117861461, intensity=18450726.0, no. of fragments=11
#  - 3 fragments annotated
# Annotating parent peakID=1574, mass=131.129118028, intensity=6165073.0, no. of fragments=11
#  - 7 fragments annotated
# Annotating parent peakID=1594, mass=132.054145176, intensity=1776054.25, no. of fragments=9
# Annotating parent peakID=1614, mass=132.065460535, intensity=18472026.0, no. of fragments=19
#  - 14 fragments annotated
# Annotating parent peakID=1634, mass=132.065526022, intensity=9824357.0, no. of fragments=5
#  - 5 fragments annotated
# Annotating parent peakID=1640, mass=132.065537511, intensity=3752215.75, no. of fragments=7
#  - 5 fragments annotated
# Annotating parent peakID=1656, mass=132.076757992, intensity=884834.8125, no. of fragments=8
#  - 3 fragments annotated
# Annotating parent peakID=1677, mass=132.090412881, intensity=621744.5, no. of fragments=19
# Annotating parent peakID=1697, mass=132.101911929, intensity=28418200.0, no. of fragments=10
#  - 4 fragments annotated
# Annotating parent peakID=1708, mass=132.101977216, intensity=6341282.5, no. of fragments=10
#  - 4 fragments annotated
# Annotating parent peakID=1719, mass=132.11312499, intensity=1481020.125, no. of fragments=4
#  - 4 fragments annotated
# Annotating parent peakID=1724, mass=132.113231297, intensity=1715688.125, no. of fragments=6
#  - 4 fragments annotated
# Annotating parent peakID=1731, mass=132.121209224, intensity=1176834.25, no. of fragments=6
# Annotating parent peakID=1748, mass=132.132479869, intensity=524139.5, no. of fragments=6
# Annotating parent peakID=1764, mass=133.060728841, intensity=25519770.0, no. of fragments=3
#  - 3 fragments annotated
# Annotating parent peakID=1768, mass=133.068795882, intensity=1052361.125, no. of fragments=8
# Annotating parent peakID=1782, mass=133.09711928, intensity=31991762.0, no. of fragments=7
#  - 3 fragments annotated
# Annotating parent peakID=1790, mass=133.097138583, intensity=567264.5625, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=1793, mass=133.097190977, intensity=6942230.5, no. of fragments=4
#  - 4 fragments annotated
# Annotating parent peakID=1798, mass=134.044727293, intensity=1106318.875, no. of fragments=2
#  - 1 fragments annotated
# Annotating parent peakID=1801, mass=134.06404358, intensity=991313.0, no. of fragments=8
#  - 2 fragments annotated
# Annotating parent peakID=1810, mass=134.081088817, intensity=2635294.25, no. of fragments=3
#  - 3 fragments annotated
# Annotating parent peakID=1814, mass=134.081101274, intensity=587644.375, no. of fragments=5
#  - 5 fragments annotated
# Annotating parent peakID=1820, mass=134.0811603, intensity=2683105.0, no. of fragments=5
#  - 5 fragments annotated
# Annotating parent peakID=1826, mass=134.10046078, intensity=1743544.0, no. of fragments=3
#  - 2 fragments annotated
# Annotating parent peakID=1830, mass=135.065172472, intensity=7459593.5, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=1838, mass=135.101546488, intensity=1544448.625, no. of fragments=4
#  - 1 fragments annotated
# Annotating parent peakID=1847, mass=136.061800804, intensity=599815168.0, no. of fragments=17
#  - 10 fragments annotated
# Annotating parent peakID=1882, mass=137.045780287, intensity=55394200.0, no. of fragments=12
#  - 9 fragments annotated
# Annotating parent peakID=1895, mass=137.045806666, intensity=6288425.5, no. of fragments=7
#  - 4 fragments annotated
# Annotating parent peakID=1903, mass=137.058867218, intensity=11245427.0, no. of fragments=19
#  - 5 fragments annotated
# Annotating parent peakID=1923, mass=137.059734305, intensity=1925210.375, no. of fragments=3
#  - 1 fragments annotated
# Annotating parent peakID=1927, mass=137.059738781, intensity=1317323.375, no. of fragments=3
#  - 1 fragments annotated
# Annotating parent peakID=1931, mass=137.059741025, intensity=2832561.25, no. of fragments=3
#  - 1 fragments annotated
# Annotating parent peakID=1935, mass=137.065110282, intensity=32562818.0, no. of fragments=19
# Annotating parent peakID=1973, mass=138.042956434, intensity=742633.4375, no. of fragments=16
#  - 8 fragments annotated
# Annotating parent peakID=1990, mass=138.049151451, intensity=3015889.5, no. of fragments=16
#  - 3 fragments annotated
# Annotating parent peakID=2007, mass=138.052557674, intensity=20002934.0, no. of fragments=2
# Annotating parent peakID=2010, mass=138.05499755, intensity=456857600.0, no. of fragments=23
#  - 14 fragments annotated
# Annotating parent peakID=2052, mass=138.068337261, intensity=635297.875, no. of fragments=8
# Annotating parent peakID=2061, mass=138.09137317, intensity=2871748.25, no. of fragments=7
#  - 7 fragments annotated
# Annotating parent peakID=2074, mass=139.050177218, intensity=717885.875, no. of fragments=6
#  - 2 fragments annotated
# Annotating parent peakID=2081, mass=139.055892376, intensity=1166527.75, no. of fragments=3
# Annotating parent peakID=2085, mass=139.058328753, intensity=34128796.0, no. of fragments=26
#  - 8 fragments annotated
# Annotating parent peakID=2112, mass=140.068127473, intensity=5671602.5, no. of fragments=2
# Annotating parent peakID=2115, mass=140.068159093, intensity=4780116.0, no. of fragments=2
# Annotating parent peakID=2118, mass=140.07052319, intensity=3114038.0, no. of fragments=6
#  - 6 fragments annotated
# Annotating parent peakID=2125, mass=140.070635549, intensity=635769.875, no. of fragments=4
#  - 2 fragments annotated
# Annotating parent peakID=2130, mass=141.054613498, intensity=3393543.5, no. of fragments=7
#  - 4 fragments annotated
# Annotating parent peakID=2138, mass=141.065855009, intensity=936020.75, no. of fragments=6
#  - 4 fragments annotated
# Annotating parent peakID=2145, mass=142.04983038, intensity=753674.5, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=2148, mass=142.049928914, intensity=563062.625, no. of fragments=4
# Annotating parent peakID=2153, mass=142.049930165, intensity=958485.5625, no. of fragments=4
# Annotating parent peakID=2163, mass=142.09752135, intensity=1354715.625, no. of fragments=4
#  - 4 fragments annotated
# Annotating parent peakID=2168, mass=143.081555743, intensity=7783711.0, no. of fragments=7
#  - 7 fragments annotated
# Annotating parent peakID=2176, mass=143.081565216, intensity=6803019.0, no. of fragments=1
#  - 1 fragments annotated
# Annotating parent peakID=2178, mass=144.065513761, intensity=896229.75, no. of fragments=12
#  - 8 fragments annotated
# Annotating parent peakID=2191, mass=144.065517683, intensity=570561.8125, no. of fragments=7
#  - 2 fragments annotated
# Annotating parent peakID=2199, mass=144.065572532, intensity=1456933.625, no. of fragments=8
#  - 5 fragments annotated
# Annotating parent peakID=2208, mass=144.065578657, intensity=4565687.0, no. of fragments=5
#  - 4 fragments annotated
# Annotating parent peakID=2237, mass=144.080807038, intensity=1283165.0, no. of fragments=16
#  - 10 fragments annotated
# Annotating parent peakID=2254, mass=144.080823009, intensity=894901.6875, no. of fragments=4
#  - 4 fragments annotated
# Annotating parent peakID=2259, mass=144.085001708, intensity=531270.6875, no. of fragments=6
#  - 2 fragments annotated
# Annotating parent peakID=2266, mass=144.101911399, intensity=10032534.0, no. of fragments=12
#  - 9 fragments annotated
# Annotating parent peakID=2279, mass=144.101920237, intensity=620164.9375, no. of fragments=5
#  - 3 fragments annotated
# Annotating parent peakID=2285, mass=144.101944436, intensity=1512001.5, no. of fragments=13
#  - 9 fragments annotated
# Annotating parent peakID=2309, mass=145.04710557, intensity=2896769.75, no. of fragments=4
# Annotating parent peakID=2314, mass=145.04949682, intensity=4455840.5, no. of fragments=7
#  - 6 fragments annotated
# Annotating parent peakID=2322, mass=145.049506824, intensity=6715682.0, no. of fragments=13
#  - 11 fragments annotated
# Annotating parent peakID=2336, mass=145.049554676, intensity=3379990.75, no. of fragments=9
#  - 5 fragments annotated
# Annotating parent peakID=2346, mass=145.049556036, intensity=2939408.0, no. of fragments=8
#  - 7 fragments annotated
# Annotating parent peakID=2355, mass=145.049560527, intensity=7991423.5, no. of fragments=8
#  - 7 fragments annotated
# Annotating parent peakID=2376, mass=145.097107112, intensity=1305652.375, no. of fragments=10
#  - 7 fragments annotated
# Annotating parent peakID=2387, mass=145.10529653, intensity=776994.6875, no. of fragments=6
#  - 1 fragments annotated
# Annotating parent peakID=2394, mass=145.133540069, intensity=880449.3125, no. of fragments=6
#  - 3 fragments annotated
# Annotating parent peakID=2431, mass=146.05994725, intensity=3048447.25, no. of fragments=12
#  - 10 fragments annotated
# Annotating parent peakID=2444, mass=146.081084739, intensity=17175450.0, no. of fragments=28
#  - 21 fragments annotated
# Annotating parent peakID=2473, mass=146.081159866, intensity=6947634.0, no. of fragments=14
#  - 13 fragments annotated
# Annotating parent peakID=2488, mass=146.081163564, intensity=3485224.0, no. of fragments=9
#  - 4 fragments annotated
# Annotating parent peakID=2498, mass=146.081174522, intensity=614663.625, no. of fragments=4
#  - 3 fragments annotated
# Annotating parent peakID=2503, mass=146.081247965, intensity=807753.0625, no. of fragments=4
#  - 3 fragments annotated
# Annotating parent peakID=2508, mass=146.092290518, intensity=225382736.0, no. of fragments=14
#  - 12 fragments annotated
# Annotating parent peakID=2523, mass=146.117503788, intensity=813167.25, no. of fragments=10
#  - 10 fragments annotated
# Annotating parent peakID=2534, mass=146.117528125, intensity=27750932.0, no. of fragments=10
#  - 5 fragments annotated
# Annotating parent peakID=2545, mass=146.117537008, intensity=35201888.0, no. of fragments=12
#  - 6 fragments annotated
# Annotating parent peakID=2558, mass=146.117561274, intensity=9458361.0, no. of fragments=13
#  - 11 fragments annotated
# Annotating parent peakID=2572, mass=146.117562068, intensity=5293531.0, no. of fragments=13
#  - 11 fragments annotated
# Annotating parent peakID=2586, mass=146.117570863, intensity=6182547.5, no. of fragments=9
#  - 8 fragments annotated
# Annotating parent peakID=2596, mass=146.117594553, intensity=2905289.5, no. of fragments=9
#  - 8 fragments annotated
# Annotating parent peakID=2606, mass=146.13899411, intensity=697136.75, no. of fragments=14
# Annotating parent peakID=2639, mass=147.065142024, intensity=5124866.0, no. of fragments=10
#  - 7 fragments annotated
# Annotating parent peakID=2650, mass=147.065195269, intensity=1184864.875, no. of fragments=5
#  - 5 fragments annotated
# Annotating parent peakID=2656, mass=147.065256032, intensity=1280027.0, no. of fragments=7
#  - 3 fragments annotated
# Annotating parent peakID=2664, mass=147.065333207, intensity=706641.875, no. of fragments=10
#  - 1 fragments annotated
# Annotating parent peakID=2675, mass=147.076313867, intensity=1287489.875, no. of fragments=10
#  - 5 fragments annotated
# Annotating parent peakID=2686, mass=147.076372363, intensity=28795256.0, no. of fragments=10
#  - 8 fragments annotated
# Annotating parent peakID=2716, mass=147.089344919, intensity=2891153.0, no. of fragments=13
#  - 5 fragments annotated
# Annotating parent peakID=2730, mass=147.095619222, intensity=12433920.0, no. of fragments=13
#  - 2 fragments annotated
# Annotating parent peakID=2744, mass=147.112685811, intensity=1298433.75, no. of fragments=1
# Annotating parent peakID=2746, mass=147.120899907, intensity=1939754.125, no. of fragments=6
# Annotating parent peakID=2759, mass=148.039288563, intensity=541372.625, no. of fragments=5
#  - 3 fragments annotated
# Annotating parent peakID=2770, mass=148.060342097, intensity=6657020.0, no. of fragments=5
#  - 4 fragments annotated
# Annotating parent peakID=2776, mass=148.060359488, intensity=1883389.375, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=2779, mass=148.060417881, intensity=1672377.625, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=2782, mass=148.096758901, intensity=724449.9375, no. of fragments=4
#  - 4 fragments annotated
# Annotating parent peakID=2790, mass=148.096768649, intensity=819289.6875, no. of fragments=3
#  - 1 fragments annotated
# Annotating parent peakID=2796, mass=148.096770222, intensity=867189.625, no. of fragments=5
#  - 4 fragments annotated
# Annotating parent peakID=2802, mass=148.096783201, intensity=767290.8125, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=2807, mass=149.023321785, intensity=2130007.75, no. of fragments=8
#  - 3 fragments annotated
# Annotating parent peakID=2816, mass=149.070903618, intensity=9784940.0, no. of fragments=9
#  - 6 fragments annotated
# Annotating parent peakID=2846, mass=149.132503035, intensity=609598.1875, no. of fragments=4
#  - 3 fragments annotated
# Annotating parent peakID=2860, mass=150.058397675, intensity=5108756.0, no. of fragments=3
# Annotating parent peakID=2869, mass=150.077447046, intensity=15326802.0, no. of fragments=16
#  - 14 fragments annotated
# Annotating parent peakID=2886, mass=150.077509845, intensity=6036490.5, no. of fragments=11
#  - 7 fragments annotated
# Annotating parent peakID=2898, mass=150.091379369, intensity=559827.625, no. of fragments=4
#  - 4 fragments annotated
# Annotating parent peakID=2903, mass=150.091406665, intensity=12314111.0, no. of fragments=10
#  - 6 fragments annotated
# Annotating parent peakID=2914, mass=151.061448088, intensity=620671.4375, no. of fragments=10
#  - 5 fragments annotated
# Annotating parent peakID=2936, mass=151.080769333, intensity=1011768.6875, no. of fragments=10
# Annotating parent peakID=2954, mass=152.031828089, intensity=8178121.0, no. of fragments=8
# Annotating parent peakID=2963, mass=152.037600947, intensity=799698.625, no. of fragments=14
#  - 8 fragments annotated
# Annotating parent peakID=2978, mass=152.056689815, intensity=165917856.0, no. of fragments=18
#  - 10 fragments annotated
# Annotating parent peakID=2997, mass=152.056775997, intensity=3810330.75, no. of fragments=8
#  - 6 fragments annotated
# Annotating parent peakID=3006, mass=152.068117838, intensity=631181.125, no. of fragments=4
# Annotating parent peakID=3011, mass=152.070514683, intensity=2492127.75, no. of fragments=17
#  - 15 fragments annotated
# Annotating parent peakID=3029, mass=152.070542876, intensity=718383.0, no. of fragments=9
#  - 8 fragments annotated
# Annotating parent peakID=3045, mass=152.106954464, intensity=21988480.0, no. of fragments=16
#  - 10 fragments annotated
# Annotating parent peakID=3062, mass=152.106978121, intensity=25753016.0, no. of fragments=15
#  - 10 fragments annotated
# Annotating parent peakID=3095, mass=152.128128151, intensity=625827.0625, no. of fragments=16
# Annotating parent peakID=3112, mass=153.053736421, intensity=3083145.0, no. of fragments=17
#  - 8 fragments annotated
# Annotating parent peakID=3130, mass=153.060031278, intensity=8850045.0, no. of fragments=17
# Annotating parent peakID=3155, mass=153.065844847, intensity=998188.8125, no. of fragments=5
#  - 3 fragments annotated
# Annotating parent peakID=3161, mass=153.065847604, intensity=948609.125, no. of fragments=5
#  - 3 fragments annotated
# Annotating parent peakID=3167, mass=153.075735263, intensity=21324176.0, no. of fragments=17
#  - 9 fragments annotated
# Annotating parent peakID=3192, mass=153.127359622, intensity=615340.5, no. of fragments=10
#  - 4 fragments annotated
# Annotating parent peakID=3212, mass=154.097355053, intensity=2377199.0, no. of fragments=9
#  - 5 fragments annotated
# Annotating parent peakID=3222, mass=155.010362485, intensity=2828702.25, no. of fragments=3
#  - 2 fragments annotated
# Annotating parent peakID=3226, mass=155.042624547, intensity=3013847.5, no. of fragments=1
# Annotating parent peakID=3228, mass=155.045015351, intensity=571738.6875, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=3231, mass=155.045062324, intensity=851736.0, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=3234, mass=155.070228754, intensity=635271.3125, no. of fragments=7
#  - 3 fragments annotated
# Annotating parent peakID=3242, mass=155.070250602, intensity=1530861.625, no. of fragments=7
#  - 3 fragments annotated
# Annotating parent peakID=3250, mass=155.08139095, intensity=1128394.625, no. of fragments=7
#  - 5 fragments annotated
# Annotating parent peakID=3258, mass=155.106576795, intensity=582391.25, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=3275, mass=156.042089241, intensity=1131471.5, no. of fragments=4
# Annotating parent peakID=3280, mass=156.042134531, intensity=923947.1875, no. of fragments=4
# Annotating parent peakID=3285, mass=156.050492779, intensity=678712.8125, no. of fragments=4
# Annotating parent peakID=3290, mass=156.050538233, intensity=697700.5625, no. of fragments=4
# Annotating parent peakID=3295, mass=156.065506028, intensity=4158336.5, no. of fragments=7
#  - 7 fragments annotated
# Annotating parent peakID=3303, mass=156.07676682, intensity=110043960.0, no. of fragments=12
#  - 9 fragments annotated
# Annotating parent peakID=3316, mass=156.076791508, intensity=1299321.5, no. of fragments=4
#  - 4 fragments annotated
# Annotating parent peakID=3329, mass=157.060757986, intensity=41611784.0, no. of fragments=13
#  - 11 fragments annotated
# Annotating parent peakID=3343, mass=157.073835425, intensity=1278001.625, no. of fragments=14
#  - 3 fragments annotated
# Annotating parent peakID=3358, mass=157.080101132, intensity=7317130.0, no. of fragments=14
#  - 5 fragments annotated
# Annotating parent peakID=3373, mass=158.044810828, intensity=971966.125, no. of fragments=10
#  - 6 fragments annotated
# Annotating parent peakID=3384, mass=158.081169096, intensity=2211410.5, no. of fragments=8
#  - 7 fragments annotated
# Annotating parent peakID=3393, mass=158.081177694, intensity=15015682.0, no. of fragments=7
#  - 6 fragments annotated
# Annotating parent peakID=3401, mass=158.081212508, intensity=2899555.0, no. of fragments=10
#  - 9 fragments annotated
# Annotating parent peakID=3412, mass=158.081214285, intensity=2773685.25, no. of fragments=10
#  - 9 fragments annotated
# Annotating parent peakID=3423, mass=158.092438263, intensity=4125850.5, no. of fragments=10
#  - 8 fragments annotated
# Annotating parent peakID=3434, mass=158.11748559, intensity=1192105.875, no. of fragments=8
#  - 7 fragments annotated
# Annotating parent peakID=3451, mass=158.11764684, intensity=1147102.375, no. of fragments=9
#  - 9 fragments annotated
# Annotating parent peakID=3461, mass=158.128794358, intensity=928385.6875, no. of fragments=1
#  - 1 fragments annotated
# Annotating parent peakID=3463, mass=159.02768124, intensity=3256996.25, no. of fragments=4
# Annotating parent peakID=3468, mass=159.051230356, intensity=2667640.5, no. of fragments=7
#  - 3 fragments annotated
# Annotating parent peakID=3481, mass=159.065170856, intensity=7522104.0, no. of fragments=2
#  - 1 fragments annotated
# Annotating parent peakID=3487, mass=159.076367229, intensity=3455806.75, no. of fragments=6
#  - 6 fragments annotated
# Annotating parent peakID=3494, mass=159.076475833, intensity=12057903.0, no. of fragments=6
#  - 4 fragments annotated
# Annotating parent peakID=3501, mass=159.076519297, intensity=1018316.9375, no. of fragments=3
#  - 2 fragments annotated
# Annotating parent peakID=3514, mass=159.112811313, intensity=832962.6875, no. of fragments=3
#  - 2 fragments annotated
# Annotating parent peakID=3518, mass=160.036961056, intensity=1509194.25, no. of fragments=11
#  - 4 fragments annotated
# Annotating parent peakID=3538, mass=160.060437775, intensity=730264.5, no. of fragments=12
#  - 9 fragments annotated
# Annotating parent peakID=3562, mass=160.096711754, intensity=560020.0, no. of fragments=7
#  - 7 fragments annotated
# Annotating parent peakID=3570, mass=160.096763292, intensity=1112952.875, no. of fragments=4
#  - 4 fragments annotated
# Annotating parent peakID=3575, mass=160.096820925, intensity=620165.25, no. of fragments=10
#  - 7 fragments annotated
# Annotating parent peakID=3586, mass=160.096824044, intensity=2147728.5, no. of fragments=12
#  - 10 fragments annotated
# Annotating parent peakID=3599, mass=160.096846577, intensity=1022245.625, no. of fragments=12
#  - 10 fragments annotated
# Annotating parent peakID=3612, mass=160.096858624, intensity=5339210.5, no. of fragments=7
#  - 7 fragments annotated
# Annotating parent peakID=3620, mass=160.108091763, intensity=2095970.75, no. of fragments=12
#  - 10 fragments annotated
# Annotating parent peakID=3633, mass=160.108119926, intensity=2137267.25, no. of fragments=10
#  - 9 fragments annotated
# Annotating parent peakID=3644, mass=160.133176973, intensity=5815443.5, no. of fragments=3
#  - 2 fragments annotated
# Annotating parent peakID=3650, mass=160.133226086, intensity=19008424.0, no. of fragments=8
#  - 6 fragments annotated
# Annotating parent peakID=3663, mass=161.092054607, intensity=810818.375, no. of fragments=4
#  - 2 fragments annotated
# Annotating parent peakID=3668, mass=161.092091807, intensity=1565268.75, no. of fragments=1
#  - 1 fragments annotated
# Annotating parent peakID=3677, mass=161.128429762, intensity=2299694.75, no. of fragments=6
#  - 5 fragments annotated
# Annotating parent peakID=3723, mass=162.058308597, intensity=5840093.5, no. of fragments=4
#  - 3 fragments annotated
# Annotating parent peakID=3728, mass=162.058311201, intensity=703019.375, no. of fragments=12
#  - 4 fragments annotated
# Annotating parent peakID=3741, mass=162.076032055, intensity=1796600.625, no. of fragments=8
#  - 8 fragments annotated
# Annotating parent peakID=3750, mass=162.076065497, intensity=10978041.0, no. of fragments=12
#  - 11 fragments annotated
# Annotating parent peakID=3763, mass=162.076068631, intensity=11745798.0, no. of fragments=12
#  - 11 fragments annotated
# Annotating parent peakID=3776, mass=162.076089978, intensity=4396076.0, no. of fragments=8
#  - 8 fragments annotated
# Annotating parent peakID=3785, mass=162.076101283, intensity=2438345.75, no. of fragments=13
#  - 11 fragments annotated
# Annotating parent peakID=3807, mass=162.091308671, intensity=4176343.5, no. of fragments=19
#  - 13 fragments annotated
# Annotating parent peakID=3827, mass=162.091310834, intensity=4208449.5, no. of fragments=14
#  - 6 fragments annotated
# Annotating parent peakID=3842, mass=162.09133797, intensity=4169072.5, no. of fragments=14
#  - 6 fragments annotated
# Annotating parent peakID=3869, mass=162.112386133, intensity=2623233.0, no. of fragments=5
#  - 5 fragments annotated
# Annotating parent peakID=3875, mass=162.112446714, intensity=7117894.0, no. of fragments=5
#  - 5 fragments annotated
# Annotating parent peakID=3892, mass=163.038900797, intensity=2222395.25, no. of fragments=14
#  - 14 fragments annotated
# Annotating parent peakID=3907, mass=163.039054709, intensity=823629.5, no. of fragments=14
#  - 14 fragments annotated
# Annotating parent peakID=3933, mass=163.059852517, intensity=2685874.5, no. of fragments=10
#  - 10 fragments annotated
# Annotating parent peakID=3944, mass=163.059895041, intensity=2890047.25, no. of fragments=10
#  - 10 fragments annotated
# Annotating parent peakID=3955, mass=163.060009865, intensity=2153199.5, no. of fragments=10
#  - 10 fragments annotated
# Annotating parent peakID=3966, mass=163.060068023, intensity=7313271.0, no. of fragments=15
#  - 11 fragments annotated
# Annotating parent peakID=3982, mass=163.060088453, intensity=3422712.0, no. of fragments=6
#  - 5 fragments annotated
# Annotating parent peakID=3989, mass=163.079409552, intensity=738826.875, no. of fragments=5
#  - 3 fragments annotated
# Annotating parent peakID=4017, mass=163.115836489, intensity=641288.0625, no. of fragments=5
# Annotating parent peakID=4023, mass=163.132824979, intensity=4091603.0, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=4026, mass=164.034246705, intensity=1957741.875, no. of fragments=9
#  - 4 fragments annotated
# Annotating parent peakID=4046, mass=164.073922994, intensity=1412806.0, no. of fragments=11
#  - 7 fragments annotated
# Annotating parent peakID=4058, mass=164.091681272, intensity=1476642.375, no. of fragments=12
#  - 7 fragments annotated
# Annotating parent peakID=4071, mass=164.091701278, intensity=657273.1875, no. of fragments=6
#  - 4 fragments annotated
# Annotating parent peakID=4078, mass=164.091705594, intensity=666380.375, no. of fragments=9
#  - 7 fragments annotated
# Annotating parent peakID=4088, mass=164.091782843, intensity=1090118.375, no. of fragments=12
#  - 7 fragments annotated
# Annotating parent peakID=4101, mass=164.093033189, intensity=7690839.5, no. of fragments=9
#  - 8 fragments annotated
# Annotating parent peakID=4111, mass=165.075756916, intensity=11474191.0, no. of fragments=3
#  - 3 fragments annotated
# Annotating parent peakID=4115, mass=165.075761993, intensity=1295761.375, no. of fragments=3
#  - 3 fragments annotated
# Annotating parent peakID=4119, mass=166.049832628, intensity=1384591.25, no. of fragments=7
#  - 4 fragments annotated
# Annotating parent peakID=4141, mass=166.072326711, intensity=3128500.0, no. of fragments=24
#  - 11 fragments annotated
# Annotating parent peakID=4166, mass=166.072397112, intensity=7916494.0, no. of fragments=24
#  - 11 fragments annotated
# Annotating parent peakID=4191, mass=166.086263257, intensity=736566.625, no. of fragments=10
#  - 8 fragments annotated
# Annotating parent peakID=4202, mass=166.086284006, intensity=880995.75, no. of fragments=6
#  - 5 fragments annotated
# Annotating parent peakID=4209, mass=166.086297543, intensity=15979306.0, no. of fragments=24
#  - 8 fragments annotated
# Annotating parent peakID=4241, mass=166.122601754, intensity=54906184.0, no. of fragments=16
#  - 10 fragments annotated
# Annotating parent peakID=4258, mass=166.122645858, intensity=799479.0625, no. of fragments=10
#  - 9 fragments annotated
# Annotating parent peakID=4269, mass=167.073620204, intensity=697482.0, no. of fragments=5
#  - 2 fragments annotated
# Annotating parent peakID=4275, mass=167.091468129, intensity=934701.25, no. of fragments=6
#  - 6 fragments annotated
# Annotating parent peakID=4282, mass=167.106630989, intensity=643866.8125, no. of fragments=4
#  - 3 fragments annotated
# Annotating parent peakID=4297, mass=168.06548874, intensity=544004.375, no. of fragments=5
#  - 4 fragments annotated
# Annotating parent peakID=4303, mass=168.065522376, intensity=915177.6875, no. of fragments=5
#  - 2 fragments annotated
# Annotating parent peakID=4309, mass=168.065549453, intensity=818138.3125, no. of fragments=5
#  - 3 fragments annotated
# Annotating parent peakID=4315, mass=168.086689465, intensity=3906225.25, no. of fragments=8
#  - 5 fragments annotated
# Annotating parent peakID=4324, mass=168.101927157, intensity=1328166.0, no. of fragments=14
#  - 11 fragments annotated
# Annotating parent peakID=4339, mass=168.113106626, intensity=604755.4375, no. of fragments=5
#  - 4 fragments annotated
# Annotating parent peakID=4351, mass=168.945995662, intensity=598759.375, no. of fragments=2
# Annotating parent peakID=4354, mass=169.058315123, intensity=1060058.5, no. of fragments=4
# Annotating parent peakID=4359, mass=169.097132757, intensity=1146616.0, no. of fragments=6
#  - 6 fragments annotated
# Annotating parent peakID=4366, mass=169.097153691, intensity=1571624.625, no. of fragments=6
#  - 6 fragments annotated
# Annotating parent peakID=4373, mass=169.122283891, intensity=641251.0, no. of fragments=6
#  - 6 fragments annotated
# Annotating parent peakID=4387, mass=170.081135687, intensity=38320380.0, no. of fragments=18
#  - 15 fragments annotated
# Annotating parent peakID=4406, mass=170.092377926, intensity=3766961.75, no. of fragments=5
#  - 5 fragments annotated
# Annotating parent peakID=4412, mass=170.102294026, intensity=3557995.25, no. of fragments=7
# Annotating parent peakID=4420, mass=171.026309456, intensity=1886304.0, no. of fragments=3
# Annotating parent peakID=4424, mass=171.062654298, intensity=661893.625, no. of fragments=13
#  - 5 fragments annotated
# Annotating parent peakID=4438, mass=171.065219914, intensity=1699188.875, no. of fragments=25
#  - 5 fragments annotated
# Annotating parent peakID=4464, mass=171.076442717, intensity=1368388.75, no. of fragments=11
#  - 7 fragments annotated
# Annotating parent peakID=4476, mass=171.084469814, intensity=3377010.75, no. of fragments=25
#  - 8 fragments annotated
# Annotating parent peakID=4502, mass=171.112778196, intensity=865779.875, no. of fragments=4
#  - 4 fragments annotated
# Annotating parent peakID=4507, mass=171.112792142, intensity=1321297.625, no. of fragments=10
#  - 6 fragments annotated
# Annotating parent peakID=4530, mass=172.060443931, intensity=1017451.75, no. of fragments=5
#  - 3 fragments annotated
# Annotating parent peakID=4545, mass=172.096784411, intensity=2176120.5, no. of fragments=9
#  - 7 fragments annotated
# Annotating parent peakID=4555, mass=172.096819112, intensity=1618689.25, no. of fragments=9
#  - 7 fragments annotated
# Annotating parent peakID=4565, mass=173.020902544, intensity=1287516.875, no. of fragments=6
#  - 3 fragments annotated
# ...
#  - 1 fragments annotated
# Annotating parent peakID=20352, mass=420.150113585, intensity=660155.9375, no. of fragments=6
#  - 5 fragments annotated
# Annotating parent peakID=20359, mass=420.162698192, intensity=9599032.0, no. of fragments=10
#  - 7 fragments annotated
# Annotating parent peakID=20370, mass=420.186390864, intensity=787943.75, no. of fragments=6
#  - 6 fragments annotated
# Annotating parent peakID=20377, mass=425.11280667, intensity=676220.5625, no. of fragments=1
# Annotating parent peakID=20379, mass=425.135867404, intensity=3658699.0, no. of fragments=1
# Annotating parent peakID=20381, mass=425.191611891, intensity=1165968.5, no. of fragments=20
#  - 19 fragments annotated
# Annotating parent peakID=20402, mass=427.29162417, intensity=796918.6875, no. of fragments=6
#  - 5 fragments annotated
# Annotating parent peakID=20409, mass=428.138977923, intensity=1036117.625, no. of fragments=5
# Annotating parent peakID=20415, mass=428.176312522, intensity=28206894.0, no. of fragments=26
#  - 24 fragments annotated
# Annotating parent peakID=20442, mass=428.212691635, intensity=896280.5, no. of fragments=4
#  - 4 fragments annotated
# Annotating parent peakID=20447, mass=430.155495318, intensity=1007433.6875, no. of fragments=14
#  - 14 fragments annotated
# Annotating parent peakID=20462, mass=431.279225839, intensity=1073411.125, no. of fragments=6
#  - 4 fragments annotated
# Annotating parent peakID=20469, mass=432.207612339, intensity=1289035.75, no. of fragments=8
#  - 6 fragments annotated
# Annotating parent peakID=20478, mass=432.237746602, intensity=621598.9375, no. of fragments=11
#  - 10 fragments annotated
# Annotating parent peakID=20499, mass=433.258362914, intensity=1118144.125, no. of fragments=6
#  - 4 fragments annotated
# Annotating parent peakID=20506, mass=434.186993595, intensity=1732606.5, no. of fragments=5
#  - 4 fragments annotated
# Annotating parent peakID=20512, mass=435.126373988, intensity=1689264.125, no. of fragments=1
# Annotating parent peakID=20516, mass=436.145031241, intensity=4664238.0, no. of fragments=26
#  - 25 fragments annotated
# Annotating parent peakID=20543, mass=437.148559538, intensity=884823.1875, no. of fragments=17
#  - 12 fragments annotated
# Annotating parent peakID=20561, mass=437.188012046, intensity=3013830.5, no. of fragments=21
#  - 12 fragments annotated
# Annotating parent peakID=20591, mass=438.210682643, intensity=739892.8125, no. of fragments=14
#  - 8 fragments annotated
# Annotating parent peakID=20606, mass=439.128370194, intensity=1498160.75, no. of fragments=3
#  - 1 fragments annotated
# Annotating parent peakID=20610, mass=439.142233339, intensity=1162249.0, no. of fragments=3
#  - 2 fragments annotated
# Annotating parent peakID=20614, mass=439.196772763, intensity=710270.1875, no. of fragments=6
#  - 3 fragments annotated
# Annotating parent peakID=20621, mass=439.218775003, intensity=898072.8125, no. of fragments=8
#  - 4 fragments annotated
# Annotating parent peakID=20630, mass=440.17614596, intensity=1061254.375, no. of fragments=10
#  - 6 fragments annotated
# Annotating parent peakID=20641, mass=440.176183718, intensity=1602831.0, no. of fragments=10
#  - 6 fragments annotated
# Annotating parent peakID=20652, mass=442.144835577, intensity=778699.6875, no. of fragments=4
#  - 4 fragments annotated
# Annotating parent peakID=20657, mass=442.192132946, intensity=4516781.0, no. of fragments=19
#  - 18 fragments annotated
# Annotating parent peakID=20677, mass=444.171616561, intensity=817559.375, no. of fragments=10
#  - 10 fragments annotated
# Annotating parent peakID=20688, mass=446.151715063, intensity=836905.25, no. of fragments=5
#  - 2 fragments annotated
# Annotating parent peakID=20694, mass=446.186687478, intensity=3222710.75, no. of fragments=6
#  - 3 fragments annotated
# Annotating parent peakID=20701, mass=447.24484832, intensity=1073121.75, no. of fragments=15
#  - 10 fragments annotated
# Annotating parent peakID=20717, mass=447.274029734, intensity=920048.625, no. of fragments=6
#  - 6 fragments annotated
# Annotating parent peakID=20724, mass=448.194121652, intensity=961082.125, no. of fragments=13
#  - 8 fragments annotated
# Annotating parent peakID=20738, mass=449.107779552, intensity=1636686.25, no. of fragments=9
#  - 5 fragments annotated
# Annotating parent peakID=20748, mass=449.235741755, intensity=725363.0625, no. of fragments=12
#  - 9 fragments annotated
# Annotating parent peakID=20761, mass=452.213445533, intensity=1070290.5, no. of fragments=6
#  - 5 fragments annotated
# Annotating parent peakID=20768, mass=453.198012363, intensity=1257744.25, no. of fragments=5
#  - 5 fragments annotated
# Annotating parent peakID=20783, mass=455.213539206, intensity=545711.375, no. of fragments=5
#  - 4 fragments annotated
# Annotating parent peakID=20789, mass=456.207471807, intensity=6633608.0, no. of fragments=17
#  - 14 fragments annotated
# Annotating parent peakID=20807, mass=456.207899047, intensity=1643487.5, no. of fragments=17
#  - 14 fragments annotated
# Annotating parent peakID=20825, mass=457.166364481, intensity=956550.875, no. of fragments=10
#  - 9 fragments annotated
# Annotating parent peakID=20841, mass=457.222171557, intensity=885203.1875, no. of fragments=1
# Annotating parent peakID=20843, mass=465.102847841, intensity=1021833.625, no. of fragments=12
#  - 8 fragments annotated
# Annotating parent peakID=20856, mass=469.208264015, intensity=1224935.125, no. of fragments=12
#  - 4 fragments annotated
# Annotating parent peakID=20876, mass=471.218552677, intensity=1715436.0, no. of fragments=14
#  - 9 fragments annotated
# Annotating parent peakID=20891, mass=471.218580489, intensity=1796000.375, no. of fragments=20
#  - 13 fragments annotated
# Annotating parent peakID=20912, mass=471.223817987, intensity=579686.9375, no. of fragments=9
#  - 5 fragments annotated
# Annotating parent peakID=20922, mass=471.237910125, intensity=991053.8125, no. of fragments=4
# Annotating parent peakID=20927, mass=475.232913963, intensity=632575.25, no. of fragments=1
# Annotating parent peakID=20929, mass=476.137612218, intensity=1243601.75, no. of fragments=5
#  - 4 fragments annotated
# Annotating parent peakID=20941, mass=479.118367074, intensity=938849.6875, no. of fragments=13
#  - 8 fragments annotated
# Annotating parent peakID=20955, mass=480.182172103, intensity=2366169.0, no. of fragments=15
#  - 13 fragments annotated
# Annotating parent peakID=20971, mass=483.219946169, intensity=1152641.75, no. of fragments=8
#  - 5 fragments annotated
# Annotating parent peakID=20980, mass=486.181866838, intensity=1097062.125, no. of fragments=8
#  - 7 fragments annotated
# Annotating parent peakID=20989, mass=487.165650043, intensity=6549144.0, no. of fragments=15
#  - 13 fragments annotated
# Annotating parent peakID=21005, mass=487.178733419, intensity=1314945.125, no. of fragments=8
#  - 6 fragments annotated
# Annotating parent peakID=21019, mass=489.248637597, intensity=646881.625, no. of fragments=1
# Annotating parent peakID=21021, mass=490.192183848, intensity=3249550.25, no. of fragments=22
#  - 19 fragments annotated
# Annotating parent peakID=21044, mass=492.1924716, intensity=1102295.25, no. of fragments=10
#  - 8 fragments annotated
# Annotating parent peakID=21055, mass=492.192575799, intensity=641764.375, no. of fragments=10
#  - 8 fragments annotated
# Annotating parent peakID=21066, mass=498.259935639, intensity=2480739.0, no. of fragments=15
#  - 10 fragments annotated
# Annotating parent peakID=21082, mass=499.224774815, intensity=2970960.25, no. of fragments=10
#  - 6 fragments annotated
# Annotating parent peakID=21093, mass=502.249891032, intensity=1322565.5, no. of fragments=3
#  - 3 fragments annotated
# Annotating parent peakID=21097, mass=505.176401785, intensity=4808667.0, no. of fragments=16
#  - 14 fragments annotated
# Annotating parent peakID=21127, mass=506.186982734, intensity=1200896.375, no. of fragments=11
#  - 8 fragments annotated
# Annotating parent peakID=21139, mass=506.254243129, intensity=630556.1875, no. of fragments=5
#  - 5 fragments annotated
# Annotating parent peakID=21145, mass=510.216409791, intensity=757470.0, no. of fragments=3
# Annotating parent peakID=21149, mass=513.189214878, intensity=721612.125, no. of fragments=2
#  - 2 fragments annotated
# Annotating parent peakID=21158, mass=515.213280958, intensity=10979118.0, no. of fragments=9
#  - 9 fragments annotated
# Annotating parent peakID=21168, mass=515.413008058, intensity=15260396.0, no. of fragments=13
#  - 9 fragments annotated
# Annotating parent peakID=21182, mass=522.202675766, intensity=74982168.0, no. of fragments=30
#  - 21 fragments annotated
# Annotating parent peakID=21213, mass=522.202798578, intensity=65583672.0, no. of fragments=30
#  - 21 fragments annotated
# Annotating parent peakID=21244, mass=522.216101767, intensity=583705.375, no. of fragments=2
# Annotating parent peakID=21247, mass=522.216225135, intensity=695855.625, no. of fragments=2
# Annotating parent peakID=21250, mass=525.211156973, intensity=567810.375, no. of fragments=8
#  - 5 fragments annotated
# Annotating parent peakID=21259, mass=527.158390324, intensity=9864012.0, no. of fragments=8
#  - 4 fragments annotated
# Annotating parent peakID=21268, mass=527.1586605, intensity=8976546.0, no. of fragments=8
#  - 4 fragments annotated
# Annotating parent peakID=21277, mass=527.161829172, intensity=749531.0, no. of fragments=4
#  - 1 fragments annotated
# Annotating parent peakID=21282, mass=527.196583801, intensity=1225963.375, no. of fragments=4
#  - 3 fragments annotated
# Annotating parent peakID=21287, mass=527.231027857, intensity=843059.125, no. of fragments=1
# Annotating parent peakID=21289, mass=527.231272182, intensity=1225017.25, no. of fragments=1
# Annotating parent peakID=21291, mass=529.175726085, intensity=1454816.0, no. of fragments=1
#  - 1 fragments annotated
# Annotating parent peakID=21293, mass=531.407908961, intensity=562032.25, no. of fragments=6
#  - 4 fragments annotated
# Annotating parent peakID=21300, mass=532.439279211, intensity=85848112.0, no. of fragments=22
#  - 13 fragments annotated
# Annotating parent peakID=21323, mass=535.439644712, intensity=959631.6875, no. of fragments=11
#  - 3 fragments annotated
# Annotating parent peakID=21335, mass=537.195202149, intensity=12640273.0, no. of fragments=6
#  - 5 fragments annotated
# Annotating parent peakID=21342, mass=538.280207591, intensity=1383142.375, no. of fragments=7
#  - 7 fragments annotated
# Annotating parent peakID=21358, mass=540.270748455, intensity=7450965.5, no. of fragments=19
#  - 14 fragments annotated
# Annotating parent peakID=21378, mass=540.330637394, intensity=604547.4375, no. of fragments=21
#  - 17 fragments annotated
# Annotating parent peakID=21400, mass=543.132717323, intensity=527494.5625, no. of fragments=3
# Annotating parent peakID=21406, mass=546.688858674, intensity=1340515.375, no. of fragments=19
# Annotating parent peakID=21426, mass=553.309721474, intensity=624766.8125, no. of fragments=13
#  - 8 fragments annotated
# Annotating parent peakID=21440, mass=553.368955839, intensity=12241528.0, no. of fragments=1
# Annotating parent peakID=21442, mass=553.369017867, intensity=13243283.0, no. of fragments=1
# Annotating parent peakID=21448, mass=560.470802202, intensity=987080.625, no. of fragments=3
# Annotating parent peakID=21452, mass=561.694164555, intensity=836040.0, no. of fragments=30
# Annotating parent peakID=21489, mass=562.343863267, intensity=695787.4375, no. of fragments=5
#  - 4 fragments annotated
# Annotating parent peakID=21495, mass=578.226686129, intensity=1222100.625, no. of fragments=1
# Annotating parent peakID=21497, mass=580.208708073, intensity=1636948.25, no. of fragments=14
#  - 12 fragments annotated
# Annotating parent peakID=21512, mass=582.216100958, intensity=1082077.875, no. of fragments=8
#  - 8 fragments annotated
# Annotating parent peakID=21521, mass=584.356759899, intensity=750901.9375, no. of fragments=7
#  - 7 fragments annotated
# Annotating parent peakID=21529, mass=590.22916006, intensity=2226019.75, no. of fragments=12
#  - 10 fragments annotated
# Annotating parent peakID=21552, mass=603.153481524, intensity=1113125.875, no. of fragments=11
#  - 11 fragments annotated
# Annotating parent peakID=21564, mass=606.369909404, intensity=744422.8125, no. of fragments=7
#  - 7 fragments annotated
# Annotating parent peakID=21580, mass=608.240082836, intensity=675486.625, no. of fragments=3
#  - 3 fragments annotated
# Annotating parent peakID=21584, mass=611.161325394, intensity=1470114.375, no. of fragments=10
#  - 8 fragments annotated
# Annotating parent peakID=21595, mass=627.187045905, intensity=1522194.5, no. of fragments=2
# Annotating parent peakID=21598, mass=628.38278007, intensity=780065.375, no. of fragments=10
#  - 10 fragments annotated
# Annotating parent peakID=21609, mass=633.271324667, intensity=587176.0, no. of fragments=7
#  - 6 fragments annotated
# Annotating parent peakID=21617, mass=647.458532567, intensity=1605510.25, no. of fragments=5
#  - 3 fragments annotated
# Annotating parent peakID=21623, mass=649.218679088, intensity=1740094.125, no. of fragments=10
#  - 10 fragments annotated
# Annotating parent peakID=21634, mass=650.396089064, intensity=699251.75, no. of fragments=7
#  - 4 fragments annotated
# Annotating parent peakID=21642, mass=654.332120523, intensity=1803081.5, no. of fragments=13
#  - 12 fragments annotated
# Annotating parent peakID=21656, mass=660.523314701, intensity=538620.625, no. of fragments=4
#  - 4 fragments annotated
# Annotating parent peakID=21661, mass=663.453626508, intensity=3320170.0, no. of fragments=14
#  - 8 fragments annotated
# Annotating parent peakID=21676, mass=666.512338214, intensity=745498.8125, no. of fragments=6
#  - 5 fragments annotated
# Annotating parent peakID=21683, mass=666.512400464, intensity=731283.625, no. of fragments=6
#  - 6 fragments annotated
# Annotating parent peakID=21690, mass=667.2285005, intensity=2478907.0, no. of fragments=18
#  - 16 fragments annotated
# Annotating parent peakID=21709, mass=667.228942796, intensity=4032921.75, no. of fragments=18
#  - 16 fragments annotated
# Annotating parent peakID=21728, mass=668.260475344, intensity=804232.25, no. of fragments=11
#  - 10 fragments annotated
# Annotating parent peakID=21740, mass=672.409058191, intensity=618715.625, no. of fragments=6
#  - 5 fragments annotated
# Annotating parent peakID=21747, mass=680.480234456, intensity=2931464.5, no. of fragments=10
#  - 8 fragments annotated
# Annotating parent peakID=21758, mass=684.25548091, intensity=21881570.0, no. of fragments=28
#  - 19 fragments annotated
# Annotating parent peakID=21787, mass=689.211028981, intensity=5848416.0, no. of fragments=5
#  - 2 fragments annotated
# Annotating parent peakID=21793, mass=763.284320193, intensity=1701424.875, no. of fragments=3
# Annotating parent peakID=21797, mass=794.297548169, intensity=972980.6875, no. of fragments=5
#  - 5 fragments annotated
# Annotating parent peakID=21808, mass=829.280912675, intensity=1226801.375, no. of fragments=9
#  - 8 fragments annotated
# Annotating parent peakID=21818, mass=829.281205647, intensity=815349.0, no. of fragments=9
#  - 8 fragments annotated
# Annotating parent peakID=21828, mass=846.307934339, intensity=4944562.5, no. of fragments=17
#  - 14 fragments annotated
# Annotating parent peakID=21846, mass=851.263349494, intensity=1416975.125, no. of fragments=1
# Annotating parent peakID=21848, mass=991.333787137, intensity=950191.9375, no. of fragments=9
#  - 8 fragments annotated
# Annotating parent peakID=21858, mass=1008.36099911, intensity=2832173.25, no. of fragments=14
#  - 10 fragments annotated
# Annotating parent peakID=21873, mass=1009.34458171, intensity=941096.8125, no. of fragments=10
#  - 7 fragments annotated
# Annotating parent peakID=21884, mass=1026.37149511, intensity=1586896.0, no. of fragments=11
#  - 8 fragments annotated
# Annotating parent peakID=21896, mass=1031.32647435, intensity=642023.0, no. of fragments=3
#  - 2 fragments annotated
# Annotating parent peakID=21900, mass=1031.32661067, intensity=862887.0, no. of fragments=3
#  - 2 fragments annotated
# Annotating parent peakID=21904, mass=1046.84495147, intensity=1334056.75, no. of fragments=6
#  - 4 fragments annotated
#
# Total annotations MS1=1390/1588, MS2=10612/16221

# %% [markdown]
# The last line in the cell output above shows the total no. of MS1/MS2 peaks annotated:
#
# > Total annotations MS1=1390/1588, MS2=10612/16221

# %% [markdown]
# <h2>Show the results</h2>

# %% [markdown]
# The 'annotation' columns in the dataframes below were produced from SIRIUS output. No idea how well this compares to results from e.g. MassBank or NIST. Also, SIRIUS returns multiple results (corresponding to different potential formulae/fragmentation trees) with different scores, but for now, we take the one with the highest score.

# %%
display(annot_ms1)
# Out:
#        peakID  MSnParentPeakID  msLevel        rt           mz      intensity  \
# 1           1                0        1   578.503    70.065165  16431632.0000
# 4           4                0        1   652.517    70.065191    602081.6875
# 6           6                0        1   566.043    72.080799   1067314.7500
# 11         11                0        1  1210.110    72.080818   1025769.1250
# 14         14                0        1   468.470    73.064788    925079.4375
# 17         17                0        1   656.240    76.039316   1047793.6875
# 20         20                0        1  1027.660    76.075699   1636355.7500
# 26         26                0        1   562.308    81.033514    766053.0000
# 29         29                0        1   632.557    83.060245    705789.6250
# 33         33                0        1   486.476    84.044375   2827970.7500
# 37         37                0        1   566.043    84.080711    978819.3750
# 40         40                0        1   667.614    85.028372   3757659.5000
# 42         42                0        1   603.462    85.028377   1687362.8750
# 45         45                0        1   465.819    85.028381   2102897.0000
# 52         52                0        1   415.512    86.059962   1211292.7500
# 55         55                0        1   646.272    86.060008   8953359.0000
# 59         59                0        1  1005.220    86.060024   1433368.6250
# 61         61                0        1  1018.270    86.060026    532986.6250
# 63         63                0        1   603.462    86.096103    569424.0000
# 65         65                0        1   609.647    86.096129    551113.2500
# 67         67                0        1   280.189    86.096375   1282799.1250
# 72         72                0        1   519.739    86.096417   2307827.7500
# 76         76                0        1   646.272    87.044055  12338473.0000
# 79         79                0        1   636.289    87.055276    735020.5000
# 82         82                0        1   434.590    89.059678    787915.5625
# 89         89                0        1   908.712    89.070924   1793272.5000
# 98         98                0        1   645.032    90.054941   2888840.5000
# 102       102                0        1   433.349    90.054973    695324.8750
# 104       104                0        1   631.311    90.054973   6755740.0000
# 108       108                0        1   804.705    90.091364   2163393.0000
# ...       ...              ...      ...       ...          ...            ...
# 21598   21598                0        1   270.932   628.382780    780065.3750
# 21609   21609                0        1   690.253   633.271325    587176.0000
# 21617   21617                0        1   217.007   647.458533   1605510.2500
# 21623   21623                0        1   677.736   649.218679   1740094.1250
# 21634   21634                0        1   270.932   650.396089    699251.7500
# 21642   21642                0        1   223.381   654.332121   1803081.5000
# 21656   21656                0        1   273.606   660.523315    538620.6250
# 21661   21661                0        1   218.245   663.453627   3320170.0000
# 21676   21676                0        1   218.245   666.512338    745498.8125
# 21683   21683                0        1   225.864   666.512400    731283.6250
# 21690   21690                0        1   666.373   667.228500   2478907.0000
# 21709   21709                0        1   676.494   667.228943   4032921.7500
# 21728   21728                0        1   661.235   668.260475    804232.2500
# 21740   21740                0        1   269.685   672.409058    618715.6250
# 21747   21747                0        1   219.484   680.480234   2931464.5000
# 21758   21758                0        1   677.736   684.255481  21881570.0000
# 21787   21787                0        1   677.736   689.211029   5848416.0000
# 21793   21793                0        1   514.793   763.284320   1701424.8750
# 21797   21797                0        1   605.939   794.297548    972980.6875
# 21808   21808                0        1   685.234   829.280913   1226801.3750
# 21818   21818                0        1   676.494   829.281206    815349.0000
# 21828   21828                0        1   686.519   846.307934   4944562.5000
# 21846   21846                0        1   686.519   851.263349   1416975.1250
# 21848   21848                0        1   689.007   991.333787    950191.9375
# 21858   21858                0        1   689.007  1008.360999   2832173.2500
# 21873   21873                0        1   661.235  1009.344582    941096.8125
# 21884   21884                0        1   663.894  1026.371495   1586896.0000
# 21896   21896                0        1   670.092  1031.326474    642023.0000
# 21900   21900                0        1   661.235  1031.326611    862887.0000
# 21904   21904                0        1   222.140  1046.844951   1334056.7500
#
#        Sample  GroupPeakMSn  CollisionEnergy     annotation
# 1           1             0                0            NaN
# 4           1             0                0            NaN
# 6           1             0                0          C4H9N
# 11          1             0                0          C4H9N
# 14          1             0                0          C4H8O
# 17          1             0                0            NaN
# 20          1             0                0         C3H9NO
# 26          1             0                0          C5H4O
# 29          1             0                0         C4H6N2
# 33          1             0                0         C4H5NO
# 37          1             0                0          C5H9N
# 40          1             0                0            NaN
# 42          1             0                0         C4H4O2
# 45          1             0                0         C4H4O2
# 52          1             0                0         C4H7NO
# 55          1             0                0         C4H7NO
# 59          1             0                0            NaN
# 61          1             0                0            NaN
# 63          1             0                0            NaN
# 65          1             0                0            NaN
# 67          1             0                0         C5H11N
# 72          1             0                0            NaN
# 76          1             0                0            NaN
# 79          1             0                0            NaN
# 82          1             0                0            NaN
# 89          1             0                0        C3H8N2O
# 98          1             0                0            NaN
# 102         1             0                0            NaN
# 104         1             0                0            NaN
# 108         1             0                0        C4H11NO
# ...       ...           ...              ...            ...
# 21598       1             0                0     C32H49N7O6
# 21609       1             0                0    C25H40N6O13
# 21617       1             0                0     C33H58N8O5
# 21623       1             0                0    C25H36N4O16
# 21634       1             0                0     C30H51N9O7
# 21642       1             0                0    C33H53NO8P2
# 21656       1             0                0     C41H65N5O2
# 21661       1             0                0     C44H58N2O3
# 21676       1             0                0      C42H67NO5
# 21683       1             0                0      C42H67NO5
# 21690       1             0                0      C24H42O21
# 21709       1             0                0    C25H38N4O17
# 21728       1             0                0    C26H37N9O12
# 21740       1             0                0      C38H57NO9
# 21747       1             0                0    C38H62N7O2P
# 21758       1             0                0     C24H45NO21
# 21787       1             0                0     C35H28N8O8
# 21793       1             0                0            NaN
# 21797       1             0                0    C31H47N5O19
# 21808       1             0                0    C32H44N8O18
# 21818       1             0                0    C32H44N8O18
# 21828       1             0                0    C32H47N9O18
# 21846       1             0                0            NaN
# 21848       1             0                0      C43H58O26
# 21858       1             0                0     C36H65NO31
# 21873       1             0                0    C49H56N2O21
# 21884       1             0                0    C38H59N9O24
# 21896       1             0                0  C42H66N2O19S4
# 21900       1             0                0  C42H66N2O19S4
# 21904       1             0                0  C22H18N2O38S4
#
# [1588 rows x 10 columns]

# %%
display(annot_ms2)
# Out:
#        peakID  MSnParentPeakID  msLevel        rt           mz  intensity  \
# 2           2                1        2   578.503    53.002529   0.005552
# 3           3                1        2   578.503    70.065056   1.000000
# 5           5                4        2   652.517    70.065071   1.000000
# 7           7                6        2   566.043    53.039211   0.050747
# 8           8                6        2   566.043    55.054646   1.000000
# 9           9                6        2   566.043    57.057762   0.391897
# 10         10                6        2   566.043    72.080719   0.679171
# 12         12               11        2  1210.110    55.054623   0.008443
# 13         13               11        2  1210.110    72.080650   1.000000
# 15         15               14        2   468.470    55.054657   1.000000
# 16         16               14        2   468.470    73.064598   0.288576
# 18         18               17        2   656.240    58.065552   1.000000
# 19         19               17        2   656.240    76.075615   0.138594
# 21         21               20        2  1027.660    53.002563   0.011185
# 22         22               20        2  1027.660    58.065498   1.000000
# 23         23               20        2  1027.660    59.073490   0.029155
# 27         27               26        2   562.308    53.038921   0.887303
# 28         28               26        2   562.308    81.033340   1.000000
# 30         30               29        2   632.557    54.034100   0.022035
# 31         31               29        2   632.557    66.034050   0.026279
# 32         32               29        2   632.557    83.060371   1.000000
# 34         34               33        2   486.476    53.002594   0.074042
# 35         35               33        2   486.476    56.049751   0.800150
# 36         36               33        2   486.476    84.044197   1.000000
# 38         38               37        2   566.043    55.054684   0.034129
# 39         39               37        2   566.043    84.080719   1.000000
# 41         41               40        2   667.614    85.028328   1.000000
# 43         43               42        2   603.462    55.018318   0.272313
# 44         44               42        2   603.462    85.028320   1.000000
# 46         46               45        2   465.819    55.018406   0.157858
# ...       ...              ...      ...       ...          ...        ...
# 21877   21877            21873        2   661.235    91.039299   0.037068
# 21878   21878            21873        2   661.235    97.028313   0.237580
# 21879   21879            21873        2   661.235   127.038559   0.285089
# 21880   21880            21873        2   661.235   145.049866   0.910275
# 21881   21881            21873        2   661.235   271.082611   0.012635
# 21882   21882            21873        2   661.235   325.112091   0.213916
# 21883   21883            21873        2   661.235   738.098083   0.009188
# 21885   21885            21884        2   663.894    71.049377   0.010740
# 21886   21886            21884        2   663.894    85.028313   1.000000
# 21887   21887            21884        2   663.894    87.043877   0.009699
# 21888   21888            21884        2   663.894    97.028366   0.267590
# 21889   21889            21884        2   663.894   115.039116   0.009385
# 21890   21890            21884        2   663.894   127.038681   0.274624
# 21891   21891            21884        2   663.894   145.049896   0.887525
# 21892   21892            21884        2   663.894   163.060471   0.362722
# 21893   21893            21884        2   663.894   204.085434   0.006161
# 21894   21894            21884        2   663.894   271.082550   0.024969
# 21895   21895            21884        2   663.894   325.111481   0.383044
# 21897   21897            21896        2   670.092   119.019157   0.007066
# 21898   21898            21896        2   670.092   347.095764   0.007377
# 21899   21899            21896        2   670.092   527.158630   1.000000
# 21901   21901            21900        2   661.235   119.019157   0.007066
# 21902   21902            21900        2   661.235   347.095764   0.007377
# 21903   21903            21900        2   661.235   527.158630   1.000000
# 21905   21905            21904        2   222.140    73.028519   0.056909
# 21906   21906            21904        2   222.140    89.005951   0.315177
# 21907   21907            21904        2   222.140   115.021629   0.137869
# 21908   21908            21904        2   222.140   143.017059   1.000000
# 21909   21909            21904        2   222.140   329.216003   0.209143
# 21910   21910            21904        2   222.140  1018.184326   0.015034
#
#        Sample  GroupPeakMSn  CollisionEnergy  fragment_bin_id  loss_bin_id  \
# 2           1             0                0         53.00259          NaN
# 3           1             0                0         70.06514          NaN
# 5           1             0                0         70.06514          NaN
# 7           1             0                0         53.03893          NaN
# 8           1             0                0         55.05466     17.02617
# 9           1             0                0         57.05774          NaN
# 10          1             0                0         72.08070          NaN
# 12          1             0                0         55.05466     17.02617
# 13          1             0                0         72.08070          NaN
# 15          1             0                0         55.05466     18.01013
# 16          1             0                0         73.06468          NaN
# 18          1             0                0         58.06553     17.97373
# 19          1             0                0         76.07561          NaN
# 21          1             0                0         53.00259          NaN
# 22          1             0                0         58.06553     18.01013
# 23          1             0                0         59.07334          NaN
# 27          1             0                0         53.03893     27.99468
# 28          1             0                0         81.03333          NaN
# 30          1             0                0         54.03418          NaN
# 31          1             0                0         66.03409     17.02617
# 32          1             0                0         83.06041          NaN
# 34          1             0                0         53.00259     31.04189
# 35          1             0                0         56.04977     27.99468
# 36          1             0                0         84.04420          NaN
# 38          1             0                0         55.05466          NaN
# 39          1             0                0         84.08072          NaN
# 41          1             0                0         85.02832          NaN
# 43          1             0                0         55.01824     30.01020
# 44          1             0                0         85.02832          NaN
# 46          1             0                0         55.01824     30.01020
# ...       ...           ...              ...              ...          ...
# 21877       1             0                0         91.03926          NaN
# 21878       1             0                0         97.02839          NaN
# 21879       1             0                0        127.03869          NaN
# 21880       1             0                0        145.04996          NaN
# 21881       1             0                0        271.08259          NaN
# 21882       1             0                0        325.11198          NaN
# 21883       1             0                0        738.09808          NaN
# 21885       1             0                0         71.04937          NaN
# 21886       1             0                0         85.02832          NaN
# 21887       1             0                0         87.04393          NaN
# 21888       1             0                0         97.02839          NaN
# 21889       1             0                0        115.03908          NaN
# 21890       1             0                0        127.03869          NaN
# 21891       1             0                0        145.04996          NaN
# 21892       1             0                0        163.06064          NaN
# 21893       1             0                0        204.08537          NaN
# 21894       1             0                0        271.08259          NaN
# 21895       1             0                0        325.11198          NaN
# 21897       1             0                0        119.01914          NaN
# 21898       1             0                0        347.09570          NaN
# 21899       1             0                0        527.15831          NaN
# 21901       1             0                0        119.01914          NaN
# 21902       1             0                0        347.09570          NaN
# 21903       1             0                0        527.15831          NaN
# 21905       1             0                0         73.02850          NaN
# 21906       1             0                0         89.00596          NaN
# 21907       1             0                0        115.02155          NaN
# 21908       1             0                0        143.01705          NaN
# 21909       1             0                0        329.21577          NaN
# 21910       1             0                0       1018.18433          NaN
#
#        annotation
# 2             NaN
# 3             NaN
# 5             NaN
# 7            C4H4
# 8            C4H6
# 9           C3H6N
# 10          C4H9N
# 12           C4H6
# 13          C4H9N
# 15           C4H6
# 16          C4H8O
# 18            NaN
# 19            NaN
# 21            NaN
# 22          C3H7N
# 23            NaN
# 27           C4H4
# 28          C5H4O
# 30          C3H3N
# 31          C4H3N
# 32         C4H6N2
# 34            C3O
# 35          C3H5N
# 36         C4H5NO
# 38           C4H6
# 39          C5H9N
# 41            NaN
# 43          C3H2O
# 44         C4H4O2
# 46          C3H2O
# ...           ...
# 21877      C3H6O3
# 21878      C5H4O2
# 21879      C6H6O3
# 21880      C6H8O4
# 21881         NaN
# 21882         NaN
# 21883         NaN
# 21885       C4H6O
# 21886      C4H4O2
# 21887      C4H6O2
# 21888      C5H4O2
# 21889      C5H6O3
# 21890      C6H6O3
# 21891      C6H8O4
# 21892     C6H10O5
# 21893         NaN
# 21894         NaN
# 21895         NaN
# 21897         NaN
# 21898    C19H22S3
# 21899  C25H34O6S3
# 21901         NaN
# 21902    C19H22S3
# 21903  C25H34O6S3
# 21905      C3H4O2
# 21906      C3H4OS
# 21907      C5H6OS
# 21908     C6H6O2S
# 21909         NaN
# 21910         NaN
#
# [16221 rows x 12 columns]

# %% [markdown]
# <h2>Save the files</h2>

# %%
ms1_filename = '../input/final/Beer_3_full1_5_2E5_pos_ms1_annotated.csv'
ms2_filename = '../input/final/Beer_3_full1_5_2E5_pos_ms2_annotated.csv'
annot_ms1.to_csv(ms1_filename)
annot_ms2.to_csv(ms2_filename)
