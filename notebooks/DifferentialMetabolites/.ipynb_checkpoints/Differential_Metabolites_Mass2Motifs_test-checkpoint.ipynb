# %% [markdown]
# <h2>Differential metabolites BeerQC (4) UP vs Beer3<h2>

# %% [markdown]
# Trying to find all the peaks in the differential metabolites (UP) list and plotting their motifs..

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import sys
basedir = '../'
sys.path.append(basedir)

import numpy as np
import pandas as pd
import networkx as nx
import pylab as plt

import matplotlib as mpl
import matplotlib.cm as cm

from IPython.display import display
from lda_for_fragments import Ms2Lda
from visualisation.networkx.lda_visualisation import *

# get rid of annoying warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h2>1. Load Data and apply thresholding</h2>
#
# Load Beer3pos project used by Justin and apply thresholding below.

# %%
ms2lda = Ms2Lda.resume_from('results/Manuscript_BeerQCPOSmode_EFassigner_ALLextended.project')
# Out:
# Project loaded from results/Manuscript_BeerQCPOSmode_EFassigner_ALLextended.project time taken = 21.5333785463
#  - input_filenames =
# 	../input/manuscript/BeerQCpos_MS1filter_Method3_fragments.csv
# 	../input/manuscript/BeerQCpos_MS1filter_Method3_losses.csv
# 	../input/manuscript/BeerQCpos_MS1filter_Method3_ms1.csv
# 	../input/manuscript/BeerQCpos_MS1filter_Method3_ms2.csv
#  - df.shape = (1363, 4250)
#  - K = 300
#  - alpha = 0.166666666667
#  - beta = 0.1
#  - number of samples stored = 1
#  - last_saved_timestamp = 11/30/15 16:58:18
#  - message = Beer4Pos analysis for the manuscript with EFassigner EF assignments for ms1, fragments, and losses

# %%
ms2lda.do_thresholding(th_doc_topic=0.05, th_topic_word=0.01)

# %% [markdown]
# <h2>2. Create network graph</h2>

# %% [markdown]
# Load the motifs of interest from an external file

# %%
import csv
motif_annotation = {}
motif_idx = {}
i = 0
for item in csv.reader(open("results/beer4pos_annotation_Nov2015.csv"), skipinitialspace=True):
    key = int(item[0])
    val = item[1]
    print str(key) + "\t" + val
    motif_annotation[key] = val
    motif_idx[key] = i
    i += 1

motifs_of_interest = motif_annotation.keys()    

# map each motif to the colourmap too
# http://matplotlib.org/1.2.1/mpl_examples/pylab_examples/show_colormaps.hires.png
norm = mpl.colors.Normalize(vmin=min(motif_idx.values()), vmax=max(motif_idx.values()))
cmap = cm.gist_rainbow
motif_colour = cm.ScalarMappable(norm=norm, cmap=cmap)
# Out:
# 9	Small nitrogen containing fragment ion - often proline or ornithine derived
# 193	Water loss - indicative of a free hydroxyl group
# 273	Combined loss of H2O and CO, suggests free carboxylic acid group (COOH) substructure
# 189	Loss of [hexose-H2O] - suggests hexose conjugation (e.g. glucose) substructure
# 169	Leucine substructure
# 149	Conjugation of a phosphate group (H4O4P) substructure
# 250	Losses indicative of a hexose with NH2 group
# 28	Fragments possibly indicative for N-Methyl-oxo-pyrrolidinecarboxylic acid like structure
# 170	Pyroglutamic acid (pyroglutamate) substructure
# 205	Amine loss - suggests free NH2 group in fragmented molecule
# 89	Double water loss - indicative for metabolites containing multiple OH groups and aliphatic chain, e.g. as in sugars
# 202	[proline-H2O] suggests conjugated proline substructure
# 36	Loss possibly indicative of carboxylic acid group with 1-carbon attached
# 68	Alkyl aromatic substructure - suggests aromatic ring with 2-carbon alkyl chain attached
# 79	Pipecolic acid (pipecolate) substructure
# 243	Trimethylated amine connected to a carboxylic acid group substructure (e.g. betaine)
# 69	Cytosine and a loss of conjugated deoxyribose substructure
# 24	Adenine substructure
# 157	Cinnamic acid (cinnamate) substructure
# 47	Histidine substructure
# 110	[phenylalanine-COOH] substructure
# 11	Xanthine substructure
# 256	Ferulic acid substructure
# 185	Ethylphenol substructure (e.g. resulting from Tyramine - MzCloud)
# 164	Possibly suggests 2-OH-4-oxo-pentanoic acid substructure
# 286	Possibly suggests agmatine based substructure (C5H15N4), with unknown conjugation
# 52	fragments from [hexose-H2O] substructure (a hexose conjugation, e.g. glucose)
# 67	Aconitic acid (aconitate) substructure
# 8	Tyrosine substructure
# 78	5-methylcytosine substructure
# 181	N-acetylputrescine substructure
# 84	Aromatic substructure, i.e., benzene ring with hydroxyl and amine substitution
# 99	[Pentose-H2O] loss, e.g. ribose

# %%
G = get_network_graph(ms2lda, motifs_of_interest)
print "\n" + nx.info(G)
# Out:
# Removed 266 motifs from the graph because they're not in the list
# Removed 428 unconnected documents from the graph
#
# Name:
# Type: Graph
# Number of nodes: 968
# Number of edges: 1375
# Average degree:   2.8409

# %% [markdown]
# How many MS1 peaks can be explained by the M2Ms in the validated list?

# %%
ms1_count = 0
nodes = G.nodes(data=True)
for node_id, node_data in nodes:
    # 1 for doc, 2 for motif
    if node_data['group'] == 1: 
        ms1_count += 1
        
print "%d (out of %d) MS1 peaks found in the graph" % (ms1_count, ms2lda.ms1.shape[0])
# Out:
# 935 (out of 1363) MS1 peaks found in the graph

# %% [markdown]
# <h2>3. Standard Peaks</h2>

# %% [markdown]
# Now we need to find which MS1 peaks match the list of standards. First, load the standard csv.

# %%
mode = 'POS' # either 'POS' or 'NEG'

de_peaks = []
with open("results/DifferentialMetabolites_BeerQC.csv", "rb") as infile:
   reader = csv.reader(infile)
   next(reader, None)  # skip the headers
   for row in reader:
    PiMP_ID = int(row[0])
    polarity = row[1]
    mz = float(row[2])
    rt = float (row[3])
    mh_intensity = float(row[4])
    tup = (PiMP_ID, polarity, mz, rt, mh_intensity)
    if mode == 'POS' and polarity == '+':
        de_peaks.append(tup)
    elif mode == 'NEG' and polarity == '-':
        de_peaks.append(tup)

for tup in de_peaks:
    print tup
# Out:
# (2424, '+', 354.1295, 429.48, 3967390.75)
# (2477, '+', 354.1408, 735.04, 3767671.667)
# (5138, '+', 260.0826, 232.43, 3451589.0)
# (777, '+', 256.03, 693.5, 2427559.083)
# (181, '+', 270.1091, 470.62, 2189550.333)
# (2299, '+', 238.092, 518.05, 1643203.253)
# (2300, '+', 243.0474, 519.31, 1495664.377)
# (2605, '+', 206.0457, 539.75, 1314105.67)
# (4372, '+', 230.9999, 695.1, 1305630.42)
# (5419, '+', 397.2238, 236.37, 1299405.087)
# (6428, '+', 323.0789, 413.15, 1336570.21)
# (778, '+', 274.0405, 693.09, 1229798.713)
# (3322, '+', 324.0591, 613.39, 890533.17)
# (1255, '+', 428.1411, 597.15, 861084.0433)
# (3208, '+', 330.1295, 622.05, 862293.2333)
# (5421, '+', 413.219, 245.14, 843271.3133)
# (2758, '+', 254.1173, 269.86, 837660.25)
# (2672, '+', 378.1403, 447.5, 821693.6033)
# (4373, '+', 246.9775, 695.38, 795583.25)
# (5918, '+', 566.2631, 294.89, 778493.44)
# (3108, '+', 211.0812, 503.57, 753995.0633)
# (2858, '+', 175.0965, 266.27, 760807.3233)
# (3209, '+', 368.1561, 616.76, 721030.23)
# (820, '+', 283.0326, 499.83, 755638.24)
# (3354, '+', 218.0811, 253.86, 709775.76)
# (6744, '+', 220.073, 429.76, 680206.71)
# (478, '+', 266.0536, 513.15, 680347.0233)
# (910, '+', 166.1074, 494.94, 625425.8333)
# (4844, '+', 288.0719, 470.11, 600080.0033)
# (3527, '+', 439.1925, 493.39, 590681.6867)
# (779, '+', 272.0076, 693.49, 552816.92)
# (3542, '+', 134.1176, 713.58, 552042.0867)
# (823, '+', 150.1125, 497.02, 518532.54)
# (4988, '+', 565.1771, 581.15, 517137.0567)
# (2668, '+', 269.0878, 524.03, 2569696.25)
# (2682, '+', 590.1805, 565.37, 1060588.42)
# (6663, '+', 322.045, 613.81, 840622.0)
# (5143, '+', 289.074, 232.15, 886942.21)
# (4313, '+', 308.9924, 643.81, 1007959.793)
# (3494, '+', 231.0975, 616.01, 640782.3567)
# (1309, '+', 244.129, 539.65, 900080.23)
# (2407, '+', 415.181, 547.32, 624152.8567)
# (536, '+', 567.1912, 582.05, 628593.595)
# (6660, '+', 261.079, 270.02, 519690.095)
# (6701, '+', 319.0843, 280.35, 650521.3567)
# (460, '+', 455.1883, 514.21, 4000435.167)
# (2852, '+', 393.1366, 550.18, 1878598.753)
# (1953, '+', 225.0968, 449.04, 1562341.543)
# (2172, '+', 606.2326, 292.18, 1104562.543)
# (4314, '+', 188.9719, 643.81, 626548.5233)
# (3075, '+', 296.1128, 482.11, 695297.02)
# (3393, '+', 324.0592, 622.28, 764969.25)
# (6280, '+', 310.9026, 1392.21, 1208669.503)
# (5014, '+', 301.1199, 411.81, 731658.25)
# (2652, '+', 234.077, 596.3, 671467.0633)
# (4371, '+', 212.9894, 697.61, 3908850.917)
# (5165, '+', 145.0143, 632.21, 17087336.67)
# (6063, '+', 173.0456, 266.55, 3685243.667)
# (4879, '+', 87.0088, 421.65, 42337389.33)
# (776, '+', 210.0608, 696.16, 29793915.33)
# (4834, '+', 395.1325, 469.46, 7040971.333)
# (5137, '+', 217.0527, 229.45, 28823858.67)
# (1938, '+', 291.6649, 674.84, 2015934.187)
# (247, '+', 487.1784, 559.83, 46749638.67)
# (4833, '+', 266.0898, 469.14, 5719657.667)
# (180, '+', 268.1039, 470.81, 244884144.0)
# (2062, '+', 332.1339, 506.41, 2112093.46)
# (3198, '+', 187.1229, 1423.46, 1179916.583)
# (3143, '+', 187.1228, 1420.67, 1220622.71)
# (2854, '+', 141.0546, 269.68, 1789204.67)
# (1867, '+', 275.0526, 482.1, 2825390.583)
# (248, '+', 509.1607, 560.76, 6087367.333)
# (5771, '+', 145.0507, 569.88, 2994952.917)
# (5924, '+', 173.0092, 542.41, 4784228.917)
# (5501, '+', 379.2133, 248.7, 10812150.0)
# (5474, '+', 383.2082, 242.85, 949461.6267)
# (5149, '+', 353.1511, 240.02, 710827.6267)
# (4965, '+', 99.0088, 294.26, 33116210.0)
# (6621, '+', 235.0826, 478.62, 775297.5433)
# (3107, '+', 185.0419, 501.49, 1125102.42)
# (6646, '+', 288.9877, 701.32, 890985.0)
# (3483, '+', 169.1335, 776.01, 564030.5433)
# (2855, '+', 381.2273, 262.86, 1477519.21)
# (830, '+', 215.0161, 709.97, 1909495.587)
# (3356, '+', 385.2221, 249.67, 574684.3033)
# (4966, '+', 161.0456, 296.44, 11701058.67)
# (2061, '+', 258.1082, 518.86, 6458264.5)
# (2170, '+', 238.0709, 293.63, 4288407.25)
# (2405, '+', 437.1629, 547.88, 1949070.253)
# (2171, '+', 568.2769, 292.41, 2153501.793)
# (4998, '+', 333.135, 220.34, 8064108.167)
# (4969, '+', 395.2079, 298.1, 3883880.667)
# (5141, '+', 333.1351, 227.03, 1985867.127)
# (465, '+', 250.0797, 513.78, 1393836.587)
# (5277, '+', 242.0786, 558.46, 20867005.33)
# (2404, '+', 388.1813, 549.53, 2997966.75)
# (6706, '+', 185.0457, 297.83, 573729.3133)
# (5809, '+', 114.0197, 416.22, 1105772.587)
# (4677, '+', 487.1326, 498.11, 848097.4567)
# (534, '+', 284.0987, 583.45, 44096980.0)
# (1866, '+', 254.1234, 480.64, 4902429.167)
# (6672, '+', 322.045, 621.15, 647102.79)
# (4967, '+', 236.0567, 293.99, 7468338.667)
# (5416, '+', 281.1397, 240.61, 15463010.33)
# (5841, '+', 319.1192, 224.99, 5983610.167)
# (2754, '+', 137.0597, 275.45, 2085911.377)
# (5720, '+', 365.1975, 250.62, 7957970.5)

# %% [markdown]
# Find out the peak ids in our MS1 dataframe that match these standards

# %%
import math

mass_tol = 3
rt_tol = 12

std = np.array(de_peaks)
std_mz = np.array([x[2] for x in de_peaks])
std_rt = np.array([x[3] for x in de_peaks])
matches = {}

ms1_label = {}
for row in ms2lda.ms1.itertuples(index=True):
    peakid = row[1]
    mz = row[5]
    rt = row[4]

    # the following line is hacky for pos mode data
    mass_delta = mz*mass_tol*1e-6
    mass_start = mz-mass_delta
    mass_end = mz+mass_delta
    rt_start = rt-rt_tol
    rt_end = rt+rt_tol

    match_mass = (std_mz>mass_start) & (std_mz<mass_end)
    match_rt = (std_rt>rt_start) & (std_rt<rt_end)
    match = match_mass & match_rt

    res = std[match]
    if len(res) == 1:
        closest = tuple(res[0])
        matches[closest] = row
        ms1_label[row[1]] = closest[1]        
    elif len(res)>1:
        closest = None
        min_dist = sys.maxint
        for match_res in res:
            match_mz = float(match_res[2])
            match_rt = float(match_res[3])
            dist = math.sqrt((match_rt-rt)**2 + (match_mz-mz)**2)
            if dist < min_dist:
                min_dist = dist
                closest = match_res
        closest = tuple(closest)
        matches[closest] = row
        ms1_label[row[1]] = closest[1]

print "Matches found %d/%d" % (len(matches), len(std))
print

ms1_list = []
for match in matches:
    key = str(match)
    ms1_row = matches[match]
    value = str(ms1_row)
    pid = ms1_row[1]
    print "Standard %s" % key
    print "MS1 %s" % value
    print
    ms1_list.append(pid)
# Out:
# Matches found 45/107
#
# Standard ('910', '+', '166.1074', '494.94', '625425.8333')
# MS1 Pandas(Index=5163, peakID=5163, MSnParentPeakID=0, msLevel=1, rt=495.17599999999999, mz=166.107378950955, intensity=607225.875, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C6H16O4N')
#
# Standard ('2858', '+', '175.0965', '266.27', '760807.3233')
# MS1 Pandas(Index=6394, peakID=6394, MSnParentPeakID=0, msLevel=1, rt=266.71899999999999, mz=175.09643940693297, intensity=947203.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C8H15O4')
#
# Standard ('180', '+', '268.1039', '470.81', '244884144.0')
# MS1 Pandas(Index=20418, peakID=20418, MSnParentPeakID=0, msLevel=1, rt=470.13699999999994, mz=268.10381038427897, intensity=229088112.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C9H18O8N')
#
# Standard ('181', '+', '270.1091', '470.62', '2189550.333')
# MS1 Pandas(Index=20724, peakID=20724, MSnParentPeakID=0, msLevel=1, rt=468.899, mz=270.10901260333901, intensity=2065372.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C11H16O5N3')
#
# Standard ('1867', '+', '275.0526', '482.1', '2825390.583')
# MS1 Pandas(Index=21520, peakID=21520, MSnParentPeakID=0, msLevel=1, rt=481.36199999999997, mz=275.05253038985802, intensity=1679217.75, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C12H12N4PS')
#
# Standard ('2404', '+', '388.1813', '549.53', '2997966.75')
# MS1 Pandas(Index=30745, peakID=30745, MSnParentPeakID=0, msLevel=1, rt=550.56100000000004, mz=388.18138664489095, intensity=3048031.75, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C18H32O4NP2')
#
# Standard ('3393', '+', '324.0592', '622.28', '764969.25')
# MS1 Pandas(Index=26075, peakID=26075, MSnParentPeakID=0, msLevel=1, rt=625.24900000000002, mz=324.05915901800699, intensity=719986.4375, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C11H20O4NP2S')
#
# Standard ('2668', '+', '269.0878', '524.03', '2569696.25')
# MS1 Pandas(Index=20579, peakID=20579, MSnParentPeakID=0, msLevel=1, rt=522.88199999999995, mz=269.08802031390303, intensity=2894803.25, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C9H17O9')
#
# Standard ('534', '+', '284.0987', '583.45', '44096980.0')
# MS1 Pandas(Index=22935, peakID=22935, MSnParentPeakID=0, msLevel=1, rt=583.25300000000004, mz=284.09884674204397, intensity=42526428.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C9H18O9N')
#
# Standard ('536', '+', '567.1912', '582.05', '628593.595')
# MS1 Pandas(Index=32541, peakID=32541, MSnParentPeakID=0, msLevel=1, rt=583.25300000000004, mz=567.19150820261393, intensity=601696.625, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C19H39O13N2S2')
#
# Standard ('2758', '+', '254.1173', '269.86', '837660.25')
# MS1 Pandas(Index=18003, peakID=18003, MSnParentPeakID=0, msLevel=1, rt=272.06700000000001, mz=254.11734716837299, intensity=874228.4375, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C10H17ON5P')
#
# Standard ('478', '+', '266.0536', '513.15', '680347.0233')
# MS1 Pandas(Index=19808, peakID=19808, MSnParentPeakID=0, msLevel=1, rt=512.69500000000005, mz=266.05363524545999, intensity=545717.4375, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C9H18O2NP2S')
#
# Standard ('2062', '+', '332.1339', '506.41', '2112093.46')
# MS1 Pandas(Index=26635, peakID=26635, MSnParentPeakID=0, msLevel=1, rt=517.75199999999995, mz=332.134025306632, intensity=2291492.25, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C18H24ONP2')
#
# Standard ('2682', '+', '590.1805', '565.37', '1060588.42')
# MS1 Pandas(Index=32588, peakID=32588, MSnParentPeakID=0, msLevel=1, rt=567.07000000000005, mz=590.18054870372202, intensity=1128395.125, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C31H32O5N3S2')
#
# Standard ('2405', '+', '437.1629', '547.88', '1949070.253')
# MS1 Pandas(Index=31534, peakID=31534, MSnParentPeakID=0, msLevel=1, rt=546.65599999999995, mz=437.16319337144205, intensity=2068422.125, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C13H29O14N2')
#
# Standard ('1866', '+', '254.1234', '480.64', '4902429.167')
# MS1 Pandas(Index=18020, peakID=18020, MSnParentPeakID=0, msLevel=1, rt=480.12599999999998, mz=254.123306348222, intensity=4740362.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C13H22NP2')
#
# Standard ('3356', '+', '385.2221', '249.67', '574684.3033')
# MS1 Pandas(Index=30633, peakID=30633, MSnParentPeakID=0, msLevel=1, rt=252.15599999999998, mz=385.22219985686399, intensity=684495.9375, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C24H35P2')
#
# Standard ('2855', '+', '381.2273', '262.86', '1477519.21')
# MS1 Pandas(Index=30535, peakID=30535, MSnParentPeakID=0, msLevel=1, rt=261.22500000000002, mz=381.22714377964502, intensity=1849363.25, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C17H39ON2P2S')
#
# Standard ('3107', '+', '185.0419', '501.49', '1125102.42')
# MS1 Pandas(Index=7426, peakID=7426, MSnParentPeakID=0, msLevel=1, rt=505.16800000000001, mz=185.04197755476201, intensity=1186315.125, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C4H13O2N2S2')
#
# Standard ('3208', '+', '330.1295', '622.05', '862293.2333')
# MS1 Pandas(Index=26502, peakID=26502, MSnParentPeakID=0, msLevel=1, rt=620.24699999999996, mz=330.12952753153002, intensity=834149.4375, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C17H22N3P2')
#
# Standard ('1953', '+', '225.0968', '449.04', '1562341.543')
# MS1 Pandas(Index=12903, peakID=12903, MSnParentPeakID=0, msLevel=1, rt=448.47199999999998, mz=225.09684230046699, intensity=1567233.5, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C8H17O7')
#
# Standard ('1309', '+', '244.129', '539.65', '900080.23')
# MS1 Pandas(Index=16568, peakID=16568, MSnParentPeakID=0, msLevel=1, rt=540.40199999999993, mz=244.12915807096101, intensity=1095401.375, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C12H23NPS')
#
# Standard ('3322', '+', '324.0591', '613.39', '890533.17')
# MS1 Pandas(Index=26088, peakID=26088, MSnParentPeakID=0, msLevel=1, rt=614.96300000000008, mz=324.05916593753301, intensity=953350.5, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C11H20O4NP2S')
#
# Standard ('778', '+', '274.0405', '693.09', '1229798.713')
# MS1 Pandas(Index=21249, peakID=21249, MSnParentPeakID=0, msLevel=1, rt=693.76699999999994, mz=274.04049524212598, intensity=1110667.125, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C10H14O4NP2')
#
# Standard ('2171', '+', '568.2769', '292.41', '2153501.793')
# MS1 Pandas(Index=32547, peakID=32547, MSnParentPeakID=0, msLevel=1, rt=295.46199999999999, mz=568.27716545635906, intensity=2419804.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C20H46O13N3S')
#
# Standard ('465', '+', '250.0797', '513.78', '1393836.587')
# MS1 Pandas(Index=17394, peakID=17394, MSnParentPeakID=0, msLevel=1, rt=513.93399999999997, mz=250.07970947464099, intensity=1659206.375, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C7H16ON5S2')
#
# Standard ('3209', '+', '368.1561', '616.76', '721030.23')
# MS1 Pandas(Index=29826, peakID=29826, MSnParentPeakID=0, msLevel=1, rt=617.75999999999999, mz=368.15642023887801, intensity=619160.25, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C14H26O10N')
#
# Standard ('2672', '+', '378.1403', '447.5', '821693.6033')
# MS1 Pandas(Index=30112, peakID=30112, MSnParentPeakID=0, msLevel=1, rt=445.94, mz=378.14043697489603, intensity=812732.8125, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C10H29O4N5PS2')
#
# Standard ('2605', '+', '206.0457', '539.75', '1314105.67')
# MS1 Pandas(Index=10189, peakID=10189, MSnParentPeakID=0, msLevel=1, rt=540.40199999999993, mz=206.04560801829101, intensity=1234846.875, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C10H8O4N')
#
# Standard ('2852', '+', '393.1366', '550.18', '1878598.753')
# MS1 Pandas(Index=30816, peakID=30816, MSnParentPeakID=0, msLevel=1, rt=550.56100000000004, mz=393.13676745660302, intensity=2064712.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C11H25O13N2')
#
# Standard ('2170', '+', '238.0709', '293.63', '4288407.25')
# MS1 Pandas(Index=15649, peakID=15649, MSnParentPeakID=0, msLevel=1, rt=296.86099999999999, mz=238.07095723134202, intensity=5652091.5, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C5H13O4N5P')
#
# Standard ('2424', '+', '354.1295', '429.48', '3967390.75')
# MS1 Pandas(Index=28129, peakID=28129, MSnParentPeakID=0, msLevel=1, rt=427.15699999999998, mz=354.12952137088701, intensity=4118729.5, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C19H22N3P2')
#
# Standard ('248', '+', '509.1607', '560.76', '6087367.333')
# MS1 Pandas(Index=32244, peakID=32244, MSnParentPeakID=0, msLevel=1, rt=560.76199999999994, mz=509.16070999482497, intensity=6732987.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C15H33O11N4S2')
#
# Standard ('779', '+', '272.0076', '693.49', '552816.92')
# MS1 Pandas(Index=21016, peakID=21016, MSnParentPeakID=0, msLevel=1, rt=695.00999999999999, mz=272.00753403875501, intensity=528421.5, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C8H7O6N3P')
#
# Standard ('3075', '+', '296.1128', '482.11', '695297.02')
# MS1 Pandas(Index=24165, peakID=24165, MSnParentPeakID=0, msLevel=1, rt=485.12599999999998, mz=296.112739196858, intensity=600373.5625, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C8H19O5N5P')
#
# Standard ('3494', '+', '231.0975', '616.01', '640782.3567')
# MS1 Pandas(Index=14518, peakID=14518, MSnParentPeakID=0, msLevel=1, rt=616.20299999999997, mz=231.09760610696802, intensity=623842.25, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C3H16O4N6P')
#
# Standard ('830', '+', '215.0161', '709.97', '1909495.587')
# MS1 Pandas(Index=11516, peakID=11516, MSnParentPeakID=0, msLevel=1, rt=707.90899999999999, mz=215.01616872903801, intensity=2809778.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C4H11O4N2S2')
#
# Standard ('460', '+', '455.1883', '514.21', '4000435.167')
# MS1 Pandas(Index=31779, peakID=31779, MSnParentPeakID=0, msLevel=1, rt=513.93399999999997, mz=455.18852263981302, intensity=3655756.25, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C19H36O8PS')
#
# Standard ('777', '+', '256.03', '693.5', '2427559.083')
# MS1 Pandas(Index=18494, peakID=18494, MSnParentPeakID=0, msLevel=1, rt=695.00999999999999, mz=256.02999489605298, intensity=2112396.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C11H6ON5S')
#
# Standard ('1255', '+', '428.1411', '597.15', '861084.0433')
# MS1 Pandas(Index=31355, peakID=31355, MSnParentPeakID=0, msLevel=1, rt=597.26900000000001, mz=428.14125101640406, intensity=853628.3125, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C28H18O2N3')
#
# Standard ('247', '+', '487.1784', '559.83', '46749638.67')
# MS1 Pandas(Index=31976, peakID=31976, MSnParentPeakID=0, msLevel=1, rt=559.52099999999996, mz=487.17838228929804, intensity=47582860.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C30H31O2S2')
#
# Standard ('2477', '+', '354.1408', '735.04', '3767671.667')
# MS1 Pandas(Index=28140, peakID=28140, MSnParentPeakID=0, msLevel=1, rt=734.88199999999995, mz=354.14074601675202, intensity=3888550.5, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C13H24O10N')
#
# Standard ('776', '+', '210.0608', '696.16', '29793915.33')
# MS1 Pandas(Index=10884, peakID=10884, MSnParentPeakID=0, msLevel=1, rt=696.25399999999991, mz=210.06078736813203, intensity=28248140.0, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C6H12O7N')
#
# Standard ('2172', '+', '606.2326', '292.18', '1104562.543')
# MS1 Pandas(Index=32621, peakID=32621, MSnParentPeakID=0, msLevel=1, rt=295.46199999999999, mz=606.23289034226605, intensity=993868.125, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C20H42O12N5P2')
#
# Standard ('3108', '+', '211.0812', '503.57', '753995.0633')
# MS1 Pandas(Index=10979, peakID=10979, MSnParentPeakID=0, msLevel=1, rt=502.67400000000004, mz=211.08128210729402, intensity=666999.5625, Sample=1, GroupPeakMSn=0, CollisionEnergy=0, annotation='C7H15O7')

# %%
m2m_list = motifs_of_interest
word_map, motif_words = ms2lda.print_motif_features(quiet=True)
for i in range(len(ms1_list)):
    
    ms1 = ms1_list[i]
    df = print_report(ms2lda, G, ms1, motif_annotation, motif_words, motif_colour, motif_idx, word_map, xlim_upper=770)
    display(df) # show the table to see the mz, annotations, etc
# Out:
#  - M2M_110	: [phenylalanine-COOH] substructure
# 		  fragment_120.0805 (0.497),fragment_103.05453 (0.160),fragment_166.08646 (0.124),fragment_53.0389 (0.024),fragment_79.05421 (0.020),fragment_91.05416 (0.019),fragment_93.06986 (0.017),loss_198.03831 (0.010),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   120.080338       1.000000   fragment_120.0805             110
# 1   103.054489       0.383683  fragment_103.05453             110
# 2   166.072098       0.332877  fragment_166.07236             NaN
# 3   167.056580       0.135715  fragment_167.05703             NaN
# 4    93.069839       0.064005   fragment_93.06986             110
# 5    91.054138       0.061631   fragment_91.05416             110
# 6    53.039024       0.055631    fragment_53.0389             110
# 7   166.086365       0.054704  fragment_166.08646             110
# 8   124.050308       0.052167  fragment_124.05046             NaN
# 9   113.060089       0.045834  fragment_113.06028             NaN
# 10   79.054314       0.044881   fragment_79.05421             110
# 11  121.064781       0.032741  fragment_121.06495             NaN
# 12  153.040359       0.031085  fragment_153.04082             NaN
# 13   83.048973       0.030114   fragment_83.04897             NaN
# 14  149.080261       0.026777  fragment_149.08026             NaN
# 15  149.046127       0.025047  fragment_149.04631             NaN
# 16  124.086945       0.021334  fragment_124.08696             NaN
# 17  142.061508       0.020914  fragment_142.06165             NaN
# 18  107.048744       0.018973  fragment_107.04888             NaN
# 19  131.049042       0.018218  fragment_131.04942             NaN
# 20   95.049370       0.015627   fragment_95.04939             NaN
# 21   69.044777       0.015483   fragment_69.04485             NaN
# 22  107.023705       0.014238   fragment_107.0237             NaN
# 23   55.029434       0.011878   fragment_55.02953             NaN
# 24  128.045517       0.011315  fragment_128.04563             NaN
# 25   67.029007       0.011100   fragment_67.02911             NaN
# 26   79.028824       0.010814    fragment_79.0289             NaN
# 27  109.051529       0.010658  fragment_109.05161             NaN
# 28  149.059937       0.008643  fragment_149.06006             NaN
# 29   96.055740       0.007498   fragment_96.05574             NaN
# 30   67.054520       0.007317   fragment_67.05448             NaN
# 31   94.040527       0.006741   fragment_94.04046             NaN
#
#          loss_word  loss_motif                  ef
# 0              NaN         NaN              C8H10N
# 1              NaN         NaN                C8H7
# 2              NaN         NaN            C6H16NS2
# 3              NaN         NaN            C6H7O2N4
# 4              NaN         NaN                C7H9
# 5              NaN         NaN                C7H7
# 6   loss_113.06868         NaN                C4H5
# 7              NaN         NaN            C9H12O2N
# 8              NaN         NaN             C5H6ON3
# 9    loss_53.04746         NaN                 NaN
# 10             NaN         NaN                C6H7
# 11             NaN         NaN               C8H9O
# 12             NaN         NaN            C5H13OS2
# 13   loss_83.05829         NaN               C5H7O
# 14   loss_17.02516         NaN             C6H13O4
# 15             NaN         NaN             C6H5ON4
# 16             NaN         NaN             C6H10N3
# 17             NaN         NaN            C5H8O2N3
# 18             NaN         NaN               C7H7O
# 19             NaN         NaN               C9H7O
# 20   loss_71.05818         NaN               C6H7O
# 21             NaN         NaN              C3H5N2
# 22             NaN         NaN             C5H3ON2
# 23             NaN         NaN              C2H3N2
# 24             NaN         NaN            C4H6O2N3
# 25             NaN         NaN              C3H3N2
# 26   loss_87.07911         NaN  C4H3N2,loss_C3H9N3
# 27             NaN         NaN                 NaN
# 28             NaN         NaN              C9H9O2
# 29             NaN         NaN              C4H6N3
# 30   loss_99.05317         NaN                C5H7
# 31             NaN         NaN                 NaN
#  - No M2M for this MS1 peak at the specified thresholding levels
# None
#  - M2M_24	: Adenine substructure
# 		  fragment_136.06243 (0.620),fragment_119.03518 (0.048),fragment_222.09816 (0.041),fragment_298.08923 (0.033),fragment_250.09302 (0.024),fragment_137.04624 (0.019),fragment_223.103 (0.011),
#  - M2M_99	: [Pentose-H2O] loss, e.g. ribose
# 		  loss_132.04195 (0.703),fragment_124.03982 (0.098),fragment_606.2359 (0.024),loss_149.06856 (0.020),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   136.062424       1.000000  fragment_136.06243              24
# 1   119.035210       0.082166  fragment_119.03518              24
# 2   268.105804       0.046591   fragment_268.1058             NaN
# 3   137.046188       0.038616  fragment_137.04624              24
# 4    57.033722       0.019212   fragment_57.03373             NaN
# 5    55.018364       0.015297   fragment_55.01826             NaN
# 6    94.039673       0.014865   fragment_94.03972             NaN
# 7    71.013100       0.012503   fragment_71.01305             NaN
# 8    85.028252       0.010128   fragment_85.02836             NaN
# 9    92.024536       0.010074   fragment_92.02436             NaN
# 10   69.033798       0.009574    fragment_69.0337             NaN
# 11   73.028450       0.009127   fragment_73.02853             NaN
# 12  109.051498       0.007448  fragment_109.05161             NaN
# 13   67.029030       0.006051   fragment_67.02911             NaN
# 14  115.039162       0.004795  fragment_115.03919             NaN
# 15  133.049942       0.004782  fragment_133.04995             NaN
# 16   70.065125       0.002361   fragment_70.06518             NaN
# 17   61.028923       0.002097   fragment_61.02864             NaN
# 18   87.044685       0.001266   fragment_87.04466             NaN
# 19   97.028412       0.001243   fragment_97.02843             NaN
# 20  127.749245       0.001099  fragment_127.74924             NaN
# 21   55.029457       0.001091   fragment_55.02953             NaN
# 22  178.071426       0.001074  fragment_178.07143             NaN
# 23   82.040314       0.001054   fragment_82.04032             NaN
# 24   80.590981       0.001038   fragment_80.59098             NaN
# 25  186.201050       0.001023  fragment_186.20105             NaN
# 26   86.851669       0.000986   fragment_86.85167             NaN
# 27  131.992218       0.000982  fragment_131.99222             NaN
# 28   65.013412       0.000956    fragment_65.0134             NaN
# 29   67.137428       0.000941   fragment_67.13743             NaN
# 30   59.698528       0.000939   fragment_59.69853             NaN
# 31   66.091148       0.000933   fragment_66.09115             NaN
# 32   59.504753       0.000811   fragment_59.50475             NaN
# 33   50.364056       0.000808   fragment_50.36406             NaN
#
#          loss_word  loss_motif                     ef
# 0   loss_132.04195          99     C5H6N5,loss_C5H8O4
# 1   loss_149.06856          99   C5H3N4,loss_C5H11O4N
# 2              NaN         NaN            C10H24ONP2S
# 3   loss_131.05779         NaN   C5H5ON4,loss_C5H9O3N
# 4              NaN         NaN                  C3H5O
# 5              NaN         NaN                  C3H3O
# 6   loss_174.06385         NaN  C4H4N3,loss_C6H10O4N2
# 7   loss_197.08984         NaN   C3H3O2,loss_C6H15O6N
# 8    loss_183.0743         NaN   C4H5O2,loss_C5H13O6N
# 9   loss_176.07929         NaN  C4H2N3,loss_C6H12O4N2
# 10  loss_199.06945         NaN    C4H5O,loss_C5H13O7N
# 11  loss_195.07427         NaN   C3H5O2,loss_C6H13O6N
# 12  loss_159.05292         NaN           loss_C6H9O4N
# 13             NaN         NaN                 C3H3N2
# 14   loss_153.0642         NaN   C5H7O3,loss_C4H11O5N
# 15  loss_135.05308         NaN    C5H9O4,loss_C4H9O4N
# 16  loss_198.03831         NaN   C4H8N,loss_C6H14O3S2
# 17             NaN         NaN                 C2H5O2
# 18  loss_181.05892         NaN          loss_C5H11O6N
# 19             NaN         NaN                 C5H5O2
# 20             NaN         NaN                    NaN
# 21             NaN         NaN                 C2H3N2
# 22   loss_90.03149         NaN   C6H12O5N,loss_C3H6O3
# 23  loss_186.06386         NaN  C3H4N3,loss_C7H10O4N2
# 24             NaN         NaN                    NaN
# 25             NaN         NaN                    NaN
# 26             NaN         NaN                    NaN
# 27             NaN         NaN                C3H2O5N
# 28             NaN         NaN                  C3HN2
# 29             NaN         NaN                    NaN
# 30             NaN         NaN                    NaN
# 31             NaN         NaN                    NaN
# 32             NaN         NaN                    NaN
# 33             NaN         NaN                    NaN
#  - M2M_52	: fragments from [hexose-H2O] substructure (a hexose conjugation, e.g. glucose)
# 		  fragment_145.05005 (0.231),fragment_85.02836 (0.179),fragment_127.03874 (0.140),fragment_97.02843 (0.106),fragment_163.06071 (0.065),fragment_61.02864 (0.052),fragment_81.03339 (0.031),fragment_91.03926 (0.026),fragment_69.0337 (0.025),fragment_109.0289 (0.021),fragment_73.02853 (0.016),fragment_325.11233 (0.016),fragment_103.03867 (0.012),fragment_99.04451 (0.011),fragment_53.0389 (0.011),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0    85.028351       1.000000   fragment_85.02836              52
# 1    73.064651       0.631002   fragment_73.06471             NaN
# 2   145.050232       0.363657  fragment_145.05005              52
# 3   136.061172       0.277150  fragment_136.06117             NaN
# 4   270.094788       0.258737  fragment_270.09485             NaN
# 5    69.033676       0.244445    fragment_69.0337              52
# 6    97.028465       0.227394   fragment_97.02843              52
# 7   127.038849       0.215684  fragment_127.03874              52
# 8    55.054657       0.167336   fragment_55.05468             NaN
# 9    61.028500       0.100475   fragment_61.02864              52
# 10   57.033665       0.086343   fragment_57.03373             NaN
# 11   81.033340       0.084629   fragment_81.03339              52
# 12  163.059067       0.078256  fragment_163.05907             NaN
# 13  137.065994       0.076823  fragment_137.06589             NaN
# 14  109.028984       0.074128   fragment_109.0289              52
# 15   91.039185       0.047849   fragment_91.03926              52
# 16   53.038891       0.047515    fragment_53.0389              52
# 17   73.028481       0.043743   fragment_73.02853              52
# 18   55.018242       0.040104   fragment_55.01826             NaN
# 19  180.062363       0.038066  fragment_180.06228             NaN
# 20   99.043877       0.032760   fragment_99.04451              52
# 21  138.068420       0.026436  fragment_138.06842             NaN
# 22  119.035194       0.021448  fragment_119.03518             NaN
# 23   53.002590       0.016999   fragment_53.00262             NaN
# 24   87.043915       0.016181   fragment_87.04394             NaN
# 25   71.049408       0.015666    fragment_71.0494             NaN
# 26   71.013069       0.008481   fragment_71.01305             NaN
# 27  138.060730       0.007872  fragment_138.06073             NaN
# 28  101.023132       0.007375  fragment_101.02317             NaN
# 29  253.129059       0.006756  fragment_253.12906             NaN
# 30  137.046234       0.006471  fragment_137.04624             NaN
# 31  115.039169       0.006314  fragment_115.03919             NaN
# 32   83.013069       0.005915   fragment_83.01306             NaN
# 33  103.038673       0.005837  fragment_103.03867              52
# 34  163.046921       0.005565  fragment_163.04692             NaN
# 35  252.085663       0.004500  fragment_252.08567             NaN
# 36  162.075790       0.004371  fragment_162.07581             NaN
# 37  250.108154       0.004289  fragment_250.10794             NaN
# 38  199.876495       0.003922   fragment_199.8765             NaN
# 39  293.180267       0.003771  fragment_293.18027             NaN
# 40  133.861526       0.003610  fragment_133.86153             NaN
# 41  139.850449       0.003409  fragment_139.85045             NaN
# 42  133.350311       0.003388  fragment_133.35031             NaN
# 43   59.049809       0.003268   fragment_59.04944             NaN
# 44   51.171673       0.003131   fragment_51.17167             NaN
# 45   50.822456       0.003048   fragment_50.82246             NaN
# 46   58.220257       0.002972   fragment_58.22026             NaN
#
#          loss_word  loss_motif                     ef
# 0   loss_185.07996         NaN  C4H5O2,loss_C7H11O3N3
# 1              NaN         NaN                  C4H9O
# 2    loss_125.0588         NaN    C6H9O4,loss_C5H7ON3
# 3              NaN         NaN                 C5H6N5
# 4              NaN         NaN             C10H17N5PS
# 5              NaN         NaN                  C4H5O
# 6   loss_173.07988         NaN  C5H5O2,loss_C6H11O3N3
# 7   loss_143.06931         NaN   C6H7O3,loss_C5H9O2N3
# 8              NaN         NaN                   C4H7
# 9              NaN         NaN                 C2H5O2
# 10             NaN         NaN                  C3H5O
# 11  loss_189.07426         NaN    C5H5O,loss_C8H16NPS
# 12  loss_107.05064         NaN          loss_C3H10ONP
# 13  loss_133.04517         NaN                    NaN
# 14  loss_161.07942         NaN  C6H5O2,loss_C5H11O3N3
# 15  loss_179.06876         NaN   C3H7O3,loss_C8H9O2N3
# 16             NaN         NaN                   C4H5
# 17             NaN         NaN                 C3H5O2
# 18             NaN         NaN                  C3H3O
# 19             NaN         NaN              C4H10O5N3
# 20  loss_171.06423         NaN   C5H7O2,loss_C6H9O3N3
# 21  loss_132.04195         NaN  C4H13O2NP,loss_C5H8O4
# 22             NaN         NaN                 C5H3N4
# 23             NaN         NaN                   C3HO
# 24             NaN         NaN                 C4H7O2
# 25             NaN         NaN                  C4H7O
# 26             NaN         NaN                 C3H3O2
# 27             NaN         NaN                    NaN
# 28    loss_169.085         NaN  C4H5O3,loss_C7H11O2N3
# 29             NaN         NaN               C10H21O7
# 30             NaN         NaN                C5H5ON4
# 31  loss_155.06959         NaN   C5H7O3,loss_C6H9O2N3
# 32             NaN         NaN                 C4H3O2
# 33  loss_167.06959         NaN   C4H7O3,loss_C7H9O2N3
# 34             NaN         NaN               C3H7O4N4
# 35             NaN         NaN             C8H20N3P2S
# 36             NaN         NaN               C6H12O4N
# 37             NaN         NaN              C13H16O4N
# 38             NaN         NaN                    NaN
# 39             NaN         NaN                    NaN
# 40             NaN         NaN                    NaN
# 41             NaN         NaN                    NaN
# 42             NaN         NaN                    NaN
# 43             NaN         NaN                  C3H7O
# 44             NaN         NaN                    NaN
# 45             NaN         NaN                    NaN
# 46             NaN         NaN                    NaN
#  - No M2M for this MS1 peak at the specified thresholding levels
# None
#  - M2M_52	: fragments from [hexose-H2O] substructure (a hexose conjugation, e.g. glucose)
# 		  fragment_145.05005 (0.231),fragment_85.02836 (0.179),fragment_127.03874 (0.140),fragment_97.02843 (0.106),fragment_163.06071 (0.065),fragment_61.02864 (0.052),fragment_81.03339 (0.031),fragment_91.03926 (0.026),fragment_69.0337 (0.025),fragment_109.0289 (0.021),fragment_73.02853 (0.016),fragment_325.11233 (0.016),fragment_103.03867 (0.012),fragment_99.04451 (0.011),fragment_53.0389 (0.011),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  loss_word  \
# 0    85.028526       1.000000   fragment_85.02836              52        NaN
# 1   145.050247       0.631684  fragment_145.05005              52        NaN
# 2   127.038918       0.257809  fragment_127.03874              52        NaN
# 3    69.033806       0.252490    fragment_69.0337              52        NaN
# 4    97.028542       0.215674   fragment_97.02843              52        NaN
# 5   163.061020       0.140207  fragment_163.06071              52        NaN
# 6    61.028641       0.109462   fragment_61.02864              52        NaN
# 7    81.033348       0.089889   fragment_81.03339              52        NaN
# 8    57.033798       0.082280   fragment_57.03373             NaN        NaN
# 9    70.065300       0.058799   fragment_70.06518             NaN        NaN
# 10  109.027885       0.058142  fragment_109.02782             NaN        NaN
# 11   91.039474       0.057590   fragment_91.03926              52        NaN
# 12   53.038872       0.048315    fragment_53.0389              52        NaN
# 13   73.028549       0.040161   fragment_73.02853              52        NaN
# 14   55.017872       0.031062   fragment_55.01826             NaN        NaN
# 15  112.050056       0.030330  fragment_112.05005             NaN        NaN
# 16   84.080772       0.029757   fragment_84.08074             NaN        NaN
#
#     loss_motif       ef
# 0          NaN   C4H5O2
# 1          NaN   C6H9O4
# 2          NaN   C6H7O3
# 3          NaN    C4H5O
# 4          NaN   C5H5O2
# 5          NaN  C6H11O5
# 6          NaN   C2H5O2
# 7          NaN    C5H5O
# 8          NaN    C3H5O
# 9          NaN    C4H8N
# 10         NaN   H6ON4P
# 11         NaN   C3H7O3
# 12         NaN     C4H5
# 13         NaN   C3H5O2
# 14         NaN    C3H3O
# 15         NaN  C4H6ON3
# 16         NaN   C5H10N
#  - M2M_69	: Cytosine and a loss of conjugated deoxyribose substructure
# 		  fragment_112.05109 (0.534),fragment_95.02391 (0.082),fragment_105.11101 (0.036),loss_156.00579 (0.036),fragment_198.08736 (0.025),fragment_228.03181 (0.021),fragment_69.04485 (0.017),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  loss_word  \
# 0   112.051186       1.000000  fragment_112.05109              69        NaN
# 1    95.024010       0.153749   fragment_95.02391              69        NaN
# 2    69.044563       0.035382   fragment_69.04485              69        NaN
# 3    98.983871       0.033448   fragment_98.98388             NaN        NaN
# 4    94.039795       0.027120   fragment_94.03972             NaN        NaN
# 5    85.028404       0.021767   fragment_85.02836             NaN        NaN
# 6    67.029083       0.017007   fragment_67.02911             NaN        NaN
# 7   145.084946       0.015443  fragment_145.08502             NaN        NaN
# 8    90.042488       0.015194   fragment_90.04249             NaN        NaN
# 9    89.038712       0.014810   fragment_89.03868             NaN        NaN
# 10   70.065178       0.013550   fragment_70.06518             NaN        NaN
# 11  145.028610       0.013541   fragment_145.0285             NaN        NaN
#
#     loss_motif       ef
# 0          NaN  C4H6ON3
# 1          NaN  C4H3ON2
# 2          NaN   C3H5N2
# 3          NaN    H4O4P
# 4          NaN   C4H4N3
# 5          NaN   C4H5O2
# 6          NaN   C3H3N2
# 7          NaN      NaN
# 8          NaN      NaN
# 9          NaN     C7H5
# 10         NaN    C4H8N
# 11         NaN   C9H5O2
#  - M2M_99	: [Pentose-H2O] loss, e.g. ribose
# 		  loss_132.04195 (0.703),fragment_124.03982 (0.098),fragment_606.2359 (0.024),loss_149.06856 (0.020),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   137.046143       1.000000  fragment_137.04624             NaN
# 1   110.034630       0.097475  fragment_110.03468             NaN
# 2   119.035179       0.068950  fragment_119.03518             NaN
# 3   166.031265       0.043539  fragment_166.03154             NaN
# 4    94.039551       0.037174   fragment_94.03972             NaN
# 5   269.060669       0.028940  fragment_269.06067             NaN
# 6    82.040367       0.026569   fragment_82.04032             NaN
# 7   269.095367       0.026186  fragment_269.09552             NaN
# 8    55.029526       0.024724   fragment_55.02953             NaN
# 9   136.062256       0.018140  fragment_136.06243             NaN
# 10  147.091095       0.016464   fragment_147.0911             NaN
# 11  112.051056       0.012635  fragment_112.05109             NaN
# 12  223.055588       0.009909  fragment_223.05559             NaN
#
#          loss_word  loss_motif                    ef
# 0   loss_132.04195          99   C5H5ON4,loss_C5H8O4
# 1   loss_159.05292         NaN  C4H4ON3,loss_C6H9O4N
# 2   loss_150.05271         NaN   C5H3N4,loss_C5H10O5
# 3              NaN         NaN              C2H9N5PS
# 4   loss_175.04797         NaN   C4H4N3,loss_C6H9O5N
# 5              NaN         NaN               C19H9O2
# 6   loss_187.04771         NaN   C3H4N3,loss_C7H9O5N
# 7              NaN         NaN           C6H18O2N6PS
# 8              NaN         NaN                C2H3N2
# 9              NaN         NaN                C5H6N5
# 10             NaN         NaN               C9H11N2
# 11  loss_157.03719         NaN  C4H6ON3,loss_C6H7O4N
# 12             NaN         NaN            C10H13N2P2
#  - M2M_11	: Xanthine substructure
# 		  fragment_152.05617 (0.393),fragment_153.04082 (0.176),fragment_110.03468 (0.052),fragment_135.02977 (0.050),fragment_128.04563 (0.029),loss_131.05779 (0.022),loss_197.05385 (0.015),
#  - M2M_99	: [Pentose-H2O] loss, e.g. ribose
# 		  loss_132.04195 (0.703),fragment_124.03982 (0.098),fragment_606.2359 (0.024),loss_149.06856 (0.020),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   152.056137       1.000000  fragment_152.05617              11
# 1   153.040817       0.265885  fragment_153.04082              11
# 2   135.029709       0.142229  fragment_135.02977              11
# 3   110.034691       0.101451  fragment_110.03468              11
# 4   128.045639       0.041836  fragment_128.04563              11
# 5    55.029625       0.020789   fragment_55.02953             NaN
# 6   107.035240       0.015506   fragment_107.0352             NaN
# 7    82.039711       0.014463   fragment_82.03971             NaN
# 8   109.050667       0.014081  fragment_109.05059             NaN
# 9    80.024574       0.011958   fragment_80.02446             NaN
# 10  134.046814       0.009427  fragment_134.04686             NaN
# 11   93.008591       0.007826   fragment_93.00856             NaN
# 12   57.033653       0.007533   fragment_57.03373             NaN
# 13  154.024170       0.006005  fragment_154.02417             NaN
# 14   69.033669       0.003497    fragment_69.0337             NaN
# 15   55.018238       0.003413   fragment_55.01826             NaN
# 16   71.013077       0.003056   fragment_71.01305             NaN
# 17  136.014313       0.002853  fragment_136.01427             NaN
# 18   68.013100       0.001890   fragment_68.01312             NaN
# 19  151.079147       0.001877  fragment_151.07915             NaN
# 20   73.028519       0.001799   fragment_73.02853             NaN
# 21   85.028358       0.001730   fragment_85.02836             NaN
# 22  114.230118       0.001715  fragment_114.23012             NaN
# 23  205.243607       0.001604  fragment_205.24361             NaN
# 24  109.010559       0.001569  fragment_109.01056             NaN
# 25   92.609955       0.001529   fragment_92.60995             NaN
# 26   63.163963       0.001463   fragment_63.16396             NaN
# 27   52.955414       0.001445   fragment_52.95541             NaN
# 28   95.565674       0.001445   fragment_95.56567             NaN
# 29   65.825935       0.001398   fragment_65.82594             NaN
#
#          loss_word  loss_motif                       ef
# 0   loss_132.04195          99     C5H14NS2,loss_C5H8O4
# 1   loss_131.05779          11    C5H13OS2,loss_C5H9O3N
# 2   loss_149.06856          99    C5H11S2,loss_C5H11O4N
# 3   loss_174.06385         NaN   C4H4ON3,loss_C6H10O4N2
# 4   loss_156.05316         NaN   C4H6O2N3,loss_C6H8O3N2
# 5              NaN         NaN                   C2H3N2
# 6   loss_177.06352         NaN     C4H3N4,loss_C6H11O5N
# 7              NaN         NaN                   C3H4N3
# 8   loss_175.04797         NaN      C4H5N4,loss_C6H9O5N
# 9              NaN         NaN                   C3H2N3
# 10  loss_150.05271         NaN             loss_C5H10O5
# 11             NaN         NaN                   C4HON2
# 12             NaN         NaN                    C3H5O
# 13  loss_130.07446         NaN  C5H4O3N3,loss_C5H10O2N2
# 14             NaN         NaN                    C4H5O
# 15             NaN         NaN                    C3H3O
# 16             NaN         NaN                   C3H3O2
# 17  loss_148.08495         NaN  C5H2O2N3,loss_C5H12O3N2
# 18             NaN         NaN                   C3H2ON
# 19             NaN         NaN                 C6H15O2S
# 20             NaN         NaN                   C3H5O2
# 21  loss_199.06945         NaN     C4H5O2,loss_C5H13O7N
# 22             NaN         NaN                      NaN
# 23             NaN         NaN                      NaN
# 24             NaN         NaN                    C6H5S
# 25             NaN         NaN                      NaN
# 26             NaN         NaN                      NaN
# 27             NaN         NaN                      NaN
# 28             NaN         NaN                      NaN
# 29             NaN         NaN                      NaN
#  - M2M_11	: Xanthine substructure
# 		  fragment_152.05617 (0.393),fragment_153.04082 (0.176),fragment_110.03468 (0.052),fragment_135.02977 (0.050),fragment_128.04563 (0.029),loss_131.05779 (0.022),loss_197.05385 (0.015),
#        ms2_mz  ms2_intensity       fragment_word  fragment_motif  loss_word  \
# 0  152.056198       1.000000  fragment_152.05617              11        NaN
# 1  153.040848       0.253247  fragment_153.04082              11        NaN
# 2  135.029968       0.066664  fragment_135.02977              11        NaN
# 3  110.034645       0.058940  fragment_110.03468              11        NaN
# 4  128.045975       0.044581  fragment_128.04563              11        NaN
#
#    loss_motif        ef
# 0         NaN  C5H14NS2
# 1         NaN  C5H13OS2
# 2         NaN   C5H11S2
# 3         NaN   C4H4ON3
# 4         NaN  C4H6O2N3
#  - M2M_193	: Water loss - indicative of a free hydroxyl group
# 		  loss_18.00764 (0.971),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   236.108383       1.000000  fragment_236.10817             NaN
# 1   180.080688       0.914774   fragment_180.0807             NaN
# 2   254.118210       0.910438  fragment_254.11769             NaN
# 3    95.049454       0.664070   fragment_95.04939             NaN
# 4   193.088470       0.483714  fragment_193.08848             NaN
# 5   167.072845       0.435892  fragment_167.07334             NaN
# 6    81.033340       0.338554   fragment_81.03339             NaN
# 7   192.079468       0.289841  fragment_192.07947             NaN
# 8   130.064651       0.255462  fragment_130.06474             NaN
# 9   144.080612       0.239637  fragment_144.08072             NaN
# 10  160.074768       0.202463  fragment_160.07499             NaN
# 11  155.071930       0.196352  fragment_155.07193             NaN
# 12  208.112350       0.190047  fragment_208.11235             NaN
# 13  220.074646       0.177971  fragment_220.07465             NaN
# 14  191.073456       0.173627  fragment_191.07346             NaN
# 15  154.065811       0.173154  fragment_154.06575             NaN
#
#          loss_word  loss_motif                      ef
# 0    loss_18.00764         193              C8H20ON3P2
# 1    loss_74.03693         NaN  C5H14O2N3S,loss_C3H6O2
# 2              NaN         NaN              C10H17ON5P
# 3              NaN         NaN                   C6H7O
# 4    loss_61.02859         NaN               C10H14N2P
# 5              NaN         NaN                C8H12N2P
# 6              NaN         NaN                   C5H5O
# 7              NaN         NaN              C6H14O2N3S
# 8   loss_124.05227         NaN       C9H8N,loss_C7H8O2
# 9   loss_110.03673         NaN     C10H10N,loss_C6H6O2
# 10             NaN         NaN                C4H11N5P
# 11             NaN         NaN                     NaN
# 12   loss_46.00537         NaN   C7H18O2N3S,loss_CH2O2
# 13             NaN         NaN                C9H11N5P
# 14             NaN         NaN               C10H12N2P
# 15  loss_100.05225         NaN      C11H8N,loss_C5H8O2
#  - M2M_9	: Small nitrogen containing fragment ion - often proline or ornithine derived
# 		  fragment_70.06518 (0.980),
#        ms2_mz  ms2_intensity       fragment_word  fragment_motif  loss_word  \
# 0  266.102020       1.000000  fragment_266.10221             NaN        NaN
# 1   70.065117       0.954738   fragment_70.06518               9        NaN
# 2   97.028412       0.663298   fragment_97.02843             NaN        NaN
# 3   87.043915       0.650043   fragment_87.04394             NaN        NaN
# 4  248.113037       0.426977  fragment_248.11296             NaN        NaN
#
#    loss_motif          ef
# 0         NaN  C7H17O4N5P
# 1         NaN       C4H8N
# 2         NaN      C5H5O2
# 3         NaN      C4H7O2
# 4         NaN   C10H18O6N
#  - M2M_9	: Small nitrogen containing fragment ion - often proline or ornithine derived
# 		  fragment_70.06518 (0.980),
#  - M2M_193	: Water loss - indicative of a free hydroxyl group
# 		  loss_18.00764 (0.971),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   108.080559       1.000000  fragment_108.08055             NaN
# 1   152.070465       0.588103  fragment_152.07033             NaN
# 2   314.123047       0.418355  fragment_314.12297             NaN
# 3    70.065186       0.352803   fragment_70.06518               9
# 4   332.134521       0.313939  fragment_332.13452             NaN
# 5   124.075294       0.312751  fragment_124.07525             NaN
# 6   134.059982       0.198686  fragment_134.06007             NaN
# 7   136.076004       0.132127  fragment_136.07602             NaN
# 8   110.071655       0.109093  fragment_110.07175             NaN
# 9    67.054749       0.094567   fragment_67.05467             NaN
# 10  123.068161       0.093545  fragment_123.06806             NaN
# 11   69.033623       0.081143    fragment_69.0337             NaN
# 12  106.065010       0.072998  fragment_106.06509             NaN
# 13   79.054146       0.072192   fragment_79.05421             NaN
# 14   85.028305       0.066480   fragment_85.02836             NaN
# 15   71.068123       0.060206   fragment_71.06824             NaN
# 16   65.038750       0.053691   fragment_65.03881             NaN
# 17   84.044136       0.050623   fragment_84.04422             NaN
# 18   93.057045       0.048968   fragment_93.05707             NaN
# 19   81.033310       0.046979   fragment_81.03339             NaN
#
#          loss_word  loss_motif                     ef
# 0              NaN         NaN                 C7H10N
# 1   loss_180.06322         NaN  C8H10O2N,loss_C6H12O6
# 2    loss_18.00764         193                    NaN
# 3              NaN         NaN                  C4H8N
# 4              NaN         NaN                    NaN
# 5              NaN         NaN                C7H10ON
# 6   loss_198.07369         NaN    C8H8ON,loss_C6H14O7
# 7   loss_196.05793         NaN   C8H10ON,loss_C6H12O7
# 8              NaN         NaN                 C5H8N3
# 9              NaN         NaN                   C5H7
# 10             NaN         NaN              C3H12ON2P
# 11             NaN         NaN                  C4H5O
# 12             NaN         NaN                  C7H8N
# 13             NaN         NaN                   C6H7
# 14             NaN         NaN                 C4H5O2
# 15             NaN         NaN                    NaN
# 16             NaN         NaN                   C5H5
# 17             NaN         NaN                 C4H6ON
# 18             NaN         NaN                    NaN
# 19             NaN         NaN                  C5H5O
#  - No M2M for this MS1 peak at the specified thresholding levels
# None
#  - No M2M for this MS1 peak at the specified thresholding levels
# None
#  - M2M_52	: fragments from [hexose-H2O] substructure (a hexose conjugation, e.g. glucose)
# 		  fragment_145.05005 (0.231),fragment_85.02836 (0.179),fragment_127.03874 (0.140),fragment_97.02843 (0.106),fragment_163.06071 (0.065),fragment_61.02864 (0.052),fragment_81.03339 (0.031),fragment_91.03926 (0.026),fragment_69.0337 (0.025),fragment_109.0289 (0.021),fragment_73.02853 (0.016),fragment_325.11233 (0.016),fragment_103.03867 (0.012),fragment_99.04451 (0.011),fragment_53.0389 (0.011),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0    85.028465       1.000000   fragment_85.02836              52
# 1    86.031532       0.428162   fragment_86.03164             NaN
# 2    73.064804       0.315785   fragment_73.06471             NaN
# 3   145.050171       0.310505  fragment_145.05005              52
# 4    97.028534       0.241403   fragment_97.02843              52
# 5    69.033836       0.233471    fragment_69.0337              52
# 6    74.068382       0.200881   fragment_74.06839             NaN
# 7   127.038986       0.185467  fragment_127.03874              52
# 8    75.044136       0.166914   fragment_75.04409             NaN
# 9   254.101395       0.142347  fragment_254.10162             NaN
# 10  128.043137       0.142010    fragment_128.043             NaN
# 11   55.054821       0.129090   fragment_55.05468             NaN
# 12   57.033760       0.127133   fragment_57.03373             NaN
# 13  146.052292       0.126669  fragment_146.05266             NaN
# 14   61.028595       0.118593   fragment_61.02864              52
# 15   81.033546       0.114628   fragment_81.03339              52
# 16   98.031670       0.101296   fragment_98.03172             NaN
# 17   70.036980       0.093580   fragment_70.03686             NaN
# 18  254.139465       0.070550     fragment_254.14             NaN
# 19   53.039066       0.066462    fragment_53.0389              52
# 20   91.038750       0.064817   fragment_91.03926              52
# 21   56.057880       0.060161   fragment_56.05784             NaN
# 22  153.055206       0.056774  fragment_153.05514             NaN
# 23  109.027878       0.054450  fragment_109.02782             NaN
# 24  163.060822       0.044026  fragment_163.06071              52
# 25  110.031387       0.040705  fragment_110.03141             NaN
# 26   82.036835       0.040611   fragment_82.03685             NaN
# 27   99.043709       0.039983   fragment_99.04367             NaN
# 28   55.018261       0.038271   fragment_55.01826             NaN
# 29   73.028549       0.032471   fragment_73.02853              52
#
#          loss_word  loss_motif                    ef
# 0   loss_169.09479         NaN  C4H5O2,loss_C6H11ON5
# 1   loss_168.09009         NaN        loss_C8H12O2N2
# 2   loss_181.05892         NaN   C4H9O,loss_C5H11O6N
# 3   loss_109.07359         NaN                C6H9O4
# 4   loss_157.09464         NaN                C5H5O2
# 5   loss_185.09001         NaN  C4H5O,loss_C6H11O2N5
# 6   loss_180.05262         NaN        loss_C2H9O2N6P
# 7   loss_127.08434         NaN                C6H7O3
# 8    loss_179.0791         NaN  C3H7O2,loss_C6H13O5N
# 9              NaN         NaN            C8H22N3P2S
# 10             NaN         NaN                   NaN
# 11  loss_199.06945         NaN    C4H7,loss_C5H13O7N
# 12  loss_197.08984         NaN   C3H5O,loss_C6H15O6N
# 13             NaN         NaN                   NaN
# 14  loss_193.09469         NaN  C2H5O2,loss_C7H15O5N
# 15             NaN         NaN                 C5H5O
# 16  loss_156.08986         NaN        loss_C7H12O2N2
# 17             NaN         NaN                   NaN
# 18             NaN         NaN              C14H16N5
# 19             NaN         NaN                  C4H5
# 20  loss_163.08412         NaN  C3H7O3,loss_C6H13O4N
# 21   loss_198.0636         NaN         loss_C10H15PS
# 22  loss_101.06848         NaN                C8H9O3
# 23  loss_145.09499         NaN  H6ON4P,loss_C4H11ON5
# 24   loss_91.06312         NaN  C6H11O5,loss_C3H9O2N
# 25             NaN         NaN                   NaN
# 26  loss_172.08498         NaN        loss_C7H12O3N2
# 27  loss_155.07895         NaN                C5H7O2
# 28  loss_199.10561         NaN  C3H3O,loss_C7H13O2N5
# 29  loss_181.09486         NaN  C3H5O2,loss_C6H15O5N
#  - No M2M for this MS1 peak at the specified thresholding levels
# None
#  - M2M_185	: Ethylphenol substructure (e.g. resulting from Tyramine - MzCloud)
# 		  fragment_121.06495 (0.496),fragment_103.05453 (0.118),fragment_93.06986 (0.093),fragment_91.05416 (0.081),fragment_53.0389 (0.072),fragment_152.10766 (0.059),fragment_95.04939 (0.010),
#  - M2M_89	: Double water loss - indicative for metabolites containing multiple OH groups and aliphatic chain, e.g. as in sugars
# 		  loss_36.01914 (0.766),fragment_207.10531 (0.034),fragment_189.09516 (0.018),loss_150.05271 (0.017),loss_138.05255 (0.014),loss_151.05662 (0.012),loss_66.03177 (0.011),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   345.207703       1.000000  fragment_345.20815             NaN
# 1    57.070011       0.982594   fragment_57.07002             NaN
# 2   327.196350       0.927894  fragment_327.19636             NaN
# 3   289.141968       0.528970  fragment_289.14204             NaN
# 4    69.070259       0.526050   fragment_69.07016             NaN
# 5   121.065262       0.474735  fragment_121.06495             185
# 6    91.054398       0.456649   fragment_91.05416             185
# 7   261.149231       0.446784  fragment_261.14929             NaN
# 8    79.054176       0.362154   fragment_79.05421             NaN
# 9   277.143005       0.333821  fragment_277.14293             NaN
# 10  107.085632       0.330049  fragment_107.08563             NaN
# 11  205.087463       0.321269  fragment_205.08747             NaN
# 12   85.064789       0.276539   fragment_85.06481             NaN
# 13  131.085022       0.262659  fragment_131.08509             NaN
#
#          loss_word  loss_motif                      ef
# 0    loss_36.01914          89                     NaN
# 1              NaN         NaN                    C4H9
# 2     loss_54.0313         NaN                     NaN
# 3              NaN         NaN                     NaN
# 4              NaN         NaN                    C5H9
# 5              NaN         NaN                   C8H9O
# 6              NaN         NaN                    C7H7
# 7   loss_120.07769         NaN   C16H21O3,loss_C5H12O3
# 8              NaN         NaN                    C6H7
# 9   loss_104.08507         NaN             C10H22O3N4P
# 10             NaN         NaN                   C8H11
# 11  loss_176.14065         NaN  C5H13ON6S,loss_C9H20O3
# 12             NaN         NaN                   C5H9O
# 13             NaN         NaN                  C10H11
#  - M2M_28	: Fragments possibly indicative for N-Methyl-oxo-pyrrolidinecarboxylic acid like structure
# 		  fragment_98.06004 (0.651),fragment_205.06809 (0.059),fragment_306.17096 (0.030),loss_182.07898 (0.030),loss_89.04784 (0.022),fragment_176.09125 (0.016),
#        ms2_mz  ms2_intensity       fragment_word  fragment_motif  loss_word  \
# 0  185.042694       1.000000  fragment_185.04253             NaN        NaN
# 1  126.092438       0.187622  fragment_126.09201             NaN        NaN
# 2   98.060089       0.158972   fragment_98.06004              28        NaN
# 3   68.997261       0.149476   fragment_68.99729             NaN        NaN
#
#    loss_motif        ef
# 0         NaN  C4H5O3N6
# 1         NaN       NaN
# 2         NaN    C5H8ON
# 3         NaN     C3HO2
#  - M2M_99	: [Pentose-H2O] loss, e.g. ribose
# 		  loss_132.04195 (0.703),fragment_124.03982 (0.098),fragment_606.2359 (0.024),loss_149.06856 (0.020),
#  - M2M_52	: fragments from [hexose-H2O] substructure (a hexose conjugation, e.g. glucose)
# 		  fragment_145.05005 (0.231),fragment_85.02836 (0.179),fragment_127.03874 (0.140),fragment_97.02843 (0.106),fragment_163.06071 (0.065),fragment_61.02864 (0.052),fragment_81.03339 (0.031),fragment_91.03926 (0.026),fragment_69.0337 (0.025),fragment_109.0289 (0.021),fragment_73.02853 (0.016),fragment_325.11233 (0.016),fragment_103.03867 (0.012),fragment_99.04451 (0.011),fragment_53.0389 (0.011),
#  - M2M_69	: Cytosine and a loss of conjugated deoxyribose substructure
# 		  fragment_112.05109 (0.534),fragment_95.02391 (0.082),fragment_105.11101 (0.036),loss_156.00579 (0.036),fragment_198.08736 (0.025),fragment_228.03181 (0.021),fragment_69.04485 (0.017),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   112.050980       1.000000  fragment_112.05109              69
# 1   198.087158       0.701612  fragment_198.08736              69
# 2    85.028259       0.205686   fragment_85.02836              52
# 3    73.028435       0.152247   fragment_73.02853              52
# 4    97.028336       0.127717   fragment_97.02843              52
# 5   145.049820       0.119487  fragment_145.05005              52
# 6   127.038681       0.118514  fragment_127.03874              52
# 7    69.033676       0.114807    fragment_69.0337              52
# 8   115.039070       0.097464  fragment_115.03919             NaN
# 9    57.033691       0.089152   fragment_57.03373             NaN
# 10   95.023895       0.088846   fragment_95.02391              69
# 11  133.049759       0.075519  fragment_133.04995             NaN
# 12  180.075775       0.073768  fragment_180.07576             NaN
# 13  163.060287       0.044081  fragment_163.06071              52
# 14   69.045059       0.040641   fragment_69.04485              69
# 15   55.018196       0.035634   fragment_55.01826             NaN
# 16   61.028431       0.032466   fragment_61.02846             NaN
# 17  330.117432       0.030657  fragment_330.11764             NaN
# 18   87.044632       0.027500   fragment_87.04466             NaN
# 19  109.028824       0.025004   fragment_109.0289              52
# 20   70.065086       0.024953   fragment_70.06518             NaN
# 21   71.013023       0.024451   fragment_71.01305             NaN
# 22   81.033989       0.023806   fragment_81.03339              52
#
#          loss_word  loss_motif                     ef
# 0              NaN         NaN                C4H6ON3
# 1   loss_132.04195          99  C8H12O3N3,loss_C5H8O4
# 2              NaN         NaN                 C4H5O2
# 3              NaN         NaN                 C3H5O2
# 4              NaN         NaN                 C5H5O2
# 5   loss_185.07996         NaN  C6H9O4,loss_C7H11O3N3
# 6              NaN         NaN                 C6H7O3
# 7              NaN         NaN                  C4H5O
# 8              NaN         NaN                 C5H7O3
# 9              NaN         NaN                  C3H5O
# 10             NaN         NaN                C4H3ON2
# 11             NaN         NaN                 C5H9O4
# 12  loss_150.05271         NaN           loss_C5H10O5
# 13  loss_167.06959         NaN  C6H11O5,loss_C7H9O2N3
# 14             NaN         NaN                 C3H5N2
# 15             NaN         NaN                  C3H3O
# 16             NaN         NaN                 C2H5O2
# 17             NaN         NaN                    NaN
# 18             NaN         NaN                    NaN
# 19             NaN         NaN                 C6H5O2
# 20             NaN         NaN                  C4H8N
# 21             NaN         NaN                 C3H3O2
# 22             NaN         NaN                  C5H5O
#  - M2M_164	: Possibly suggests 2-OH-4-oxo-pentanoic acid substructure
# 		  fragment_69.0337 (0.483),fragment_57.03373 (0.222),fragment_73.02853 (0.060),fragment_61.02864 (0.033),fragment_99.04451 (0.028),fragment_71.0494 (0.021),fragment_71.01305 (0.017),fragment_55.01826 (0.017),fragment_53.00262 (0.016),fragment_53.0389 (0.012),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   133.049911       1.000000  fragment_133.04995             NaN
# 1    81.033371       0.998710   fragment_81.03339             NaN
# 2   115.039154       0.907576  fragment_115.03919             NaN
# 3    73.028557       0.802372   fragment_73.02853             164
# 4    69.033707       0.686086    fragment_69.0337             164
# 5    97.028343       0.624761   fragment_97.02843             NaN
# 6    85.028427       0.565253   fragment_85.02836             NaN
# 7    57.033722       0.545170   fragment_57.03373             164
# 8    55.018345       0.330017   fragment_55.01826             164
# 9    71.013123       0.311132   fragment_71.01305             164
# 10  153.054840       0.242274  fragment_153.05514             NaN
# 11  125.023201       0.161139  fragment_125.02322             NaN
# 12   89.059418       0.134190   fragment_89.05947             NaN
# 13   61.028957       0.129136   fragment_61.02864             164
# 14  136.076080       0.123691  fragment_136.07602             NaN
# 15  179.117386       0.120328   fragment_179.1173             NaN
# 16  207.065735       0.114035   fragment_207.0656             NaN
# 17   87.043968       0.104746   fragment_87.04394             NaN
# 18  126.055817       0.102678  fragment_126.05571             NaN
#
#          loss_word  loss_motif                    ef
# 0     loss_92.0472         NaN    C5H9O4,loss_C3H8O3
# 1   loss_144.06226         NaN    C5H5O,loss_C7H12OS
# 2   loss_110.05761         NaN                C5H7O3
# 3   loss_152.06843         NaN   C3H5O2,loss_C5H12O5
# 4   loss_156.06297         NaN                 C4H5O
# 5   loss_128.06885         NaN   C5H5O2,loss_C4H8ON4
# 6   loss_140.06871         NaN   C4H5O2,loss_C5H8ON4
# 7   loss_168.06318         NaN    C3H5O,loss_C5H12O6
# 8   loss_170.07936         NaN  C3H3O,loss_C6H10O2N4
# 9   loss_154.08371         NaN                C3H3O2
# 10    loss_72.0423         NaN                C8H9O3
# 11             NaN         NaN                C6H5O3
# 12  loss_136.03716         NaN    C4H9O2,loss_C4H8O5
# 13  loss_164.06838         NaN   C2H5O2,loss_C6H12O5
# 14             NaN         NaN               C8H10ON
# 15             NaN         NaN              C4H16N6P
# 16             NaN         NaN              C11H11O4
# 17  loss_138.05255         NaN   C4H7O2,loss_C4H10O5
# 18             NaN         NaN                   NaN
#  - M2M_9	: Small nitrogen containing fragment ion - often proline or ornithine derived
# 		  fragment_70.06518 (0.980),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0    70.065117       1.000000   fragment_70.06518               9
# 1    72.080673       0.320156   fragment_72.08073             NaN
# 2   147.075836       0.184563  fragment_147.07595             NaN
# 3   244.077881       0.152966  fragment_244.07788             NaN
# 4   244.130127       0.118627  fragment_244.12921             NaN
# 5    84.044182       0.117270   fragment_84.04422             NaN
# 6   112.051048       0.099855  fragment_112.05109             NaN
# 7   130.050369       0.090396  fragment_130.05062             NaN
# 8   226.071777       0.037833  fragment_226.07178             NaN
# 9   180.064529       0.036150  fragment_180.06467             NaN
# 10  244.052567       0.034650  fragment_244.05257             NaN
# ...
# 7    81.033432       0.163176   fragment_81.03339             NaN
# 8    79.054291       0.118228   fragment_79.05421             NaN
# 9    53.038952       0.102686    fragment_53.0389             NaN
# 10  120.080612       0.101106   fragment_120.0805             NaN
# 11  192.064438       0.082670  fragment_192.06443             NaN
# 12  192.101791       0.054662  fragment_192.10213             NaN
# 13   91.054108       0.045256   fragment_91.05416             NaN
# 14  109.028839       0.045027   fragment_109.0289             NaN
# 15   80.049461       0.039030   fragment_80.04952             NaN
# 16  238.106232       0.038961  fragment_238.10628             NaN
# 17  136.075928       0.038830  fragment_136.07602             NaN
# 18  238.144562       0.038758  fragment_238.14457             NaN
# 19  238.071381       0.038164  fragment_238.07145             NaN
# 20  170.045547       0.037751  fragment_170.04552             NaN
# 21   97.028366       0.035538   fragment_97.02843             NaN
# 22  220.096268       0.035377  fragment_220.09633             NaN
# 23   53.002560       0.032576   fragment_53.00262             NaN
# 24  108.044235       0.029354  fragment_108.04432             NaN
# 25   95.049339       0.028603   fragment_95.04939             NaN
# 26   65.038742       0.026553   fragment_65.03881             NaN
# 27   94.064743       0.024837   fragment_94.06484             NaN
#
#          loss_word  loss_motif                    ef
# 0    loss_96.02094         NaN   C6H8O3N,loss_C5H4O2
# 1   loss_170.02143         NaN     C4H6N,loss_C7H6O5
# 2   loss_124.01617         NaN   C5H8O2N,loss_C6H4O3
# 3              NaN         NaN                C4H6ON
# 4    loss_131.0218         NaN    C7H7O,loss_C4H5O4N
# 5     loss_74.0004         NaN  C9H10O2N,loss_C2H2O3
# 6    loss_142.0266         NaN    C5H6ON,loss_C6H6O4
# 7   loss_157.03719         NaN    C5H5O,loss_C6H7O4N
# 8              NaN         NaN                  C6H7
# 9              NaN         NaN                  C4H5
# 10             NaN         NaN                C8H10N
# 11    loss_46.0065         NaN            C4H11O2N5P
# 12   loss_45.96933         NaN             C11H14O2N
# 13   loss_147.0168         NaN     C7H7,loss_C4H5O5N
# 14  loss_129.04246         NaN   C6H5O2,loss_C5H7O3N
# 15             NaN         NaN                 C5H6N
# 16             NaN         NaN            C6H17O3N5P
# 17             NaN         NaN               C8H10ON
# 18             NaN         NaN             C13H20O3N
# 19             NaN         NaN             C11H12O5N
# 20   loss_68.02599         NaN    C7H8O4N,loss_C4H4O
# 21  loss_141.04236         NaN   C5H5O2,loss_C6H7O3N
# 22   loss_17.97377         NaN            C6H15O2N5P
# 23  loss_185.06795         NaN    C3HO,loss_C8H11O4N
# 24  loss_130.02643         NaN    C6H6ON,loss_C5H6O4
# 25             NaN         NaN                 C6H7O
# 26  loss_173.03218         NaN     C5H5,loss_C6H7O5N
# 27             NaN         NaN                 C6H8N
#  - M2M_99	: [Pentose-H2O] loss, e.g. ribose
# 		  loss_132.04195 (0.703),fragment_124.03982 (0.098),fragment_606.2359 (0.024),loss_149.06856 (0.020),
#        ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0  162.065872       1.000000  fragment_162.06594             NaN
# 1  222.088455       0.480311  fragment_222.08874             NaN
# 2  204.077240       0.306100  fragment_204.07724             NaN
# 3  134.071686       0.162565  fragment_134.07179             NaN
# 4  163.074814       0.049734  fragment_163.07467             NaN
# 5   68.049820       0.049598    fragment_68.0498             NaN
# 6   70.065132       0.047462   fragment_70.06518             NaN
# 7  103.075386       0.035622  fragment_103.07539             NaN
# 8  126.055748       0.034065  fragment_126.05571             NaN
# 9   95.023911       0.025652   fragment_95.02391             NaN
#
#         loss_word  loss_motif                       ef
# 0  loss_192.06314         NaN     C8H8ON3,loss_C7H12O6
# 1  loss_132.04195          99    C8H17O4NP,loss_C5H8O4
# 2  loss_150.05271         NaN  C10H10O2N3,loss_C5H10O5
# 3             NaN         NaN                   C7H8N3
# 4             NaN         NaN                C4H12ON4P
# 5             NaN         NaN                    C4H6N
# 6             NaN         NaN                    C4H8N
# 7             NaN         NaN                  C5H11O2
# 8             NaN         NaN                      NaN
# 9             NaN         NaN                  C4H3ON2
#  - No M2M for this MS1 peak at the specified thresholding levels
# None
#  - No M2M for this MS1 peak at the specified thresholding levels
# None
#  - No M2M for this MS1 peak at the specified thresholding levels
# None
#  - M2M_9	: Small nitrogen containing fragment ion - often proline or ornithine derived
# 		  fragment_70.06518 (0.980),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0    70.065262       1.000000   fragment_70.06518               9
# 1   126.092110       0.375153  fragment_126.09201             NaN
# 2   231.146652       0.275736  fragment_231.14665             NaN
# 3    60.055977       0.138714   fragment_60.05588             NaN
# 4   172.098007       0.079586  fragment_172.09784             NaN
# 5   128.107178       0.076774  fragment_128.10746             NaN
# 6   231.098007       0.073207  fragment_231.09801             NaN
# 7    83.072731       0.068327   fragment_83.07268             NaN
# 8   130.097275       0.064911  fragment_130.09771             NaN
# 9    72.080940       0.050646   fragment_72.08073             NaN
# 10   84.080650       0.045887   fragment_84.08074             NaN
# 11  214.119644       0.043827  fragment_214.11964             NaN
# 12   71.048897       0.042580    fragment_71.0494             NaN
# 13   69.057053       0.036624   fragment_69.05705             NaN
# 14  114.102859       0.032437  fragment_114.10283             NaN
# 15   86.060204       0.027250   fragment_86.06019             NaN
# 16   68.049828       0.026770    fragment_68.0498             NaN
# 17  158.091843       0.025685  fragment_158.09177             NaN
# 18  196.108658       0.023839  fragment_196.10866             NaN
# 19   97.075600       0.023274   fragment_97.07565             NaN
#
#          loss_word  loss_motif                   ef
# 0   loss_161.03236         NaN   C4H8N,loss_C5H7O5N
# 1              NaN         NaN                  NaN
# 2              NaN         NaN                  NaN
# 3              NaN         NaN                CH6N3
# 4              NaN         NaN                  NaN
# 5              NaN         NaN              C7H14ON
# 6              NaN         NaN            C9H15O5N2
# 7              NaN         NaN                  NaN
# 8              NaN         NaN             C5H12ON3
# 9              NaN         NaN               C4H10N
# 10   loss_147.0168         NaN  C5H10N,loss_C4H5O5N
# 11             NaN         NaN            C9H16O3N3
# 12  loss_160.04814         NaN  C4H7O,loss_C5H8O4N2
# 13             NaN         NaN                  NaN
# 14             NaN         NaN              C5H12N3
# 15  loss_145.03741         NaN  C4H8ON,loss_C5H7O4N
# 16  loss_163.04789         NaN   C4H6N,loss_C5H9O5N
# 17   loss_73.00533         NaN            C6H12O2N3
# 18             NaN         NaN            C9H14O2N3
# 19  loss_134.02146         NaN   C5H9N2,loss_C4H6O5
#  - No M2M for this MS1 peak at the specified thresholding levels
# None
#  - M2M_69	: Cytosine and a loss of conjugated deoxyribose substructure
# 		  fragment_112.05109 (0.534),fragment_95.02391 (0.082),fragment_105.11101 (0.036),loss_156.00579 (0.036),fragment_198.08736 (0.025),fragment_228.03181 (0.021),fragment_69.04485 (0.017),
#        ms2_mz  ms2_intensity       fragment_word  fragment_motif  loss_word  \
# 0  112.051071       1.000000  fragment_112.05109              69        NaN
# 1   95.023895       0.096927   fragment_95.02391              69        NaN
# 2   69.045158       0.022855   fragment_69.04485              69        NaN
# 3   94.039749       0.012932   fragment_94.03972             NaN        NaN
# 4   70.065208       0.012008   fragment_70.06518             NaN        NaN
# 5  228.097122       0.007717  fragment_228.09712             NaN        NaN
# 6   68.013062       0.007108   fragment_68.01312             NaN        NaN
# 7   67.029015       0.006089   fragment_67.02911             NaN        NaN
# 8  117.054756       0.003386  fragment_117.05478             NaN        NaN
#
#    loss_motif         ef
# 0         NaN    C4H6ON3
# 1         NaN    C4H3ON2
# 2         NaN     C3H5N2
# 3         NaN     C4H4N3
# 4         NaN      C4H8N
# 5         NaN  C11H19NPS
# 6         NaN     C3H2ON
# 7         NaN     C3H3N2
# 8         NaN     C5H9O3
#  - No M2M for this MS1 peak at the specified thresholding levels
# None
#  - M2M_11	: Xanthine substructure
# 		  fragment_152.05617 (0.393),fragment_153.04082 (0.176),fragment_110.03468 (0.052),fragment_135.02977 (0.050),fragment_128.04563 (0.029),loss_131.05779 (0.022),loss_197.05385 (0.015),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  loss_word  \
# 0   296.097229       1.000000  fragment_296.09723             NaN        NaN
# 1   152.056335       0.751048  fragment_152.05617              11        NaN
# 2   153.040863       0.284515  fragment_153.04082              11        NaN
# 3   188.056320       0.125233  fragment_188.05632             NaN        NaN
# 4   135.029694       0.120517  fragment_135.02977              11        NaN
# 5   278.085632       0.089167  fragment_278.08599             NaN        NaN
# 6   218.066513       0.081173  fragment_218.06656             NaN        NaN
# 7   110.034897       0.079370  fragment_110.03468              11        NaN
# 8    70.065132       0.055913   fragment_70.06518             NaN        NaN
# 9    69.033661       0.049016    fragment_69.0337             NaN        NaN
# 10  178.073700       0.043993   fragment_178.0737             NaN        NaN
# 11   97.028419       0.042203   fragment_97.02843             NaN        NaN
#
#     loss_motif          ef
# 0          NaN         NaN
# 1          NaN    C5H14NS2
# 2          NaN    C5H13OS2
# 3          NaN    C8H14NS2
# 4          NaN     C5H11S2
# 5          NaN  C14H18ONP2
# 6          NaN    C8H12O6N
# 7          NaN     C4H4ON3
# 8          NaN       C4H8N
# 9          NaN       C4H5O
# 10         NaN  C5H13O2N3P
# 11         NaN      C5H5O2
#  - M2M_69	: Cytosine and a loss of conjugated deoxyribose substructure
# 		  fragment_112.05109 (0.534),fragment_95.02391 (0.082),fragment_105.11101 (0.036),loss_156.00579 (0.036),fragment_198.08736 (0.025),fragment_228.03181 (0.021),fragment_69.04485 (0.017),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  loss_word  \
# 0   112.051140       1.000000  fragment_112.05109              69        NaN
# 1    95.023933       0.106422   fragment_95.02391              69        NaN
# 2    69.045174       0.029074   fragment_69.04485              69        NaN
# 3   244.093292       0.022667  fragment_244.09284             NaN        NaN
# 4   266.073578       0.017643   fragment_266.0734             NaN        NaN
# 5    94.039787       0.013900   fragment_94.03972             NaN        NaN
# 6   487.145050       0.010342  fragment_487.14505             NaN        NaN
# 7   134.032257       0.009454   fragment_134.0322             NaN        NaN
# 8    70.065231       0.008070   fragment_70.06518             NaN        NaN
# 9    68.013100       0.007073   fragment_68.01312             NaN        NaN
# 10   67.029053       0.006987   fragment_67.02911             NaN        NaN
# 11   85.028366       0.005742   fragment_85.02836             NaN        NaN
# 12   52.018448       0.002369   fragment_52.01855             NaN        NaN
# 13   72.080704       0.002238   fragment_72.08073             NaN        NaN
#
#     loss_motif           ef
# 0          NaN      C4H6ON3
# 1          NaN      C4H3ON2
# 2          NaN       C3H5N2
# 3          NaN   C11H19ONPS
# 4          NaN  C8H17O3N3PS
# 5          NaN       C4H4N3
# 6          NaN          NaN
# 7          NaN          NaN
# 8          NaN        C4H8N
# 9          NaN       C3H2ON
# 10         NaN       C3H3N2
# 11         NaN       C4H5O2
# 12         NaN        C3H2N
# 13         NaN       C4H10N
#  - M2M_24	: Adenine substructure
# 		  fragment_136.06243 (0.620),fragment_119.03518 (0.048),fragment_222.09816 (0.041),fragment_298.08923 (0.033),fragment_250.09302 (0.024),fragment_137.04624 (0.019),fragment_223.103 (0.011),
#  - M2M_99	: [Pentose-H2O] loss, e.g. ribose
# 		  loss_132.04195 (0.703),fragment_124.03982 (0.098),fragment_606.2359 (0.024),loss_149.06856 (0.020),
#         ms2_mz  ms2_intensity       fragment_word  fragment_motif  \
# 0   222.098160       1.000000  fragment_222.09816              24
# 1   136.062363       0.515073  fragment_136.06243              24
# 2   354.137939       0.137764  fragment_354.13794             NaN
# 3   204.088257       0.107891  fragment_204.08818             NaN
# 4    87.043884       0.040448   fragment_87.04394             NaN
# 5    69.033684       0.040285    fragment_69.0337             NaN
# 6   119.035187       0.033590  fragment_119.03518              24
# 7   160.061539       0.031274  fragment_160.06143             NaN
# 8   137.046356       0.024587  fragment_137.04624              24
# 9   174.077866       0.020812  fragment_174.07787             NaN
# 10  207.076233       0.016570  fragment_207.07689             NaN
# 11   53.002583       0.013882   fragment_53.00262             NaN
# 12  148.062057       0.013031  fragment_148.06206             NaN
# 13   94.039688       0.012613   fragment_94.03972             NaN
# 14  175.084869       0.010145  fragment_175.08487             NaN
# 15   59.049366       0.009367   fragment_59.04944             NaN
# 16   57.033638       0.008931   fragment_57.03373             NaN
# 17   72.081253       0.007519   fragment_72.08125             NaN
#
#          loss_word  loss_motif                        ef
# 0   loss_132.04195          99      C8H16O6N,loss_C5H8O4
# 1              NaN         NaN                    C5H6N5
# 2              NaN         NaN                       NaN
# 3   loss_150.05271         NaN     C9H18NS2,loss_C5H10O5
# 4              NaN         NaN                    C4H7O2
# 5              NaN         NaN                     C4H5O
# 6              NaN         NaN                    C5H3N4
# 7   loss_194.07897         NaN       C7H6N5,loss_C7H14O6
# 8              NaN         NaN                   C5H5ON4
# 9   loss_180.06322         NaN       C8H8N5,loss_C6H12O6
# 10  loss_147.06523         NaN  C10H11O3N2,loss_C4H9O3N3
# 11             NaN         NaN                      C3HO
# 12             NaN         NaN                    C6H6N5
# 13             NaN         NaN                    C4H4N3
# 14  loss_179.05736         NaN  C4H12N6P,loss_C3H10O2N5P
# 15             NaN         NaN                     C3H7O
# 16             NaN         NaN                     C3H5O
# 17             NaN         NaN                       NaN
#  - No M2M for this MS1 peak at the specified thresholding levels
# None
#  - M2M_99	: [Pentose-H2O] loss, e.g. ribose
# 		  loss_132.04195 (0.703),fragment_124.03982 (0.098),fragment_606.2359 (0.024),loss_149.06856 (0.020),
#        ms2_mz  ms2_intensity      fragment_word  fragment_motif  loss_word  \
# 0  606.235901       1.000000  fragment_606.2359              99        NaN
# 1  509.186401       0.154514  fragment_509.1864             NaN        NaN
# 2   70.065109       0.088706  fragment_70.06518             NaN        NaN
#
#    loss_motif     ef
# 0         NaN    NaN
# 1         NaN    NaN
# 2         NaN  C4H8N
#  - No M2M for this MS1 peak at the specified thresholding levels
# None
