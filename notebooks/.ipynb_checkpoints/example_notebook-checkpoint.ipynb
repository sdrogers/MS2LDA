# %% [markdown]
# Example Notebook
# ============

# %% [markdown]
# <h2>1. Run LDA the first time</h2>

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
basedir = '../'
sys.path.append(basedir)

from lda_for_fragments import Ms2Lda

# %%
fragment_filename = basedir + 'input/final/Beer_3_full1_5_2E5_pos_fragments.csv'
neutral_loss_filename = basedir + 'input/final/Beer_3_full1_5_2E5_pos_losses.csv'
mzdiff_filename = None
ms1_filename = basedir + 'input/final/Beer_3_full1_5_2E5_pos_ms1.csv'
ms2_filename = basedir + 'input/final/Beer_3_full1_5_2E5_pos_ms2.csv'
ms2lda = Ms2Lda.lcms_data_from_R(fragment_filename, neutral_loss_filename, mzdiff_filename, 
                             ms1_filename, ms2_filename)
# Out:
# Data shape (1588, 3171)

# %%
### all the parameters you need to specify to run LDA ###

n_topics = 300 # 300 - 400 topics from cross-validation
n_samples = 500 # 100 is probably okay for testing. For manuscript, use > 500-1000.
n_burn = 250 # if 0 then we only use the last sample
n_thin = 5 # every n-th sample to use for averaging after burn-in
alpha = 50.0/n_topics # hyper-parameter for document-topic distributions
beta = 0.1 # hyper-parameter for topic-word distributions

ms2lda.run_lda(n_topics, n_samples, n_burn, n_thin, alpha, beta)
# Out:
# Fitting model...
# CGS LDA initialising
# ...............................................................................................................................................................
# Using Numba for LDA sampling
# Preparing words
# Preparing Z matrix
# DONE
# Burn-in 1
# Burn-in 2
# Burn-in 3
# Burn-in 4
# Burn-in 5
# Burn-in 6
# Burn-in 7
# Burn-in 8
# Burn-in 9
# Burn-in 10
# Burn-in 11
# Burn-in 12
# Burn-in 13
# Burn-in 14
# Burn-in 15
# Burn-in 16
# Burn-in 17
# Burn-in 18
# Burn-in 19
# Burn-in 20
# Burn-in 21
# Burn-in 22
# Burn-in 23
# Burn-in 24
# Burn-in 25
# Burn-in 26
# Burn-in 27
# Burn-in 28
# Burn-in 29
# Burn-in 30
# Burn-in 31
# Burn-in 32
# Burn-in 33
# Burn-in 34
# Burn-in 35
# Burn-in 36
# Burn-in 37
# Burn-in 38
# Burn-in 39
# Burn-in 40
# Burn-in 41
# Burn-in 42
# Burn-in 43
# Burn-in 44
# Burn-in 45
# Burn-in 46
# Burn-in 47
# Burn-in 48
# Burn-in 49
# Burn-in 50
# Burn-in 51
# Burn-in 52
# Burn-in 53
# Burn-in 54
# Burn-in 55
# Burn-in 56
# Burn-in 57
# Burn-in 58
# Burn-in 59
# Burn-in 60
# Burn-in 61
# Burn-in 62
# Burn-in 63
# Burn-in 64
# Burn-in 65
# Burn-in 66
# Burn-in 67
# Burn-in 68
# Burn-in 69
# Burn-in 70
# Burn-in 71
# Burn-in 72
# Burn-in 73
# Burn-in 74
# Burn-in 75
# Burn-in 76
# Burn-in 77
# Burn-in 78
# Burn-in 79
# Burn-in 80
# Burn-in 81
# Burn-in 82
# Burn-in 83
# Burn-in 84
# Burn-in 85
# Burn-in 86
# Burn-in 87
# Burn-in 88
# Burn-in 89
# Burn-in 90
# Burn-in 91
# Burn-in 92
# Burn-in 93
# Burn-in 94
# Burn-in 95
# Burn-in 96
# Burn-in 97
# Burn-in 98
# Burn-in 99
# Burn-in 100
# Burn-in 101
# Burn-in 102
# Burn-in 103
# Burn-in 104
# Burn-in 105
# Burn-in 106
# Burn-in 107
# Burn-in 108
# Burn-in 109
# Burn-in 110
# Burn-in 111
# Burn-in 112
# Burn-in 113
# Burn-in 114
# Burn-in 115
# Burn-in 116
# Burn-in 117
# Burn-in 118
# Burn-in 119
# Burn-in 120
# Burn-in 121
# Burn-in 122
# Burn-in 123
# Burn-in 124
# Burn-in 125
# Burn-in 126
# Burn-in 127
# Burn-in 128
# Burn-in 129
# Burn-in 130
# Burn-in 131
# Burn-in 132
# Burn-in 133
# Burn-in 134
# Burn-in 135
# Burn-in 136
# Burn-in 137
# Burn-in 138
# Burn-in 139
# Burn-in 140
# Burn-in 141
# Burn-in 142
# Burn-in 143
# Burn-in 144
# Burn-in 145
# Burn-in 146
# Burn-in 147
# Burn-in 148
# Burn-in 149
# Burn-in 150
# Burn-in 151
# Burn-in 152
# Burn-in 153
# Burn-in 154
# Burn-in 155
# Burn-in 156
# Burn-in 157
# Burn-in 158
# Burn-in 159
# Burn-in 160
# Burn-in 161
# Burn-in 162
# Burn-in 163
# Burn-in 164
# Burn-in 165
# Burn-in 166
# Burn-in 167
# Burn-in 168
# Burn-in 169
# Burn-in 170
# Burn-in 171
# Burn-in 172
# Burn-in 173
# Burn-in 174
# Burn-in 175
# Burn-in 176
# Burn-in 177
# Burn-in 178
# Burn-in 179
# Burn-in 180
# Burn-in 181
# Burn-in 182
# Burn-in 183
# Burn-in 184
# Burn-in 185
# Burn-in 186
# Burn-in 187
# Burn-in 188
# Burn-in 189
# Burn-in 190
# Burn-in 191
# Burn-in 192
# Burn-in 193
# Burn-in 194
# Burn-in 195
# Burn-in 196
# Burn-in 197
# Burn-in 198
# Burn-in 199
# Burn-in 200
# Burn-in 201
# Burn-in 202
# Burn-in 203
# Burn-in 204
# Burn-in 205
# Burn-in 206
# Burn-in 207
# Burn-in 208
# Burn-in 209
# Burn-in 210
# Burn-in 211
# Burn-in 212
# Burn-in 213
# Burn-in 214
# Burn-in 215
# Burn-in 216
# Burn-in 217
# Burn-in 218
# Burn-in 219
# Burn-in 220
# Burn-in 221
# Burn-in 222
# Burn-in 223
# Burn-in 224
# Burn-in 225
# Burn-in 226
# Burn-in 227
# Burn-in 228
# Burn-in 229
# Burn-in 230
# Burn-in 231
# Burn-in 232
# Burn-in 233
# Burn-in 234
# Burn-in 235
# Burn-in 236
# Burn-in 237
# Burn-in 238
# Burn-in 239
# Burn-in 240
# Burn-in 241
# Burn-in 242
# Burn-in 243
# Burn-in 244
# Burn-in 245
# Burn-in 246
# Burn-in 247
# Burn-in 248
# Burn-in 249
# Sample 250
# Sample 251
# Sample 252
# Sample 253
# Sample 254
# Sample 255   Log joint likelihood = -2100292.816
# Sample 256
# Sample 257
# Sample 258
# Sample 259
# Sample 260   Log joint likelihood = -2100106.592
# Sample 261
# Sample 262
# Sample 263
# Sample 264
# Sample 265   Log joint likelihood = -2100059.955
# Sample 266
# Sample 267
# Sample 268
# Sample 269
# Sample 270   Log joint likelihood = -2100116.306
# Sample 271
# Sample 272
# Sample 273
# Sample 274
# Sample 275   Log joint likelihood = -2100176.687
# Sample 276
# Sample 277
# Sample 278
# Sample 279
# Sample 280   Log joint likelihood = -2099975.402
# Sample 281
# Sample 282
# Sample 283
# Sample 284
# Sample 285   Log joint likelihood = -2099103.824
# Sample 286
# Sample 287
# Sample 288
# Sample 289
# Sample 290   Log joint likelihood = -2099242.688
# Sample 291
# Sample 292
# Sample 293
# Sample 294
# Sample 295   Log joint likelihood = -2098554.790
# Sample 296
# Sample 297
# Sample 298
# Sample 299
# Sample 300   Log joint likelihood = -2099129.274
# Sample 301
# Sample 302
# Sample 303
# Sample 304
# Sample 305   Log joint likelihood = -2098813.586
# Sample 306
# Sample 307
# Sample 308
# Sample 309
# Sample 310   Log joint likelihood = -2098799.258
# Sample 311
# Sample 312
# Sample 313
# Sample 314
# Sample 315   Log joint likelihood = -2098602.363
# Sample 316
# Sample 317
# Sample 318
# Sample 319
# Sample 320   Log joint likelihood = -2098734.351
# Sample 321
# Sample 322
# Sample 323
# Sample 324
# Sample 325   Log joint likelihood = -2098376.327
# Sample 326
# Sample 327
# Sample 328
# Sample 329
# Sample 330   Log joint likelihood = -2097845.041
# Sample 331
# Sample 332
# Sample 333
# Sample 334
# Sample 335   Log joint likelihood = -2098289.989
# Sample 336
# Sample 337
# Sample 338
# Sample 339
# Sample 340   Log joint likelihood = -2097530.589
# Sample 341
# Sample 342
# Sample 343
# Sample 344
# Sample 345   Log joint likelihood = -2098114.458
# Sample 346
# Sample 347
# Sample 348
# Sample 349
# Sample 350   Log joint likelihood = -2097872.114
# Sample 351
# Sample 352
# Sample 353
# Sample 354
# Sample 355   Log joint likelihood = -2098156.126
# Sample 356
# Sample 357
# Sample 358
# Sample 359
# Sample 360   Log joint likelihood = -2097685.196
# Sample 361
# Sample 362
# Sample 363
# Sample 364
# Sample 365   Log joint likelihood = -2097555.948
# Sample 366
# Sample 367
# Sample 368
# Sample 369
# Sample 370   Log joint likelihood = -2097560.348
# Sample 371
# Sample 372
# Sample 373
# Sample 374
# Sample 375   Log joint likelihood = -2098244.203
# Sample 376
# Sample 377
# Sample 378
# Sample 379
# Sample 380   Log joint likelihood = -2098281.753
# Sample 381
# Sample 382
# Sample 383
# Sample 384
# Sample 385   Log joint likelihood = -2098650.774
# Sample 386
# Sample 387
# Sample 388
# Sample 389
# Sample 390   Log joint likelihood = -2098036.292
# Sample 391
# Sample 392
# Sample 393
# Sample 394
# Sample 395   Log joint likelihood = -2097314.131
# Sample 396
# Sample 397
# Sample 398
# Sample 399
# Sample 400   Log joint likelihood = -2097603.714
# Sample 401
# Sample 402
# Sample 403
# Sample 404
# Sample 405   Log joint likelihood = -2097200.520
# Sample 406
# Sample 407
# Sample 408
# Sample 409
# Sample 410   Log joint likelihood = -2097514.756
# Sample 411
# Sample 412
# Sample 413
# Sample 414
# Sample 415   Log joint likelihood = -2097265.847
# Sample 416
# Sample 417
# Sample 418
# Sample 419
# Sample 420   Log joint likelihood = -2096772.322
# Sample 421
# Sample 422
# Sample 423
# Sample 424
# Sample 425   Log joint likelihood = -2096846.471
# Sample 426
# Sample 427
# Sample 428
# Sample 429
# Sample 430   Log joint likelihood = -2096843.650
# Sample 431
# Sample 432
# Sample 433
# Sample 434
# Sample 435   Log joint likelihood = -2097111.076
# Sample 436
# Sample 437
# Sample 438
# Sample 439
# Sample 440   Log joint likelihood = -2098105.746
# Sample 441
# Sample 442
# Sample 443
# Sample 444
# Sample 445   Log joint likelihood = -2097438.783
# Sample 446
# Sample 447
# Sample 448
# Sample 449
# Sample 450   Log joint likelihood = -2097253.601
# Sample 451
# Sample 452
# Sample 453
# Sample 454
# Sample 455   Log joint likelihood = -2096784.858
# Sample 456
# Sample 457
# Sample 458
# Sample 459
# Sample 460   Log joint likelihood = -2096990.258
# Sample 461
# Sample 462
# Sample 463
# Sample 464
# Sample 465   Log joint likelihood = -2096935.712
# Sample 466
# Sample 467
# Sample 468
# Sample 469
# Sample 470   Log joint likelihood = -2096241.138
# Sample 471
# Sample 472
# Sample 473
# Sample 474
# Sample 475   Log joint likelihood = -2096891.731
# Sample 476
# Sample 477
# Sample 478
# Sample 479
# Sample 480   Log joint likelihood = -2096526.992
# Sample 481
# Sample 482
# Sample 483
# Sample 484
# Sample 485   Log joint likelihood = -2097390.929
# Sample 486
# Sample 487
# Sample 488
# Sample 489
# Sample 490   Log joint likelihood = -2097390.034
# Sample 491
# Sample 492
# Sample 493
# Sample 494
# Sample 495   Log joint likelihood = -2096477.758
# Sample 496
# Sample 497
# Sample 498
# Sample 499
# Sample 500   Log joint likelihood = -2096575.921
# Using all samples
# DONE. Time=1345.12675595

# %%
ms2lda.write_results('beer3_test_method3')
ms2lda.save_project('results/beer3pos.project')
# Out:
# Writing topics to results/beer3_test_method3/beer3_test_method3_topics.csv
# Writing fragments x topics to results/beer3_test_method3/beer3_test_method3_all.csv
# Writing topic docs to results/beer3_test_method3/beer3_test_method3_docs.csv
# Project saved to results/beer3pos.project time taken = 21.3921849728

# %% [markdown]
# <h2>2. Resuming from Previous Run</h2>

# %% [markdown]
# If you did the save_project() above, you can resume from this step directly the next time you load the notebook ..

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
basedir = '../'
sys.path.append(basedir)

from lda_for_fragments import Ms2Lda

# %%
ms2lda = Ms2Lda.resume_from('results/beer3pos.project')
# Out:
# Project loaded from results/beer3pos.project time taken = 16.8985421658
#  - input_filenames =
# 	../input/final/Beer_3_full1_5_2E5_pos_fragments.csv
# 	../input/final/Beer_3_full1_5_2E5_pos_losses.csv
# 	../input/final/Beer_3_full1_5_2E5_pos_ms1.csv
# 	../input/final/Beer_3_full1_5_2E5_pos_ms2.csv
#  - df.shape = (1588, 3171)
#  - K = 300
#  - alpha = 0.166666666667
#  - beta = 0.1
#  - last_saved_timestamp = Thu Aug  6 16:13:04 2015

# %% [markdown]
# <h2>3. Visualisation</h2>

# %% [markdown]
# If the 'interactive' parameter below is True, we will show an interactive visualisation of the results in a separate tab. You need to interrupt the kernel to stop it once you're done with it (from the menu above, Kernel > Interrupt).

# %%
ms2lda.plot_lda_fragments(consistency=0.50, sort_by="h_index", interactive=True)
# ms2lda.plot_lda_fragments(consistency=0.50, sort_by="in_degree")
# Out:
# Ranking topics ...
# Topic 53 h-index=5
# Topic 53 has 6 ms1 peaks
# Topic 253 h-index=5
# Topic 253 has 10 ms1 peaks
# Topic 54 h-index=4
# Topic 54 has 8 ms1 peaks
# Topic 57 h-index=4
# Topic 57 has 19 ms1 peaks
# Topic 68 h-index=4
# Topic 68 has 19 ms1 peaks
# Topic 71 h-index=4
# Topic 71 has 4 ms1 peaks
# Topic 76 h-index=4
# Topic 76 has 21 ms1 peaks
# Topic 98 h-index=4
# Topic 98 has 30 ms1 peaks
# Topic 166 h-index=4
# Topic 166 has 15 ms1 peaks
# Topic 168 h-index=4
# Topic 168 has 21 ms1 peaks
# Topic 177 h-index=4
# Topic 177 has 12 ms1 peaks
# Topic 194 h-index=4
# Topic 194 has 8 ms1 peaks
# Topic 228 h-index=4
# Topic 228 has 9 ms1 peaks
# Topic 272 h-index=4
# Topic 272 has 20 ms1 peaks
# Topic 290 h-index=4
# Topic 290 has 32 ms1 peaks
# Topic 3 h-index=3
# Topic 3 has 39 ms1 peaks
# Topic 11 h-index=3
# Topic 11 has 7 ms1 peaks
# Topic 12 h-index=3
# Topic 12 has 25 ms1 peaks
# Topic 13 h-index=3
# Topic 13 has 6 ms1 peaks
# Topic 19 h-index=3
# Topic 19 has 9 ms1 peaks
# Topic 20 h-index=3
# Topic 20 has 18 ms1 peaks
# Topic 23 h-index=3
# Topic 23 has 16 ms1 peaks
# Topic 29 h-index=3
# Topic 29 has 8 ms1 peaks
# Topic 32 h-index=3
# Topic 32 has 17 ms1 peaks
# Topic 37 h-index=3
# Topic 37 has 11 ms1 peaks
# Topic 48 h-index=3
# Topic 48 has 20 ms1 peaks
# Topic 58 h-index=3
# Topic 58 has 6 ms1 peaks
# Topic 59 h-index=3
# Topic 59 has 8 ms1 peaks
# Topic 65 h-index=3
# Topic 65 has 36 ms1 peaks
# Topic 66 h-index=3
# Topic 66 has 5 ms1 peaks
# Topic 75 h-index=3
# Topic 75 has 6 ms1 peaks
# Topic 78 h-index=3
# Topic 78 has 14 ms1 peaks
# Topic 79 h-index=3
# Topic 79 has 13 ms1 peaks
# Topic 83 h-index=3
# Topic 83 has 11 ms1 peaks
# Topic 90 h-index=3
# Topic 90 has 8 ms1 peaks
# Topic 94 h-index=3
# Topic 94 has 6 ms1 peaks
# Topic 104 h-index=3
# Topic 104 has 8 ms1 peaks
# Topic 105 h-index=3
# Topic 105 has 25 ms1 peaks
# Topic 111 h-index=3
# Topic 111 has 18 ms1 peaks
# Topic 116 h-index=3
# Topic 116 has 15 ms1 peaks
# Topic 121 h-index=3
# Topic 121 has 26 ms1 peaks
# Topic 124 h-index=3
# Topic 124 has 9 ms1 peaks
# Topic 129 h-index=3
# Topic 129 has 7 ms1 peaks
# Topic 139 h-index=3
# Topic 139 has 9 ms1 peaks
# Topic 146 h-index=3
# Topic 146 has 7 ms1 peaks
# Topic 147 h-index=3
# Topic 147 has 6 ms1 peaks
# Topic 152 h-index=3
# Topic 152 has 13 ms1 peaks
# Topic 156 h-index=3
# Topic 156 has 5 ms1 peaks
# Topic 162 h-index=3
# Topic 162 has 6 ms1 peaks
# Topic 170 h-index=3
# Topic 170 has 12 ms1 peaks
# Topic 175 h-index=3
# Topic 175 has 8 ms1 peaks
# Topic 176 h-index=3
# Topic 176 has 10 ms1 peaks
# Topic 178 h-index=3
# Topic 178 has 7 ms1 peaks
# Topic 179 h-index=3
# Topic 179 has 4 ms1 peaks
# Topic 183 h-index=3
# Topic 183 has 16 ms1 peaks
# Topic 187 h-index=3
# Topic 187 has 11 ms1 peaks
# Topic 192 h-index=3
# Topic 192 has 8 ms1 peaks
# Topic 193 h-index=3
# Topic 193 has 12 ms1 peaks
# Topic 195 h-index=3
# Topic 195 has 11 ms1 peaks
# Topic 199 h-index=3
# Topic 199 has 10 ms1 peaks
# Topic 200 h-index=3
# Topic 200 has 11 ms1 peaks
# Topic 207 h-index=3
# Topic 207 has 12 ms1 peaks
# Topic 208 h-index=3
# Topic 208 has 7 ms1 peaks
# Topic 214 h-index=3
# Topic 214 has 8 ms1 peaks
# Topic 215 h-index=3
# Topic 215 has 11 ms1 peaks
# Topic 227 h-index=3
# Topic 227 has 14 ms1 peaks
# Topic 229 h-index=3
# Topic 229 has 7 ms1 peaks
# Topic 230 h-index=3
# Topic 230 has 45 ms1 peaks
# Topic 233 h-index=3
# Topic 233 has 21 ms1 peaks
# Topic 235 h-index=3
# Topic 235 has 9 ms1 peaks
# Topic 255 h-index=3
# Topic 255 has 9 ms1 peaks
# Topic 258 h-index=3
# Topic 258 has 8 ms1 peaks
# Topic 260 h-index=3
# Topic 260 has 16 ms1 peaks
# Topic 264 h-index=3
# Topic 264 has 36 ms1 peaks
# Topic 265 h-index=3
# Topic 265 has 14 ms1 peaks
# Topic 280 h-index=3
# Topic 280 has 11 ms1 peaks
# Topic 282 h-index=3
# Topic 282 has 11 ms1 peaks
# Topic 285 h-index=3
# Topic 285 has 12 ms1 peaks
# Topic 293 h-index=3
# Topic 293 has 9 ms1 peaks
# Topic 0 h-index=2
# Topic 0 has 18 ms1 peaks
# Topic 1 h-index=2
# Topic 1 has 10 ms1 peaks
# Topic 2 h-index=2
# Topic 2 has 7 ms1 peaks
# Topic 5 h-index=2
# Topic 5 has 26 ms1 peaks
# Topic 6 h-index=2
# Topic 6 has 17 ms1 peaks
# Topic 7 h-index=2
# Topic 7 has 16 ms1 peaks
# Topic 8 h-index=2
# Topic 8 has 8 ms1 peaks
# Topic 9 h-index=2
# Topic 9 has 10 ms1 peaks
# Topic 15 h-index=2
# Topic 15 has 6 ms1 peaks
# Topic 16 h-index=2
# Topic 16 has 10 ms1 peaks
# Topic 17 h-index=2
# Topic 17 has 11 ms1 peaks
# Topic 21 h-index=2
# Topic 21 has 10 ms1 peaks
# Topic 22 h-index=2
# Topic 22 has 10 ms1 peaks
# Topic 25 h-index=2
# Topic 25 has 13 ms1 peaks
# Topic 26 h-index=2
# Topic 26 has 8 ms1 peaks
# Topic 27 h-index=2
# Topic 27 has 15 ms1 peaks
# Topic 28 h-index=2
# Topic 28 has 8 ms1 peaks
# Topic 34 h-index=2
# Topic 34 has 8 ms1 peaks
# Topic 35 h-index=2
# Topic 35 has 3 ms1 peaks
# Topic 240 h-index=2
# Topic 240 has 55 ms1 peaks
# Topic 241 h-index=2
# Topic 241 has 4 ms1 peaks
# Topic 242 h-index=2
# Topic 242 has 5 ms1 peaks
# Topic 243 h-index=2
# Topic 243 has 13 ms1 peaks
# Topic 245 h-index=2
# Topic 245 has 7 ms1 peaks
# Topic 248 h-index=2
# Topic 248 has 4 ms1 peaks
# Topic 249 h-index=2
# Topic 249 has 13 ms1 peaks
# Topic 250 h-index=2
# Topic 250 has 8 ms1 peaks
# Topic 251 h-index=2
# Topic 251 has 6 ms1 peaks
# Topic 254 h-index=2
# Topic 254 has 4 ms1 peaks
# Topic 256 h-index=2
# Topic 256 has 13 ms1 peaks
# Topic 257 h-index=2
# Topic 257 has 18 ms1 peaks
# Topic 259 h-index=2
# Topic 259 has 8 ms1 peaks
# Topic 261 h-index=2
# Topic 261 has 9 ms1 peaks
# Topic 263 h-index=2
# Topic 263 has 44 ms1 peaks
# Topic 268 h-index=2
# Topic 268 has 6 ms1 peaks
# Topic 269 h-index=2
# Topic 269 has 17 ms1 peaks
# Topic 270 h-index=2
# Topic 270 has 7 ms1 peaks
# Topic 273 h-index=2
# Topic 273 has 9 ms1 peaks
# Topic 274 h-index=2
# Topic 274 has 16 ms1 peaks
# Topic 276 h-index=2
# Topic 276 has 13 ms1 peaks
# Topic 279 h-index=2
# Topic 279 has 5 ms1 peaks
# Topic 281 h-index=2
# Topic 281 has 4 ms1 peaks
# Topic 283 h-index=2
# Topic 283 has 10 ms1 peaks
# Topic 284 h-index=2
# Topic 284 has 6 ms1 peaks
# Topic 286 h-index=2
# Topic 286 has 26 ms1 peaks
# Topic 289 h-index=2
# Topic 289 has 12 ms1 peaks
# Topic 291 h-index=2
# Topic 291 has 8 ms1 peaks
# Topic 292 h-index=2
# Topic 292 has 13 ms1 peaks
# Topic 294 h-index=2
# Topic 294 has 7 ms1 peaks
# Topic 295 h-index=2
# Topic 295 has 2 ms1 peaks
# Topic 297 h-index=2
# Topic 297 has 16 ms1 peaks
# Topic 298 h-index=2
# Topic 298 has 10 ms1 peaks
# Topic 299 h-index=2
# Topic 299 has 12 ms1 peaks
# Topic 4 h-index=1
# Topic 4 has 34 ms1 peaks
# Topic 10 h-index=1
# Topic 10 has 6 ms1 peaks
# Topic 14 h-index=1
# Topic 14 has 35 ms1 peaks
# Topic 18 h-index=1
# Topic 18 has 41 ms1 peaks
# Topic 24 h-index=1
# Topic 24 has 23 ms1 peaks
# Topic 30 h-index=1
# Topic 30 has 2 ms1 peaks
# Topic 31 h-index=1
# Topic 31 has 9 ms1 peaks
# Topic 33 h-index=1
# Topic 33 has 10 ms1 peaks
# Topic 36 h-index=1
# Topic 36 has 16 ms1 peaks
# Topic 39 h-index=1
# Topic 39 has 62 ms1 peaks
# Topic 40 h-index=1
# Topic 40 has 8 ms1 peaks
# Topic 41 h-index=1
# Topic 41 has 66 ms1 peaks
# Topic 42 h-index=1
# Topic 42 has 2 ms1 peaks
# Topic 50 h-index=1
# Topic 50 has 62 ms1 peaks
# Topic 63 h-index=1
# Topic 63 has 11 ms1 peaks
# Topic 278 h-index=1
# Topic 278 has 1 ms1 peaks
# Topic 287 h-index=1
# Topic 287 has 52 ms1 peaks
# Topic 288 h-index=1
# Topic 288 has 23 ms1 peaks
# Topic 296 h-index=1
# Topic 296 has 1 ms1 peaks
# Topic 108 h-index=0
# Topic 108 has 1 ms1 peaks
# Topic 275 h-index=0
# Topic 275 has 1 ms1 peaks
# Using visualisation script defined in /LDAvis.js
#
# Note: if you're in the IPython notebook, pyLDAvis.show() is not the best command
#       to use. Consider using pyLDAvis.display(), or pyLDAvis.enable_notebook().
#       See more information at http://pyLDAvis.github.io/quickstart.html .
#
# You must interrupt the kernel to end this command
#
# Serving to http://127.0.0.1:8889/    [Ctrl-C to exit]
# 127.0.0.1 - - [08/Aug/2015 22:55:23] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2015 22:55:24] "GET /LDAvis.css HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2015 22:55:24] "GET /d3.js HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2015 22:55:24] "GET /LDAvis.js HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2015 22:55:24] "GET /images/default_logo.png HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2015 22:55:24] code 404, message Not Found
# 127.0.0.1 - - [08/Aug/2015 22:55:24] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Aug/2015 22:55:54] "GET /topic?circle_id=ldavis_el63071397823576559366600349087-topic118&action=load HTTP/1.1" 200 -
# Traceback (most recent call last):
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 295, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 321, in process_request
#     self.finish_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 334, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 657, in __init__
#     self.finish()
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 716, in finish
#     self.wfile.close()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 283, in close
#     self.flush()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 307, in flush
#     self._sock.sendall(view[write_offset:write_offset+buffer_size])
# error: [Errno 32] Broken pipe
# 127.0.0.1 - - [08/Aug/2015 22:55:54] "GET /topic?circle_id=ldavis_el63071397823576559366600349087-topic203&action=load HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2015 22:55:56] "GET /images/default_logo.png HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2015 22:55:56] "GET /topic?circle_id=ldavis_el63071397823576559366600349087-topic220&action=load HTTP/1.1" 200 -
# ----------------------------------------
# Exception happened during processing of request from ('127.0.0.1', 38661)
# ----------------------------------------
# ----------------------------------------
# Traceback (most recent call last):
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 295, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 321, in process_request
#     self.finish_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 334, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 657, in __init__
#     self.finish()
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 716, in finish
#     self.wfile.close()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 283, in close
#     self.flush()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 307, in flush
#     self._sock.sendall(view[write_offset:write_offset+buffer_size])
# error: [Errno 32] Broken pipe
# 127.0.0.1 - - [08/Aug/2015 22:55:56] "GET /images/default_logo.png HTTP/1.1" 200 -
# Traceback (most recent call last):
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 295, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 321, in process_request
#     self.finish_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 334, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 657, in __init__
#     self.finish()
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 716, in finish
#     self.wfile.close()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 283, in close
#     self.flush()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 307, in flush
#     self._sock.sendall(view[write_offset:write_offset+buffer_size])
# error: [Errno 32] Broken pipe
# 127.0.0.1 - - [08/Aug/2015 22:55:56] "GET /topic?circle_id=ldavis_el63071397823576559366600349087-topic268&action=load HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2015 22:55:57] "GET /images/default_logo.png HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2015 22:55:57] "GET /topic?circle_id=ldavis_el63071397823576559366600349087-topic110&action=load HTTP/1.1" 200 -
# Exception happened during processing of request from ('127.0.0.1', 38664)
# ----------------------------------------
# ----------------------------------------
# Exception happened during processing of request from ('127.0.0.1', 38665)
# ----------------------------------------
# ----------------------------------------
# Traceback (most recent call last):
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 295, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 321, in process_request
#     self.finish_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 334, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 657, in __init__
#     self.finish()
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 716, in finish
#     self.wfile.close()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 283, in close
#     self.flush()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 307, in flush
#     self._sock.sendall(view[write_offset:write_offset+buffer_size])
# error: [Errno 32] Broken pipe
# 127.0.0.1 - - [08/Aug/2015 22:55:57] "GET /images/default_logo.png HTTP/1.1" 200 -
# Traceback (most recent call last):
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 295, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 321, in process_request
#     self.finish_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 334, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 657, in __init__
#     self.finish()
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 716, in finish
#     self.wfile.close()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 283, in close
#     self.flush()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 307, in flush
#     self._sock.sendall(view[write_offset:write_offset+buffer_size])
# error: [Errno 32] Broken pipe
# 127.0.0.1 - - [08/Aug/2015 22:55:58] "GET /topic?circle_id=ldavis_el63071397823576559366600349087-topic272&action=load HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2015 22:55:58] "GET /images/default_logo.png HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2015 22:55:58] "GET /topic?circle_id=ldavis_el63071397823576559366600349087-topic247&action=load HTTP/1.1" 200 -
# Exception happened during processing of request from ('127.0.0.1', 38668)
# ----------------------------------------
# ----------------------------------------
# Exception happened during processing of request from ('127.0.0.1', 38669)
# ----------------------------------------
# ----------------------------------------
# Traceback (most recent call last):
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 295, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 321, in process_request
#     self.finish_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 334, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 657, in __init__
#     self.finish()
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 716, in finish
#     self.wfile.close()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 283, in close
#     self.flush()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 307, in flush
#     self._sock.sendall(view[write_offset:write_offset+buffer_size])
# error: [Errno 32] Broken pipe
# 127.0.0.1 - - [08/Aug/2015 22:55:58] "GET /images/default_logo.png HTTP/1.1" 200 -
# Traceback (most recent call last):
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 295, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 321, in process_request
#     self.finish_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 334, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 657, in __init__
#     self.finish()
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 716, in finish
#     self.wfile.close()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 283, in close
#     self.flush()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 307, in flush
#     self._sock.sendall(view[write_offset:write_offset+buffer_size])
# error: [Errno 32] Broken pipe
# 127.0.0.1 - - [08/Aug/2015 22:55:58] "GET /topic?circle_id=ldavis_el63071397823576559366600349087-topic51&action=load HTTP/1.1" 200 -
# Exception happened during processing of request from ('127.0.0.1', 38672)
# ----------------------------------------
# ----------------------------------------
# Exception happened during processing of request from ('127.0.0.1', 38673)
# ----------------------------------------
# ----------------------------------------
# Traceback (most recent call last):
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 295, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 321, in process_request
#     self.finish_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 334, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 657, in __init__
#     self.finish()
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 716, in finish
#     self.wfile.close()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 283, in close
#     self.flush()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 307, in flush
#     self._sock.sendall(view[write_offset:write_offset+buffer_size])
# error: [Errno 32] Broken pipe
# 127.0.0.1 - - [08/Aug/2015 22:55:58] "GET /images/default_logo.png HTTP/1.1" 200 -
# Traceback (most recent call last):
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 295, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 321, in process_request
#     self.finish_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 334, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 657, in __init__
#     self.finish()
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 716, in finish
#     self.wfile.close()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 283, in close
#     self.flush()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 307, in flush
#     self._sock.sendall(view[write_offset:write_offset+buffer_size])
# error: [Errno 32] Broken pipe
# 127.0.0.1 - - [08/Aug/2015 22:55:59] "GET /topic?circle_id=ldavis_el63071397823576559366600349087-topic288&action=load HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2015 22:55:59] "GET /images/default_logo.png HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Aug/2015 22:55:59] "GET /topic?circle_id=ldavis_el63071397823576559366600349087-topic145&action=load HTTP/1.1" 200 -
# Exception happened during processing of request from ('127.0.0.1', 38674)
# ----------------------------------------
# ----------------------------------------
# Exception happened during processing of request from ('127.0.0.1', 38675)
# ----------------------------------------
# ----------------------------------------
# Traceback (most recent call last):
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 295, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 321, in process_request
#     self.finish_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 334, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 657, in __init__
#     self.finish()
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 716, in finish
#     self.wfile.close()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 283, in close
#     self.flush()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 307, in flush
#     self._sock.sendall(view[write_offset:write_offset+buffer_size])
# error: [Errno 32] Broken pipe
# 127.0.0.1 - - [08/Aug/2015 22:55:59] "GET /images/default_logo.png HTTP/1.1" 200 -
# Traceback (most recent call last):
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 295, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 321, in process_request
#     self.finish_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 334, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 657, in __init__
#     self.finish()
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 716, in finish
#     self.wfile.close()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 283, in close
#     self.flush()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 307, in flush
#     self._sock.sendall(view[write_offset:write_offset+buffer_size])
# error: [Errno 32] Broken pipe
# 127.0.0.1 - - [08/Aug/2015 22:55:59] "GET /topic?circle_id=ldavis_el63071397823576559366600349087-topic144&action=load HTTP/1.1" 200 -
# Exception happened during processing of request from ('127.0.0.1', 38678)
# ----------------------------------------
# ----------------------------------------
# Exception happened during processing of request from ('127.0.0.1', 38679)
# ----------------------------------------
# ----------------------------------------
# Traceback (most recent call last):
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 295, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 321, in process_request
#     self.finish_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 334, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 657, in __init__
#     self.finish()
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 716, in finish
#     self.wfile.close()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 283, in close
#     self.flush()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 307, in flush
#     self._sock.sendall(view[write_offset:write_offset+buffer_size])
# error: [Errno 32] Broken pipe
# 127.0.0.1 - - [08/Aug/2015 22:55:59] "GET /images/default_logo.png HTTP/1.1" 200 -
# Traceback (most recent call last):
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 295, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 321, in process_request
#     self.finish_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 334, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 657, in __init__
#     self.finish()
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 716, in finish
#     self.wfile.close()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 283, in close
#     self.flush()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 307, in flush
#     self._sock.sendall(view[write_offset:write_offset+buffer_size])
# error: [Errno 32] Broken pipe
# 127.0.0.1 - - [08/Aug/2015 22:55:59] "GET /topic?circle_id=ldavis_el63071397823576559366600349087-topic213&action=load HTTP/1.1" 200 -
# Exception happened during processing of request from ('127.0.0.1', 38680)
# ----------------------------------------
# ----------------------------------------
# Exception happened during processing of request from ('127.0.0.1', 38681)
# ----------------------------------------
# ----------------------------------------
# Traceback (most recent call last):
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 295, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 321, in process_request
#     self.finish_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 334, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 657, in __init__
#     self.finish()
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 716, in finish
#     self.wfile.close()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 283, in close
#     self.flush()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 307, in flush
#     self._sock.sendall(view[write_offset:write_offset+buffer_size])
# error: [Errno 32] Broken pipe
# 127.0.0.1 - - [08/Aug/2015 22:55:59] "GET /images/default_logo.png HTTP/1.1" 200 -
# Traceback (most recent call last):
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 295, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 321, in process_request
#     self.finish_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 334, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 657, in __init__
#     self.finish()
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 716, in finish
#     self.wfile.close()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 283, in close
#     self.flush()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 307, in flush
#     self._sock.sendall(view[write_offset:write_offset+buffer_size])
# error: [Errno 32] Broken pipe
# 127.0.0.1 - - [08/Aug/2015 22:55:59] "GET /topic?circle_id=ldavis_el63071397823576559366600349087-topic267&action=load HTTP/1.1" 200 -
# Exception happened during processing of request from ('127.0.0.1', 38682)
# ----------------------------------------
# ----------------------------------------
# Exception happened during processing of request from ('127.0.0.1', 38683)
# ----------------------------------------
# ----------------------------------------
# Traceback (most recent call last):
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 295, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 321, in process_request
#     self.finish_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 334, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 657, in __init__
#     self.finish()
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 716, in finish
#     self.wfile.close()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 283, in close
#     self.flush()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 307, in flush
#     self._sock.sendall(view[write_offset:write_offset+buffer_size])
# error: [Errno 32] Broken pipe
# 127.0.0.1 - - [08/Aug/2015 22:55:59] "GET /images/default_logo.png HTTP/1.1" 200 -
# Traceback (most recent call last):
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 295, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 321, in process_request
#     self.finish_request(request, client_address)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 334, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 657, in __init__
#     self.finish()
#   File "/home/joewandy/anaconda/lib/python2.7/SocketServer.py", line 716, in finish
#     self.wfile.close()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 283, in close
#     self.flush()
#   File "/home/joewandy/anaconda/lib/python2.7/socket.py", line 307, in flush
#     self._sock.sendall(view[write_offset:write_offset+buffer_size])
# error: [Errno 32] Broken pipe
# 127.0.0.1 - - [08/Aug/2015 22:56:00] "GET /topic?circle_id=ldavis_el63071397823576559366600349087-topic151&action=load HTTP/1.1" 200 -
# Exception happened during processing of request from ('127.0.0.1', 38684)
# ----------------------------------------
# ----------------------------------------
# Exception happened during processing of request from ('127.0.0.1', 38685)
# ----------------------------------------
# ----------------------------------------
